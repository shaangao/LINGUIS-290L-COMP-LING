# %% [markdown]
# # Using regex to explore consonant clusters in WikiPron
#
#
# The goal of this homework is to identify, count, and compare <b>word-initial and word-final consonant clusters</b> in two languages: English and Arabic.
#
#
# - Created by Geoff Bacon; lightly touched up by Terry Regier, Aug 30 2020.
# - [WikiPron](https://github.com/kylebgorman/wikipron) is a great project, [check it out](https://www.aclweb.org/anthology/2020.lrec-1.521.pdf)!

# %%
import re

# %%
# Read in English words.  
with open("data-WP/eng_rp.txt") as file:
    eng_words = file.read().split("\n")
# uncomment the following lines if you want to look at the words before processing them.
#for w in eng_words:
#    print(w)

# %%
# Read in Arabic words.  
with open("data-WP/ara.txt") as file:
    ara_words = file.read().split("\n")
# uncomment the following lines if you want to look at the words before processing them.
#for w in ara_words:
#    print(w)

# %%
# We are simplifying the task by focusing only on consonant clusters involving the two phonemes /s/ and /t/.

# Create a regex to search for consonant clusters involving /s/ and/or /t/.
cc_RE = r"[st](?: [st])+"
# Now a regex to search for WORD-INITIAL consonant clusters involving /s/ and/or /t/.
wicc_RE = r"^[st](?: [st])+"
# Now a regex to search for WORD-FINAL consonant clusters involving /s/ and/or /t/.
wfcc_RE = r"[st](?: [st])+$"
print(cc_RE)
print(wicc_RE)
print(wfcc_RE)
# Out:
# [st](?: [st])+
# ^[st](?: [st])+
# [st](?: [st])+$

# %%
# Now search for consonant clusters in the English words you read in.
# Print out - and count - what you find.
cc_count = 0
wicc_count = 0
wfcc_count = 0
for w in eng_words:
    cc_results = re.findall(cc_RE,w)
    wicc_results = re.findall(wicc_RE,w)
    wfcc_results = re.findall(wfcc_RE,w)
    if cc_results:
        cc_count += 1
        print(w,"\t",cc_results,end="")
        if wicc_results:
            wicc_count += 1
            print ('  initial  ',end="")
        if wfcc_results:
            wfcc_count += 1
            print ('  final  ',end="")
        print()
# Out:
# ɡ æ n s t 	 ['s t']  final
# t w ɪ k s t 	 ['s t']  final
# ɑː l s t 	 ['s t']  final
# æ b ə k ɒ s t 	 ['s t']  final
# ə b e ɪ s t 	 ['s t']  final
# ə b e ɪ t s 	 ['t s']  final
# æ b ə t ɪ s t 	 ['s t']  final
# æ b ə t s 	 ['t s']  final
# ə b d j uː s t 	 ['s t']  final
# æ b ə ɹ ɪ s t w ɪ θ 	 ['s t']
# ə b ɛ t s 	 ['t s']  final
# ə b h ɒ ɹ n̩ t s 	 ['t s']  final
# ə b a ɪ d ɪ s t 	 ['s t']  final
# æ b ə l ɪ ʃ n̩ ɪ s t 	 ['s t']  final
# æ b ə l ɪ ʃ n̩ ɪ s t s 	 ['s t s']  final
# ə b ɹ ɛ s t 	 ['s t']  final
# æ b ɹ ə ɡ e ɪ ʃ n̩ ɪ s t 	 ['s t']  final
# æ b s n̩ t s 	 ['t s']  final
# æ b s ə l j uː t ɪ s t 	 ['s t']  final
# æ b s ə l uː t ɪ s t 	 ['s t']  final
# ə b s t e ɪ n 	 ['s t']
# æ b s t iː m ɪ ə s 	 ['s t']
# æ b s t i m i ə s l i 	 ['s t']
# ə b s t i m i ə s l i 	 ['s t']
# ə b s t ɛ n ʃ n̩ 	 ['s t']
# ə b s t ɛ n ʃ n̩ ɪ z m̩ 	 ['s t']
# ə b s t ɛ n ʃ n̩ ɪ s t 	 ['s t', 's t']  final
# ə b s t ɜː ɹ d͡ʒ 	 ['s t']
# ə b s t ɝː ɹˑ d͡ʒ n̩ t 	 ['s t']
# ə b s t ɜː ɹ s 	 ['s t']
# æ b s t ɜː ʒ n̩ 	 ['s t']
# ə b s t ɝː ɹ s ɪ v 	 ['s t']
# ə b s t ɝː ɹ s ɪ v n ə s 	 ['s t']
# æ b s t ɪ n ə n s 	 ['s t']
# æ b s t ɹ æ k t 	 ['s t']
# ə b s t ɹ æ k t 	 ['s t']
# ə b s t ɹ æ k t ə 	 ['s t']
# ə b s t ɹ æ k t ə b l̩ 	 ['s t']
# ə b s t ɹ æ k t ɪ d 	 ['s t']
# ə b s t ɹ æ k t ɪ d n ə s 	 ['s t']
# ə b s t ɹ æ k ʃ n̩ 	 ['s t']
# ə b s t ɹ æ k t ɪ v 	 ['s t']
# ə b s t ɹ æ k t m̩ 	 ['s t']
# æ b s t ɹ ɪ k t 	 ['s t']
# ə b s t ɹ ɪ n d ʒ 	 ['s t']
# ə b s t ɹ uː s 	 ['s t']
# ə b s t ɹ uː s l i 	 ['s t']
# ə b s t ɹ uː s n ə s 	 ['s t']
# ə b s t ɹ uː s ə t i 	 ['s t']
# ə b s t ɹ uː s ɪ v 	 ['s t']
# ə b s ɜː d ə s t 	 ['s t']  final
# ə b ɜː s t 	 ['s t']  final
# ə b ʌ t s 	 ['t s']  final
# æ b ɪ d ə k ə ʊ m ɪ s t 	 ['s t']  final
# æ k s ɛ n t s 	 ['t s']  final
# ə k s ɛ p t s 	 ['t s']  final
# æ k s ɛ s t 	 ['s t']  final
# ə k s ɛ s t 	 ['s t']  final
# æ k s ə d ə n t s 	 ['t s']  final
# æ k s ə d ɛ n t s 	 ['t s']  final
# ə k ʌ m p l ɪ ʃ m ə n t s 	 ['t s']  final
# ə k ɒ s t 	 ['s t']  final
# ə k a ʊ n t s 	 ['t s']  final
# ə k uː t ə m ə n t s 	 ['t s']  final
# ə k ɹ ɛ d ɪ t s 	 ['t s']  final
# æ k ɜː s t 	 ['s t']  final
# ə k ɜː s t 	 ['s t']  final
# ə k ʌ s t ə m 	 ['s t']
# ə k ʌ s t ə m ə b l i 	 ['s t']
# ə k ʌ s t ə m d 	 ['s t']
# e ɪ s t 	 ['s t']  final
# ə s iː t ɪ l s ɪ s t iː n 	 ['s t']
# ʌ s ɛ t iː l s ɪ s t iː n 	 ['s t']
# ə t͡ʃ iː v m ə n t s 	 ['t s']  final
# e ɪ k ɑ n d ɹ ə p l æ s t ɪ k 	 ['s t']
# æ k n iː s t ɪ s 	 ['s t']
# ə k uː s t ɪ k 	 ['s t']
# ə k uː s t ɪ k s 	 ['s t']
# ə k w ɪ t s 	 ['t s']  final
# ə k ɹ ɒ s t ɪ k 	 ['s t']
# æ k t s 	 ['t s']  final
# ə d ɹ ɛ s t 	 ['s t']  final
# æ d ɛ p t s 	 ['t s']  final
# æ d ɪ t s 	 ['t s']  final
# ə d ʒ ʌ s t 	 ['s t']  final
# ə d ʒ ʌ s t ɪ d 	 ['s t']
# ə d ʒ ʌ s t ɪ ŋ 	 ['s t']
# ə d ʒ ʌ s t ɪ ŋ z 	 ['s t']
# ə d ʒ ʌ s t m ə n t 	 ['s t']
# ə d ʒ ʌ s t s 	 ['s t s']  final
# æ d ʒ ə t ə n t s 	 ['t s']  final
# ə d m ɪ n ə s t ɹ e ɪ ʃ ə n 	 ['s t']
# ə d m ɪ n ɪ s t ɹ e ɪ t ə 	 ['s t']
# æ d m ɪ n ə s t ɹ e ɪ t ɚ ʃ ɪ p 	 ['s t']
# æ d m ɪ n ɪ s t ɹ e ɪ t ɹ ɪ k s 	 ['s t']
# ə d m ɪ t s 	 ['t s']  final
# æ d ʌ l t s 	 ['t s']  final
# ə d ʌ s t 	 ['s t']  final
# ə d ʌ s t ɪ b ə l 	 ['s t']
# ə d v ɑː n s t 	 ['s t']  final
# æ d v ə k e ɪ t s 	 ['t s']  final
# æ d v ə k ə t s 	 ['t s']  final
# ɛː ɹ ə l ʌ ɪ t s 	 ['t s']  final
# ɛː ɹ ə ʊ f ʌ ɪ t s 	 ['t s']  final
# e ɪ ə ɹ ə ʊ s t æ t ɪ k 	 ['s t']
# ɛ s t ɪ f ɛ ɹ ʌ s 	 ['s t']
# iː s t ɪ v ə l 	 ['s t']
# iː s t ʌ ɪ v ə l 	 ['s t']
# ɛ s t ʌ ɪ v ə l 	 ['s t']
# iː s t ɪ v e ɪ ʃ ə n 	 ['s t']
# ə f ɒ ɹ ɪ s t 	 ['s t']  final
# æ f ɡ æ n ɪ s t æ n 	 ['s t']
# æ f ɡ æ n ɪ s t ɑː n 	 ['s t']
# ə ɡ ɛ n s t 	 ['s t']  final
# ə ɡ ɛ ɪ n s t 	 ['s t']  final
# æ ɡ ə ɹ ɪ k ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# e ɪ d ʒ ɪ s t 	 ['s t']  final
# e ɪ d͡ʒ ə l æ s t 	 ['s t']  final
# e ɪ d ʒ ə n t s 	 ['t s']  final
# æ ɡ j uː s t ɪ ə 	 ['s t']
# ə ɡ j uː s t ɪ ə 	 ['s t']
# ə d ʒ ɛ s t 	 ['s t']  final
# ə ɡ ɑː s t 	 ['s t']  final
# e ɪ d͡ʒ ɪ s t m ə n t 	 ['s t']
# a ɡ n ɒ s t ɪ k 	 ['s t']
# æ ɡ n ɒ s t ɪ s ɪ z ə m 	 ['s t']
# a ɡ ə n ɪ s t ɪ k 	 ['s t']
# ə ɡ ɹ ɒ n ə m ɪ s t 	 ['s t']  final
# a ɪ l t s 	 ['t s']  final
# ɛ ə p ɔː t s 	 ['t s']  final
# æ l ə b æ s t ə 	 ['s t']
# æ l ə b ɑː s t ə 	 ['s t']
# æ l ə s t ə 	 ['s t']
# a l k ə h ɛ s t 	 ['s t']  final
# ɔː l d ə m ɑː s t ə n 	 ['s t']
# æ l i s t ə 	 ['s t']
# e ɪ l ɪ ə n ɪ s t 	 ['s t']  final
# e ɪ l ɪ ə n ɪ s t s 	 ['s t s']  final
# æ l ɪ k w ɒ t s 	 ['t s']  final
# e ɪ l ɪ s t 	 ['s t']  final
# æ l i s t ə 	 ['s t']
# a l k ə h ɛ s t 	 ['s t']  final
# a l k ə h ɛ s t s 	 ['s t s']  final
# æ l ɪ s t ɪ k 	 ['s t']
# ə l ɪ s t ɪ k 	 ['s t']
# a l ə ʊ h ɪ s t ɒ ɹ ɪ k ə l 	 ['s t']
# a l ə ʊ h ɪ s t ə ɹ i 	 ['s t']
# a l ə ʊ h ɪ s t ə ɹ ɪ 	 ['s t']
# ɔː l m ə ʊ s t 	 ['s t']  final
# æ l f ə b ɛ t s 	 ['t s']  final
# æ l s t ɹ ɨ m iː ɹ i ə 	 ['s t']
# æ l t ɹ u ɪ s t ɪ k 	 ['s t']
# a m b ɪ d ɛ k s t ə 	 ['s t']
# æ m b i d ɛ k s t ɹ ə s 	 ['s t']
# a m b ɪ v ə ɹ t s 	 ['t s']  final
# æ m ə θ ɪ s t 	 ['s t']  final
# æ m ə θ ɪ s t s 	 ['s t s']  final
# a m ɪ d s t 	 ['s t']  final
# ə m ɪ t s t 	 ['t s t']  final
# æ m n ɛ s t ɪ k 	 ['s t']
# a m n ə s t iː d 	 ['s t']
# æ m n ɪ s t i 	 ['s t']
# æ m n ɪ k ə l ɪ s t 	 ['s t']  final
# a m n ɪ ə ʊ t s 	 ['t s']  final
# ə m ʌ ŋ s t 	 ['s t']  final
# ə m a ʊ n t s 	 ['t s']  final
# æ m f ɪ p ɹ ə ʊ s t a ɪ l ə ɹ 	 ['s t']
# æ m s t ə l v ɛ n 	 ['s t']
# æ m s t ə d æ m 	 ['s t']
# æ m j ə l ɪ t s 	 ['t s']  final
# ə n æ k ɹ ə n ɪ s t ɪ k 	 ['s t']
# ə n æ k ɹ ə n ɪ s t ɪ k l i 	 ['s t']
# ə n iː s θ ə t ɪ s t 	 ['s t']  final
# æ n ə n k æ s t ɪ k 	 ['s t']
# æ n ə p iː s t 	 ['s t']  final
# æ n ə p ɛ s t 	 ['s t']  final
# æ n ə p iː s t 	 ['s t']  final
# æ n ə p ɛ s t 	 ['s t']  final
# æ n ə p iː s t ɪ k 	 ['s t']
# æ n ə p ɛ s t s 	 ['s t s']  final
# æ n ə p l æ s t ɪ k 	 ['s t']
# æ n ə p iː s t 	 ['s t']  final
# æ n ə p ɛ s t 	 ['s t']  final
# æ n ə k ɪ s t 	 ['s t']  final
# æ n ə s t e ɪ ʃ i ə 	 ['s t']
# æ n ə s t e ɪ ʃ ə 	 ['s t']
# æ n ə s t e ɪ ʒ i ə 	 ['s t']
# æ n ə s t e ɪ ʒ ə 	 ['s t']
# æ n ə s t ɑ s i ə 	 ['s t']
# ɑ n ə s t ɑ s i ə 	 ['s t']
# ɑ n ə s t ɑ ʃ ə 	 ['s t']
# ə n æ s t ə m ə ʊ s ɪ s 	 ['s t']
# ə n æ t ə m ɪ s t 	 ['s t']  final
# æ n s ɛ s t ə 	 ['s t']
# æ n s ɛ s t ə z 	 ['s t']
# æ n s ɛ s t ɹ ə l ɪ i 	 ['s t']
# æ n s ɛ s t ɹ ə s 	 ['s t']
# æ n s ɛ s t ɹ ɪ s 	 ['s t']
# æ n s ɛ s t ɹ ə s ɪ z 	 ['s t']
# æ n s ɛ s t ɹ ɪ s ɪ z 	 ['s t']
# æ n s ɪ s t ɹ ɪ k s 	 ['s t']
# æ n d ʒ i ə ʊ p l æ s t i z 	 ['s t']
# æ n d ʒ i ə ʊ p l æ s t i 	 ['s t']
# æ ŋ k s t 	 ['s t']  final
# æ ŋ s t ɹ ə m 	 ['s t']
# æ ŋ s t ɹ ʌ m 	 ['s t']
# æ ŋ s t ɹ ə m z 	 ['s t']
# ɔ ŋ s t ɹ ə m z 	 ['s t']
# æ ŋ k s t s 	 ['s t s']  final
# æ ŋ ɡ ʌ s t 	 ['s t']  final
# æ n h a ɪ p ə s t e ɪ s ɪ ə 	 ['s t']
# æ n h a ɪ p ə s t e ɪ ʒ ə 	 ['s t']
# æ n h a ɪ p ə s t e ɪ s ɪ s 	 ['s t']
# a n ɪ m a l k j ʊ l ɪ s t 	 ['s t']  final
# a n l a ʊ t s 	 ['t s']  final
# æ n ɛ k s t 	 ['s t']  final
# æ n s æ t s 	 ['t s']  final
# æ n t æ ɡ ə n ɪ s t 	 ['s t']  final
# æ n t æ ɡ ə n ɪ s t ɪ k 	 ['s t']
# æ n θ ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# æ ŋ θ ɹ ə p ɒ s ə f ɪ s t 	 ['s t']  final
# a n t ɪ k ɹ ɪ s t ɪ ə n 	 ['s t']
# æ n t i d ɪ s ɪ s t æ b l ɪ ʃ m ə n t ɛ ə ɹ i ə n ɪ z ə m 	 ['s t']
# æ n t a ɪ n i ə p l æ s t ɪ k 	 ['s t']
# æ n t i n i ə p l æ s t ɪ k 	 ['s t']
# æ n t ɪ p ɹ iː d ɛ s t ɪ n ɛ ə ɹ ɪ ə n 	 ['s t']
# a n t i p ɹ iː f ɔː m e ɪ ʃ n̩ ɪ s t 	 ['s t']  final
# æ n t s 	 ['t s']  final
# æ n t s i 	 ['t s']
# e ɪ ə ɹ ɪ s t 	 ['s t']  final
# ɑː ɒ s t ə 	 ['s t']
# ə p æ s t ɹ ə n 	 ['s t']
# ə b iː t s 	 ['t s']  final
# æ p ə ʊ æ s t ɹ ə n 	 ['s t']
# ə p ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# ə p ɒ s t ə s i 	 ['s t']
# ə p ɒ s t e ɪ t 	 ['s t']
# ə p ɒ s t ə t 	 ['s t']
# æ p ə s t æ t ɪ k ə l 	 ['s t']
# æ p ə s t ɒ l ɪ k 	 ['s t']
# ə p ɒ s t ə l ɪ s ɪ t i 	 ['s t']
# ə p ɒ s t ɹ ə f i 	 ['s t']
# a ɹ ə b ɪ s t 	 ['s t']  final
# æ ɹ ə f ɑ s t ɪ k 	 ['s t']
# ɑː b l ɑː s t 	 ['s t']  final
# ɑ ɹ k i ə l ɪ ŋ ɡ w ɪ s t ɪ k s 	 ['s t']
# ɑː k e ɪ ɪ s t ɪ k 	 ['s t']
# ɑː ɹ k a ɪ v ɪ s t 	 ['s t']  final
# ɑː ɹ k ə v ɪ s t 	 ['s t']  final
# ə ɹ ɛ t s ə ʊ 	 ['t s']
# ɑː ɡ j ʊ m ə n t s 	 ['t s']  final
# æ ɹ ɨ s t iː ə s 	 ['s t']
# æ ɹ ɪ s t ɑː k 	 ['s t']
# æ ɹ ɪ s t ɒ k ɹ ə s i 	 ['s t']
# æ ɹ ɪ s t ə k ɹ æ t 	 ['s t']
# æ ɹ ɪ s t ə k ɹ æ t ɪ k 	 ['s t']
# ə ɹ ɪ s t ə l o ʊ k ɪ k 	 ['s t']
# æ ɹ ɪ s t ɒ f ə n iː z 	 ['s t']
# æ r ɪ s t ɒ t ə l 	 ['s t']
# ɑː m ɪ s t ɪ s 	 ['s t']
# ə ɹ e ɪ n d͡ʒ m ə n t s 	 ['t s']  final
# ə ɹ ɛ s t 	 ['s t']  final
# ə ɹ ɛ s t ɪ d 	 ['s t']
# æ ɹ ɪ v iː s t 	 ['s t']  final
# ɑː s t ʃ i k 	 ['s t']
# ɑː s t 	 ['s t']  final
# ɑː s ə n ɪ s t 	 ['s t']  final
# ɑː t ɪ s t 	 ['s t']  final
# ɑː t ɪ s t ɪ k 	 ['s t']
# ɑː t ɪ s t s 	 ['s t s']  final
# ɑː t s 	 ['t s']  final
# æ s b ɛ s t ɒ s 	 ['s t']
# æ s b ɛ s t ə s 	 ['s t']
# æ z b ɛ s t ə s 	 ['s t']
# æ s b ɛ s t ə ʊ s ɪ s 	 ['s t']
# e ɪ ɛ s ɛ m ɑː t ɪ s t 	 ['s t']  final
# æ s p ɛ k t s 	 ['t s']  final
# æ s t ʃ i k 	 ['s t']
# ə s ɛ s t 	 ['s t']  final
# æ s e t s 	 ['t s']  final
# ə s ɪ s t 	 ['s t']  final
# ə s ɪ s t ə n s 	 ['s t']
# ə s ɪ s t ə n t 	 ['s t']
# ə s ɪ s t ɪ d 	 ['s t']
# ə s ɪ s t ɪ ŋ 	 ['s t']
# ə s ɪ s t ɪ v 	 ['s t']
# ə s ɪ s t s 	 ['s t s']  final
# ə s ə ʊ s i e ɪ t s 	 ['t s']  final
# ə s ə ʊ s i ə t s 	 ['t s']  final
# ə s ə ʊ ʃ i e ɪ t s 	 ['t s']  final
# ə s ə ʊ ʃ i ə t s 	 ['t s']  final
# æ s t æ s t ɪ k 	 ['s t', 's t']
# ə s t ɑː n ə 	 ['s t']
# ə s t æ n d 	 ['s t']
# ə s t ɛ ə ɹ 	 ['s t']
# ə s t ɑː ɹ t 	 ['s t']
# a s t ə t iː n 	 ['s t']
# ə s t e ɪ 	 ['s t']
# æ s t ə ɹ 	 ['s t']
# æ s t ə ɹ ɪ s k 	 ['s t']
# æ s t ɹ ɪ s k 	 ['s t']
# a s t ə ɹ ɪ z ə m 	 ['s t']
# æ s t ə ɹ ɪ k s 	 ['s t']
# ə s t ɜː n 	 ['s t']
# æ s t ə ɹ o ɪ d 	 ['s t']
# æ s t ə ɹ o ɪ d z 	 ['s t']
# æ s t ə ɹ ə ʊ s t ɹ ə ʊ m ə l ɔ ɪ d 	 ['s t', 's t']
# æ s t ɪ k ə s 	 ['s t']
# ə s t ɜː ɹ 	 ['s t']
# ə s t ɑ n i d 	 ['s t']
# ə s t ɒ n ɪ ʃ 	 ['s t']
# ə s t ɒ n ɪ ʃ ɪ ŋ 	 ['s t']
# ə s t ɒ n ɪ ʃ m ə n t 	 ['s t']
# ə s t ɒ n i 	 ['s t']
# ə s t uː p 	 ['s t']
# ə s t a ʊ n d 	 ['s t']
# ə s t ɹ æ d ə l 	 ['s t']
# æ s t ɹ iː ə 	 ['s t']
# ə s t ɹ iː ə s 	 ['s t']
# ə s t ɹ e ɪ n 	 ['s t']
# æ s t ɹ ə k æ n 	 ['s t']
# ə s t ɹ æ n d 	 ['s t']
# ə s t ɹ a ɪ d 	 ['s t']
# ə s t ɹ ɪ n d ʒ ə n s 	 ['s t']
# ə s t ɹ ɪ n d ʒ ə n s i 	 ['s t']
# æ s t ɹ ə æ n θ ɹ ə p ɑː l ə d ʒ i 	 ['s t']
# æ s t ɹ ə ɑ ɹ k ə t ɛ k t ʃ ɚ 	 ['s t']
# æ s t ɹ ə ʊ b l iː m 	 ['s t']
# æ s t ɹ ə b ɒ t ə n ɪ 	 ['s t']
# æ s t ɹ ə d ʒ ɪ ɒ ɡ ɹ ə f i 	 ['s t']
# æ s t ɹ ə d ʒ iː ɑ m ɛ t ɹ i 	 ['s t']
# æ s t ɹ ə h ɪ s t ə ɹ i 	 ['s t', 's t']
# æ s t ɹ ə l e ɪ b 	 ['s t']
# æ s t ɹ ə l ɪ ŋ ɡ w ɪ s t ɪ k s 	 ['s t', 's t']
# ə s t ɹ ɒ l ə d ʒ i 	 ['s t']
# æ s t ɹ ɵ m æ n s i 	 ['s t']
# ə s t ɹ ɒ m ə t ɹ i 	 ['s t']
# æ s t ɹ ə n ɔː t 	 ['s t']
# ə s t ɹ ɒ n ə m ə 	 ['s t']
# æ s t ɹ ə n ɒ m ɪ k ə l 	 ['s t']
# æ s t ɹ ə f ɪ l ɒ s ə f i 	 ['s t']
# ə s t ɹ ɑ t ɛ k n ɒ l ə d ʒ i 	 ['s t']
# æ s t ɹ ə ʊ t ɪ p ɪ k 	 ['s t']
# æ s t ɹ ə z ə ʊ ɒ l ə d ʒ i 	 ['s t']
# ə s t ɹ ʌ t 	 ['s t']
# æ s t ʊ ə ɹ i ə n 	 ['s t']
# ə s t j ʊ ə ɹ i ə n 	 ['s t']
# æ s t ʊ ə ɹ i ə s 	 ['s t']
# ə s t j ʊ ə ɹ i ə s 	 ['s t']
# ə s t j uː t 	 ['s t']
# æ s t a ɪ ə d͡ʒ iː z 	 ['s t']
# æ t ə v ɪ s t ɪ k 	 ['s t']
# e ɪ θ i ɪ s t 	 ['s t']  final
# æ θ e l s t æ n 	 ['s t']
# ə θ əː s t 	 ['s t']  final
# ɑ t l ɑ t l̩ ɪ s t 	 ['s t']  final
# æ t ə m ɪ s t 	 ['s t']  final
# ə t e ɪ n m ə n t s 	 ['t s']  final
# ə t ɛ m p t s 	 ['t s']  final
# ə t ɛ n d ə n t s 	 ['t s']  final
# ə t ɛ s t 	 ['s t']  final
# æ t ɛ s t e ɪ ʃ ə n 	 ['s t']
# ə t ɛ s t ɪ d 	 ['s t']
# ə t ɛ s t ɪ ŋ 	 ['s t']
# ə t ɛ s t s 	 ['s t s']  final
# ə t ɹ ɪ s t 	 ['s t']  final
# ə t w ɪ s t 	 ['s t']  final
# ɔː d ɪ t s 	 ['t s']  final
# ɔː t s 	 ['t s']  final
# ɔː ɡ ə s t 	 ['s t']  final
# ɔː ɡ ʌ s t 	 ['s t']  final
# ə ɡ ʌ s t ə 	 ['s t']
# ɔː ɡ ʌ s t ə n 	 ['s t']
# a ʊ ɡ ʊ s t 	 ['s t']  final
# ɔː ɡ ə s t iː n 	 ['s t']
# ɔː ɡ ʌ s t ɪ n 	 ['s t']
# ɔ ɡ ə s t s 	 ['s t s']  final
# ɔː ɡ ʌ s t ə s 	 ['s t']
# a ʊ̯ ʃ v ɪ t s 	 ['t s']  final
# a ʊ̯ ʃ w ɪ t s 	 ['t s']  final
# ɒ s t ɪ n 	 ['s t']
# ɔː s t ə n ɛ s k 	 ['s t']
# ɔː s t iː n ɪ ə n 	 ['s t']
# ɒ s t ɪ n a ɪ t 	 ['s t']
# ɒ s t ə 	 ['s t']
# ɒ s t ə ɹ 	 ['s t']
# ɔː s t ə 	 ['s t']
# ɔː s t ə ɹ 	 ['s t']
# ɒ s t ɪ ə ɹ 	 ['s t']
# ɔː s t ɪ ə ɹ 	 ['s t']
# a ʊ s t ə l ɪ t s 	 ['s t', 't s']  final
# ɔː s t ə l ɪ t s 	 ['s t', 't s']  final
# ɒ s t ɪ n 	 ['s t']
# ɒ s t ɪ n a ɪ t 	 ['s t']
# ɒ s t ɪ n a ɪ t s 	 ['s t', 't s']  final
# ɒ s t ɹ ə l 	 ['s t']
# ɔː s t ɹ ə l 	 ['s t']
# ɒ s t ɹ ə l e ɪ ʒ ə 	 ['s t']
# ɒ s t ɹ e ɪ l i j ə 	 ['s t']
# ɒ s t ɹ e ɪ l iː ə 	 ['s t']
# ɔː s t ɹ e ɪ l ɪ j ə 	 ['s t']
# ɔː s t ɹ e ɪ l ɪ ə 	 ['s t']
# ɒ s t ɹ e ɪ l i j ə n 	 ['s t']
# ɒ s t ɹ e ɪ l iː ə n 	 ['s t']
# ɔ s t ɹ e ɪ l i e ɪ n ə 	 ['s t']
# ɔ s t ɹ e ɪ l i æ n ə 	 ['s t']
# ɔ s t ɹ e ɪ l i ɑ n ə 	 ['s t']
# ɒ s t ɹ e ɪ l j ə n a ɪ z 	 ['s t']
# ɒ s t ɹ e ɪ l j ə n a ɪ z 	 ['s t']
# ɒ s t ɹ ə l ə ʊ p ɪ θ ɪ s iː n 	 ['s t']
# ɒ s t ɹ ɪ ə 	 ['s t']
# ɔː s t ɹ ɪ ə 	 ['s t']
# ɒ s t ɹ i ə n 	 ['s t']
# ɒ s t ɹ i ə n ɪ z ə m 	 ['s t']
# ɒ s t ɹ i ə n ɪ z ə m s 	 ['s t']
# ɒ s t ɹ i ə n s 	 ['s t']
# ɒ s t ɹ ə n iː ʒ ə 	 ['s t']
# ɔː s t ɹ o ʊ n iː ʒ ə n 	 ['s t']
# ɔː s t ɹ o ʊ n iː ʒ ə n z 	 ['s t']
# ɒ s t ɹ ə ʊ f ə ʊ b 	 ['s t']
# ɔː t ɪ s t 	 ['s t']  final
# ɔː t ɪ s t ɪ k 	 ['s t']
# ɔː t ɒ n ə m ɪ s t 	 ['s t']  final
# ɔː t ə s k ɛ d i æ s t ɪ k 	 ['s t']
# ɔː t ə ʊ s k ɛ d i æ s t ɪ k 	 ['s t']
# ə v ɑː s t 	 ['s t']  final
# ə v ɛ s t ə n 	 ['s t']
# ə w e ɪ t s 	 ['t s']  final
# ə w e ɪ s t 	 ['s t']  final
# ɔ s m̩ t æ s t ɪ k 	 ['s t']
# æ k s t 	 ['s t']  final
# ə z ɒ k s i s t ɹ ə ʊ b ɪ n 	 ['s t']
# b ə b uː v ɪ s t 	 ['s t']  final
# b æ k ɹ e s t 	 ['s t']  final
# b æ k s t æ b 	 ['s t']
# b æ k s t æ b ɚ 	 ['s t']
# b æ k s t e ɪ d ʒ 	 ['s t']
# b æ k s t ɹ ɛ t ʃ 	 ['s t']
# b æ k t ɪ ə ɹ ɪ ə ʊ s t e ɪ s ɪ s 	 ['s t']
# b æ ɡ ɛ t s 	 ['t s']  final
# b e ɪ t s 	 ['t s']  final
# b æ l ə n s t 	 ['s t']  final
# b ɑː l ə b ɒ s t ə 	 ['s t']
# b ɑː l ə b ɔ s t ə 	 ['s t']
# b ɑː l ə b ʌ s t ə 	 ['s t']
# b æ l ə s t 	 ['s t']  final
# b ə l ɪ s t ə 	 ['s t']
# b ə l ɪ s t ɪ k 	 ['s t']
# b ə l ɪ s t ɪ k s 	 ['s t']
# b æ l ə s t ɹ e ɪ d 	 ['s t']
# b æ n d s t æ n d 	 ['s t']
# b æ n ɪ s t ə ɹ 	 ['s t']
# b æ ŋ k ɹ ʌ p t s ɪ 	 ['t s']
# b æ ŋ k s t ə 	 ['s t']
# b æ n s t ɛ d 	 ['s t']
# b a n t uː s t a n 	 ['s t']
# b a n t uː s t ɑː n 	 ['s t']
# b æ p t ɪ s t 	 ['s t']  final
# b e ə ɹ f e ɪ s t 	 ['s t']  final
# b ɛ ə ɹ f æ s t 	 ['s t']  final
# b ɛ ə ɹ f ɑː s t 	 ['s t']  final
# b ɑː ɡ ɛ s t 	 ['s t']  final
# b ə ɹ iː s t ə 	 ['s t']
# b ə ɹ ɪ s t ə 	 ['s t']
# b a ɹ i s t o 	 ['s t']
# b ə ɹ ɪ s t ə ʊ 	 ['s t']
# b ɑː ɹ ɪ t s uː 	 ['t s']
# b ɑ ɹ n s t ə b ə l 	 ['s t']
# b ɑː ɹ n s t ə b ə l 	 ['s t']
# b ɑː ɹ n s t ə p ə ɫ 	 ['s t']
# b ɑː ɹ n s t ɔː ɹ m 	 ['s t']
# b æ ɹ ə m ɛ t s 	 ['t s']  final
# b æ ɹ ɪ s t ə ɹ 	 ['s t']
# b ɑː t ɪ t s uː 	 ['t s']
# b e ɪ s t 	 ['s t']  final
# b e ɪ s m ə n t s 	 ['t s']  final
# b e ɪ z ɪ ŋ ɡ s t ə ʊ k 	 ['s t']
# b e ɪ s ɪ s t 	 ['s t']  final
# b æ s t 	 ['s t']  final
# b ɑː s t ə d 	 ['s t']
# b e ɪ s t 	 ['s t']  final
# b e ɪ s t ɪ d 	 ['s t']
# b e ɪ s t ə 	 ['s t']
# b e ɪ s t ə z 	 ['s t']
# b e ɪ s t s 	 ['s t s']  final
# b æ s t i ə n 	 ['s t']
# b e ɪ s t ɪ ŋ z 	 ['s t']
# b æ s t i ə n 	 ['s t']
# b æ s t ə n 	 ['s t']
# b e ɪ t s 	 ['t s']  final
# b ə t iː s t 	 ['s t']  final
# b æ t s 	 ['t s']  final
# b a t s k w iː k 	 ['t s']
# b æ k s t ə 	 ['s t']
# b iː s t 	 ['s t']  final
# b iː s t i 	 ['s t']
# b iː s t i z 	 ['s t']
# b iː s t l i 	 ['s t']
# b iː s t s 	 ['s t s']  final
# b iː t s 	 ['t s']  final
# b j uː t s 	 ['t s']  final
# b iː t ʃ m ɑː s t 	 ['s t']  final
# b iː f s t e ɪ k 	 ['s t']
# b iː s t ɪ ŋ z 	 ['s t']
# b iː t s 	 ['t s']  final
# b ɪ ɡ æ n s t 	 ['s t']  final
# b i h ɛ s t 	 ['s t']  final
# b ɪ n o ʊ n s t 	 ['s t']  final
# b ɛ l f æ s t 	 ['s t']  final
# b ɛ l f ɑː s t 	 ['s t']  final
# b ɛ l l ɛ t ɹ ɪ s t ɪ k 	 ['s t']
# b ɛ l t s 	 ['t s']  final
# b ɛ n t s 	 ['t s']  final
# b ɪ k w ɛ s t 	 ['s t']  final
# b ɛ ɹ ə s t ɒ l ə d͡ʒ i 	 ['s t']
# b ɜː ɹ k ə m s t ɛ d 	 ['s t']
# b ɛ s t 	 ['s t']  final
# b ɛ s t ɪ d 	 ['s t']
# b ɪ s t ɛ d 	 ['s t']
# b ɛ s t i ə l 	 ['s t']
# b ɛ s t ʃ ə l l ɪ t ɪ 	 ['s t']
# b ɛ s t i 	 ['s t']
# b ɛ s t ɪ ŋ 	 ['s t']
# b ɪ s t ɜː 	 ['s t']
# b ɪ s t ə ʊ 	 ['s t']
# b ɪ s t ə ʊ d 	 ['s t']
# b ɛ s t s 	 ['s t s']  final
# b ɛ t s 	 ['t s']  final
# b ɪ t w ɪ k s t 	 ['s t']  final
# b ɪ b l i ɒ m ə t ɹ ɪ s t 	 ['s t']  final
# b ɪ b l ɪ s t 	 ['s t']  final
# b ɪ s t ə 	 ['s t']
# b ɪ ɡ ə m ɪ s t 	 ['s t']  final
# b ɪ ɡ ɪ s t 	 ['s t']  final
# b a ɪ t s 	 ['t s']  final
# b ɪ ɡ ə t s 	 ['t s']  final
# b ɪ n d ə l s t ɪ f 	 ['s t']
# b a ɪ o ʊ s t ə t ɪ s t ɪ k l̩ 	 ['s t', 's t']
# b a ɪ ə ʊ t ɛ ɹ ə ɹ ɪ s t 	 ['s t']  final
# b ɪ s ɛ k s t ɪ l 	 ['s t']
# b ɪ s t ʊ ɹ i 	 ['s t']
# b iː s t ɹ ə ʊ 	 ['s t']
# b ɪ s t ɹ ə ʊ 	 ['s t']
# b a ɪ t s 	 ['t s']  final
# b ɪ t s 	 ['t s']  final
# b l æ k ə s t 	 ['s t']  final
# b l æ k l ɪ s t 	 ['s t']  final
# b l æ k l ɪ s t ə d 	 ['s t']
# b l æ k a ʊ t s 	 ['t s']  final
# b l æ n k ɛ t s 	 ['t s']  final
# b l ɑː s t 	 ['s t']  final
# b l ɑː s t ɪ d 	 ['s t']
# b l ɑː s t ə 	 ['s t']
# b l æ s t ə s p ɔː ɹ 	 ['s t']
# b l æ s t p a ɪ p 	 ['s t']
# b l ɑː s t p a ɪ p 	 ['s t']
# b l ɛ s t 	 ['s t']  final
# b l ɛ s t 	 ['s t']  final
# b l uː ɪ t s 	 ['t s']  final
# b l a ɪ t s 	 ['t s']  final
# b l ɪ t s 	 ['t s']  final
# b l ɪ t s t 	 ['t s t']  final
# b l ɪ t s ɪ z 	 ['t s']
# b l ɪ t s ɪ ŋ 	 ['t s']
# b l ə ʊ t s 	 ['t s']  final
# b l ɒ k b ʌ s t ə ɹ 	 ['s t']
# b l ɒ ɡ t æ s t ɪ k 	 ['s t']
# b l ʌ d l ʌ s t 	 ['s t']  final
# b l ʌ d s t ɹ ɪ i m 	 ['s t']
# b l ʌ d θ əː s t i 	 ['s t']
# b l uː s t ɛ m 	 ['s t']
# b l ʌ n t s 	 ['t s']  final
# b l ʌ s t ə 	 ['s t']
# b l ʌ s t ə ɹ ə s 	 ['s t']
# b ə ʊ s t 	 ['s t']  final
# b ə ʊ s t ɪ d 	 ['s t']
# b ə ʊ s t ɪ ŋ l i 	 ['s t']
# b ə ʊ t s 	 ['t s']  final
# b ə ʊ t s w e ɪ n 	 ['t s']
# b ɔ ɪ s t ə ɹ ə s 	 ['s t']
# b ɒ l ʃ ə v ɪ s t 	 ['s t']  final
# b ə ʊ l s t ə 	 ['s t']
# b ə ʊ l t s 	 ['t s']  final
# b ɒ m b æ s t 	 ['s t']  final
# b ɒ m b æ s t ɪ k 	 ['s t']
# b ʊ k s t æ f 	 ['s t']
# b ʊ k s t ɑː f 	 ['s t']
# b ʊ k s t ə f 	 ['s t']
# b ʊ k s t ɪ f 	 ['s t']
# b ʊ k s t æ n d 	 ['s t']
# b ʊ k s t ɪ v 	 ['s t']
# b ʊ k s t ɔː 	 ['s t']
# b uː s t 	 ['s t']  final
# b uː t s 	 ['t s']  final
# b uː t s t ɹ æ p 	 ['t s t']
# b ɒ ɹ ə m ɛ t s 	 ['t s']  final
# b ɒ s t ə n 	 ['s t']
# b ɒ t ə n ɪ s t 	 ['s t']  final
# b ɒ t s w ɑː n ə 	 ['t s']
# b a ʊ n s t 	 ['s t']  final
# b a ʊ n s i ɪ s t 	 ['s t']  final
# b uː s t ɹ ə f iː d ə n 	 ['s t']
# b a ʊ t s 	 ['t s']  final
# b ə ʊ s t ɹ ɪ ŋ 	 ['s t']
# b ɑː k s t 	 ['s t']  final
# b ɒ k s t 	 ['s t']  final
# b ɒ k s t i 	 ['s t']
# b ɹ e ɪ s t 	 ['s t']  final
# b ɹ æ k ɪ t s 	 ['t s']  final
# b ɹ e ɪ n s t ɔː ɹ m 	 ['s t']
# b ɹ æ t s 	 ['t s']  final
# b ɹ ɛ d s t ʌ f 	 ['s t']
# b ɹ ɛ k f ə s t 	 ['s t']  final
# b ɹ ɛ k f ə s t i 	 ['s t']
# b ɹ ɛ s t 	 ['s t']  final
# b ɹ ɛ s t f i d ɪ ŋ 	 ['s t']
# b ɹ ɛ s t s 	 ['s t s']  final
# b ɹ ɛ s t i 	 ['s t']
# b ɹ a ɪ t ʃ v ɑː n t s 	 ['t s']  final
# b ɹ ɛ s t 	 ['s t']  final
# b ɹ u s t ɚ 	 ['s t']
# b ɹ a ɪ t s 	 ['t s']  final
# b ɹ ɪ l j ə n t s 	 ['t s']  final
# b ɹ ɪ m s t ə ʊ n 	 ['s t']
# b ɹ ɪ s t ə l 	 ['s t']
# b ɹ ɪ s t ə ʊ l i ə n 	 ['s t']
# b ɹ ɪ t s 	 ['t s']  final
# b ɹ ɪ k s t ə n 	 ['s t']
# b ɹ ɔː d k ɑː s t 	 ['s t']  final
# b ɹ u m s t ɪ k 	 ['s t']
# b ɹ ə ʊ t æ s t ɪ k 	 ['s t']
# b ɹ uː t s 	 ['t s']  final
# b j uː k ə ɹ ɛ s t 	 ['s t']  final
# b uː k ə ɹ ɛ s t 	 ['s t']  final
# b j uː d ə p ɛ s t 	 ['s t']  final
# b uː d ə p ɛ s t 	 ['s t']  final
# b ʊ d ə p ɛ s t 	 ['s t']  final
# b u d ɪ s t 	 ['s t']  final
# b ʊ d ɪ s t 	 ['s t']  final
# b ʌ d ʒ ɪ t s 	 ['t s']  final
# b ʊ l d ʌ s t 	 ['s t']  final
# b ʊ l ɪ t s 	 ['t s']  final
# b ʊ l m æ s t ɪ f 	 ['s t']
# b ʌ m s t ə 	 ['s t']
# b ʌ m t æ s t ɪ k 	 ['s t']
# b ʊ n d ə s t ɑː ɡ 	 ['s t']
# b ʌ n d ə b ʌ s t 	 ['s t']  final
# b ɚ s t o ʊ n 	 ['s t']
# b ɜː s t 	 ['s t']  final
# b ɜː s t ɪ ŋ 	 ['s t']
# b ʌ s t 	 ['s t']  final
# b ʌ s t 	 ['s t']  final
# b ʌ s t 	 ['s t']  final
# b ʌ s t ə d 	 ['s t']
# b ʌ s t ə d 	 ['s t']
# b uː s t i e ɪ 	 ['s t']
# b ʌ s t i ə ɹ 	 ['s t']
# b ʌ s t ɪ ŋ 	 ['s t']
# b ʌ s t ɪ t j uː ʃ ə n 	 ['s t']
# b ʌ s t ə ʊ 	 ['s t']
# b ʌ s t s 	 ['s t s']  final
# b ʌ s t i 	 ['s t']
# b ʌ t s 	 ['t s']  final
# b j uː t s 	 ['t s']  final
# b ʌ t s 	 ['t s']  final
# b a ɪ t s 	 ['t s']  final
# k ə f ɛ s t ɒ l 	 ['s t']
# k ə h uː t s 	 ['t s']  final
# k æ l s t 	 ['s t']  final
# k æ l ə n d ə ɹ ɪ s t 	 ['s t']  final
# k æ l v ə n ɪ s t 	 ['s t']  final
# k æ l v ɪ n ɪ s t 	 ['s t']  final
# k æ l t s ə ʊ n i 	 ['t s']
# k ə m ɒ ɹ ɪ s t 	 ['s t']  final
# k a m ə ɹ ɪ s t ə 	 ['s t']
# k ə n æ s t ə 	 ['s t']
# k æ n d l̩ s t ɪ k 	 ['s t']
# k æ n d ə l s t ɪ k 	 ['s t']
# k æ n ɪ s t ə l 	 ['s t']
# k a n ɪ b ə l ɪ s t ɪ k 	 ['s t']
# k æ n ɪ t s ɑː ɹ a ɪ t 	 ['t s']
# k æ n s t 	 ['s t']  final
# t s a ʊ ʃ uː 	 ['t s']  initial
# k æ p ə w e ə ɹ ɪ s t ə 	 ['s t']
# k æ p ə ʊ e ə ɹ ɪ i s t ə 	 ['s t']
# k a p s t ə n 	 ['s t']
# k ɑː d ɪ s t 	 ['s t']  final
# k ɑː d ɪ s t ɹ ɪ 	 ['s t']
# k ə ɹ ɛ s t 	 ['s t']  final
# k æ ɹ ɪ k ə t͡ʃ ʊ ə ɹ ɪ s t 	 ['s t']  final
# k ɑː n uː s t i 	 ['s t']
# k ɑː t s 	 ['t s']  final
# k e ɪ s t 	 ['s t']  final
# k æ s t 	 ['s t']  final
# k ɑː s t 	 ['s t']  final
# k æ s t æ l ə d͡ʒ ɪ n 	 ['s t']
# k æ s t ə n ɛ t 	 ['s t']
# k æ s t ə n ɛ t s 	 ['s t', 't s']  final
# k æ s t ə w e ɪ 	 ['s t']
# k ɑː s t 	 ['s t']  final
# k æ s t ə n 	 ['s t']
# k æ s t ə l ɑː n ə s 	 ['s t']
# k a s t ə l e ɪ t 	 ['s t']
# k a s t ə l ə t 	 ['s t']
# k a s t ə l e ɪ t ɪ d 	 ['s t']
# k æ s t ə r 	 ['s t']
# k ɑː s t ə r 	 ['s t']
# k æ s t ə ɡ e ɪ t 	 ['s t']
# k æ s t ɪ ɡ e ɪ t 	 ['s t']
# k ə s t iː l 	 ['s t']
# k ə s t ɪ l j ə n 	 ['s t']
# k ɑː s t ɪ ŋ 	 ['s t']
# k ɑː s t l ɪ ŋ 	 ['s t']
# k ɑː s t ə 	 ['s t']
# k æ s t ɹ e ɪ t 	 ['s t']
# k æ s t ɹ e ɪ ʃ ə n 	 ['s t']
# k a s t ɹ e ɪ t ɪ v 	 ['s t']
# k æ s t ɹ ɑː t ə ʊ 	 ['s t']
# k æ s t ɹ e ɪ t ɹ ɪ s iː z 	 ['s t']
# k æ s t ɹ e ɪ t ɹ ɪ k s 	 ['s t']
# k æ s t ɹ iː z 	 ['s t']
# k æ z j ʊ ɪ s t 	 ['s t']  final
# k æ z j u ɪ s t ɪ k 	 ['s t']
# k æ ʒ u ɪ s t ɪ k 	 ['s t']
# k æ z j u ɪ s t ɹ i 	 ['s t']
# k æ ʒ u ɪ s t ɹ i 	 ['s t']
# k æ t ə l ɪ s t 	 ['s t']  final
# k æ t ə m a ɪ t s 	 ['t s']  final
# k ə t æ s t ə s ɪ s 	 ['s t']
# k ə t æ s t ɹ ə f i 	 ['s t']
# k æ t ə s t ɹ ɒ f ɪ k 	 ['s t']
# k ə t æ s t ɹ ə f a ɪ z 	 ['s t']
# k æ t s 	 ['t s']  final
# k æ t t e ɪ l 	 ['t t']
# k ɒ s t ɪ k 	 ['s t']
# k ɔː s t ɪ k 	 ['s t']
# k ɔː s t ɪ s ɪ t i 	 ['s t']
# s iː s t 	 ['s t']  final
# s ə l ɛ s t ə 	 ['s t']
# s ə l ɛ s t 	 ['s t']  final
# s ə l ɛ s t i ə l 	 ['s t']
# s ə l ɛ s t͡ʃ ə l 	 ['s t']
# t͡ʃ ɛ l ɪ s t 	 ['s t']  final
# s ɛ n t ɹ ə b l æ s t 	 ['s t']  final
# s ɛ n t s 	 ['t s']  final
# t s ɛ p ə l iː n ə s 	 ['t s']  initial
# k ɛ p s t ɹ ə m 	 ['s t']
# k ɛ p s t ɹ ʌ m 	 ['s t']
# s ɛ p s t ɹ ə m 	 ['s t']
# s ɛ p s t ɹ ʌ m 	 ['s t']
# s ə ɹ a m ɪ s t 	 ['s t']  final
# s ɛ s t 	 ['s t']  final
# s ɛ s t ə ʊ d 	 ['s t']
# s e s t ɹ iː ʌ n 	 ['s t']
# s ɛ s t ə s 	 ['s t']
# χ ɑː m ɪ t s 	 ['t s']  final
# χ ə m ɛ t s 	 ['t s']  final
# χ ʌ m ɪ t s 	 ['t s']  final
# t͡ʃ ɑː n s t 	 ['s t']  final
# t ʃ ɑː n t s ə l ɹ i 	 ['t s']
# k æ ɹ ə k t ə ɹ ɪ s t ɪ k 	 ['s t']
# k æ ɹ ə k t ə ɹ ɪ s t ɪ k s 	 ['s t']
# t ʃ ɑː ɹ m ɛ s t 	 ['s t']  final
# t ʃ e j s t 	 ['s t']  final
# t ʃ e ɪ s t 	 ['s t']  final
# t ʃ æ s t a ɪ z 	 ['s t']
# t ʃ æ s t a ɪ z m ə n t 	 ['s t']
# t ʃ æ s t ə z m ə n t 	 ['s t']
# t ʃ æ s t ɪ z m ə n t 	 ['s t']
# t ʃ æ t s 	 ['t s']  final
# t ʃ æ v t æ s t ɪ k 	 ['s t']
# t͡ʃ iː s t ə ɹ 	 ['s t']
# t ʃ iː t s 	 ['t s']  final
# t ʃ ɛ k l ɪ s t 	 ['s t']  final
# t ʃ iː z t æ s t ɪ k 	 ['s t']
# k ɛ m ɪ s t 	 ['s t']  final
# k ɛ m ɪ s t ɹ i 	 ['s t']
# k ɛ m n ɪ t s 	 ['t s']  final
# k ɪ i m ə ʊ s t ɛ ɹ ɪ l ə n t 	 ['s t']
# t͡ʃ ɜː t s iː 	 ['t s']
# t͡ʃ ɛ s t 	 ['s t']  final
# t ʃ ɛ s t ɪ d 	 ['s t']
# t ʃ ɛ s t ə 	 ['s t']
# t͡ʃ ɛ s t ɪ k l̩ 	 ['s t']
# t ʃ ɛ s t ɪ ŋ 	 ['s t']
# t ʃ ɛ s t n ʌ t 	 ['s t']
# t ʃ ɛ s t s 	 ['s t s']  final
# t ʃ ɛ s t i 	 ['s t']
# t ʃ ɪ t ʃ ɪ s t ə 	 ['s t']
# k ɪ l i ə s t 	 ['s t']  final
# k ɪ l i a s t ɪ k 	 ['s t']
# t ʃ ɪ n t s 	 ['t s']  final
# t ʃ ɪ n t s i 	 ['t s']
# k ɪ r ɒ p ə d ɪ s t 	 ['s t']  final
# k a ɪ ɹ ɒ p t ə ɹ ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# t͡ʃ ɪ z ə l h ɜː s t 	 ['s t']  final
# t ʃ ɪ t s 	 ['t s']  final
# k l ɔː r ə ʊ p l æ s t 	 ['s t']  final
# k l ɔː r ə ʊ p l æ s t s 	 ['s t s']  final
# t ʃ ɒ k s t ə ʊ n 	 ['s t']
# t ʃ ɔ ɪ s ə s t 	 ['s t']  final
# k ə l ɛ s t i ə tʰ ə ʊ̯ m ə 	 ['s t']
# t ʃ ɒ p s t ɪ k s 	 ['s t']
# k ɹ ɛ s t ə ʊ m æ θ i z 	 ['s t']
# k ɹ ɛ s t ɒ m ə θ i 	 ['s t']
# k ɹ a ɪ s s e ɪ k 	 ['s s']
# k ɹ a ɪ s t 	 ['s t']  final
# k ɹ ʌ ɪ s tˑ t͡ʃ ɜː t͡ʃ 	 ['s t']
# k ɹ a ɪ s t ɚ 	 ['s t']
# k ɹ ɪ s t j ə n 	 ['s t']
# k ɹ ɪ s t ʃ ə n 	 ['s t']
# k ɹ ɪ s t i æ n ɪ t i 	 ['s t']
# k ɹ ɪ s t i 	 ['s t']
# k ɹ ɪ s t iː n ə 	 ['s t']
# k ɹ ɪ s t iː n 	 ['s t']
# k ɹ ɪ s t ɪ ŋ ɡ ə l 	 ['s t']
# k ɹ ɪ s t k ɪ n d ə l 	 ['s t']
# k ɹ ɪ s t m ə n 	 ['s t']
# k ɹ ɪ s t ɑ l ə d ʒ i 	 ['s t']
# k ɹ ɪ s t ə f ə ɹ 	 ['s t']
# k ɹ ə n ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# k ɹ ɪ s ə s t ə m 	 ['s t']
# t ʃ ʌ m p i ɪ s t 	 ['s t']  final
# h ʊ t s p ə d ɪ k 	 ['t s']
# x ʊ t s p ə d ɪ k 	 ['t s']
# h ʊ t s p ɑ 	 ['t s']
# x ʊ t s p ɑ 	 ['t s']
# s ɪ l ɒ s t ə z ɒ l 	 ['s t']
# t ʃ i ŋ k w ɛ t ʃ ɛ n t ɪ s t 	 ['s t']  final
# s ɜː k ə m s t ə n s 	 ['s t']
# s ɜː k ə m s t ɑː n s ɪ z 	 ['s t']
# s ɜː k ə m s t ə n s ɪ z 	 ['s t']
# s əː k ə m s t a n ʃ ə l 	 ['s t']
# s ɜː ɹ k ə m s t æ n ʃ ə l ɪ i 	 ['s t']
# s ɜː k ə m s t ɛ l ə 	 ['s t']
# s ʌ ɪ ɹ ə n s ɛ s t ə 	 ['s t']
# s ɪ ɹ ə s t ɹ e ɪ t ə s 	 ['s t']
# k ɪ s t 	 ['s t']  final
# s ɪ s t 	 ['s t']  final
# s ɪ s t ə n 	 ['s t']
# s ɨ s t ɪ k ɘ l ɘ 	 ['s t']
# s a ɪ t s 	 ['t s']  final
# s ɪ v ɪ l ɪ s t 	 ['s t']  final
# s ɪ v ɪ l ɪ s t s 	 ['s t s']  final
# s ɪː v ɪː t e ɪ t s 	 ['t s']  final
# k l e ɪ d ɪ s t 	 ['s t']  final
# k l ə d ɪ s t ɪ k ə l i 	 ['s t']
# k l ə d ɪ s t ɪ k s 	 ['s t']
# k l æ n d ə s t a ɪ n 	 ['s t']
# k l æ n d ɛ s t ɪ n 	 ['s t']
# k l æ n d ɪ s t a ɪ n 	 ['s t']
# k l æ ɹ ɪ n ɛ t ɪ s t 	 ['s t']  final
# k l ɑː s m e ɪ t s 	 ['t s']  final
# k l æ s t 	 ['s t']  final
# k l æ t s ə p 	 ['t s']
# k l ɒ s t ɹ ə f ə ʊ b 	 ['s t']
# k l ɔː s t ɹ ə m 	 ['s t']
# k l iː t s 	 ['t s']  final
# k l a ɪ s t o ʊ θ iː s i ə l 	 ['s t']
# k l a ɪ s t o ʊ θ iː ʃ i ə l 	 ['s t']
# k l a ɪ s t o ʊ θ iː ʃ ə l 	 ['s t']
# k l ɛ ɹ ɪ k ə l ɪ s t 	 ['s t']  final
# k l ɪ t s 	 ['t s']  final
# k l ɒ k p ə ʊ s t 	 ['s t']  final
# k l ɔ ɪ s t ə 	 ['s t']
# k l ə ʊ s ɪ s t 	 ['s t']  final
# k l ə ʊ s t 	 ['s t']  final
# k l a ʊ d b ɜː s t 	 ['s t']  final
# k l ʌ s t ə 	 ['s t']
# k l ʌ s t ə f ʌ k 	 ['s t']
# k l ɪ s t ə 	 ['s t']
# k l a ɪ t ə m n ɛ s t ɹ ə 	 ['s t']
# k l a ɪ t ɪ m n ɛ s t ɹ ə 	 ['s t']
# k ə ʊ s t 	 ['s t']  final
# k ə ʊ s t ə l 	 ['s t']
# k ə ʊ s t ə ɹ 	 ['s t']
# k ə ʊ s t s 	 ['s t s']  final
# k ə ʊ t s 	 ['t s']  final
# k ə ʊ t s 	 ['t s']  final
# k ə ʊ k s t 	 ['s t']  final
# k ɒ b l̩ s t ə ʊ n 	 ['s t']
# k ɒ k f ɒ s t ə z 	 ['s t']
# k ə ʊ ɪ k s t ɛ n s ɪ v 	 ['s t']
# k o ʊ ɛ k s t ɪ ŋ k t 	 ['s t']
# k o ʊ ɪ k s t ɪ ŋ k t 	 ['s t']
# k ʌ s t ɹ ə l 	 ['s t']
# k ɒ l t ʃ ɛ s t ə 	 ['s t']
# k ə l ɛ k t ɪ v ɪ s t 	 ['s t']  final
# k ɒ l ə n ɪ s t 	 ['s t']  final
# k ɒ l ə n ɪ s t s 	 ['s t s']  final
# k ə l ɒ s t ɹ ə m 	 ['s t']
# k ɒ l ə m n ɪ s t 	 ['s t']  final
# k ɒ l ə m ɪ s t 	 ['s t']  final
# k ə m b ʌ s t ʃ ə n 	 ['s t']
# k ə m b ʌ s t ʃ ə n ɛ ə ɹ i 	 ['s t']
# k ə m ɛ s t ə b l̩ 	 ['s t']
# k ə m ɛ s t ɪ b l̩ 	 ['s t']
# k ə m ɛ n s t 	 ['s t']  final
# k ɒ m ɛ n t s 	 ['t s']  final
# k ə m ɪ t s 	 ['t s']  final
# k ə m ɪ k s t ʃ ə n 	 ['s t']
# k ɒ m j ʊ n ɪ s t 	 ['s t']  final
# k ʌ m p ə s t 	 ['s t']  final
# k ə m p iː t s 	 ['t s']  final
# k ə m p l e ɪ n t s 	 ['t s']  final
# k ə m p l iː t s 	 ['t s']  final
# k ɒ m p l ɪ m ə n t s 	 ['t s']  final
# k ɒ m p ɒ s t 	 ['s t']  final
# k ə m p ɹ ɛ s t 	 ['s t']  final
# k ə m p j uː t s 	 ['t s']  final
# k ə n s ɪ l ɪ ə ɹ ɪ s t 	 ['s t']  final
# k ə n f ɛ s t 	 ['s t']  final
# k ə n f ʌ s t ə k e ɪ t 	 ['s t']
# k ɒ n d ʒ ɛ s t iː 	 ['s t']
# k ə n d͡ʒ ɛ s t ʃ ə n 	 ['s t']
# k ə n ɡ ɹ æ t s 	 ['t s']  final
# k ɒ ŋ ɡ ɹ ə ɡ e ɪ ʃ ə n ə l ɪ s t 	 ['s t']  final
# k ə n ɛ k t s 	 ['t s']  final
# k ɒ ŋ k w ə s t 	 ['s t']  final
# k ɒ ŋ k w ɛ s t 	 ['s t']  final
# k ɒ n s ɪ s t 	 ['s t']  final
# k ə n s ɪ s t 	 ['s t']  final
# k ə n s ɪ s t ɪ d 	 ['s t']
# k ə n s ɪ s t ə n s 	 ['s t']
# k ə n s ɪ s t ə n s i 	 ['s t']
# k ə n s ɪ s t ə n t 	 ['s t']
# k ə n s ɪ s t ɪ ŋ 	 ['s t']
# k ə n s ɪ s t ə ɹ i 	 ['s t']
# k ə n s ɪ s t s 	 ['s t s']  final
# k ʌ n s t ə b ə l 	 ['s t']
# k ə n s t æ b j ʊ l ə ɹ i 	 ['s t']
# k ɒ n s t ə n t 	 ['s t']
# k ɒ n s t ə n t a ɪ n 	 ['s t']
# k ɔ n s t æ n t ɪ n ə ʊ p ə l 	 ['s t']
# k ɒ n s t æ n t ɨ n ɵ p ɒ l ɨ t ə n 	 ['s t']
# k ɒ n s t ə n t l i 	 ['s t']
# k ɒ n s t a t 	 ['s t']
# k ɒ n s t ə t ɪ v 	 ['s t']
# k ə n s t e ɪ t ɪ v 	 ['s t']
# k ɒ n s t ə l e ɪ ʃ ə n 	 ['s t']
# k ɒ n s t ə l e ɪ ʃ ə n ə l i 	 ['s t']
# k ɒ n s t ə n e ɪ ʃ ə n 	 ['s t']
# k ɒ n s t ɪ p e ɪ t 	 ['s t']
# k ɒ n s t ə p e ɪ t ə d 	 ['s t']
# k ə n s t ɪ t j u ə n s ɨ z 	 ['s t']
# k ə n s t ɪ t ʃ ʊ ə n s ɨ z 	 ['s t']
# k ɒ n s t ɪ t j uː t 	 ['s t']
# k ɒ n s t ɪ t j uː t ɪ d 	 ['s t']
# k ɒ n s t ɪ t j uː t s 	 ['s t', 't s']  final
# k ɒ n s t ɪ t j uː ʃ ə n 	 ['s t']
# k ɒ n s t ɪ t ʃ uː ʃ ə n 	 ['s t']
# k ɒ n s t ɪ t j uː ʃ ə n ə l 	 ['s t']
# k ɒ n s t ɪ t j uː ʃ ə n ə l ɪ z ə m 	 ['s t']
# k ɒ n s t ɪ t j uː ʃ ə n ə l i 	 ['s t']
# k ə n s t ɹ e ɪ n 	 ['s t']
# k ə n s t ɹ e ɪ n d 	 ['s t']
# k ə n s t ɹ e ɪ n t 	 ['s t']
# k ə n s t ɹ e ɪ n t s 	 ['s t', 't s']  final
# k ə n s t ɹ ɪ k t 	 ['s t']
# k ə n s t ɹ uː ə l 	 ['s t']
# k ɒ n s t ɹ ʌ k t 	 ['s t']
# k ə n s t ɹ ʌ k t 	 ['s t']
# k ə n s t ɹ ʌ k t ə d 	 ['s t']
# k ə n s t ɹ ʌ k ʃ ə n 	 ['s t']
# k ə n s t ɹ ʌ k t ɪ v 	 ['s t']
# k ə n s t ɹ uː 	 ['s t']
# k ə n s t ɹ uː d 	 ['s t']
# k ə n s t ɹ uː z 	 ['s t']
# k ə n s t ɹ uː ɪ ŋ 	 ['s t']
# k ɒ n s ə b s t a n ʃ ə l 	 ['s t']
# k ɔ n s ʌ b s t n̩ ʃ i e ɪ ʃ ə n 	 ['s t']
# k ɒ n t æ k t s 	 ['t s']  final
# k ə n t æ k t s 	 ['t s']  final
# k ɒ n t ɛ n t s 	 ['t s']  final
# k ɒ n t ɛ s t 	 ['s t']  final
# k ə n t ɛ s t 	 ['s t']  final
# k ə n t ɛ s t ə n t 	 ['s t']
# k ɒ n t ɛ k s t 	 ['s t']  final
# k ɒ n t ɹ æ k t s 	 ['t s']  final
# k ə n t ɹ æ k t s 	 ['t s']  final
# k ɒ n t ɹ ə p ɒ s t ə ʊ 	 ['s t']
# k ə n t ɹ ɪ s t 	 ['s t']  final
# k ɒ n v ə s e ɪ ʃ ə n ə l ɪ s t 	 ['s t']  final
# k ə n v ɪ n s t 	 ['s t']  final
# k uː t s 	 ['t s']  final
# k ɒ p i ɪ s t 	 ['s t']  final
# k ɒ p i p e ɪ s t ə 	 ['s t']
# k ɒ p i p æ s t ə 	 ['s t']
# k ɒ p i p ɑː s t ə 	 ['s t']
# k ɒ k ɛ t s 	 ['t s']  final
# k ɔː n ɪ t s i 	 ['t s']
# k ɒ s t 	 ['s t']  final
# k ɒ s t i d ʒ 	 ['s t']
# k ɒ s t l̩ 	 ['s t']
# k ɒ s t ə m ɪ ə 	 ['s t']
# k ɒ s t ə d 	 ['s t']
# k ɒ s t ɪ v 	 ['s t']
# k ɒ s t ɪ v n ə s 	 ['s t']
# k ɒ s t l i 	 ['s t']
# k ɒ s t s 	 ['s t s']  final
# k ɒ s t j uː m 	 ['s t']
# k ɒ s t ʃ uː m 	 ['s t']
# k ɒ s t j uː m ə ɹ 	 ['s t']
# k ə ʊ t ə ʊ n iː a s t ə 	 ['s t']
# k ɒ t s w ə ʊ l d 	 ['t s']
# k a ʊ n t ə ɹ ə t ɹ a k t s 	 ['t s']  final
# k a ʊ n t ə s t ɹ ə ʊ k 	 ['s t']
# k a ʊ n t s 	 ['t s']  final
# k uː ɪ s t 	 ['s t']  final
# k ɔː t s 	 ['t s']  final
# k ʌ v n̩ s t ɛ d 	 ['s t']
# k a ʊ l s t ɑː f 	 ['s t']
# k ɹ ɑː f t s p ɜː s ə n 	 ['t s']
# k ɹ æ f t s p ɜː s ə n ʃ ɪ p 	 ['t s']
# k ɹ æ f t s w ʊ m ʌ n ʃ ɪ p 	 ['t s']
# k ɹ æ p t æ s t ɪ k 	 ['s t']
# k ɹ e ɪ t s 	 ['t s']  final
# k ɹ iː s t 	 ['s t']  final
# k ɹ ɛ d ɪ t s 	 ['t s']  final
# k ɹ iː p i p e ɪ s t ə 	 ['s t']
# k ɹ iː p i p æ s t ə 	 ['s t']
# k ɹ iː p i p ɑː s t ə 	 ['s t']
# k ɹ iː m a s t ə 	 ['s t']
# k ɹ ɛ s t 	 ['s t']  final
# k ɹ ɛ s t ɪ d 	 ['s t']
# k ɹ ɛ s t f ɔː l ə n 	 ['s t']
# k ɹ ɛ s t ɪ ŋ 	 ['s t']
# k ɹ ɛ s t ɪ ŋ z 	 ['s t']
# k ɹ ɛ s t s 	 ['s t s']  final
# k ɹ ɪ k ɪ t s 	 ['t s']  final
# k ɹ ɪ m ɪ n ə l ɪ s t ɪ k 	 ['s t']
# k ɹ ɪ m ɪ n ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# k ɹ ɪ n d ʒ f ɛ s t 	 ['s t']  final
# k ɹ ɪ s t ə 	 ['s t']
# k ɹ ɪ s t a ɪ 	 ['s t']
# k ɹ ɪ s t i 	 ['s t']
# k ɹ ɒ s t 	 ['s t']  final
# k ɹ ɒ s l ɒ t s 	 ['t s']  final
# k ɹ ʌ s t 	 ['s t']  final
# k ɹ ʌ s t e ɪ ʃ ə n 	 ['s t']
# k ɹ ʌ s t e ɪ ʃ ə s 	 ['s t']
# k ɹ ʌ s t ə l 	 ['s t']
# k ɹ ʌ s t ɪ d 	 ['s t']
# k ɹ ʌ s t ɪ ŋ 	 ['s t']
# k ɹ ʌ s t ɪ ŋ z 	 ['s t']
# k ɹ ʊ s t ə ʊ s 	 ['s t']
# k ɹ ʌ s t s 	 ['s t s']  final
# k ɹ ʌ s t i 	 ['s t']
# k ɹ ɪ s t ə l 	 ['s t']
# k ɹ ɪ s t ə l a ɪ z 	 ['s t']
# k ɹ ɪ s t ə l a ɪ n 	 ['s t']
# k ɹ ɪ s t ə l a ɪ z 	 ['s t']
# k ɹ ɪ s t ə l z 	 ['s t']
# k j uː b ɪ s t 	 ['s t']  final
# t s uː d ʒ uː 	 ['t s']  initial
# k j uː l ɒ t s 	 ['t s']  final
# k ʌ l t ɪ s t 	 ['s t']  final
# k ʌ l t ɪ s t s 	 ['s t s']  final
# k ʌ l t s 	 ['t s']  final
# k ʌ m ʃ ɑ t s 	 ['t s']  final
# k ʌ n t s 	 ['t s']  final
# k ɜː s t 	 ['s t']  final
# k ɜː t s ɪ 	 ['t s']
# k ʌ s t 	 ['s t']  final
# k ʌ s t ə d 	 ['s t']
# k ʌ s t ə d iː 	 ['s t']
# k ʌ s t ə m 	 ['s t']
# k ʌ s t ə m ə ɹ i 	 ['s t']
# k ʌ s t ə m ə 	 ['s t']
# k ʌ s t ə m ə z 	 ['s t']
# k ʌ s t ə m a ɪ̯ z 	 ['s t']
# k ʌ s t ə m z 	 ['s t']
# k ʌ s t ɹ ə l 	 ['s t']
# k ʌ t s 	 ['t s']  final
# s a ɪ k l ɪ s t 	 ['s t']  final
# s ɪ m b ə l ɪ s t 	 ['s t']  final
# s ɪ s t 	 ['s t']  final
# s ɪ s t ɪ k 	 ['s t']
# s ɪ s t s 	 ['s t s']  final
# s a ɪ t ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# t s ɑː ɹ 	 ['t s']  initial
# d æ b s t ə 	 ['s t']
# d æ k ɹ ɪ ə ʊ s ɪ s t a ɪ t ɪ s 	 ['s t']
# d æ k r ɪ ə ʊ s ɪ s t ə ʊ r a ɪ n ɒ s t ə m i 	 ['s t', 's t']
# d ɑː d ɑː ɪ s t 	 ['s t']  final
# d ɑː d ɑː ɪ s t ɪ k 	 ['s t']
# d ɑː d ɑː ɪ s t ɪ k l i 	 ['s t']
# d æ ɡ ɪ s t æ n 	 ['s t']
# d æ ɡ ɪ s t ɑː n 	 ['s t']
# d æ ɡ ɪ s t æ n i 	 ['s t']
# d æ ɡ ɪ s t ɑː n i 	 ['s t']
# d æ l f ə ʊ p ɹ ɪ s t ɪ n 	 ['s t']
# d ɑː n s t 	 ['s t']  final
# d ɑː n d ɪ s t 	 ['s t']  final
# d ɑː t s 	 ['t s']  final
# d ɑː w ɪ n ɪ s t 	 ['s t']  final
# d æ s t ə d 	 ['s t']
# d ɑː s t ə d 	 ['s t']
# d æ s t ə d l i 	 ['s t']
# d ɑː s t ə d l i 	 ['s t']
# d æ t s 	 ['t s']  final
# d e ɪ t s 	 ['t s']  final
# d e ɪ l a ɪ t s 	 ['t s']  final
# d e ɪ s t ɑː 	 ['s t']
# d ɪ ə ɹ ɪ s t 	 ['s t']  final
# d iː b ɹ ɛ s t ə d 	 ['s t']
# d ɛ t s 	 ['t s']  final
# d ɪ k æ p ɪ t e ɪ t s 	 ['t s']  final
# d ɛ k ə s t a ɪ ə ɫ 	 ['s t']
# d ɪ s iː s t 	 ['s t']  final
# d iː s ɛ n t ɹ ə l ɪ s t 	 ['s t']  final
# d ɛ s ɪ m ə ʊ s ɛ k s t ə ʊ 	 ['s t']
# d ɪ s ɪ ʒ ə n ɪ s t 	 ['s t']  final
# d ɪ k l ɛ n ʃ ə n ɪ s t 	 ['s t']  final
# d ɪ k l a ɪ n ɪ s t 	 ['s t']  final
# d iː k l ʊ s t ə ɹ ɪ ŋ ɡ 	 ['s t']
# d iː k l ʌ s t ə ɹ ɪ ŋ 	 ['s t']
# d iː k ə n d ɛ n s t 	 ['s t']  final
# d iː k ə n d ʒ ɛ s t 	 ['s t']  final
# d iː k ə n d ʒ ɛ s t ə n t 	 ['s t']
# d iː k ə n d ʒ ɛ s t ɪ v 	 ['s t']
# d iː k ə n s t ɹ ʊ k t 	 ['s t']
# d iː k ə n s t ɹ ʌ k t 	 ['s t']
# d iː k ə n s t ɹ ʊ k ʃ ə n 	 ['s t']
# d iː k ə n s t ɹ ʌ k ʃ ə n 	 ['s t']
# d iː k ə n s t ɹ ʊ k ʃ ə n ɪ z ə m 	 ['s t']
# d iː k ə n s t ɹ ʌ k ʃ ə n ɪ z ə m 	 ['s t']
# d iː k ə n s t ɹ ʊ k ʃ ə n ɪ s t 	 ['s t', 's t']  final
# d iː k ə n s t ɹ ʌ k ʃ ə n ɪ s t 	 ['s t', 's t']  final
# d iː k ə n s t ɹ ʊ k t ɪ v 	 ['s t']
# d iː k ə n s t ɹ ʌ k t ɪ v 	 ['s t']
# d iː k ə n s t ɹ ʊ k t ɪ v l i 	 ['s t']
# d iː k ə n s t ɹ ʌ k t ɪ v l i 	 ['s t']
# d iː k ə n s t ɹ ʊ k t ɪ v ɪ z ə m 	 ['s t']
# d iː k ə n s t ɹ ʌ k t ɪ v ɪ z ə m 	 ['s t']
# d iː k ə n s t ɹ ʊ k t ɪ v ɪ s t 	 ['s t', 's t']  final
# d iː k ə n s t ɹ ʌ k t ɪ v ɪ s t 	 ['s t', 's t']  final
# d iː k ə n s t ɹ ʊ k t ɪ v ɪ s t ɪ k 	 ['s t', 's t']
# d iː k ə n s t ɹ ʌ k t ɪ v ɪ s t ɪ k 	 ['s t', 's t']
# d iː k ə n s t ɹ ʊ k t ə 	 ['s t']
# d iː k ə n s t ɹ ʌ k t ə ɹ 	 ['s t']
# d iː k ə n t ɛ k s t ʃ ə l a ɪ z e ɪ ʃ ə n 	 ['s t']
# d iː k ə n t ɛ k s t ʃ ə l a ɪ z 	 ['s t']
# d ɪ k ɹ iː t ɪ s t 	 ['s t']  final
# d iː k ɹ ʊ s t e ɪ ʃ ə n 	 ['s t']
# d iː k ɹ ʌ s t e ɪ ʃ ə n 	 ['s t']
# d iː k ɹ ɪ s t ə l a ɪ z e ɪ ʃ ə n 	 ['s t']
# d ɪ d ʊ k t ɪ v ɪ s t 	 ['s t']  final
# d ɪ d ʌ k t ɪ v ɪ s t 	 ['s t']  final
# d iː p ɪ s t 	 ['s t']  final
# d iː t s 	 ['t s']  final
# d ɪ f iː z ə n s t 	 ['s t']  final
# d ɪ f iː t ɪ s t 	 ['s t']  final
# d ɪ f ɛ k ʃ ə n ɪ s t 	 ['s t']  final
# d ɪ f ɛ n ɪ s t ɹ e ɪ t 	 ['s t']
# d ɪ f ɛ n ɪ s t ɹ e ɪ ʃ ə n 	 ['s t']
# d ɪ f l e ɪ ʃ ə n ɪ s t 	 ['s t']  final
# d iː f ə ʊ k ə s t 	 ['s t']  final
# d ɪ f ɒ ɹ ɪ s t 	 ['s t']  final
# d ɪ f ɒ ɹ ɪ s t e ɪ ʃ ə n 	 ['s t']
# d ɪ f ɒ ɹ ɪ s t ə d 	 ['s t']
# d iː f ɹ ɒ s t 	 ['s t']  final
# d iː f ɹ ɒ s t ə b ə ɫ 	 ['s t']
# d iː f ɹ ɒ s t ə ɹ 	 ['s t']
# d e ɪ ĭ s t 	 ['s t']  final
# d iː ĭ s t 	 ['s t']  final
# d e ɪ ɪ s t ɪ k 	 ['s t']
# d e ɪ ɪ s t ɪ k ə l 	 ['s t']
# d e ɪ ɪ s t ɪ k l i 	 ['s t']
# d e ɪ ĭ s t s 	 ['s t s']  final
# d ɪ l a ɪ t s 	 ['t s']  final
# d ə l a ɪ t s ə m 	 ['t s']
# d ɪ l a ɪ t s ə m 	 ['t s']
# d ə l a ɪ t s ə m l i 	 ['t s']
# d ɪ l a ɪ t s ə m l i 	 ['t s']
# d ə l a ɪ t s ə m n ə s 	 ['t s']
# d ɪ l a ɪ t s ə m n ə s 	 ['t s']
# d ɛ l t s 	 ['t s']  final
# d iː m ɪ s t 	 ['s t']  final
# d ɛ m ə n s t ɹ ə b l̩ 	 ['s t']
# d ɪ m ɑ n s t ɹ ə b l̩ 	 ['s t']
# d ɛ m ə n s t ɹ e ɪ t ə b l 	 ['s t']
# d ɛ m ə n s t ɹ e ɪ t 	 ['s t']
# d ɛ m ə n s t ɹ e ɪ t ɪ d 	 ['s t']
# d ɛ m ə n s t ɹ e ɪ ʃ ə n 	 ['s t']
# d ɪ m ɒ n s t ɹ ə t ɪ v 	 ['s t']
# d ɛ m ə n s t ɹ e ɪ t ə ɹ 	 ['s t']
# d iː m ɪ s t ɪ f a ɪ 	 ['s t']
# d ɛ n d ɹ ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# d ɪ n a ɪ j ə l ɪ s t 	 ['s t']  final
# d ɪ n a ʊ n s t 	 ['s t']  final
# d ɛ n t ɒ ɹ s t ə ɹ 	 ['s t']
# d ɛ n t ɪ s t 	 ['s t']  final
# d ɛ n t ɪ s t ɹ i 	 ['s t']
# d ɛ n t s 	 ['t s']  final
# d i ɒ k s ɪ s t ɹ ɛ p t ə m iː n 	 ['s t']
# d i f l ɒ d͡ʒ ɪ s t ɪ k e ɪ t 	 ['s t']
# d ɪ p ɒ z ɪ t s 	 ['t s']  final
# d ɪ p ɹ ɛ s t 	 ['s t']  final
# d iː ɹ ɛ d ʒ ɪ s t ə ɹ 	 ['s t']
# d iː ɹ ɪ s t ɹ ɪ k t 	 ['s t']
# d ɜː m ə t ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# d ɝ m æ t ə p l æ s t ɪ k 	 ['s t']
# d ɪ s ɛ n d ə n t s 	 ['t s']  final
# d ɛ z ə t s 	 ['t s']  final
# d ɪ z ɜː t s 	 ['t s']  final
# d ɪ s ɪ s t 	 ['s t']  final
# d ɪ z ɪ s t 	 ['s t']  final
# d e s k f ə s t 	 ['s t']  final
# d iː s t e ɪ b ɪ l a ɪ z 	 ['s t']
# d iː s t e ɪ b ɪ l a ɪ z 	 ['s t']
# d iː s t ɪ ɡ m ə t a ɪ z 	 ['s t']
# d ɛ s t ɪ n e ɪ ʃ ə n 	 ['s t']
# d ɛ s t ɪ n 	 ['s t']
# d ɛ s t ɪ n d 	 ['s t']
# d ɛ s t ɪ n i 	 ['s t']
# d ɛ s t ɪ t j uː t 	 ['s t']
# d ɛ s t ɪ t j uː ʃ ə n 	 ['s t']
# d ɛ s t ɪ t ʃ uː ʃ ə n 	 ['s t']
# d ɛ s t ɪ t j uː ʃ ə n z 	 ['s t']
# d ɛ s t ɪ t ʃ uː ʃ ə n z 	 ['s t']
# d ɛ s t ɹ iː e ɪ 	 ['s t']
# d ɛ s t ɹ ɪ ə 	 ['s t']
# d ɪ s t ɹ ɔ ɪ 	 ['s t']
# d ɪ s t ɹ ɔ ɪ d 	 ['s t']
# d ɪ s t ɹ ɔ ɪ j ɪ ŋ 	 ['s t']
# d ɪ s t ɹ ʌ k ʃ ə n 	 ['s t']
# d ɪ s t ɹ ʊ k t ɪ v 	 ['s t']
# d ɪ s t ɹ ʌ k t ɪ v 	 ['s t']
# d ɪ t ɜː m ɪ n ɪ s t 	 ['s t']  final
# d ɪ t ɜː m ɪ n ɪ s t ɪ k 	 ['s t']
# d ɪ t ɛ s t 	 ['s t']  final
# d j uː s t 	 ['s t']  final
# d ɛ v ə s t e ɪ t 	 ['s t']
# d ɛ v ə s t e ɪ ʃ ə n 	 ['s t']
# d iː v ə s t e ɪ v ɪ t 	 ['s t']
# d ɛ k s t ə 	 ['s t']
# d ɛ k s t ɛ ɹ ɪ t i 	 ['s t']
# d ɛ k s t ɹ ə s 	 ['s t']
# d ɛ k s t ə ɹ ə s l i 	 ['s t']
# d ɛ k s t ɹ ɪ n 	 ['s t']
# d ɛ k s t ɹ ə ʊ æ m f ɛ t ə m iː n 	 ['s t']
# d ɛ k s t ɹ ə ʊ z 	 ['s t']
# d a ɪ ə ɡ n ɒ s t ɪ k 	 ['s t']
# d a ɪ ə l ɛ k t s 	 ['t s']  final
# d a ɪ ə ɹ ɪ s t 	 ['s t']  final
# d a ɪ ə s t æ ɫ s ɪ s 	 ['s t']
# d a ɪ ə s t æ ɫ t ɪ k 	 ['s t']
# d a ɪ ə s t e ɪ z 	 ['s t']
# d a ɪ ə s t e ɪ z ɪ k 	 ['s t']
# d a ɪ ə s t e ɪ s ɪ s 	 ['s t']
# d a ɪ ə s t æ t ɪ k 	 ['s t']
# d a ɪ ə s t iː m ə 	 ['s t']
# d a ɪ ə s t ɛ ə ɹ i o ʊ s ə l ɛ k t ɪ v ɪ t i 	 ['s t']
# d a ɪ æ s t ə l i 	 ['s t']
# d a ɪ ə s t ɒ l ɪ k 	 ['s t']
# d a ɪ s t 	 ['s t']  final
# d ɪ d ɛ s t 	 ['s t']  final
# d ɪ d s t 	 ['s t']  final
# d ɪ f ɹ ə n t s 	 ['t s']  final
# d a ɪ d ʒ ə s t 	 ['s t']  final
# d a ɪ d ʒ ɛ s t 	 ['s t']  final
# d ə d ʒ ɛ s t 	 ['s t']  final
# d a ɪ d ʒ ɛ s t ə b ə ɫ 	 ['s t']
# d a ɪ d ʒ ɛ s t ɪ f 	 ['s t']
# d iː ʒ ɛ s t iː f 	 ['s t']
# d a ɪ d ʒ ɛ s t ʃ ə n 	 ['s t']
# d ɨ d ʒ ɛ s t ʃ ə n 	 ['s t']
# d a ɪ d ʒ ɛ s t ɪ v 	 ['s t']
# d ɪ m ɪ s t 	 ['s t']  final
# d a ɪ iː s t ɹ ə s 	 ['s t']
# d ɪ p s t ɪ k 	 ['s t']
# d ɪ ɹ ɛ m p t s 	 ['t s']  final
# d ɪ ɹ ɪ ʒ ɪ s t 	 ['s t']  final
# d ɪ s e ɪ b l ɪ s t 	 ['s t']  final
# d ɪ z ɑː s t ə ɹ 	 ['s t']
# d ɪ z ɑː s t ɹ ə s 	 ['s t']
# d ɪ s t ʃ ɑː d ʒ d 	 ['s t']
# d ɪ s k ʌ s t 	 ['s t']  final
# d ɪ s ɪ s t æ b l ɪ ʃ 	 ['s t']
# d ɪ s ɪ s t æ b l ɪ ʃ m ə n t 	 ['s t']
# d ɪ s ə s t iː m 	 ['s t']
# d ɪ s ɡ ʌ s t 	 ['s t']  final
# d ɪ s ɡ ʌ s t ɪ d 	 ['s t']
# d ɪ s k ʌ s t ɪ ŋ 	 ['s t']
# d ɪ s ɡ ʌ s t ɪ ŋ 	 ['s t']
# d ɪ s ɒ n ɪ s t 	 ['s t']  final
# d ɪ s ɒ n ɪ s t ɪ 	 ['s t']
# d ɪ s ɪ n t ɹ ɛ s t 	 ['s t']  final
# d ɪ s ɪ n t ə ɹ ɛ s t ɪ d 	 ['s t']
# d ɪ s ɪ n t ə ɹ ɛ s t ɪ d l i 	 ['s t']
# d ɪ s m ɪ s t 	 ['s t']  final
# d ɪ s p æ ɹ ə d a ɪ s t 	 ['s t']  final
# d ɪ s p ɜː s t 	 ['s t']  final
# d ɪ s s æ t ɪ s f æ k ʃ ə n 	 ['s s']
# d ɪ s s æ t ɪ s f a ɪ d 	 ['s s']
# d ɪ s s æ t ɪ s f a ɪ 	 ['s s']
# d ɪ s t 	 ['s t']  final
# d ɪ s s ɜː v ɪ s 	 ['s s']
# d ɪ s t ɑː f 	 ['s t']
# d ɪ s t ə l 	 ['s t']
# d ɪ s t ɪ n s 	 ['s t']
# d ɪ s t ə n t 	 ['s t']
# d ɪ s t e ɪ s t 	 ['s t', 's t']  final
# d ɪ s t e ɪ s t f ə ɫ 	 ['s t', 's t']
# d ɪ s t æ k s i 	 ['s t']
# d ɪ s t ɛ m p ə ɹ 	 ['s t']
# d ɪ s t ɛ m p ə ɹ ə t j ʊ ə 	 ['s t']
# d ɪ s t ɛ m p ə d 	 ['s t']
# d ɪ s t ɛ n d 	 ['s t']
# d ɪ s t ɛ n d ɪ d 	 ['s t']
# d ɪ s t ɛ n ʃ ə n 	 ['s t']
# d ɪ s t ɛ n ʃ ə n 	 ['s t']
# d ɪ s t ɪ l ə t 	 ['s t']
# d ɪ s t ɪ l e ɪ ʃ ə n 	 ['s t']
# d ɪ s t ɪ l d 	 ['s t']
# d ɪ s t ɪ l ə ɹ i 	 ['s t']
# d ɪ s t ɪ l m ə n t 	 ['s t']
# d ɪ s t ɪ ŋ k t 	 ['s t']
# d ɪ s t ɪ ŋ k ʃ ə n 	 ['s t']
# d ɪ s t ɪ ŋ k t ɪ v 	 ['s t']
# d ɪ s t ɪ ŋ k t ɪ v n ɪ s 	 ['s t']
# d ɪ s t ɪ ŋ k t l i 	 ['s t']
# d ɪ s t æ ŋ ɡ e ɪ 	 ['s t']
# d ɪ s t ɪ ŋ ɡ w ɪ ʃ 	 ['s t']
# d ɪ s t ɪ ŋ ɡ w ɪ ʃ ə b l̩ 	 ['s t']
# d ɪ s t ɪ ŋ ɡ w ɪ ʃ t 	 ['s t']
# d ɪ s t ɪ ŋ ɡ w ɪ ʃ m ə n t 	 ['s t']
# d ɪ s t ɔː t 	 ['s t']
# d ɪ s t ɔː t ɪ d 	 ['s t']
# d ɪ s t ɔː ʃ ə n 	 ['s t']
# d ɪ s t ɹ æ k t 	 ['s t']
# d ɪ s t ɹ æ k ʃ ə n 	 ['s t']
# d ɪ s t ɹ e ɪ n 	 ['s t']
# d ɪ s t ɹ e ɪ 	 ['s t']
# d ɪ s t ɹ ɔː t 	 ['s t']
# d ɪ s t ɹ ɛ s 	 ['s t']
# d ɪ s t ɹ ɛ s t 	 ['s t', 's t']  final
# d ɪ s t ɹ ɛ s ɪ ŋ 	 ['s t']
# d ɨ s t ɹ ɪ b j uː t 	 ['s t']
# d ɪ s t ɹ ɨ b j uː t 	 ['s t']
# d ɪ s t ɹ ɪ b j u t ɪ d 	 ['s t']
# d ɪ s t ɹ ɪ b j u t ɪ ŋ 	 ['s t']
# d ɪ s t ɹ ə b j uː ʃ ə n 	 ['s t']
# d ɪ s t ɹ ɪ k t 	 ['s t']
# d ɪ s t ɹ ɪ k t s 	 ['s t', 't s']  final
# d ɪ s t ɹ ə ʊ 	 ['s t']
# d ɪ s t ɹ ʌ s t 	 ['s t', 's t']  final
# d ɪ s t ɜː b 	 ['s t']
# d ɪ s t ɜː b n̩ s 	 ['s t']
# d ɪ s t ɜː b d 	 ['s t']
# d ɪ s t ɜː b ɪ ŋ 	 ['s t']
# d ɪ t s 	 ['t s']  final
# d ɪ t s i 	 ['t s']
# d a ɪ v ɛ s t 	 ['s t']  final
# d ɪ v ɛ s t 	 ['s t']  final
# d a ɪ v ɛ s t m ə n t 	 ['s t']
# d ɒ k j ʊ m ə n t s 	 ['t s']  final
# d ɒ k j ʊ m ɛ n t s 	 ['t s']  final
# d o ʊ l ə m a ɪ t s 	 ['t s']  final
# d ɒ l ə m a ɪ t s 	 ['t s']  final
# d o ʊ l t s 	 ['t s']  final
# d ə m ɛ s t ɪ k 	 ['s t']
# d ɒ n ə t ɪ s t 	 ['s t']  final
# d ə ʊ n ə t ɪ s t 	 ['s t']  final
# d ɒ n k æ s t ə ɹ 	 ['s t']
# d ʌ s t 	 ['s t']  final
# d ə ʊ t s 	 ['t s']  final
# d a ʊ t s 	 ['t s']  final
# d a ʊ n s t ɛ ə z 	 ['s t']
# d ɒ k s æ s t ɪ k 	 ['s t']
# d ɹ ɑː s t ɪ k 	 ['s t']
# d ɹ ɑː f t s 	 ['t s']  final
# d ɹ ɑː f t s m ə n 	 ['t s']
# d ɹ ɛ s t 	 ['s t']  final
# d ɹ ɪ f t s 	 ['t s']  final
# d ɹ a ɪ t s 	 ['t s']  final
# d ɹ ɒ s t æ n ə l o ʊ n 	 ['s t']
# d ɹ ʌ ɡ s t ɔː ɹ 	 ['s t']
# d ʌ b s t ɛ p 	 ['s t']
# d ʌ m p s t ɚ 	 ['s t']
# d ʊ n h w æ ŋ ɒ l ɒ d͡ʒ ɪ s t 	 ['s t']  final
# d ʊ n h w ɑ ŋ ɒ l ɒ d͡ʒ ɪ s t 	 ['s t']  final
# d ʌ n s t ə b ə l 	 ['s t']
# d ʊ ɹ æ t s o ʊ 	 ['t s']
# d ʊ ɹ ɑː t s o ʊ 	 ['t s']
# d ɝ s t 	 ['s t']  final
# d ʌ s t 	 ['s t']  final
# d ʌ s t ɪ d 	 ['s t']
# d ʌ s t i 	 ['s t']
# d ʌ s t ə 	 ['s t']
# d ʌ s t ɪ n 	 ['s t']
# d ʌ s t ɪ ŋ 	 ['s t']
# d ʌ s t ɪ ŋ z 	 ['s t']
# d ʌ s t p æ n 	 ['s t']
# d ʌ s t s 	 ['s t s']  final
# d ʌ s t s t ɔː ɹ m 	 ['s t s t']
# d ʌ s t i 	 ['s t']
# d a ɪ n æ s t 	 ['s t']  final
# d ɪ n ə s t i 	 ['s t']
# d ɪ s p l æ s t ɪ k 	 ['s t']
# d ɪ s s ɒ m n ɪ ə 	 ['s s']
# d ɪ s t ə ʊ ʃ ə 	 ['s t']
# d ɪ s t ə ʊ p ɪ i ə 	 ['s t']
# d ɪ s t ɹ ə f i 	 ['s t']
# iː ɡ l̩ s t ə ʊ n 	 ['s t']
# ɜː l i ɪ s t 	 ['s t']  final
# ɜː n ɪ s t 	 ['s t']  final
# ɜː n ɪ s t l i 	 ['s t']
# ɜː n ɪ s t n ə s 	 ['s t']
# iː s t 	 ['s t']  final
# iː s t b ɔː ɹ n 	 ['s t']
# iː s t k ə t 	 ['s t']
# iː s t ə 	 ['s t']
# i s t ɚ l i 	 ['s t']
# iː s t ə n 	 ['s t']
# iː s t l i 	 ['s t']
# iː s t ə n 	 ['s t']
# iː s t ɹ æ ɪ l j ə 	 ['s t']
# iː s t w ə d 	 ['s t']
# iː s t w ʊ d 	 ['s t']
# iː t s 	 ['t s']  final
# ə k l i z i æ s t ɪ k 	 ['s t']
# ə k l iː z i æ s t ɪ k ə l 	 ['s t']
# ɛ k d ɪ z i æ s t 	 ['s t']  final
# iː k ɒ n ə m ɪ s t 	 ['s t']  final
# iː k ə ʊ s ɪ s t ə m 	 ['s t']
# ɛ k f ɹ æ s t ɪ k 	 ['s t']
# ɛ k s t ə s i 	 ['s t']
# ɛ k s t æ t ɪ k 	 ['s t']
# ɛ k s t æ t ɪ k ə 	 ['s t']
# ɛ d ɪ t s 	 ['t s']  final
# ɪ f ɛ k t s 	 ['t s']  final
# ɛ f l ə ɹ ɛ s t 	 ['s t']  final
# ɛ f ə t s 	 ['t s']  final
# iː d ʒ ɛ s t 	 ['s t']  final
# iː d͡ʒ ɛ s t͡ʃ ə n 	 ['s t']
# a ɪ n s t a ɪ n 	 ['s t']
# a ɪ n s t a ɪ n ɪ ə n 	 ['s t']
# e ɪ s t e ð v ɒ d 	 ['s t']
# iː s t e ð v ɒ d 	 ['s t']
# ə s t ɛ d f ə d 	 ['s t']
# æ ɪ s t ɛ ð f ə d s 	 ['s t']
# ɛ k f ɹ æ s t ɪ k 	 ['s t']
# ɛ k s t ə s ɪ s 	 ['s t']
# i l æ s t ɪ k 	 ['s t']
# ə l æ s t ɪ k 	 ['s t']
# ɪ l æ s t ɪ s ɪ t i 	 ['s t']
# ɛ l d ɪ s t 	 ['s t']  final
# e l ɪ m ə n t s 	 ['t s']  final
# e l ɪ f ə n t s 	 ['t s']  final
# ɛ l ɡ ɪ n ɪ s t 	 ['s t']  final
# ɛ l t s 	 ['t s']  final
# ɪ m æ n s ɪ p e ɪ t ɪ s t 	 ['s t']  final
# ɪ m æ n s ɪ p ɪ s t 	 ['s t']  final
# ɛ m b ɹ e ɪ s t 	 ['s t']  final
# ɪ m b ɹ e ɪ s t 	 ['s t']  final
# ɛ n k o ʊ m i æ s t ɪ k 	 ['s t']
# ɛ n s ɪ s t 	 ['s t']  final
# ɪ n s ɪ s t 	 ['s t']  final
# ɛ n s ɪ s t ɪ d 	 ['s t']
# ɛ n d ə ʊ k ɹ ɪ n ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# ɛ n d ɒ s t ɪː ə m 	 ['s t']
# ɪ n f ɔː s t 	 ['s t']  final
# ɪ ŋ ɡ ɹ æ f t s 	 ['t s']  final
# ɪ ŋ ɡ ɹ ɑː f t s 	 ['t s']  final
# ɛ n h a ɪ p ə s t e ɪ s ɪ ə 	 ['s t']
# ɛ n h a ɪ p ə s t e ɪ ʒ ə 	 ['s t']
# ɛ n h a ɪ p ə s t e ɪ s ɪ s 	 ['s t']
# ɛ n ɪ ɡ m æ t ɪ s t 	 ['s t']  final
# ɛ n i ə s t a ɪ l 	 ['s t']
# ɛ n s t ɹ e ɪ t ə̆ n 	 ['s t']
# ɛ n s t ɹ ɛ ŋ θ ə̆ n 	 ['s t']
# ɛ n t ɛ k s t j ʊ æ l a ɪ z e ɪ ʃ ʌ n 	 ['s t']
# ɪ n θ j uː z ɪ æ s t ɪ k 	 ['s t']
# ɛ n t ɹ æ n s t 	 ['s t']  final
# ɪ n t ɹ ʌ s t 	 ['s t']  final
# ɪ n t ɹ ʌ s t ɪ d 	 ['s t']
# ɪ p ɪ s t ə s ɪ s 	 ['s t']
# ɛ p ɪ s t æ k s ɪ s 	 ['s t']
# ɛ p ɪ s t iː m a ɪ 	 ['s t']
# ɛ p ɪ s t iː m i 	 ['s t']
# ɛ p ə s t i m ɪ k 	 ['s t']
# ɪ p ɪ s t ə m ə l ɒ d͡ʒ ɪ k ə l 	 ['s t']
# ɪ p ɪ s t ə m ɒ l ə d ʒ i 	 ['s t']
# ɪ p ɪ s t ə l ə ɹ i 	 ['s t']
# ə p ɪ t ə m ɪ s t ɪ k 	 ['s t']
# ɛ p s t a ɪ n 	 ['s t']
# ɛ p s t iː n 	 ['s t']
# ɛ ɹ æ s t a ɪ 	 ['s t']
# ɛ ɹ æ s t e ɪ s 	 ['s t']
# ɪ ɹ a s t ɪ ə n 	 ['s t']
# ɜː ɹ n ɪ s t 	 ['s t']  final
# ɛ ə z æ t s 	 ['t s']  final
# ɜː s æ t s 	 ['t s']  final
# ɜː s t 	 ['s t']  final
# ɜː ɹ s t w a ɪ l 	 ['s t']
# ɛ s k ə p ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# ə s t͡ʃ iː t 	 ['s t']
# ɛ s t͡ʃ iː t m ə n t 	 ['s t']
# ɪ s t͡ʃ iː t m ə n t 	 ['s t']
# ɛ s t ʃ uː 	 ['s t']
# ɪ s t ʃ uː 	 ['s t']
# ɛ s ɛ m p l æ s t ɪ k 	 ['s t']
# ɪ s ɒ f ə ɡ ə ʊ ɡ a s t ɹ ə ʊ d j uː ə ʊ d ɪ n ɒ s k ə p i 	 ['s t']
# ɛ s t 	 ['s t']  final
# ɪ s t æ b l ɪ ʃ 	 ['s t']
# ɪ s t æ b l ɪ ʃ t 	 ['s t']
# ɪ s t æ b l ɪ ʃ ɪ ŋ 	 ['s t']
# ɪ s t æ b l ɪ ʃ m ə n t 	 ['s t']
# ɛ s t æ m ɪ n e ɪ 	 ['s t']
# ɪ s t e ɪ t 	 ['s t']
# ɪ s t e ɪ t ɪ d 	 ['s t']
# ɪ s t e ɪ t s 	 ['s t', 't s']  final
# ɪ s t iː m d 	 ['s t']
# ɛ s t ə 	 ['s t']
# ɛ s t i z 	 ['s t']
# ɛ s t ə 	 ['s t']
# ɛ̝ s t aː 	 ['s t']
# ɛ s t ə ʊ n i ə 	 ['s t']
# ɛ s t ɨ m e ɪ̪ t 	 ['s t']
# ɛ s t ɨ m ɨ t 	 ['s t']
# ɛ s t ɪ m e ɪ ʃ ə n 	 ['s t']
# ɛ s t ɪ m e ɪ t ɪ v 	 ['s t']
# ɛ s t ɪ m ə t ɪ v 	 ['s t']
# ɛ s t ɪ v e ɪ t 	 ['s t']
# ɪ s t ɔ ɪ l 	 ['s t']
# ɛ s t ə ʊ n i ə 	 ['s t']
# ɪ s t ɒ p 	 ['s t']
# ɪ s t ɹ ɑː d 	 ['s t']
# iː s t ɹ ə d a ɪ ɒ l 	 ['s t']
# ə s t ɹ e ɪ n d ʒ 	 ['s t']
# ɪ s t ɹ e ɪ n d ʒ 	 ['s t']
# ə s t ɹ e ɪ 	 ['s t']
# iː s t ɹ ə d͡ʒ ə n 	 ['s t']
# ɛ θ ɪ s ɪ s t 	 ['s t']  final
# iː θ ɒ s t 	 ['s t']  final
# j uː k ə t æ s t ɹ ə f i 	 ['s t']
# j uː k ə ɹ ɪ s t 	 ['s t']  final
# j uː k ɹ ɪ s t 	 ['s t']  final
# j uː d ʒ ɛ n ɪ s t 	 ['s t']  final
# j u k æ ɹ i ə t s 	 ['t s']  final
# j u k æ ɹ i ə ʊ t s 	 ['t s']  final
# j uː s t ɪ s 	 ['s t']
# j uː s t e ɪ k i ə n 	 ['s t']
# j uː s t e ɪ ʃ ə n 	 ['s t']
# j u s t ə s i 	 ['s t']
# j uː s t ə s i 	 ['s t']
# j uː s t ə n 	 ['s t']
# j uː s t ɹ ɛ s 	 ['s t']
# ɛ k s t ə n 	 ['s t']
# ...
# s t a ɪ l ɪ s t 	 ['s t', 's t']  initial    final
# s t a ɪ l ɪ s t ɪ k 	 ['s t', 's t']  initial
# s t ʌ ɪ l ʌ ɪ t 	 ['s t']  initial
# s t a ɪ l a ɪ t iː z 	 ['s t']  initial
# s t ʌ ɪ l ʌ ɪ t iː z 	 ['s t']  initial
# s t ʌ ɪ l ʌ ɪ t s 	 ['s t', 't s']  initial    final
# s t a ɪ l ə f ə ʊ n 	 ['s t']  initial
# s t a ɪ l ə s 	 ['s t']  initial
# s t a ɪ m i 	 ['s t']  initial
# s t ɪ p t ɪ k 	 ['s t']  initial
# s t a ɪ ð 	 ['s t']  initial
# s t ɪ k s 	 ['s t']  initial
# s t ɜː d 	 ['s t']  initial
# s ʌ b k ə m m ɪ t t i 	 ['t t']
# s ʌ b d ʒ ɛ k t s 	 ['t s']  final
# s ʌ b p ɛ ɹ i ɒ s t ɪ ə l 	 ['s t']
# s ə b s ɪ s t 	 ['s t']  final
# s ə b s ɪ s t ə n s 	 ['s t']
# s ʌ b s t æ n d ə d 	 ['s t']
# s ə b s t æ n ʃ ə l 	 ['s t']
# s ə b s t a n ʃ ɪ e ɪ t 	 ['s t']
# s ʌ b s t ɪ t j u t 	 ['s t']
# s ʌ b s t ɪ t u t 	 ['s t']
# s ʌ b s t ɪ t j uː t ɪ d 	 ['s t']
# s ʌ b s t ɹ e ɪ t 	 ['s t']
# s ʌ k t æ s t ɪ k 	 ['s t']
# s ə d ʒ ɛ s t 	 ['s t']  final
# s ə d ʒ ɛ s t ɪ d 	 ['s t']
# s ə d͡ʒ ɛ s t j ə n 	 ['s t']
# s ə d͡ʒ ɛ s t j ə n z 	 ['s t']
# s ə ɡ d͡ʒ ɛ s t ɪ v 	 ['s t']
# s ə d ʒ ɛ s t s 	 ['s t s']  final
# s j uː t s 	 ['t s']  final
# s uː t s 	 ['t s']  final
# s ʌ n s t ɛ d 	 ['s t']
# s uː p ə k æ l ɨ f ɹ æ d ʒ ɨ l ɪ s t ɪ k 	 ['s t']
# s uː p ə k æ l ɨ f ɹ æ d ʒ ɨ l ɪ s t ɪ k ɛ k s p ɪ æ l ɨ d ə ʊ ʃ ə s 	 ['s t']
# s u p ɚ f æ s t 	 ['s t']  final
# s j u p ə ɹ s t ɪ ʃ n̩ 	 ['s t']
# s j uː p ə ɹ s t ɪ ʃ ə n 	 ['s t']
# s j uː p ə s t ɪ ʃ ə s 	 ['s t']
# s ə p ɹ ɛ s t 	 ['s t']  final
# s uː p ɹ ə s t ɜː n ə l 	 ['s t']
# s ə ɹ iː ə l ɪ s t ɪ k 	 ['s t']
# s ə s t e ɪ n 	 ['s t']
# s ə s t e ɪ n ə b ɪ l ɪ t i 	 ['s t']
# s ə s t e ɪ n ə b ə l 	 ['s t']
# s ə s t e ɪ n d 	 ['s t']
# s ʌ s t ə n ə n s 	 ['s t']
# s ʌ s t ɛ n t a k j ʊ l ə m 	 ['s t']
# s w ɔ ɹ t s a ɪ t 	 ['t s']
# s w ɒ s t ə k ə 	 ['s t']
# s w ɒ s t ɪ k ə 	 ['s t']
# s w ɛ t s 	 ['t s']  final
# s w iː t ə s t 	 ['s t']  final
# s w ɪ t s ə l ə n d 	 ['t s']
# s ɪ l v ɛ s t ɚ 	 ['s t']
# s ɪ ŋ k ɹ ə t ɪ s t ɪ k 	 ['s t']
# s ɪ n ɛ s t ɪ ə 	 ['s t']
# s ɪ n ə d ɪ s t 	 ['s t']  final
# s ɪ n θ ɪ s ɪ s t 	 ['s t']  final
# s ɪ s t ə m 	 ['s t']
# s ɪ s t ə m æ t ɪ k 	 ['s t']
# s ɪ s t ə m ə t a ɪ z 	 ['s t']
# s ɪ s t ə m z 	 ['s t']
# s ɪ s t ə l i 	 ['s t']
# t æ l ə n t s 	 ['t s']  final
# t ɔː l ɪ s t 	 ['s t']  final
# t æ n ɪ s t 	 ['s t']  final
# t æ n ɪ s t ɹ i 	 ['s t']
# t æ p ə s t ɹ i 	 ['s t']
# t e ɪ p ɪ s t 	 ['s t']  final
# t e ɪ s t 	 ['s t']  final
# t e ɪ s t ɪ d 	 ['s t']
# t e ɪ s t f ə l 	 ['s t']
# t e ɪ s t ɚ 	 ['s t']
# t e ɪ s t͡s 	 ['s t']
# t e ɪ s t ɪ ŋ 	 ['s t']
# t e ɪ s t i 	 ['s t']
# t ɪ ə s t e ɪ n 	 ['s t']
# t ɛ k n ɒ l ə d͡ʒ ɪ s t 	 ['s t']  final
# t ə l ɛ s t͡ʃ ə l 	 ['s t']
# t ɛ l ɛ s t ɪ k 	 ['s t']
# t ɛ l ɪ v æ n d ʒ ə l ɪ s t 	 ['s t']  final
# t ɛ m p ə s t 	 ['s t']  final
# t ɛ n t s 	 ['t s']  final
# t ɜː m a ɪ t s 	 ['t s']  final
# t ə ɹ ɛ s t ɹ i ə l 	 ['s t']
# t ə ɹ ɛ s t ɹ i ə s 	 ['s t']
# t ɛ ɹ ə ɹ ɪ s t 	 ['s t']  final
# t ɛ s t 	 ['s t']  final
# t ɛ s t e ɪ ʃ ə s 	 ['s t']
# t ɛ s t ə m ə n t 	 ['s t']
# t ɛ s t e ɪ t ɹ ɪ s iː z 	 ['s t']
# t ɛ s t e ɪ t ɹ ɪ k s 	 ['s t']
# t ɛ s t k ɹ ɒ s 	 ['s t']
# t ɛ s t ə 	 ['s t']
# t ɛ s t ɪ k ə l 	 ['s t']
# t ɛ s t ɪ k j ə l ə 	 ['s t']
# t ɛ s t ɪ k j ə l ɚ 	 ['s t']
# t ɛ s t ɪ f a ɪ 	 ['s t']
# t ɛ s t ɪ m ə n i 	 ['s t']
# t ɛ s t ɪ ŋ 	 ['s t']
# t ɛ s t ɪ ŋ z 	 ['s t']
# t ɛ s t ɒ s t ə ɹ ə ʊ n 	 ['s t', 's t']
# t ɛ s t s 	 ['s t s']  final
# t ɛ s t i 	 ['s t']
# t ɛ t ɹ ə h a ɪ d ɹ ə ʊ d ʒ ɛ s t ɹ ɪ n ə ʊ n 	 ['s t']
# t ɛ t ɹ ə s t ɪ k 	 ['s t']
# t ɛ t ɹ a s t ə w ä n 	 ['s t']
# t ɛ t ɹ ə s t o ä n 	 ['s t']
# t ɛ t ɹ ə θ i ɪ s t 	 ['s t']  final
# t ɛ k s t 	 ['s t']  final
# t ɛ k s t 	 ['s t']  final
# t ɛ k s t b ʊ k 	 ['s t']
# t ɛ k s t ɪ d 	 ['s t']
# t ɛ k s t a ɪ l 	 ['s t']
# t ɛ k s t s 	 ['s t s']  final
# t ɛ k s t s p i k 	 ['s t s']
# t ɛ k s t j u ə l 	 ['s t']
# ð æ t s 	 ['t s']  final
# θ iː ɪ s t 	 ['s t']  final
# θ i ɪ s t ɪ k 	 ['s t']
# θ i ɪ s t s 	 ['s t s']  final
# θ ɛ m ɪ s t ɪ ə s 	 ['s t']
# θ ɪ m ɪ s t ɪ ə s 	 ['s t']
# θ i ɑ m æ k ɪ s t 	 ['s t']  final
# θ ɪ ə p n j uː s t 	 ['s t']  final
# θ ɪ ə ɹ ɪ s t 	 ['s t']  final
# θ ɜː ɹ m ʊ ə k ɑː ɹ s t 	 ['s t']  final
# θ ə ɹ m ɒ l ə d͡ʒ ɪ s t 	 ['s t']  final
# θ ɪ n ə s t 	 ['s t']  final
# θ ɜː s t 	 ['s t']  final
# θ ɜː ɹ s t i 	 ['s t']
# ð a ʊ t s t 	 ['t s t']  final
# ð a ʊ s t 	 ['s t']  final
# θ ɔː t s 	 ['t s']  final
# θ ɹ ɛ t s 	 ['t s']  final
# θ ɹ ɒ m b ə ʊ b l æ s t 	 ['s t']  final
# θ ɹ ʌ s t 	 ['s t']  final
# θ ɹ ʌ s t s 	 ['s t s']  final
# θ ʌ n d ɚ b l æ s t 	 ['s t']  final
# θ ʌ n d ə ɹ s t ɔː ɹ m 	 ['s t']
# θ ʌ n ə ɹ s t ɔː ɹ m 	 ['s t']
# θ ʌ n d ə ɹ s t ɹ ɪ k ə n 	 ['s t']
# θ ʌ n d ə s t ɹ ʌ k 	 ['s t']
# t ɪ k ɪ t s 	 ['t s']  final
# t a ɪ t s 	 ['t s']  final
# t a ɪ m s t æ m p 	 ['s t']
# t a ɪ m ə n ɪ s t 	 ['s t']  final
# t ɪ t s 	 ['t s']  final
# t ə ʊ d s t uː l 	 ['s t']
# t ə ʊ s t 	 ['s t']  final
# t ə ʊ s t ə 	 ['s t']
# t ə ʊ s t ɪ n ə s 	 ['s t']
# t ə ʊ k ə n ɪ s t 	 ['s t']  final
# t uː m s t o ʊ n 	 ['s t']
# t uː m s t ə ʊ n 	 ['s t']
# t ɒ ŋ k a t s uː 	 ['t s']
# t ɒ ŋ k ɒ t s uː 	 ['t s']
# t ə ʊ n ɑ l ə d͡ʒ ɪ s t 	 ['s t']  final
# t uː θ p e ɪ s t 	 ['s t']  final
# t ə p ɒ n ɪ m ɪ s t 	 ['s t']  final
# t ɒ s t 	 ['s t']  final
# t ʊ ə ɹ ɪ s t 	 ['s t']  final
# t ɹ e ɪ t s 	 ['t s']  final
# t ɹ æ n t s ɛ n d 	 ['t s']
# t ɹ æ n t s ɛ n d ə n s 	 ['t s']
# t ɹ æ n t s ɛ n d ə n t 	 ['t s']
# t ɹ æ n z n ɪ s t ɹ i ə 	 ['s t']
# t ɹ æ n t s p æ ɹ ə n t 	 ['t s']
# t ɹ æ n t s p æ ɹ ɪ f a ɪ 	 ['t s']
# t ɹ æ n s p æ ɹ ɪ s t iː l 	 ['s t']
# t ɹ æ n z v ɛ s t a ɪ t 	 ['s t']
# t ɹ ə v ɜː s t 	 ['s t']  final
# t ɹ æ v ə s t i 	 ['s t']
# t ɹ ʌ ɪ ə l ɪ s t 	 ['s t']  final
# t ɹ a ɪ k æ s t 	 ['s t']  final
# t ɹ a ɪ k ɑː s t 	 ['s t']  final
# t ɹ a ɪ m ɛ s t ə ɹ 	 ['s t']
# t ɹ ɪ s t 	 ['s t']  final
# t ɹ ɪ s t ə n 	 ['s t']
# t ɹ ɪ s t 	 ['s t']  final
# t ɹ ɪ s t ɹ ə m 	 ['s t']
# t ɹ ɒ m b ə ʊ n ɪ s t 	 ['s t']  final
# t ɹ ɒ f ə ʊ b l ɑː s t 	 ['s t']  final
# t r ʌ s t 	 ['s t']  final
# t ɹ ʌ s t ɪ d 	 ['s t']
# t ɹ ʌ s t ɪ ŋ 	 ['s t']
# t ɹ ʌ s t s 	 ['s t s']  final
# t ɹ ʌ s t w ɜ ɹ ð ɪ l i 	 ['s t']
# t ɹ ʌ s t w ɜ ɹ ð i n ɛ s 	 ['s t']
# t ɹ ʌ s t w ɜ ɹ ð i 	 ['s t']
# t ɹ ʌ s t i 	 ['s t']
# t ɹ a ɪ s t 	 ['s t']  final
# t ɹ ɪ s t 	 ['s t']  final
# t s ɑː d e ɪ 	 ['t s']  initial
# t s ɑː d i 	 ['t s']  initial
# t s ɑː 	 ['t s']  initial
# t s ɑː ɹ d ə m 	 ['t s']  initial
# t s ɑː ɹ ɛ v n ə 	 ['t s']  initial
# t s ɑː ɹ ɪ s a ɪ d 	 ['t s']  initial
# t s a ɹ iː n ə 	 ['t s']  initial
# t s ɑː ɹ ɪ s t 	 ['t s', 's t']  initial    final
# z ɑː ɹ ɪ s t 	 ['s t']  final
# t s ɑː ɹ ɪ t s ə 	 ['t s', 't s']  initial
# z ɑː ɹ ɪ t s ə 	 ['t s']
# s ɛ t s i 	 ['t s']
# t s ɛ t s i 	 ['t s', 't s']  initial
# t ɛ t s i 	 ['t s']
# t s ɪ k uː d i ə 	 ['t s']  initial
# t s ɪ k uː ð i ə 	 ['t s']  initial
# t s ɪ p ʊ ɹ o ʊ 	 ['t s']  initial
# t s ɪ t s ɪ t 	 ['t s', 't s']  initial
# t s ɪ t s ɪ θ 	 ['t s', 't s']  initial
# t s k ɪ n v a l i 	 ['t s']  initial
# t s ɒ ŋ ɡ ə 	 ['t s']  initial
# t s ɒ t s i 	 ['t s', 't s']  initial
# t s u b ə 	 ['t s']  initial
# t s uː k ə m ɪ n ɑː ɡ e ɪ 	 ['t s']  initial
# t s uː k uː b a ɪ 	 ['t s']  initial
# t s uː n ə 	 ['t s']  initial
# t s uː n ɑː m i 	 ['t s']  initial
# t s uː n ɑː uː t ʃ i 	 ['t s']  initial
# t s uː ɹ i d ɑː ʃ i 	 ['t s']  initial
# t s uː ɹ i o ʊ t o ʊ ʃ i 	 ['t s']  initial
# t s uː ɹ ɪ s 	 ['t s']  initial
# t s ʊ ɹ ɪ s 	 ['t s']  initial
# t s uː t ɑː e ɪ z ɔː ɹ i 	 ['t s']  initial
# t s u t s u ɡ æ m uː ʃ iː 	 ['t s', 't s']  initial
# t s uː j uː h ɑː ɹ a ɪ 	 ['t s']  initial
# t s w ɑː n ə 	 ['t s']  initial
# t ʌ ŋ s t ɛ n ɪ k 	 ['s t']
# t ʌ ŋ s t ɪ k 	 ['s t']
# t ɜː k m ɛ n ɪ s t ɑː n 	 ['s t']
# t ɜː n s t a ɪ l 	 ['s t']
# t w a ɪ s t 	 ['s t']  final
# t w ɪ n s ɛ s t 	 ['s t']  final
# t w ɪ s t 	 ['s t']  final
# t w ɪ s t ɪ d 	 ['s t']
# t w ɪ s t ə ɹ 	 ['s t']
# t w ɪ s t ɪ ŋ 	 ['s t']
# t w ɪ k s t 	 ['s t']  final
# t a ɪ p k ɑː s t 	 ['s t']  final
# t ʌ ɪ p s k ɹ ɪ p t s 	 ['t s']  final
# t a ɪ p ɪ s t 	 ['s t']  final
# t ʌ ɪ p ɪ s t s 	 ['s t s']  final
# t s ɑː d iː k 	 ['t s']  initial
# t s ɑː d ə k 	 ['t s']  initial
# s æ t s ɪ k ɪ 	 ['t s']
# t s æ t s ɪ k ɪ 	 ['t s', 't s']  initial
# z æ t s ɪ k ɪ 	 ['t s']
# t s ə n iː ə t 	 ['t s']  initial
# t s ɪ ɡ ɑː n 	 ['t s']  initial
# ʊ f iː t s ɪ 	 ['t s']
# ʌ l s t ə 	 ['s t']
# ʌ l s t ə ɹ 	 ['s t']
# ʌ l s t ə ɹ ɛ t 	 ['s t']
# ʌ n æ p ə s t ɒ l ɪ k 	 ['s t']
# ʌ n ɑː t ɪ s t ɪ k 	 ['s t']
# ʌ n b ɪ n o ʊ n s t 	 ['s t']  final
# ə n b ɪ p ɪ s t 	 ['s t']  final
# ʌ n t ʃ e ɪ s t 	 ['s t']  final
# ʌ n t ʃ e ɪ s t 	 ['s t']  final
# ʌ n t ʃ a s t ɪ t i 	 ['s t']
# ʌ n k ɹ ɪ s t ɪ ə n 	 ['s t']
# ʌ n k ɹ ɪ s t ʃ ə n 	 ['s t']
# ʌ n k ɒ n s t ə n s i 	 ['s t']
# ʌ n k ə n s t ɹ ʌ k t ɪ v 	 ['s t']
# ʌ n d ɚ ɛ s t ɨ m e ɪ t 	 ['s t']
# ʌ n d ɚ ɛ s t ɨ m ə t 	 ['s t']
# ʌ n d ɚ ɛ s t ɨ m ɨ t 	 ['s t']
# ʌ n d ə s t æ n d 	 ['s t']
# ʌ n d ə s t a n d ɪ ŋ 	 ['s t']
# ʌ n d ə ɹ s t ʊ d 	 ['s t']
# ʌ n d ə ɹ s t ɔː ɹ i 	 ['s t']
# ʌ n d ə s t ʌ d i 	 ['s t']
# ʌ n d ɪ s t ɪ ŋ ɡ w ɪ ʃ ə b ə l 	 ['s t']
# ʌ n ɛ n θ j uː z i æ s t ɪ k 	 ['s t']
# ʌ n f ɛ n ɪ s t ɹ e ɪ t ɪ d 	 ['s t']
# ʌ n d ʒ ʌ s t 	 ['s t']  final
# ʌ n l a ɪ s n̩ s t 	 ['s t']  final
# ʌ n ɹ ɛ s t 	 ['s t']  final
# ʌ n s ɪ s t ɪ ŋ 	 ['s t']
# ʌ n s t e ɪ b ə ɫ 	 ['s t']
# ʌ n s t e ɪ t 	 ['s t']
# ʌ n s t ɛ d i 	 ['s t']
# ʌ n s t ɪ n t ɪ d 	 ['s t']
# ʌ n s t ɹ æ p 	 ['s t']
# ʌ n s t ɹ ɛ s t 	 ['s t', 's t']  final
# ʌ n j uː s t 	 ['s t']  final
# ʌ n w ɪ s t 	 ['s t']  final
# ə p ɐ l s t ə ɹ 	 ['s t']
# ə p ɒ l s t ə ɹ 	 ['s t']
# ʌ p h ə ʊ l s t ə ɹ ə 	 ['s t']
# ə p ɐ l s t ɹ i 	 ['s t']
# ʌ p m ɪ n s t ə 	 ['s t']
# ʌ p ə m ə ʊ s t 	 ['s t']  final
# ʌ p s t e ɪ d͡ʒ 	 ['s t']
# ʌ p s t ɛ ə z 	 ['s t']
# j ʊ ə ɹ ə n ɪ s t 	 ['s t']  final
# ɜː ɹ b e ɪ n ɪ s t 	 ['s t']  final
# j uː s t ə 	 ['s t']
# ʌ s t j ʊ l e ɪ ʃ ə n 	 ['s t']
# j u t ɪ l ɪ t ɛː ɹ i ə n ɪ s t 	 ['s t']  final
# j ʊ t ɪ l ɪ t ɛː ɹ i ə n ɪ s t 	 ['s t']  final
# ʌ t m o ʊ̯ s t 	 ['s t']  final
# ʌ t m ə ʊ̯ s t 	 ['s t']  final
# ʊ t s 	 ['t s']  final
# ʊ z b ɛ k ɪ s t ɑː n 	 ['s t']
# v ə d uː t s 	 ['t s']  final
# v ɛ ɹ i ə n t s 	 ['t s']  final
# v ɛ ə ɹ ɪ s t ə ɹ 	 ['s t']
# v ɑː s t 	 ['s t']  final
# v ɑː s t ɪ t i 	 ['s t']
# v æ s t n ə s 	 ['s t']
# v æ t s ɹ iː ɡ ɑː 	 ['t s']
# v ɛ t s ɹ iː ɡ a 	 ['t s']
# v iː h ə m ə n t s 	 ['t s']  final
# v iː ə m ə n t s 	 ['t s']  final
# f ɛ l t s k ʊ n 	 ['t s']
# v ɛ n t ɹ ɪ l ə k w ɪ s t 	 ['s t']  final
# v əː b ə l ɪ s t 	 ['s t']  final
# v ɚ b ə l i s t 	 ['s t']  final
# v ɛ ɹ i ə s t 	 ['s t']  final
# v ɛ ɹ i ɪ s t 	 ['s t']  final
# v ɜː ɹ s ə n t s 	 ['t s']  final
# v ɜː r s t 	 ['s t']  final
# v əː s t 	 ['s t']  final
# v ɜː ɹ t s 	 ['t s']  final
# v ɛ s t 	 ['s t']  final
# v ɛ s t ə 	 ['s t']
# v ɛ s t ə l 	 ['s t']
# v ɛ s t ɪ ə ɹ i 	 ['s t']
# v ɛ s t ɪ b j uː l 	 ['s t']
# v ɛ s t ɪ d͡ʒ 	 ['s t']
# v ɛ s t ɪ d ʒ ə l 	 ['s t']
# v ɛ s t ɪ d ʒ ɪ ə l 	 ['s t']
# v ɛ s t ɪ m ɛ n t ə ɹ i 	 ['s t']
# v ɛ s t i t ʃ ə 	 ['s t']
# v ɛ s t ɪ s t j ʊ ə 	 ['s t', 's t']
# v ɛ s t m ə n t 	 ['s t']
# v ɛ t s 	 ['t s']  final
# v ɛ k s t 	 ['s t']  final
# v ɛ k s ɪ l ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# v iː h ə ʊ s t 	 ['s t']  final
# v a ɪ s d ʒ ɪ ə ɹ ə n t s i 	 ['t s']
# v a ɪ s ɹ iː d ʒ ə n t s i 	 ['t s']
# v a ɪ ə l ɪ s t 	 ['s t']  final
# v i ə ʊ l ɪ s t 	 ['s t']  final
# v ɪ z ɪ t s 	 ['t s']  final
# v iː s t ə 	 ['s t']
# v ɪ s t ə 	 ['s t']
# v ɪ t ɛ l o ʊ ɪ n t ɛ s t ɪ n ə l 	 ['s t']
# f ʊ ɹ t s ɑ k 	 ['t s']
# v ʊ ɹ t s ɑ k 	 ['t s']
# f ʊ t s ɑ k 	 ['t s']
# v ʊ t s ɑ k 	 ['t s']
# v ɔ ɪ s t 	 ['s t']  final
# v ɒ l k ə n ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# v ə l k ə n ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# v ɒ l ə n t ə ɹ ɪ s t ɪ k 	 ['s t']
# v ɒ l ə n t ʊ ə ɹ ɪ s t 	 ['s t']  final
# v ə ʊ t s 	 ['t s']  final
# v ʌ l k ə n ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# w e ɪ n s k ɒ t s 	 ['t s']  final
# w e ɪ s t 	 ['s t']  final
# w e ɪ s t b æ n d 	 ['s t']
# w e ɪ s t ɪ d 	 ['s t']
# w ɒ l θ ə m s t o ʊ 	 ['s t']
# w ɔː l θ ə m s t o ʊ 	 ['s t']
# w ɔː l t s 	 ['t s']  final
# v æ n d ə l ʊ s t 	 ['s t']  final
# w ɒ n d ə l ʌ s t 	 ['s t']  final
# w ɒ n s t ɛ d 	 ['s t']
# w ɒ n t s 	 ['t s']  final
# w e ɪ s t 	 ['s t']  final
# w e ɪ s t ɪ d 	 ['s t']
# w e ɪ s t f ə l 	 ['s t']
# w e ɪ s t ɡ e ɪ t 	 ['s t']
# w e ɪ s t n ə s 	 ['s t']
# w e ɪ s t ə 	 ['s t']
# w e ɪ s t s 	 ['s t s']  final
# w e ɪ s t ɪ ŋ 	 ['s t']
# w e ɪ s t ɹ i 	 ['s t']
# w ɒ t ʃ l ɪ s t 	 ['s t']  final
# w ɒ t s ə n 	 ['t s']
# w ɛ b s t ə 	 ['s t']
# w ɛ b s t ə ɹ a ɪ t 	 ['s t']
# w e ɪ t s 	 ['t s']  final
# w ɛ l f ɛː ɹ ɪ s t 	 ['s t']  final
# v ɛ l t ʃ m ɛː t s 	 ['t s']  final
# w ɛ s t 	 ['s t']  final
# w ɛ s t b ɹ ʊ k 	 ['s t']
# w ɛ s t ə ɹ l i 	 ['s t']
# w ɛ s t ə n 	 ['s t']
# w ɛ s t ɪ ŋ h a ʊ s 	 ['s t']
# w ɛ s t m ɪ n s t ə 	 ['s t', 's t']
# w ɛ s t f e ɪ l j ə 	 ['s t']
# w ɛ s t f e ɪ l j ə n 	 ['s t']
# w ɛ s t f e ɪ l j ə n z 	 ['s t']
# w ɛ s t s a ɪ d 	 ['s t s']
# w ɛ s t w ə d 	 ['s t']
# w ɛ s t w ə d l i 	 ['s t']
# w ɛ s t w ɜː k 	 ['s t']
# w ɛ s t i 	 ['s t']
# w ɛ t s j u t 	 ['t s']
# w ɒ t s 	 ['t s']  final
# w ɒ t s ə ʊ ɛ v ə ɹ 	 ['t s']
# w ɛ t s t ə ʊ n 	 ['t s t']
# h w a ɪ l s t 	 ['s t']  final
# w a ɪ l s t 	 ['s t']  final
# w ʌ ɪ l s t 	 ['s t']  final
# w ɪ p s t ɑː f 	 ['s t']
# ʍ ɪ p s t ɑː f 	 ['s t']
# w ʌ ɪ t t͡ʃ æ p ə l 	 ['t t']
# h w a ɪ t s 	 ['t s']  final
# h w ɪ t s t ə ɹ 	 ['t s t']
# w ɪ t s t ə ɹ 	 ['t s t']
# ʍ ɪ t s ə n 	 ['t s']
# h uː m s t 	 ['s t']  final
# w a ɪ d ə s t 	 ['s t']  final
# w ɪ n t͡ʃ ɛ s t ə ɹ 	 ['s t']
# w ɪ n t͡ʃ ɪ s t ə ɹ 	 ['s t']
# w a ɪ n d s t ə 	 ['s t']
# w ɪ n ɪ ŋ ɨ s t 	 ['s t']  final
# w ɪ n s t i n 	 ['s t']
# w ɪ s t f ə l 	 ['s t']
# w ɪ ð s t æ n d 	 ['s t']
# w ɪ t n ə s t 	 ['s t']  final
# w ɪ t n ɪ s t 	 ['s t']  final
# w ɪ t s 	 ['t s']  final
# w ɪ t ɪ s ɪ s t 	 ['s t']  final
# w ɒ n t s 	 ['t s']  final
# w ə ʊ n t s 	 ['t s']  final
# w ʊ d s t ɒ k 	 ['s t']
# w ʊ s t ə ɹ 	 ['s t']
# w uː t s 	 ['t s']  final
# w ʊ s t ə 	 ['s t']
# w ʊ s t ə ɹ b ɛ ɹ i 	 ['s t']
# w ʊ s t ə ɹ ʃ ə ɹ 	 ['s t']
# w ɜː d s t ə 	 ['s t']
# w ɜː d s t ə z 	 ['s t']
# w ɜː s t 	 ['s t']  final
# w əː s t ɪ d 	 ['s t']
# w ʊ s t ɪ d 	 ['s t']
# ɹ ɛ s t 	 ['s t']  final
# ɹ ɛ s t s 	 ['s t s']  final
# ɹ ɪ s t 	 ['s t']  final
# ɹ ɪ s t b æ n d 	 ['s t']
# ɹ ɪ s t l ə t 	 ['s t']
# ɹ ɪ s t i 	 ['s t']
# ɹ a ɪ t s 	 ['t s']  final
# v ɹ ɒ t s l ɑː f 	 ['t s']
# v ɹ ɒ t s l ɑː v 	 ['t s']
# v ɹ ɒ t s w ɑː f 	 ['t s']
# v ɜː s t 	 ['s t']  final
# v ʊ ə s t 	 ['s t']  final
# w ɜː s t 	 ['s t']  final
# z ɛ n ə h ɪ s t ə ɹ i 	 ['s t']
# ʃ j o ʊ t s a ɪ 	 ['t s']
# z ɪ s t ɹ̩ 	 ['s t']
# z ɪ s t ə s 	 ['s t']
# j ɑː t s a ɪ t 	 ['t s']
# j ɔː l d h əː s t 	 ['s t']  final
# j æ ŋ t s i 	 ['t s']
# j e ɪ t s 	 ['t s']  final
# j iː s t 	 ['s t']  final
# j iː s t i 	 ['s t']
# j ɛ l ə ʊ s t ə ʊ n 	 ['s t']
# j e l t s ɪ n 	 ['t s']
# j ɛ s t ə d e ɪ 	 ['s t']
# j ɛ s t ə d e ɪ 	 ['s t']
# j ɛ s t ə d ɪ 	 ['s t']
# j ɛ s t ə j ɪ ə 	 ['s t']
# j ɛ t s 	 ['t s']  final
# j ɛ k s t 	 ['s t']  final
# j o ʊ t s e ɪ 	 ['t s']
# j ʌ ŋ ɡ ə s t 	 ['s t']  final
# j ʌ ŋ s t ə 	 ['s t']
# j ʌ m t æ s t ɪ k 	 ['s t']
# j ʌ t s 	 ['t s']  final
# z a ɪ b æ t s u 	 ['t s']
# t s ʌ ɪ t ɡ e ɪ b ə 	 ['t s']  initial
# t s a ɪ t ɡ a ɪ s t 	 ['t s', 's t']  initial    final
# z a ɪ t ɡ a ɪ s t 	 ['s t']  final
# t͡s a ɪ t ɡ a ɪ s t ɐ 	 ['s t']
# z a ɪ t ɡ a ɪ s t ə 	 ['s t']
# z ɛ m s t v a 	 ['s t']
# z ɛ m s t v ə ʊ 	 ['s t']
# t s ɛ p ə l ə 	 ['t s']  initial
# z ɛ s t 	 ['s t']  final
# z ə ʊ ɑː k iː ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# t s ɒ l f ə ɹ a ɪ n 	 ['t s']  initial
# t s ʊ̂ ŋ t s ɨ 	 ['t s', 't s']  initial
# z ə ʊ ɒ l ə d ʒ ɪ s t 	 ['s t']  final
# z o ʊ ə p l æ s t i 	 ['s t']
# z ɒ ɹ o ʊ æ s t ə ɹ 	 ['s t']
# z ɒ ɹ ə ʊ æ s t ɹ ɪ ə n 	 ['s t']
# z ɒ ɹ ə ʊ æ s t ɹ ɪ ə n ɪ z ə m 	 ['s t']
# t s ʊ k ɛ t ə ʊ 	 ['t s']  initial
# t s uː k t s v a ŋ 	 ['t s', 't s']  initial
# t s uː k t s v ɛ ŋ ə 	 ['t s', 't s']  initial
# t s v a ɪ h æ n d ɚ 	 ['t s']  initial
# t s v a ɪ h ɛ n d ɐ 	 ['t s']  initial
# t s v a ɪ h ɛ n d ɚ 	 ['t s']  initial
# t s v ɪ ŋ ɡ l i 	 ['t s']  initial
# t s v ɪ t ə ɹ a ɪ ə n 	 ['t s']  initial
# t s w ɪ t ə ɹ a ɪ ə n 	 ['t s']  initial

# %%
num_words = len(eng_words)
print((cc_count/num_words)*100, "percent of words had consonant clusters containing /s/ and/or /t/.")
print((wicc_count/num_words)*100, "percent of words had word-initial consonant clusters with /s/ and/or /t/.")
print((wfcc_count/num_words)*100, "percent of words had word-final consonant clusters with /s/ and/or /t/.")
# Out:
# 8.486987207763566 percent of words had consonant clusters containing /s/ and/or /t/.
# 1.388619320688134 percent of words had word-initial consonant clusters with /s/ and/or /t/.
# 2.6272606969563297 percent of words had word-final consonant clusters with /s/ and/or /t/.

# %%
# Now search for consonant clusters in the Arabic words you read in.
# Print out - and count - what you find.
cc_count = 0
wicc_count = 0
wfcc_count = 0
for w in ara_words:
    cc_results = re.findall(cc_RE,w)
    wicc_results = re.findall(wicc_RE,w)
    wfcc_results = re.findall(wfcc_RE,w)
    if cc_results:
        cc_count += 1
        print(w,"\t",cc_results,end="")
        if wicc_results:
            wicc_count += 1
            print ('  initial  ',end="")
        if wfcc_results:
            wfcc_count += 1
            print ('  final  ',end="")
        print()
# Out:
# ʔ a t t uː n 	 ['t t']
# ʔ u ħ a s s a n 	 ['s s']
# ʔ u ħ a s s a n a 	 ['s s']
# ʔ u ħ a s s a n u 	 ['s s']
# ʔ u ħ a s s i n 	 ['s s']
# ʔ u ħ a s s i n a 	 ['s s']
# ʔ u ħ a s s i n u 	 ['s s']
# ʔ u s t aː z 	 ['s t']
# ʔ u s t aː ð 	 ['s t']
# ʔ u s t u r aː l i j j 	 ['s t']
# ʔ u s t u r aː l i j aː 	 ['s t']
# ʔ a s tˤ u r l aː b 	 ['s t']
# ʔ u s tˤ u w aː n a h 	 ['s t']
# ʔ u s tˤ uː r a 	 ['s t']
# ʔ u s tˤ uː l 	 ['s t']
# ʔ a ɣ u s tˤ u s 	 ['s t']
# ʔ a f ɣ aː n i s t aː n 	 ['s t']
# ʔ a m a s s a 	 ['s s']
# ʔ a m a s s i 	 ['s s']
# ʔ a m a s s u 	 ['s s']
# ʔ u m a s s a 	 ['s s']
# ʔ u m a s s i 	 ['s s']
# ʔ u m a s s u 	 ['s s']
# ʔ o r k e s t r aː 	 ['s t']
# ʔ uː z b a k i s t aː n 	 ['s t']
# ʔ i s t aː d 	 ['s t']
# ʔ i s t i d j oː 	 ['s t']
# ʔ i s t uː d i j oː 	 ['s t']
# ʔ i s t oː n i j aː 	 ['s t']
# ʔ i s tˤ a b l 	 ['s t']
# i t t i ħ aː d 	 ['t t']
# i t t a dˤ a ħ a 	 ['t t']
# i t t a ʕ a d a 	 ['t t']
# i t t i h aː m 	 ['t t']
# i s t a ʔ n a f a 	 ['s t']
# i s t a b ħ a r a 	 ['s t']
# i s t a b a d d a 	 ['s t']
# i s t a d͡ʒ h a l a 	 ['s t']
# i s t a ħ sˤ a l a 	 ['s t']
# i s t a ħ w a ð a 	 ['s t']
# i s t i d ʕ aː ʔ 	 ['s t']
# i s t a d ʕ aː 	 ['s t']
# i s t a d a l l a 	 ['s t']
# i s t a r d͡ʒ a ʕ a 	 ['s t']
# i s t a dˤ aː f a 	 ['s t']
# i s t a tˤ aː r a 	 ['s t']
# i s t a ʕ aː n a 	 ['s t']
# i s t a ɣ r a q a 	 ['s t']
# i s t a ɣ f a r a 	 ['s t']
# i s t i f r aː ɣ 	 ['s t']
# i s t a f r a ɣ a 	 ['s t']
# i s t a f a z z a 	 ['s t']
# i s t a k r aː 	 ['s t']
# i s t i k ʃ aː f 	 ['s t']
# i s t a l l a 	 ['s t']
# i s t a m t a ʕ a 	 ['s t']
# i s t i m r aː r 	 ['s t']
# i s t a m s a k a 	 ['s t']
# i s t a m n aː 	 ['s t']
# i s t i n f aː d 	 ['s t']
# i s t a n k a r a 	 ['s t']
# i s t a h l a k a 	 ['s t']
# i s t a w dˤ a ħ a 	 ['s t']
# i s t a w q a f a 	 ['s t']
# a f ɣ aː n i s t aː n 	 ['s t']
# a t t͡ʃ iː k 	 ['t t']
# a s s a b t 	 ['s s']
# a s s a ʕ uː d i j j a 	 ['s s']
# a s s u ʕ uː d i j j a 	 ['s s']
# a s s u f u n 	 ['s s']
# a s s a l f aː d uː r 	 ['s s']
# a s s i n i ɣ aː l 	 ['s s']
# a s s uː d aː n 	 ['s s']
# a s s u w a j d 	 ['s s']
# b i s t i m r aː r 	 ['s t']
# b aː k i s t aː n 	 ['s t']
# b i t t a w f iː q i 	 ['t t']
# b a s s 	 ['s s']  final
# b a s s a 	 ['s s']
# b u s t aː n 	 ['s t']
# b l a s t iː k 	 ['s t']
# b l a s t iː k i j j 	 ['s t']
# t a ʔ a s s a f a 	 ['s s']
# t u r k u m aː n i s t aː n 	 ['s t']
# d͡ʒ u n d u b aː d a s t a r 	 ['s t']
# ħ a s s aː s i j j 	 ['s s']
# ħ a s s a n n aː 	 ['s s']
# d u s t uː r 	 ['s t']
# d u s t uː r i j j 	 ['s t']
# r u s t aː q 	 ['s t']
# s i t t a 	 ['t t']
# s i t t uː n a 	 ['t t']
# tˤ aː d͡ʒ iː k i s t aː n 	 ['s t']
# ʕ a s s aː l 	 ['s s']
# ɣ a s s aː l a 	 ['s s']
# f a t t aː ħ a 	 ['t t']
# f a t t a 	 ['t t']
# f a t t aː t 	 ['t t']
# f a t t a ʃ a 	 ['t t']
# f a s s a ħ a 	 ['s s']
# f a l a s tˤ iː n 	 ['s t']
# f i l a s tˤ iː n 	 ['s t']
# q aː z aː q i s t aː n 	 ['s t']
# q a t t a l a 	 ['t t']
# q a r a s tˤ uː n 	 ['s t']
# q i s tˤ aː s 	 ['s t']
# q u s tˤ aː s 	 ['s t']
# q a s tˤ a r aː n 	 ['s t']
# q a s s a m a 	 ['s s']
# q i s s iː s 	 ['s s']
# q i r ɣ i z i s t aː n 	 ['s t']
# k aː z aː x i s t aː n 	 ['s t']
# k aː z a x i s t aː n 	 ['s t']
# k u t t aː b 	 ['t t']
# k a t t aː n 	 ['t t']
# k a t t a b a 	 ['t t']
# k a s t a d͡ʒ 	 ['s t']
# k a s t i d͡ʒ 	 ['s t']
# k u s t a d͡ʒ 	 ['s t']
# k u s t iː d͡ʒ 	 ['s t']
# k o s t a r iː k aː 	 ['s t']
# m u ʔ a s s a s 	 ['s s']
# m u ʔ a s s i s 	 ['s s']
# m u ʔ a s s a s a 	 ['s s']
# m u ʔ a s s i s a 	 ['s s']
# m u t t a ħ i d 	 ['t t']
# m u t t a sˤ i l 	 ['t t']
# m u t a w a s s i tˤ 	 ['s s']
# m a t t aː 	 ['t t']
# m u d͡ʒ a s s a m a 	 ['s s']
# m i ħ a s s a 	 ['s s']
# m u ħ a s s a n 	 ['s s']
# m u ħ a s s i n 	 ['s s']
# m a s s aː ħ a 	 ['s s']
# m u s t a d iː r 	 ['s t']
# m u s t a ʃ f a n 	 ['s t']
# m u s t a f r a ɣ 	 ['s t']
# m u s t a f r i ɣ 	 ['s t']
# m u s t a q iː m 	 ['s t']
# m u s t a n q a ʕ 	 ['s t']
# m u s t a w sˤ a f 	 ['s t']
# m a s s a ħ a 	 ['s s']
# m a s s a d a 	 ['s s']
# m i s tˤ aː r 	 ['s t']
# m u s tˤ aː r 	 ['s t']
# m i s tˤ a r a 	 ['s t']
# m u f a t t a ʃ 	 ['t t']
# m u f a t t i ʃ 	 ['t t']
# m u k a s s a r aː t 	 ['s s']
# m u m aː s s 	 ['s s']  final
# m u m a s s a ħ 	 ['s s']
# m u m a s s i ħ 	 ['s s']
# n a s s aː b 	 ['s s']
# n a s t a ʕ l iː q 	 ['s t']
# w a s tˤ 	 ['s t']

# %%
num_words = len(ara_words)
print((cc_count/num_words)*100, "percent of words had consonant clusters containing /s/ and/or /t/.")
print((wicc_count/num_words)*100, "percent of words had word-initial consonant clusters with /s/ and/or /t/.")
print((wfcc_count/num_words)*100, "percent of words had word-final consonant clusters with /s/ and/or /t/.")
# Out:
# 3.0374289633548894 percent of words had consonant clusters containing /s/ and/or /t/.
# 0.0 percent of words had word-initial consonant clusters with /s/ and/or /t/.
# 0.03919263178522438 percent of words had word-final consonant clusters with /s/ and/or /t/.

# %% [markdown]
# # Observations
#
# - Consonant clusters containing /s/ and/or /t/ are more common in English than in Arabic, overall.
# - Arabic has no such clusters word-initially - and many of the clusters it does have are actually gemination.

# %% [markdown]
# # Directions for possible extensions (optional)
#
# - Look for clusters involving more consonants in each language - or any consonants in the language.
# - Some phonemes have representations that are more than one character long - this is the reason the Wikipron pronunciations are presented in space-separated form, to clarify phoneme segmentation.  I have avoided searching for such multi-character phonemes in this homework, to keep things simple, but if you would like to extend this to tackle such phonemes as well, you will need to represent each phoneme as a *string* rather than as a character, and you will need to search for 2 or more consecutive instances of such strings.
# - Do the same thing for other languages.  E.g. [PHOIBLE](https://phoible.org/) has phoneme inventories for many languages - you would need to first download the data and then get it in the format of the existing English and Arabic data.
