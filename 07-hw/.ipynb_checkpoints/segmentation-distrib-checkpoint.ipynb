# %% [markdown]
# # Word segmentation in child-directed speech
#
# In this homework we will bring together, and extend, two things we have worked on before: (1) child-directed speech, and (2) phoneme transition probabilities.
#
# Specifically, we will explore phoneme transition probabilities as a possible cue for word segmentation in child-directed speech, following the reading by Hockema 2006.
#
# As in an earlier homework, we will rely on data from the Adam section of the Brown corpus in the [CHILDES dataset](https://childes.talkbank.org/).  We focus specifically on the last transcript, when Adam was oldest, to get relatively complex child-directed speech.  Hockema used all of the corpora in the US English portion of CHILDES, so we are examining a very small portion of the overall dataset he considered.
#
# As in a different earlier homework, we will rely on data from [Wikipron](https://github.com/kylebgorman/wikipron) to get phoneme-level representations of word pronunciations.  We use US English pronunciation, to match the child data from CHILDES.
#
# Please feel free, and even warmly invited, to extend this to any language for which you can find matching data in CHILDES and Wikipron!

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# ### Read in CHILDES data
#
# This is mostly copy-and-paste from an earlier homework.  Use an XML parser, to avoid tears!  The one difference is that here we are interested in mother's speech only, not child's.

# %%
fname = 'data/adam-050212.xml' # last adam file

# %%
# read in and traverse the entire XML tree, pull out utterances, store in a pandas df, and keep only 
# utterances produced by the mother, i.e. MOT.
# that df will be called mdf, for mother df.

# YOUR CODE GOES HERE.

tree = ET.parse(fname)
root = tree.getroot()

d = {'Who': [], 'Utt': []}

th = "{http://www.talkbank.org/ns/talkbank}"   # th = tag header
for utt in root.iter(th+'u'):  # 'u' = tag for utterance
    who = utt.attrib['who']
    d['Who'].append(who)
    ll = []
    for word in utt.findall(th+'w'):
        if word.text != None:  # ignore null words, of which there are some
            ll.append(word.text)
    d['Utt'].append(ll)
    
mdf = pd.DataFrame(data = d)  # df with both child and mother's utt
mdf = mdf[mdf['Who'] == 'MOT']  # keep only mother's utt

# pd.set_option('display.max_rows', None)  # display all rows in the dataframe
# mdf  # sanity check

mdf.sample(n=25)
# Out:
#       Who                                                Utt
# 1002  MOT                               [with, the, teacher]
# 1309  MOT  [forty, two, meeting, and, the, Williams, street]
# 1246  MOT                                   [surprise, what]
# 1592  MOT                           [oh, is, that, my, name]
# 965   MOT  [I, don't, think, it's, sposta, stick, on, the...
# 1508  MOT          [well, maybe, you, just, can't, see, huh]
# 902   MOT          [or, something, so, he, could, hear, you]
# 1414  MOT  [why, don't, you, start, picking, them, up, an...
# 24    MOT             [I'm, going, upstairs, and, check, on]
# 1053  MOT                                          [alright]
# 922   MOT                                           [no, no]
# 710   MOT                            [oh, what, is, it, now]
# 1123  MOT    [no, I, don't, know, how, to, make, a, monster]
# 1248  MOT                                               [oh]
# 1281  MOT      [don't, throw, it, dear, you, may, crack, it]
# 997   MOT         [what, kind, of, game, were, you, playing]
# 1301  MOT                 [now, no, more, throwing, alright]
# 1390  MOT  [if, you've, finished, why, don't, you, put, t...
# 678   MOT          [you, pin, those, things, on, your, back]
# 354   MOT                                   [what, is, that]
# 1389  MOT                                           [no, no]
# 788   MOT                                        [yes, Adam]
# 1338  MOT  [then, they, wouldn't, be, nice, to, play, wit...
# 717   MOT  [oh, why, don't, you, give, her, one, of, the,...
# 990   MOT                                        [you, what]

# %% [markdown]
# ### Read in word pronunciation data from WikiPron
#
# Again, this is copy-and-paste from an earlier homework.

# %%
# read in english words.  pdf = pronunciation df.
fname = "data/eng_us_phonemic.tsv"

# YOUR CODE GOES HERE.
pdf = pd.read_csv(fname, sep='\t', names=['Word', 'Pron'])
pdf.Pron = pdf.Pron.str.split()  # turn space-separated strings into lists of phonemes

pdf.sample(n=25)
# Out:
#                Word                            Pron
# 46260  succussation  [s, ʌ, k, ə, s, e, ɪ, ʃ, ə, n]
# 11799    complexion  [k, ə, m, p, l, ɛ, k, ʃ, ə, n]
# 34443          oose                          [u, z]
# 52700        xavier        [ɪ, ɡ, z, e, ɪ, v, j, ɚ]
# 21168       gazelle                 [ɡ, ə, z, ɛ, l]
# 16734        effing                    [ɛ, f, ɪ, ŋ]
# 25628     indenture           [ɪ, n, d, ɛ, n, ʃ, ɝ]
# 46697       sweeper                 [s, w, i, p, ɚ]
# 52910         yayan               [j, ɑː, j, ɑː, n]
# 20476      frighten             [f, ɹ, a, ɪ, t, n̩]
# 18705         faggy                    [f, æ, ɡ, i]
# 1719       acoustic          [ə, k, uː, s, t, ɪ, k]
# 48438        toldja           [t, o, ʊ, l, d, ʒ, ə]
# 37593    polychaete          [p, ɒ, l, ɪ, k, iː, t]
# 45157      spinward        [s, p, ɪ, n, w, ɜ, ɹ, d]
# 47367        teased                   [t, iː, z, d]
# 30970           meg                       [m, ɛ, ɡ]
# 35666         parol              [p, ɑ, ɹ, o, ʊ, l]
# 32018         momma                    [m, ɑ, m, ə]
# 27595      kickings              [k, ɪ, k, ɪ, ŋ, z]
# 20672       fumings          [f, j, uː, m, ɪ, ŋ, z]
# 25783       infidel           [ɪ, n, f, ə, d, ɛ, l]
# 20779       fustian           [f, ʌ, s, t, i, ə, n]
# 33785           nun                      [n, uː, n]
# 36901       piggies                 [p, ɪ, ɡ, i, z]

# %%
# now create a dict called pron, s.t. pron[word] yields the pronunciation of that word in phonemes.

# YOUR CODE GOES HERE.

pron = {}

for i in range(len(pdf)):
    pron[pdf.iloc[i].Word] = pdf.iloc[i].Pron


print(pron['big'])
print(pron['drum'])
if 'you' in pron:
    print(pron['you'])
if 'i' in pron:
    print(pron['i'])
# Out:
# ['b', 'ɪ', 'ɡ']
# ['d', 'ɹ', 'ʌ', 'm']
# ['ɪ']

# %% [markdown]
# # Replicate Hockema's central finding
#
# Hockema's central finding is illustrated in his Figure 2: US English phoneme transition pairs, or PTPs are strongly bimodally distributed in child-directed speech, such that most are either almost certain to cross a word boundary, or almost certain not to - suggesting that PTPs can in principle be used as a cue to word segmentation.
#
# We want to replicate that finding.  Here's what is needed to do that, beyond what we already have:
#
# - Retain word boundaries but merge all utterances together into one long list.
# - Explode each word in that list into phonemes, e.g.: "big" $\rightarrow$ ['b', 'ɪ', 'ɡ'].
# - Determine which phonemes are in the corpus.
# - Determine the set of all possible phoneme transition pairs, or PTPs.
# - Determine p(word boundary|ptp) for each ptp, or phoneme transition pair.
# - Plot histogram.

# %%
# retain word boundaries but merge all utterances together into one long list, called corpus.

# YOUR CODE GOES HERE.
corpus = [j for i in range(len(mdf)) for j in mdf.Utt.iloc[i]] # REPLACE

print("corpus is", len(corpus), "words long.")
corpus
# Out:
# corpus is 1230 words long.
# ['you',
#  'say',
#  'no',
#  'why',
#  'not',
#  'why',
#  'not',
#  "I'm",
#  'going',
#  'upstairs',
#  'and',
#  'check',
#  'on',
#  'you',
#  'have',
#  'a',
#  'car',
#  'in',
#  'the',
#  'back',
#  'yard',
#  'what',
#  'does',
#  'it',
#  'play',
#  'or',
#  'sing',
#  'it',
#  'can',
#  'sing',
#  'to',
#  'make',
#  'jingle',
#  'bells',
#  'try',
#  'it',
#  'again',
#  'use',
#  'your',
#  'finger',
#  'oh',
#  'did',
#  'you',
#  'tell',
#  'Ursula',
#  'about',
#  'your',
#  'school',
#  'maybe',
#  'one',
#  'day',
#  'when',
#  "you're",
#  'a',
#  'little',
#  'older',
#  'and',
#  'a',
#  'little',
#  'bigger',
#  'David',
#  'is',
#  'eleven',
#  'now',
#  'no',
#  'I',
#  'think',
#  'so',
#  'whatever',
#  "you'd",
#  'like',
#  'to',
#  'play',
#  'Old_Mac_Donald',
#  'he',
#  'says',
#  "he'd",
#  'sharpen',
#  'scissors',
#  'and',
#  'knives',
#  'and',
#  'gives',
#  'you',
#  'a',
#  "year's",
#  'guarantee',
#  'for',
#  'the',
#  'sound',
#  'maybe',
#  'the',
#  'hole',
#  'is',
#  'for',
#  'the',
#  'sound',
#  'to',
#  'come',
#  'out',
#  'do',
#  'you',
#  'think',
#  "you're",
#  'finished',
#  'with',
#  'the',
#  'banjo',
#  'you',
#  "don't",
#  'like',
#  'those',
#  'now',
#  "let's",
#  'make',
#  'a',
#  'little',
#  'ball',
#  'and',
#  'hide',
#  'it',
#  'inside',
#  'did',
#  'you',
#  'tell',
#  'Ursula',
#  'what',
#  'you',
#  'do',
#  'at',
#  'school',
#  'www',
#  'oh',
#  "that's",
#  'delicious',
#  'it',
#  'will',
#  'come',
#  'off',
#  'you',
#  'can',
#  'wash',
#  'it',
#  'off',
#  'very',
#  'pretty',
#  'oh',
#  'no',
#  'thank_you',
#  "I'll",
#  'just',
#  'enjoy',
#  'yours',
#  'shall',
#  'we',
#  'make',
#  'something',
#  'with',
#  'these',
#  'did',
#  'you',
#  'tell',
#  'her',
#  'our',
#  'telephone',
#  'number',
#  'Adam',
#  'alright',
#  'now',
#  "what's",
#  'our',
#  'telephone',
#  'number',
#  'remember',
#  'two',
#  'six',
#  'two',
#  'one',
#  'three',
#  'seven',
#  'eight',
#  'this',
#  'is',
#  'a',
#  'key',
#  'the',
#  'part',
#  'of',
#  'the',
#  'what',
#  'what',
#  'kind',
#  'of',
#  'dog',
#  'is',
#  'that',
#  'what',
#  'is',
#  'that',
#  'with',
#  'how',
#  'many',
#  'legs',
#  'I',
#  'thought',
#  'there',
#  'were',
#  'two',
#  'back',
#  'there',
#  'oh',
#  'you',
#  'can',
#  'do',
#  'that',
#  'you',
#  'hafta',
#  'give',
#  'him',
#  'some',
#  'nice',
#  'strong',
#  'legs',
#  'to',
#  'stand',
#  'on',
#  'with',
#  'a',
#  'clock',
#  'on',
#  'it',
#  'oh',
#  'no',
#  'can',
#  'you',
#  'blow',
#  'if',
#  'she',
#  'said',
#  'yes',
#  'it',
#  'must',
#  'be',
#  'yes',
#  'hold',
#  'it',
#  'up',
#  'so',
#  'Adam',
#  'can',
#  'see',
#  'how',
#  'it',
#  'looks',
#  'look',
#  'at',
#  'it',
#  'you',
#  'can',
#  'make',
#  'it',
#  'oh',
#  'you',
#  'know',
#  'you',
#  'can',
#  'try',
#  'I',
#  'doubt',
#  'that',
#  'try',
#  'oh',
#  "you're",
#  'making',
#  'another',
#  'one',
#  "I'll",
#  'go',
#  'get',
#  'it',
#  'for',
#  'you',
#  'what',
#  'did',
#  'you',
#  'draw',
#  'in',
#  'school',
#  'yesterday',
#  'I',
#  "don't",
#  'understand',
#  'how',
#  'to',
#  'play',
#  'that',
#  'game',
#  'you',
#  'pin',
#  'those',
#  'things',
#  'on',
#  'your',
#  'back',
#  'and',
#  'then',
#  'what',
#  'do',
#  'you',
#  'do',
#  'and',
#  'then',
#  'you',
#  "don't",
#  'let',
#  'anybody',
#  'look',
#  'behind',
#  'your',
#  'back',
#  'oh',
#  "that's",
#  'not',
#  'a',
#  'banjo',
#  "that's",
#  'a',
#  'guitar',
#  'Paul',
#  'oh',
#  'what',
#  'is',
#  'it',
#  'now',
#  'oh',
#  'you',
#  'changed',
#  'it',
#  'to',
#  'what',
#  'was',
#  'it',
#  'a',
#  'clarinet',
#  'oh',
#  'why',
#  "don't",
#  'you',
#  'give',
#  'her',
#  'one',
#  'of',
#  'the',
#  'ones',
#  'that',
#  'you',
#  'had',
#  'her',
#  'make',
#  'oh',
#  'oh',
#  'you',
#  'always',
#  'wanna',
#  'keep',
#  'something',
#  'what',
#  'was',
#  'that',
#  'game',
#  'you',
#  'were',
#  'playing',
#  'that',
#  'I',
#  'heard',
#  'downstairs',
#  'alright',
#  'why',
#  'do',
#  'you',
#  'do',
#  'that',
#  'the',
#  'what',
#  "don't",
#  'let',
#  'it',
#  'you',
#  'stay',
#  'there',
#  'you',
#  'hafta',
#  'press',
#  'the',
#  'button',
#  'to',
#  'talk',
#  'hello',
#  'Adam',
#  'hello',
#  'Adam',
#  'what',
#  'are',
#  'you',
#  'doing',
#  'what',
#  'yes',
#  'Adam',
#  'I',
#  'heard',
#  'you',
#  'talking',
#  'to',
#  'Adam',
#  'does',
#  'it',
#  'have',
#  'an',
#  'antenna',
#  'yes',
#  'Adam',
#  'xxx',
#  'where',
#  'are',
#  'you',
#  'Adam',
#  'okay',
#  'I',
#  'was',
#  'in',
#  'the',
#  'forest',
#  'these',
#  'are',
#  'nice',
#  "I'll",
#  'go',
#  'out',
#  'hello',
#  'Adam',
#  'xxx',
#  "Rinny's",
#  'outside',
#  'playing',
#  'you',
#  'start',
#  'talking',
#  'I',
#  'thought',
#  'you',
#  'said',
#  'is',
#  'Rinny',
#  'doing',
#  'now',
#  "I'll",
#  'go',
#  'all',
#  'the',
#  'way',
#  'downstairs',
#  'you',
#  'go',
#  'back',
#  'in',
#  'there',
#  'what',
#  'did',
#  'you',
#  'say',
#  'hello',
#  'Adam',
#  "how're",
#  'you',
#  'what',
#  'did',
#  'you',
#  'say',
#  'what',
#  'did',
#  'you',
#  'say',
#  "I'm",
#  'sitting',
#  'on',
#  'the',
#  'top',
#  'stair',
#  'can',
#  'you',
#  'hear',
#  'me',
#  'can',
#  'you',
#  'hear',
#  'me',
#  'press',
#  'the',
#  'button',
#  'down',
#  'what',
#  'did',
#  'you',
#  'say',
#  'you',
#  'said',
#  'xxx',
#  'Adam',
#  'press',
#  'the',
#  'button',
#  'down',
#  'alright',
#  'when',
#  'you',
#  'talk',
#  'you',
#  'hafta',
#  'press',
#  'the',
#  'button',
#  'no',
#  'not',
#  'with',
#  'this',
#  'I',
#  "don't",
#  'think',
#  "you'd",
#  'hafta',
#  'use',
#  'the',
#  'telephone',
#  "you'd",
#  'probably',
#  'need',
#  'a',
#  'bigger',
#  'set',
#  "don't",
#  'put',
#  'your',
#  'mouth',
#  'on',
#  'it',
#  "he'd",
#  'hafta',
#  'have',
#  'one',
#  'too',
#  'or',
#  'something',
#  'so',
#  'he',
#  'could',
#  'hear',
#  'you',
#  'go',
#  'from',
#  'one',
#  'end',
#  'of',
#  'the',
#  'street',
#  'to',
#  'the',
#  'other',
#  'okay',
#  "don't",
#  'play',
#  'with',
#  'it',
#  'Adam',
#  'you',
#  'may',
#  'break',
#  'it',
#  'well',
#  'maybe',
#  'when',
#  'you',
#  'get',
#  'a',
#  'little',
#  'bigger',
#  "David's",
#  'eleven',
#  'years',
#  'old',
#  'no',
#  'no',
#  'you',
#  'may',
#  'break',
#  'it',
#  'I',
#  'see',
#  'a',
#  'box',
#  'over',
#  'there',
#  'why',
#  "don't",
#  'you',
#  'look',
#  'and',
#  'see',
#  'what',
#  'else',
#  'is',
#  'in',
#  'the',
#  'box',
#  'last',
#  'time',
#  'we',
#  'went',
#  'to',
#  'get',
#  'them',
#  'they',
#  'were',
#  'out_of',
#  'them',
#  'a',
#  'game',
#  'like',
#  'Urs',
#  'brought',
#  'for',
#  'you',
#  'alright',
#  'oh',
#  'is',
#  'that',
#  'right',
#  'you',
#  "don't",
#  'snap',
#  'buttons',
#  'do',
#  'you',
#  'we',
#  'thought',
#  "we'd",
#  'try',
#  'something',
#  'different',
#  "it's",
#  'so',
#  'peculiar',
#  'yes',
#  'you',
#  "don't",
#  'what',
#  'd',
#  'you',
#  'think',
#  'it',
#  'is',
#  'I',
#  "don't",
#  'think',
#  "it's",
#  'sposta',
#  'stick',
#  'on',
#  'the',
#  'wall',
#  'what',
#  'else',
#  'did',
#  'you',
#  'do',
#  'in',
#  'school',
#  'today',
#  'oh',
#  'everyone',
#  'else',
#  'was',
#  'running',
#  'outside',
#  'the',
#  'circle',
#  'you',
#  'what',
#  'oh',
#  'you',
#  'were',
#  'in',
#  'the',
#  'circle',
#  'you',
#  "weren't",
#  'sposta',
#  'be',
#  'in',
#  'the',
#  'circle',
#  'what',
#  'kind',
#  'of',
#  'game',
#  'were',
#  'you',
#  'playing',
#  'oh',
#  'and',
#  'left',
#  'the',
#  'boys',
#  'in',
#  'the',
#  'room',
#  'in',
#  'a',
#  'circle',
#  'with',
#  'the',
#  'teacher',
#  'maybe',
#  "I'll",
#  'build',
#  'a',
#  'Prudential',
#  'Tower',
#  'what',
#  'um',
#  'what',
#  'happened',
#  'to',
#  'that',
#  'school',
#  'not',
#  'very',
#  'big',
#  'but',
#  "it's",
#  'very',
#  'tall',
#  'peculiar',
#  'oh',
#  'you',
#  "don't",
#  'mean',
#  'peculiar',
#  "isn't",
#  'that',
#  'the',
#  'way',
#  'it',
#  'works',
#  'yes',
#  'I',
#  'see',
#  'yes',
#  'yes',
#  'how',
#  'are',
#  'you',
#  'going',
#  'to',
#  'make',
#  'those',
#  'alright',
#  'how',
#  'should',
#  'we',
#  'begin',
#  'well',
#  'why',
#  "don't",
#  'you',
#  'make',
#  'a',
#  'bottom',
#  'for',
#  'it',
#  'here',
#  'are',
#  'the',
#  'sliding_stairs',
#  "you're",
#  'what',
#  'thank_you',
#  'what',
#  'does',
#  'that',
#  'one',
#  'say',
#  'it',
#  'says',
#  'what',
#  'no',
#  'I',
#  "don't",
#  'know',
#  'how',
#  'to',
#  'make',
#  'a',
#  'monster',
#  'yes',
#  'please',
#  'just',
#  'one',
#  'more',
#  'I',
#  'think',
#  'he',
#  'started',
#  'to',
#  'ask',
#  'you',
#  'something',
#  'else',
#  'and',
#  'then',
#  'changed',
#  'it',
#  'ssh',
#  'surprise',
#  'what',
#  'oh',
#  'ssh',
#  'take',
#  'your',
#  'time',
#  "don't",
#  'throw',
#  'it',
#  'dear',
#  'you',
#  'may',
#  'crack',
#  'it',
#  'honey',
#  'you',
#  "shouldn't",
#  'really',
#  'throw',
#  'these',
#  'things',
#  'these',
#  'are',
#  'for',
#  'building',
#  'you',
#  'can',
#  'throw',
#  'a',
#  'ball',
#  'now',
#  'no',
#  'more',
#  'throwing',
#  'alright',
#  'Adam',
#  'no',
#  'more',
#  'throwing',
#  'please',
#  'forty',
#  'two',
#  'meeting',
#  'and',
#  'the',
#  'Williams',
#  'street',
#  'what',
#  'does',
#  'that',
#  'mean',
#  'thirty',
#  'two',
#  'thirty',
#  'two',
#  'Williams',
#  'Street',
#  'and',
#  'Greenwich',
#  'Park',
#  'do',
#  'what',
#  'again',
#  'thirty',
#  'two',
#  'Williams',
#  'Street',
#  'and',
#  'Greenwich',
#  'Park',
#  "what's",
#  'the',
#  'number',
#  'on',
#  'Greenwich',
#  'Park',
#  'forty',
#  'ninety',
#  'where',
#  'does',
#  'eleven',
#  'and',
#  'one',
#  'half',
#  'come',
#  'in',
#  'these',
#  'are',
#  'made',
#  'of',
#  'plastic',
#  'and',
#  'they',
#  'might',
#  'crack',
#  'then',
#  'they',
#  "wouldn't",
#  'be',
#  'nice',
#  'to',
#  'play',
#  'with',
#  'anymore',
#  'no',
#  'she',
#  "wouldn't",
#  'give',
#  'it',
#  'to',
#  'you',
#  'if',
#  'they',
#  'were',
#  'cracked',
#  "she'd",
#  'hafta',
#  'throw',
#  'it',
#  'away',
#  'you',
#  "couldn't",
#  'play',
#  'with',
#  'it',
#  'but',
#  'Robin',
#  'and',
#  'David',
#  'might',
#  'not',
#  'want',
#  'broken',
#  'toys',
#  'a',
#  'what',
#  'did',
#  'you',
#  'tell',
#  'Ursula',
#  'we',
#  'saw',
#  'a',
#  'train',
#  'this',
#  'morning',
#  'a',
#  'what',
#  'choo_choo',
#  'model',
#  'some',
#  'trim',
#  'shrimp',
#  'what',
#  'is',
#  'shrimp',
#  'stop',
#  'throwing',
#  'that',
#  'oh',
#  'did',
#  'some',
#  'clay',
#  'fall',
#  'down',
#  'there',
#  'too',
#  'no',
#  'no',
#  'if',
#  "you've",
#  'finished',
#  'why',
#  "don't",
#  'you',
#  'put',
#  ...]

# %%
# explode each word into phonemes.  
# simply drop words that are not in the pron dict.
# and add the pseudo-phoneme '*' after each word to mark word boundaries
# ec = exploded corpus

# YOUR CODE GOES HERE.
ec = [p for word in corpus if word in pron.keys() for p in pron[word]+['*']]  # REPLACE

print("exploded corpus is", len(ec), "phonemes long, including word boundaries.")
ec
# Out:
# exploded corpus is 4270 phonemes long, including word boundaries.
# ['s',
#  'e',
#  'ɪ',
#  '*',
#  'ʍ',
#  'a',
#  'ɪ',
#  '*',
#  'n',
#  'ɒ',
#  't',
#  '*',
#  'ʍ',
#  'a',
#  'ɪ',
#  '*',
#  'n',
#  'ɒ',
#  't',
#  '*',
#  'ɡ',
#  'ɔ',
#  'ɪ',
#  'ŋ',
#  '*',
#  'ʌ',
#  'p',
#  's',
#  't',
#  'ɛ',
#  'ɹ',
#  'z',
#  '*',
#  't͡ʃ',
#  'ɛ',
#  'k',
#  '*',
#  'ə',
#  '*',
#  'k',
#  'ɑ',
#  'ɹ',
#  '*',
#  'ɪ',
#  'n',
#  '*',
#  'ð',
#  'iː',
#  '*',
#  'b',
#  'æ',
#  'k',
#  '*',
#  'j',
#  'ɑ',
#  'ɹ',
#  'd',
#  '*',
#  'ʍ',
#  'ʌ',
#  't',
#  '*',
#  'd',
#  'o',
#  'ʊ',
#  'z',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'p',
#  'l',
#  'e',
#  'ɪ',
#  '*',
#  'ɚ',
#  '*',
#  's',
#  'ɪ',
#  'ŋ',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'k',
#  'ə',
#  'n',
#  '*',
#  's',
#  'ɪ',
#  'ŋ',
#  '*',
#  't',
#  'ʊ',
#  '*',
#  'm',
#  'e',
#  'ɪ',
#  'k',
#  '*',
#  'd',
#  'ʒ',
#  'ɪ',
#  'ŋ',
#  'ɡ',
#  'ə',
#  'l',
#  '*',
#  'b',
#  'ɛ',
#  'l',
#  'z',
#  '*',
#  't',
#  'ɹ',
#  'a',
#  'ɪ',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'ə',
#  'ɡ',
#  'ɛ',
#  'n',
#  '*',
#  'j',
#  'uː',
#  's',
#  '*',
#  'j',
#  'ʊ',
#  'ə',
#  'ɹ',
#  '*',
#  'f',
#  'ɪ',
#  'ŋ',
#  'ɡ',
#  'ɚ',
#  '*',
#  'o',
#  'ʊ',
#  '*',
#  'd',
#  'ɪ',
#  'd',
#  '*',
#  't',
#  'ɛ',
#  'ɫ',
#  '*',
#  'ə',
#  'b',
#  'a',
#  'ʊ',
#  't',
#  '*',
#  'j',
#  'ʊ',
#  'ə',
#  'ɹ',
#  '*',
#  's',
#  'k',
#  'uː',
#  'l',
#  '*',
#  'm',
#  'e',
#  'ɪ',
#  'b',
#  'i',
#  '*',
#  'w',
#  'ʌ',
#  'n',
#  '*',
#  'd',
#  'e',
#  'ɪ',
#  '*',
#  'ʍ',
#  'ɪ',
#  'n',
#  '*',
#  'ə',
#  '*',
#  'l',
#  'ɪ',
#  't',
#  'l̩',
#  '*',
#  'o',
#  'ʊ',
#  'l',
#  'd',
#  'ɚ',
#  '*',
#  'ə',
#  '*',
#  'l',
#  'ɪ',
#  't',
#  'l̩',
#  '*',
#  'b',
#  'ɪ',
#  'ɡ',
#  'ɚ',
#  '*',
#  'ɪ',
#  'z',
#  '*',
#  'ɪ',
#  'l',
#  'ɛ',
#  'v',
#  'ə',
#  'n',
#  '*',
#  'n',
#  'a',
#  'ʊ',
#  '*',
#  'θ',
#  'ɪ',
#  'ŋ',
#  'k',
#  '*',
#  's',
#  'o',
#  'ʊ',
#  '*',
#  'w',
#  'ʌ',
#  't',
#  'ɛ',
#  'v',
#  'ɚ',
#  '*',
#  'j',
#  'uː',
#  'd',
#  '*',
#  'l',
#  'a',
#  'ɪ',
#  'k',
#  '*',
#  't',
#  'ʊ',
#  '*',
#  'p',
#  'l',
#  'e',
#  'ɪ',
#  '*',
#  'h',
#  'i',
#  '*',
#  'h',
#  'iː',
#  'd',
#  '*',
#  'ʃ',
#  'ɑ',
#  'ɹ',
#  'p',
#  'ɨ',
#  'n',
#  '*',
#  's',
#  'ɪ',
#  'z',
#  'ɚ',
#  'z',
#  '*',
#  'n',
#  'a',
#  'ɪ',
#  'v',
#  'z',
#  '*',
#  'ɡ',
#  'ɪ',
#  'v',
#  'z',
#  '*',
#  'ə',
#  '*',
#  'ɡ',
#  'ɛ',
#  'ə',
#  'ɹ',
#  'ə',
#  'n',
#  't',
#  'iː',
#  '*',
#  'f',
#  'ɚ',
#  '*',
#  'ð',
#  'iː',
#  '*',
#  's',
#  'a',
#  'ʊ',
#  'n',
#  'd',
#  '*',
#  'm',
#  'e',
#  'ɪ',
#  'b',
#  'i',
#  '*',
#  'ð',
#  'iː',
#  '*',
#  'h',
#  'o',
#  'ʊ',
#  'l',
#  '*',
#  'ɪ',
#  'z',
#  '*',
#  'f',
#  'ɚ',
#  '*',
#  'ð',
#  'iː',
#  '*',
#  's',
#  'a',
#  'ʊ',
#  'n',
#  'd',
#  '*',
#  't',
#  'ʊ',
#  '*',
#  'k',
#  'ʌ',
#  'm',
#  '*',
#  'a',
#  'ʊ',
#  't',
#  '*',
#  'd',
#  'u',
#  '*',
#  'θ',
#  'ɪ',
#  'ŋ',
#  'k',
#  '*',
#  'f',
#  'ɪ',
#  'n',
#  'ɪ',
#  'ʃ',
#  't',
#  '*',
#  'w',
#  'ɪ',
#  'θ',
#  '*',
#  'ð',
#  'iː',
#  '*',
#  'b',
#  'æ',
#  'n',
#  'd',
#  'ʒ',
#  'o',
#  'ʊ',
#  '*',
#  'd',
#  'o',
#  'ʊ',
#  'n',
#  't',
#  '*',
#  'l',
#  'a',
#  'ɪ',
#  'k',
#  '*',
#  'ð',
#  'o',
#  'ʊ',
#  'z',
#  '*',
#  'n',
#  'a',
#  'ʊ',
#  '*',
#  'l',
#  'ɛ',
#  't',
#  's',
#  '*',
#  'm',
#  'e',
#  'ɪ',
#  'k',
#  '*',
#  'ə',
#  '*',
#  'l',
#  'ɪ',
#  't',
#  'l̩',
#  '*',
#  'b',
#  'ɔː',
#  'l',
#  '*',
#  'h',
#  'a',
#  'ɪ',
#  'd',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'ɪ',
#  'n',
#  's',
#  'a',
#  'ɪ',
#  'd',
#  '*',
#  'd',
#  'ɪ',
#  'd',
#  '*',
#  't',
#  'ɛ',
#  'ɫ',
#  '*',
#  'ʍ',
#  'ʌ',
#  't',
#  '*',
#  'd',
#  'u',
#  '*',
#  's',
#  'k',
#  'uː',
#  'l',
#  '*',
#  'd',
#  'ʌ',
#  'b',
#  'ə',
#  'l',
#  'j',
#  'uː',
#  'd',
#  'ʌ',
#  'b',
#  'ə',
#  'l',
#  'j',
#  'uː',
#  'd',
#  'ʌ',
#  'b',
#  'ə',
#  'l',
#  'j',
#  'uː',
#  '*',
#  'o',
#  'ʊ',
#  '*',
#  'ð',
#  'æ',
#  't',
#  's',
#  '*',
#  'd',
#  'ə',
#  'l',
#  'ɪ',
#  'ʃ',
#  'ə',
#  's',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'w',
#  'ɪ',
#  'l',
#  '*',
#  'k',
#  'ʌ',
#  'm',
#  '*',
#  'ɔ',
#  'f',
#  '*',
#  'k',
#  'ə',
#  'n',
#  '*',
#  'w',
#  'ɔ',
#  'ʃ',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'ɔ',
#  'f',
#  '*',
#  'v',
#  'ɛ',
#  'ɹ',
#  'i',
#  '*',
#  'p',
#  'ɹ',
#  'ʊ',
#  't',
#  'i',
#  '*',
#  'o',
#  'ʊ',
#  '*',
#  'd͡ʒ',
#  'ʌ',
#  's',
#  't',
#  '*',
#  'ɪ',
#  'n',
#  'd͡ʒ',
#  'ɔ',
#  'ɪ',
#  '*',
#  'j',
#  'ɝː',
#  'z',
#  '*',
#  'w',
#  'iː',
#  '*',
#  'm',
#  'e',
#  'ɪ',
#  'k',
#  '*',
#  's',
#  'ʌ',
#  'm',
#  'θ',
#  'ɪ',
#  'ŋ',
#  '*',
#  'w',
#  'ɪ',
#  'θ',
#  '*',
#  'ð',
#  'iː',
#  'z',
#  '*',
#  'd',
#  'ɪ',
#  'd',
#  '*',
#  't',
#  'ɛ',
#  'ɫ',
#  '*',
#  'ɚ',
#  '*',
#  'ɑː',
#  '*',
#  't',
#  'ɛ',
#  'l',
#  'ə',
#  'f',
#  'o',
#  'ʊ',
#  'n',
#  '*',
#  'n',
#  'ʌ',
#  'm',
#  'ɚ',
#  '*',
#  'n',
#  'a',
#  'ʊ',
#  '*',
#  'ʍ',
#  'ʌ',
#  't',
#  's',
#  '*',
#  'ɑː',
#  '*',
#  't',
#  'ɛ',
#  'l',
#  'ə',
#  'f',
#  'o',
#  'ʊ',
#  'n',
#  '*',
#  'n',
#  'ʌ',
#  'm',
#  'ɚ',
#  '*',
#  'ɹ',
#  'ɪ',
#  'm',
#  'ɛ',
#  'm',
#  'b',
#  'ɚ',
#  '*',
#  't',
#  'u',
#  '*',
#  's',
#  'ɪ',
#  'k',
#  's',
#  '*',
#  't',
#  'u',
#  '*',
#  'w',
#  'ʌ',
#  'n',
#  '*',
#  'θ',
#  'ɹ',
#  'iː',
#  '*',
#  's',
#  'ɛ',
#  'v',
#  'ə',
#  'n',
#  '*',
#  'e',
#  'ɪ',
#  't',
#  '*',
#  'ð',
#  'ɪ',
#  's',
#  '*',
#  'ɪ',
#  'z',
#  '*',
#  'ə',
#  '*',
#  'k',
#  'i',
#  '*',
#  'ð',
#  'iː',
#  '*',
#  'p',
#  'ɑ',
#  'ɹ',
#  't',
#  '*',
#  'ʌ',
#  'v',
#  '*',
#  'ð',
#  'iː',
#  '*',
#  'ʍ',
#  'ʌ',
#  't',
#  '*',
#  'ʍ',
#  'ʌ',
#  't',
#  '*',
#  'k',
#  'a',
#  'ɪ',
#  'n',
#  'd',
#  '*',
#  'ʌ',
#  'v',
#  '*',
#  'd',
#  'ɔ',
#  'ɡ',
#  '*',
#  'ɪ',
#  'z',
#  '*',
#  'ð',
#  'æ',
#  't',
#  '*',
#  'ʍ',
#  'ʌ',
#  't',
#  '*',
#  'ɪ',
#  'z',
#  '*',
#  'ð',
#  'æ',
#  't',
#  '*',
#  'w',
#  'ɪ',
#  'θ',
#  '*',
#  'h',
#  'a',
#  'ʊ',
#  '*',
#  'm',
#  'ɪ',
#  'n',
#  'i',
#  '*',
#  'l',
#  'ɛ',
#  'ɡ',
#  'z',
#  '*',
#  'θ',
#  'ɔ',
#  't',
#  '*',
#  'ð',
#  'ɛ',
#  'ə',
#  'ɹ',
#  '*',
#  'w',
#  'ɝ',
#  '*',
#  't',
#  'u',
#  '*',
#  'b',
#  'æ',
#  'k',
#  '*',
#  'ð',
#  'ɛ',
#  'ə',
#  'ɹ',
#  '*',
#  'o',
#  'ʊ',
#  '*',
#  'k',
#  'ə',
#  'n',
#  '*',
#  'd',
#  'u',
#  '*',
#  'ð',
#  'æ',
#  't',
#  '*',
#  'h',
#  'æ',
#  'f',
#  't',
#  'ə',
#  '*',
#  'ɡ',
#  'ɪ',
#  'v',
#  '*',
#  'ə',
#  'm',
#  '*',
#  's',
#  'ʌ',
#  'm',
#  '*',
#  'n',
#  'iː',
#  's',
#  '*',
#  's',
#  't',
#  'ɹ',
#  'ɔ',
#  'ŋ',
#  '*',
#  'l',
#  'ɛ',
#  'ɡ',
#  'z',
#  '*',
#  't',
#  'ʊ',
#  '*',
#  's',
#  't',
#  'æ',
#  'n',
#  'd',
#  '*',
#  'w',
#  'ɪ',
#  'θ',
#  '*',
#  'ə',
#  '*',
#  'k',
#  'l',
#  'ɑ',
#  'k',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'o',
#  'ʊ',
#  '*',
#  'k',
#  'ə',
#  'n',
#  '*',
#  'b',
#  'l',
#  'o',
#  'ʊ',
#  '*',
#  'ɪ',
#  'f',
#  '*',
#  'ʃ',
#  'i',
#  '*',
#  's',
#  'a',
#  'ɪ',
#  'd',
#  '*',
#  'j',
#  'ɛ',
#  's',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'b',
#  'i',
#  '*',
#  'j',
#  'ɛ',
#  's',
#  '*',
#  'h',
#  'o',
#  'ʊ',
#  'l',
#  'd',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'ʌ',
#  'p',
#  '*',
#  's',
#  'o',
#  'ʊ',
#  '*',
#  'k',
#  'ə',
#  'n',
#  '*',
#  's',
#  'iː',
#  '*',
#  'h',
#  'a',
#  'ʊ',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'l',
#  'ʊ',
#  'k',
#  's',
#  '*',
#  'l',
#  'ʊ',
#  'k',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'k',
#  'ə',
#  'n',
#  '*',
#  'm',
#  'e',
#  'ɪ',
#  'k',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'o',
#  'ʊ',
#  '*',
#  'n',
#  'o',
#  'ʊ',
#  '*',
#  'k',
#  'ə',
#  'n',
#  '*',
#  't',
#  'ɹ',
#  'a',
#  'ɪ',
#  '*',
#  'd',
#  'a',
#  'ʊ',
#  't',
#  '*',
#  'ð',
#  'æ',
#  't',
#  '*',
#  't',
#  'ɹ',
#  'a',
#  'ɪ',
#  '*',
#  'o',
#  'ʊ',
#  '*',
#  'm',
#  'e',
#  'ɪ',
#  'k',
#  'ɪ',
#  'ŋ',
#  '*',
#  'ə',
#  'n',
#  'ʌ',
#  'ð',
#  'ɚ',
#  '*',
#  'w',
#  'ʌ',
#  'n',
#  '*',
#  'ɡ',
#  'o',
#  'ʊ',
#  '*',
#  'ɡ',
#  'ɪ',
#  't',
#  '*',
#  'ɪ',
#  't',
#  '*',
#  'f',
#  'ɚ',
#  '*',
#  'ʍ',
#  'ʌ',
#  't',
#  '*',
#  'd',
#  ...]

# %%
# determine the set of all phonemes in the corpus.
# but do not include the pseudo-phoneme '*'.

# YOUR CODE GOES HERE.
phonemes = set([i for i in ec if i != '*'])  # REPLACE

print(len(phonemes))
print(phonemes)
# Out:
# 51
# {'k', 'ɑː', 'l', 'e', 'ɨ', 'p', 'ɛ', 'f', 'l̩', 'ɹ', 'ʌ', 'n', 'ɒ', 'i', 'u', 't', 'z', 'ɑ', 'iː', 'ɝː', 'ɜ', 'o', 'j', 'ʍ', 'm', 'θ', 'ɔː', 'ɔ', 'ʒ', 'ɡ', 'a', 'æ', 't͡ʃ', 'ʊ', 'ð', 'h', 'v', 'd', 'w', 's', 'uː', 'ŋ', 'd͡ʒ', 'b', 'ɝ', 'ʃ', 'ɫ', 'n̩', 'ɪ', 'ɚ', 'ə'}

# %%
# create a list of all possible phoneme transition pairs, or PTPs.

# YOUR CODE GOES HERE.
ptps = [(i, j) for i in phonemes for j in phonemes]  # REPLACE

print(len(ptps))
print(ptps)
# Out:
# 2601
# [('k', 'k'), ('k', 'ɑː'), ('k', 'l'), ('k', 'e'), ('k', 'ɨ'), ('k', 'p'), ('k', 'ɛ'), ('k', 'f'), ('k', 'l̩'), ('k', 'ɹ'), ('k', 'ʌ'), ('k', 'n'), ('k', 'ɒ'), ('k', 'i'), ('k', 'u'), ('k', 't'), ('k', 'z'), ('k', 'ɑ'), ('k', 'iː'), ('k', 'ɝː'), ('k', 'ɜ'), ('k', 'o'), ('k', 'j'), ('k', 'ʍ'), ('k', 'm'), ('k', 'θ'), ('k', 'ɔː'), ('k', 'ɔ'), ('k', 'ʒ'), ('k', 'ɡ'), ('k', 'a'), ('k', 'æ'), ('k', 't͡ʃ'), ('k', 'ʊ'), ('k', 'ð'), ('k', 'h'), ('k', 'v'), ('k', 'd'), ('k', 'w'), ('k', 's'), ('k', 'uː'), ('k', 'ŋ'), ('k', 'd͡ʒ'), ('k', 'b'), ('k', 'ɝ'), ('k', 'ʃ'), ('k', 'ɫ'), ('k', 'n̩'), ('k', 'ɪ'), ('k', 'ɚ'), ('k', 'ə'), ('ɑː', 'k'), ('ɑː', 'ɑː'), ('ɑː', 'l'), ('ɑː', 'e'), ('ɑː', 'ɨ'), ('ɑː', 'p'), ('ɑː', 'ɛ'), ('ɑː', 'f'), ('ɑː', 'l̩'), ('ɑː', 'ɹ'), ('ɑː', 'ʌ'), ('ɑː', 'n'), ('ɑː', 'ɒ'), ('ɑː', 'i'), ('ɑː', 'u'), ('ɑː', 't'), ('ɑː', 'z'), ('ɑː', 'ɑ'), ('ɑː', 'iː'), ('ɑː', 'ɝː'), ('ɑː', 'ɜ'), ('ɑː', 'o'), ('ɑː', 'j'), ('ɑː', 'ʍ'), ('ɑː', 'm'), ('ɑː', 'θ'), ('ɑː', 'ɔː'), ('ɑː', 'ɔ'), ('ɑː', 'ʒ'), ('ɑː', 'ɡ'), ('ɑː', 'a'), ('ɑː', 'æ'), ('ɑː', 't͡ʃ'), ('ɑː', 'ʊ'), ('ɑː', 'ð'), ('ɑː', 'h'), ('ɑː', 'v'), ('ɑː', 'd'), ('ɑː', 'w'), ('ɑː', 's'), ('ɑː', 'uː'), ('ɑː', 'ŋ'), ('ɑː', 'd͡ʒ'), ('ɑː', 'b'), ('ɑː', 'ɝ'), ('ɑː', 'ʃ'), ('ɑː', 'ɫ'), ('ɑː', 'n̩'), ('ɑː', 'ɪ'), ('ɑː', 'ɚ'), ('ɑː', 'ə'), ('l', 'k'), ('l', 'ɑː'), ('l', 'l'), ('l', 'e'), ('l', 'ɨ'), ('l', 'p'), ('l', 'ɛ'), ('l', 'f'), ('l', 'l̩'), ('l', 'ɹ'), ('l', 'ʌ'), ('l', 'n'), ('l', 'ɒ'), ('l', 'i'), ('l', 'u'), ('l', 't'), ('l', 'z'), ('l', 'ɑ'), ('l', 'iː'), ('l', 'ɝː'), ('l', 'ɜ'), ('l', 'o'), ('l', 'j'), ('l', 'ʍ'), ('l', 'm'), ('l', 'θ'), ('l', 'ɔː'), ('l', 'ɔ'), ('l', 'ʒ'), ('l', 'ɡ'), ('l', 'a'), ('l', 'æ'), ('l', 't͡ʃ'), ('l', 'ʊ'), ('l', 'ð'), ('l', 'h'), ('l', 'v'), ('l', 'd'), ('l', 'w'), ('l', 's'), ('l', 'uː'), ('l', 'ŋ'), ('l', 'd͡ʒ'), ('l', 'b'), ('l', 'ɝ'), ('l', 'ʃ'), ('l', 'ɫ'), ('l', 'n̩'), ('l', 'ɪ'), ('l', 'ɚ'), ('l', 'ə'), ('e', 'k'), ('e', 'ɑː'), ('e', 'l'), ('e', 'e'), ('e', 'ɨ'), ('e', 'p'), ('e', 'ɛ'), ('e', 'f'), ('e', 'l̩'), ('e', 'ɹ'), ('e', 'ʌ'), ('e', 'n'), ('e', 'ɒ'), ('e', 'i'), ('e', 'u'), ('e', 't'), ('e', 'z'), ('e', 'ɑ'), ('e', 'iː'), ('e', 'ɝː'), ('e', 'ɜ'), ('e', 'o'), ('e', 'j'), ('e', 'ʍ'), ('e', 'm'), ('e', 'θ'), ('e', 'ɔː'), ('e', 'ɔ'), ('e', 'ʒ'), ('e', 'ɡ'), ('e', 'a'), ('e', 'æ'), ('e', 't͡ʃ'), ('e', 'ʊ'), ('e', 'ð'), ('e', 'h'), ('e', 'v'), ('e', 'd'), ('e', 'w'), ('e', 's'), ('e', 'uː'), ('e', 'ŋ'), ('e', 'd͡ʒ'), ('e', 'b'), ('e', 'ɝ'), ('e', 'ʃ'), ('e', 'ɫ'), ('e', 'n̩'), ('e', 'ɪ'), ('e', 'ɚ'), ('e', 'ə'), ('ɨ', 'k'), ('ɨ', 'ɑː'), ('ɨ', 'l'), ('ɨ', 'e'), ('ɨ', 'ɨ'), ('ɨ', 'p'), ('ɨ', 'ɛ'), ('ɨ', 'f'), ('ɨ', 'l̩'), ('ɨ', 'ɹ'), ('ɨ', 'ʌ'), ('ɨ', 'n'), ('ɨ', 'ɒ'), ('ɨ', 'i'), ('ɨ', 'u'), ('ɨ', 't'), ('ɨ', 'z'), ('ɨ', 'ɑ'), ('ɨ', 'iː'), ('ɨ', 'ɝː'), ('ɨ', 'ɜ'), ('ɨ', 'o'), ('ɨ', 'j'), ('ɨ', 'ʍ'), ('ɨ', 'm'), ('ɨ', 'θ'), ('ɨ', 'ɔː'), ('ɨ', 'ɔ'), ('ɨ', 'ʒ'), ('ɨ', 'ɡ'), ('ɨ', 'a'), ('ɨ', 'æ'), ('ɨ', 't͡ʃ'), ('ɨ', 'ʊ'), ('ɨ', 'ð'), ('ɨ', 'h'), ('ɨ', 'v'), ('ɨ', 'd'), ('ɨ', 'w'), ('ɨ', 's'), ('ɨ', 'uː'), ('ɨ', 'ŋ'), ('ɨ', 'd͡ʒ'), ('ɨ', 'b'), ('ɨ', 'ɝ'), ('ɨ', 'ʃ'), ('ɨ', 'ɫ'), ('ɨ', 'n̩'), ('ɨ', 'ɪ'), ('ɨ', 'ɚ'), ('ɨ', 'ə'), ('p', 'k'), ('p', 'ɑː'), ('p', 'l'), ('p', 'e'), ('p', 'ɨ'), ('p', 'p'), ('p', 'ɛ'), ('p', 'f'), ('p', 'l̩'), ('p', 'ɹ'), ('p', 'ʌ'), ('p', 'n'), ('p', 'ɒ'), ('p', 'i'), ('p', 'u'), ('p', 't'), ('p', 'z'), ('p', 'ɑ'), ('p', 'iː'), ('p', 'ɝː'), ('p', 'ɜ'), ('p', 'o'), ('p', 'j'), ('p', 'ʍ'), ('p', 'm'), ('p', 'θ'), ('p', 'ɔː'), ('p', 'ɔ'), ('p', 'ʒ'), ('p', 'ɡ'), ('p', 'a'), ('p', 'æ'), ('p', 't͡ʃ'), ('p', 'ʊ'), ('p', 'ð'), ('p', 'h'), ('p', 'v'), ('p', 'd'), ('p', 'w'), ('p', 's'), ('p', 'uː'), ('p', 'ŋ'), ('p', 'd͡ʒ'), ('p', 'b'), ('p', 'ɝ'), ('p', 'ʃ'), ('p', 'ɫ'), ('p', 'n̩'), ('p', 'ɪ'), ('p', 'ɚ'), ('p', 'ə'), ('ɛ', 'k'), ('ɛ', 'ɑː'), ('ɛ', 'l'), ('ɛ', 'e'), ('ɛ', 'ɨ'), ('ɛ', 'p'), ('ɛ', 'ɛ'), ('ɛ', 'f'), ('ɛ', 'l̩'), ('ɛ', 'ɹ'), ('ɛ', 'ʌ'), ('ɛ', 'n'), ('ɛ', 'ɒ'), ('ɛ', 'i'), ('ɛ', 'u'), ('ɛ', 't'), ('ɛ', 'z'), ('ɛ' ...

# %% [markdown]
# ### What quantity do we want?
#
# For each phoneme transition pair or PTP, we want the probability of a word boundary given that PTP, i.e. we want $p($word boundary$ | $PTP$_i), \forall i$.  This is the probability that a word boundary intervenes between the two phonemes of the pair.  We will use those quantities to create a histogram, with probability of a word boundary on the x-axis, while the y-axis denotes the percentage of PTPs that have that probability of a word boundary, binned.
#
# The conditional probability of a word boundary given a particular PTP can be calculated as a simple relative frequency:
#
# \begin{equation}
# p(\text{word boundary} | \text{PTP}_i) = \frac{c(\text{word boundary} \land \text{PTP}_i)}{c(\text{PTP}_i)}
# \end{equation}
#
# where $c(\cdot)$ stands for count, and measures counts in the corpus.

# %%
# start with the numerator of the above eqn: count the number of times each PTP in the corpus
# crosses a word boundary.
# we start by creating a dict ptp_across_counts. 
# the key is a pair (p1,p2), and the value is the count for that pair crossing a word boundary.
# we initialize all PTP counts to 0.

# YOUR CODE GOES HERE.
ptp_across_count = {ptp: 0 for ptp in ptps}   # REPLACE

ptp_across_count
# Out:
# {('k', 'k'): 0,
#  ('k', 'ɑː'): 0,
#  ('k', 'l'): 0,
#  ('k', 'e'): 0,
#  ('k', 'ɨ'): 0,
#  ('k', 'p'): 0,
#  ('k', 'ɛ'): 0,
#  ('k', 'f'): 0,
#  ('k', 'l̩'): 0,
#  ('k', 'ɹ'): 0,
#  ('k', 'ʌ'): 0,
#  ('k', 'n'): 0,
#  ('k', 'ɒ'): 0,
#  ('k', 'i'): 0,
#  ('k', 'u'): 0,
#  ('k', 't'): 0,
#  ('k', 'z'): 0,
#  ('k', 'ɑ'): 0,
#  ('k', 'iː'): 0,
#  ('k', 'ɝː'): 0,
#  ('k', 'ɜ'): 0,
#  ('k', 'o'): 0,
#  ('k', 'j'): 0,
#  ('k', 'ʍ'): 0,
#  ('k', 'm'): 0,
#  ('k', 'θ'): 0,
#  ('k', 'ɔː'): 0,
#  ('k', 'ɔ'): 0,
#  ('k', 'ʒ'): 0,
#  ('k', 'ɡ'): 0,
#  ('k', 'a'): 0,
#  ('k', 'æ'): 0,
#  ('k', 't͡ʃ'): 0,
#  ('k', 'ʊ'): 0,
#  ('k', 'ð'): 0,
#  ('k', 'h'): 0,
#  ('k', 'v'): 0,
#  ('k', 'd'): 0,
#  ('k', 'w'): 0,
#  ('k', 's'): 0,
#  ('k', 'uː'): 0,
#  ('k', 'ŋ'): 0,
#  ('k', 'd͡ʒ'): 0,
#  ('k', 'b'): 0,
#  ('k', 'ɝ'): 0,
#  ('k', 'ʃ'): 0,
#  ('k', 'ɫ'): 0,
#  ('k', 'n̩'): 0,
#  ('k', 'ɪ'): 0,
#  ('k', 'ɚ'): 0,
#  ('k', 'ə'): 0,
#  ('ɑː', 'k'): 0,
#  ('ɑː', 'ɑː'): 0,
#  ('ɑː', 'l'): 0,
#  ('ɑː', 'e'): 0,
#  ('ɑː', 'ɨ'): 0,
#  ('ɑː', 'p'): 0,
#  ('ɑː', 'ɛ'): 0,
#  ('ɑː', 'f'): 0,
#  ('ɑː', 'l̩'): 0,
#  ('ɑː', 'ɹ'): 0,
#  ('ɑː', 'ʌ'): 0,
#  ('ɑː', 'n'): 0,
#  ('ɑː', 'ɒ'): 0,
#  ('ɑː', 'i'): 0,
#  ('ɑː', 'u'): 0,
#  ('ɑː', 't'): 0,
#  ('ɑː', 'z'): 0,
#  ('ɑː', 'ɑ'): 0,
#  ('ɑː', 'iː'): 0,
#  ('ɑː', 'ɝː'): 0,
#  ('ɑː', 'ɜ'): 0,
#  ('ɑː', 'o'): 0,
#  ('ɑː', 'j'): 0,
#  ('ɑː', 'ʍ'): 0,
#  ('ɑː', 'm'): 0,
#  ('ɑː', 'θ'): 0,
#  ('ɑː', 'ɔː'): 0,
#  ('ɑː', 'ɔ'): 0,
#  ('ɑː', 'ʒ'): 0,
#  ('ɑː', 'ɡ'): 0,
#  ('ɑː', 'a'): 0,
#  ('ɑː', 'æ'): 0,
#  ('ɑː', 't͡ʃ'): 0,
#  ('ɑː', 'ʊ'): 0,
#  ('ɑː', 'ð'): 0,
#  ('ɑː', 'h'): 0,
#  ('ɑː', 'v'): 0,
#  ('ɑː', 'd'): 0,
#  ('ɑː', 'w'): 0,
#  ('ɑː', 's'): 0,
#  ('ɑː', 'uː'): 0,
#  ('ɑː', 'ŋ'): 0,
#  ('ɑː', 'd͡ʒ'): 0,
#  ('ɑː', 'b'): 0,
#  ('ɑː', 'ɝ'): 0,
#  ('ɑː', 'ʃ'): 0,
#  ('ɑː', 'ɫ'): 0,
#  ('ɑː', 'n̩'): 0,
#  ('ɑː', 'ɪ'): 0,
#  ('ɑː', 'ɚ'): 0,
#  ('ɑː', 'ə'): 0,
#  ('l', 'k'): 0,
#  ('l', 'ɑː'): 0,
#  ('l', 'l'): 0,
#  ('l', 'e'): 0,
#  ('l', 'ɨ'): 0,
#  ('l', 'p'): 0,
#  ('l', 'ɛ'): 0,
#  ('l', 'f'): 0,
#  ('l', 'l̩'): 0,
#  ('l', 'ɹ'): 0,
#  ('l', 'ʌ'): 0,
#  ('l', 'n'): 0,
#  ('l', 'ɒ'): 0,
#  ('l', 'i'): 0,
#  ('l', 'u'): 0,
#  ('l', 't'): 0,
#  ('l', 'z'): 0,
#  ('l', 'ɑ'): 0,
#  ('l', 'iː'): 0,
#  ('l', 'ɝː'): 0,
#  ('l', 'ɜ'): 0,
#  ('l', 'o'): 0,
#  ('l', 'j'): 0,
#  ('l', 'ʍ'): 0,
#  ('l', 'm'): 0,
#  ('l', 'θ'): 0,
#  ('l', 'ɔː'): 0,
#  ('l', 'ɔ'): 0,
#  ('l', 'ʒ'): 0,
#  ('l', 'ɡ'): 0,
#  ('l', 'a'): 0,
#  ('l', 'æ'): 0,
#  ('l', 't͡ʃ'): 0,
#  ('l', 'ʊ'): 0,
#  ('l', 'ð'): 0,
#  ('l', 'h'): 0,
#  ('l', 'v'): 0,
#  ('l', 'd'): 0,
#  ('l', 'w'): 0,
#  ('l', 's'): 0,
#  ('l', 'uː'): 0,
#  ('l', 'ŋ'): 0,
#  ('l', 'd͡ʒ'): 0,
#  ('l', 'b'): 0,
#  ('l', 'ɝ'): 0,
#  ('l', 'ʃ'): 0,
#  ('l', 'ɫ'): 0,
#  ('l', 'n̩'): 0,
#  ('l', 'ɪ'): 0,
#  ('l', 'ɚ'): 0,
#  ('l', 'ə'): 0,
#  ('e', 'k'): 0,
#  ('e', 'ɑː'): 0,
#  ('e', 'l'): 0,
#  ('e', 'e'): 0,
#  ('e', 'ɨ'): 0,
#  ('e', 'p'): 0,
#  ('e', 'ɛ'): 0,
#  ('e', 'f'): 0,
#  ('e', 'l̩'): 0,
#  ('e', 'ɹ'): 0,
#  ('e', 'ʌ'): 0,
#  ('e', 'n'): 0,
#  ('e', 'ɒ'): 0,
#  ('e', 'i'): 0,
#  ('e', 'u'): 0,
#  ('e', 't'): 0,
#  ('e', 'z'): 0,
#  ('e', 'ɑ'): 0,
#  ('e', 'iː'): 0,
#  ('e', 'ɝː'): 0,
#  ('e', 'ɜ'): 0,
#  ('e', 'o'): 0,
#  ('e', 'j'): 0,
#  ('e', 'ʍ'): 0,
#  ('e', 'm'): 0,
#  ('e', 'θ'): 0,
#  ('e', 'ɔː'): 0,
#  ('e', 'ɔ'): 0,
#  ('e', 'ʒ'): 0,
#  ('e', 'ɡ'): 0,
#  ('e', 'a'): 0,
#  ('e', 'æ'): 0,
#  ('e', 't͡ʃ'): 0,
#  ('e', 'ʊ'): 0,
#  ('e', 'ð'): 0,
#  ('e', 'h'): 0,
#  ('e', 'v'): 0,
#  ('e', 'd'): 0,
#  ('e', 'w'): 0,
#  ('e', 's'): 0,
#  ('e', 'uː'): 0,
#  ('e', 'ŋ'): 0,
#  ('e', 'd͡ʒ'): 0,
#  ('e', 'b'): 0,
#  ('e', 'ɝ'): 0,
#  ('e', 'ʃ'): 0,
#  ('e', 'ɫ'): 0,
#  ('e', 'n̩'): 0,
#  ('e', 'ɪ'): 0,
#  ('e', 'ɚ'): 0,
#  ('e', 'ə'): 0,
#  ('ɨ', 'k'): 0,
#  ('ɨ', 'ɑː'): 0,
#  ('ɨ', 'l'): 0,
#  ('ɨ', 'e'): 0,
#  ('ɨ', 'ɨ'): 0,
#  ('ɨ', 'p'): 0,
#  ('ɨ', 'ɛ'): 0,
#  ('ɨ', 'f'): 0,
#  ('ɨ', 'l̩'): 0,
#  ('ɨ', 'ɹ'): 0,
#  ('ɨ', 'ʌ'): 0,
#  ('ɨ', 'n'): 0,
#  ('ɨ', 'ɒ'): 0,
#  ('ɨ', 'i'): 0,
#  ('ɨ', 'u'): 0,
#  ('ɨ', 't'): 0,
#  ('ɨ', 'z'): 0,
#  ('ɨ', 'ɑ'): 0,
#  ('ɨ', 'iː'): 0,
#  ('ɨ', 'ɝː'): 0,
#  ('ɨ', 'ɜ'): 0,
#  ('ɨ', 'o'): 0,
#  ('ɨ', 'j'): 0,
#  ('ɨ', 'ʍ'): 0,
#  ('ɨ', 'm'): 0,
#  ('ɨ', 'θ'): 0,
#  ('ɨ', 'ɔː'): 0,
#  ('ɨ', 'ɔ'): 0,
#  ('ɨ', 'ʒ'): 0,
#  ('ɨ', 'ɡ'): 0,
#  ('ɨ', 'a'): 0,
#  ('ɨ', 'æ'): 0,
#  ('ɨ', 't͡ʃ'): 0,
#  ('ɨ', 'ʊ'): 0,
#  ('ɨ', 'ð'): 0,
#  ('ɨ', 'h'): 0,
#  ('ɨ', 'v'): 0,
#  ('ɨ', 'd'): 0,
#  ('ɨ', 'w'): 0,
#  ('ɨ', 's'): 0,
#  ('ɨ', 'uː'): 0,
#  ('ɨ', 'ŋ'): 0,
#  ('ɨ', 'd͡ʒ'): 0,
#  ('ɨ', 'b'): 0,
#  ('ɨ', 'ɝ'): 0,
#  ('ɨ', 'ʃ'): 0,
#  ('ɨ', 'ɫ'): 0,
#  ('ɨ', 'n̩'): 0,
#  ('ɨ', 'ɪ'): 0,
#  ('ɨ', 'ɚ'): 0,
#  ('ɨ', 'ə'): 0,
#  ('p', 'k'): 0,
#  ('p', 'ɑː'): 0,
#  ('p', 'l'): 0,
#  ('p', 'e'): 0,
#  ('p', 'ɨ'): 0,
#  ('p', 'p'): 0,
#  ('p', 'ɛ'): 0,
#  ('p', 'f'): 0,
#  ('p', 'l̩'): 0,
#  ('p', 'ɹ'): 0,
#  ('p', 'ʌ'): 0,
#  ('p', 'n'): 0,
#  ('p', 'ɒ'): 0,
#  ('p', 'i'): 0,
#  ('p', 'u'): 0,
#  ('p', 't'): 0,
#  ('p', 'z'): 0,
#  ('p', 'ɑ'): 0,
#  ('p', 'iː'): 0,
#  ('p', 'ɝː'): 0,
#  ('p', 'ɜ'): 0,
#  ('p', 'o'): 0,
#  ('p', 'j'): 0,
#  ('p', 'ʍ'): 0,
#  ('p', 'm'): 0,
#  ('p', 'θ'): 0,
#  ('p', 'ɔː'): 0,
#  ('p', 'ɔ'): 0,
#  ('p', 'ʒ'): 0,
#  ('p', 'ɡ'): 0,
#  ('p', 'a'): 0,
#  ('p', 'æ'): 0,
#  ('p', 't͡ʃ'): 0,
#  ('p', 'ʊ'): 0,
#  ('p', 'ð'): 0,
#  ('p', 'h'): 0,
#  ('p', 'v'): 0,
#  ('p', 'd'): 0,
#  ('p', 'w'): 0,
#  ('p', 's'): 0,
#  ('p', 'uː'): 0,
#  ('p', 'ŋ'): 0,
#  ('p', 'd͡ʒ'): 0,
#  ('p', 'b'): 0,
#  ('p', 'ɝ'): 0,
#  ('p', 'ʃ'): 0,
#  ('p', 'ɫ'): 0,
#  ('p', 'n̩'): 0,
#  ('p', 'ɪ'): 0,
#  ('p', 'ɚ'): 0,
#  ('p', 'ə'): 0,
#  ('ɛ', 'k'): 0,
#  ('ɛ', 'ɑː'): 0,
#  ('ɛ', 'l'): 0,
#  ('ɛ', 'e'): 0,
#  ('ɛ', 'ɨ'): 0,
#  ('ɛ', 'p'): 0,
#  ('ɛ', 'ɛ'): 0,
#  ('ɛ', 'f'): 0,
#  ('ɛ', 'l̩'): 0,
#  ('ɛ', 'ɹ'): 0,
#  ('ɛ', 'ʌ'): 0,
#  ('ɛ', 'n'): 0,
#  ('ɛ', 'ɒ'): 0,
#  ('ɛ', 'i'): 0,
#  ('ɛ', 'u'): 0,
#  ('ɛ', 't'): 0,
#  ('ɛ', 'z'): 0,
#  ('ɛ', 'ɑ'): 0,
#  ('ɛ', 'iː'): 0,
#  ('ɛ', 'ɝː'): 0,
#  ('ɛ', 'ɜ'): 0,
#  ('ɛ', 'o'): 0,
#  ('ɛ', 'j'): 0,
#  ('ɛ', 'ʍ'): 0,
#  ('ɛ', 'm'): 0,
#  ('ɛ', 'θ'): 0,
#  ('ɛ', 'ɔː'): 0,
#  ('ɛ', 'ɔ'): 0,
#  ('ɛ', 'ʒ'): 0,
#  ('ɛ', 'ɡ'): 0,
#  ('ɛ', 'a'): 0,
#  ('ɛ', 'æ'): 0,
#  ('ɛ', 't͡ʃ'): 0,
#  ('ɛ', 'ʊ'): 0,
#  ('ɛ', 'ð'): 0,
#  ('ɛ', 'h'): 0,
#  ('ɛ', 'v'): 0,
#  ('ɛ', 'd'): 0,
#  ('ɛ', 'w'): 0,
#  ('ɛ', 's'): 0,
#  ('ɛ', 'uː'): 0,
#  ('ɛ', 'ŋ'): 0,
#  ('ɛ', 'd͡ʒ'): 0,
#  ('ɛ', 'b'): 0,
#  ('ɛ', 'ɝ'): 0,
#  ('ɛ', 'ʃ'): 0,
#  ('ɛ', 'ɫ'): 0,
#  ('ɛ', 'n̩'): 0,
#  ('ɛ', 'ɪ'): 0,
#  ('ɛ', 'ɚ'): 0,
#  ('ɛ', 'ə'): 0,
#  ('f', 'k'): 0,
#  ('f', 'ɑː'): 0,
#  ('f', 'l'): 0,
#  ('f', 'e'): 0,
#  ('f', 'ɨ'): 0,
#  ('f', 'p'): 0,
#  ('f', 'ɛ'): 0,
#  ('f', 'f'): 0,
#  ('f', 'l̩'): 0,
#  ('f', 'ɹ'): 0,
#  ('f', 'ʌ'): 0,
#  ('f', 'n'): 0,
#  ('f', 'ɒ'): 0,
#  ('f', 'i'): 0,
#  ('f', 'u'): 0,
#  ('f', 't'): 0,
#  ('f', 'z'): 0,
#  ('f', 'ɑ'): 0,
#  ('f', 'iː'): 0,
#  ('f', 'ɝː'): 0,
#  ('f', 'ɜ'): 0,
#  ('f', 'o'): 0,
#  ('f', 'j'): 0,
#  ('f', 'ʍ'): 0,
#  ('f', 'm'): 0,
#  ('f', 'θ'): 0,
#  ('f', 'ɔː'): 0,
#  ('f', 'ɔ'): 0,
#  ('f', 'ʒ'): 0,
#  ('f', 'ɡ'): 0,
#  ('f', 'a'): 0,
#  ('f', 'æ'): 0,
#  ('f', 't͡ʃ'): 0,
#  ('f', 'ʊ'): 0,
#  ('f', 'ð'): 0,
#  ('f', 'h'): 0,
#  ('f', 'v'): 0,
#  ('f', 'd'): 0,
#  ('f', 'w'): 0,
#  ('f', 's'): 0,
#  ('f', 'uː'): 0,
#  ('f', 'ŋ'): 0,
#  ('f', 'd͡ʒ'): 0,
#  ('f', 'b'): 0,
#  ('f', 'ɝ'): 0,
#  ('f', 'ʃ'): 0,
#  ('f', 'ɫ'): 0,
#  ('f', 'n̩'): 0,
#  ('f', 'ɪ'): 0,
#  ('f', 'ɚ'): 0,
#  ('f', 'ə'): 0,
#  ('l̩', 'k'): 0,
#  ('l̩', 'ɑː'): 0,
#  ('l̩', 'l'): 0,
#  ('l̩', 'e'): 0,
#  ('l̩', 'ɨ'): 0,
#  ('l̩', 'p'): 0,
#  ('l̩', 'ɛ'): 0,
#  ('l̩', 'f'): 0,
#  ('l̩', 'l̩'): 0,
#  ('l̩', 'ɹ'): 0,
#  ('l̩', 'ʌ'): 0,
#  ('l̩', 'n'): 0,
#  ('l̩', 'ɒ'): 0,
#  ('l̩', 'i'): 0,
#  ('l̩', 'u'): 0,
#  ('l̩', 't'): 0,
#  ('l̩', 'z'): 0,
#  ('l̩', 'ɑ'): 0,
#  ('l̩', 'iː'): 0,
#  ('l̩', 'ɝː'): 0,
#  ('l̩', 'ɜ'): 0,
#  ('l̩', 'o'): 0,
#  ('l̩', 'j'): 0,
#  ('l̩', 'ʍ'): 0,
#  ('l̩', 'm'): 0,
#  ('l̩', 'θ'): 0,
#  ('l̩', 'ɔː'): 0,
#  ('l̩', 'ɔ'): 0,
#  ('l̩', 'ʒ'): 0,
#  ('l̩', 'ɡ'): 0,
#  ('l̩', 'a'): 0,
#  ('l̩', 'æ'): 0,
#  ('l̩', 't͡ʃ'): 0,
#  ('l̩', 'ʊ'): 0,
#  ('l̩', 'ð'): 0,
#  ('l̩', 'h'): 0,
#  ('l̩', 'v'): 0,
#  ('l̩', 'd'): 0,
#  ('l̩', 'w'): 0,
#  ('l̩', 's'): 0,
#  ('l̩', 'uː'): 0,
#  ('l̩', 'ŋ'): 0,
#  ('l̩', 'd͡ʒ'): 0,
#  ('l̩', 'b'): 0,
#  ('l̩', 'ɝ'): 0,
#  ('l̩', 'ʃ'): 0,
#  ('l̩', 'ɫ'): 0,
#  ('l̩', 'n̩'): 0,
#  ('l̩', 'ɪ'): 0,
#  ('l̩', 'ɚ'): 0,
#  ('l̩', 'ə'): 0,
#  ('ɹ', 'k'): 0,
#  ('ɹ', 'ɑː'): 0,
#  ('ɹ', 'l'): 0,
#  ('ɹ', 'e'): 0,
#  ('ɹ', 'ɨ'): 0,
#  ('ɹ', 'p'): 0,
#  ('ɹ', 'ɛ'): 0,
#  ('ɹ', 'f'): 0,
#  ('ɹ', 'l̩'): 0,
#  ('ɹ', 'ɹ'): 0,
#  ('ɹ', 'ʌ'): 0,
#  ('ɹ', 'n'): 0,
#  ('ɹ', 'ɒ'): 0,
#  ('ɹ', 'i'): 0,
#  ('ɹ', 'u'): 0,
#  ('ɹ', 't'): 0,
#  ('ɹ', 'z'): 0,
#  ('ɹ', 'ɑ'): 0,
#  ('ɹ', 'iː'): 0,
#  ('ɹ', 'ɝː'): 0,
#  ('ɹ', 'ɜ'): 0,
#  ('ɹ', 'o'): 0,
#  ('ɹ', 'j'): 0,
#  ('ɹ', 'ʍ'): 0,
#  ('ɹ', 'm'): 0,
#  ('ɹ', 'θ'): 0,
#  ('ɹ', 'ɔː'): 0,
#  ('ɹ', 'ɔ'): 0,
#  ('ɹ', 'ʒ'): 0,
#  ('ɹ', 'ɡ'): 0,
#  ('ɹ', 'a'): 0,
#  ('ɹ', 'æ'): 0,
#  ('ɹ', 't͡ʃ'): 0,
#  ('ɹ', 'ʊ'): 0,
#  ('ɹ', 'ð'): 0,
#  ('ɹ', 'h'): 0,
#  ('ɹ', 'v'): 0,
#  ('ɹ', 'd'): 0,
#  ('ɹ', 'w'): 0,
#  ('ɹ', 's'): 0,
#  ('ɹ', 'uː'): 0,
#  ('ɹ', 'ŋ'): 0,
#  ('ɹ', 'd͡ʒ'): 0,
#  ('ɹ', 'b'): 0,
#  ('ɹ', 'ɝ'): 0,
#  ('ɹ', 'ʃ'): 0,
#  ('ɹ', 'ɫ'): 0,
#  ('ɹ', 'n̩'): 0,
#  ('ɹ', 'ɪ'): 0,
#  ('ɹ', 'ɚ'): 0,
#  ('ɹ', 'ə'): 0,
#  ('ʌ', 'k'): 0,
#  ('ʌ', 'ɑː'): 0,
#  ('ʌ', 'l'): 0,
#  ('ʌ', 'e'): 0,
#  ('ʌ', 'ɨ'): 0,
#  ('ʌ', 'p'): 0,
#  ('ʌ', 'ɛ'): 0,
#  ('ʌ', 'f'): 0,
#  ('ʌ', 'l̩'): 0,
#  ('ʌ', 'ɹ'): 0,
#  ('ʌ', 'ʌ'): 0,
#  ('ʌ', 'n'): 0,
#  ('ʌ', 'ɒ'): 0,
#  ('ʌ', 'i'): 0,
#  ('ʌ', 'u'): 0,
#  ('ʌ', 't'): 0,
#  ('ʌ', 'z'): 0,
#  ('ʌ', 'ɑ'): 0,
#  ('ʌ', 'iː'): 0,
#  ('ʌ', 'ɝː'): 0,
#  ('ʌ', 'ɜ'): 0,
#  ('ʌ', 'o'): 0,
#  ('ʌ', 'j'): 0,
#  ('ʌ', 'ʍ'): 0,
#  ('ʌ', 'm'): 0,
#  ('ʌ', 'θ'): 0,
#  ('ʌ', 'ɔː'): 0,
#  ('ʌ', 'ɔ'): 0,
#  ('ʌ', 'ʒ'): 0,
#  ('ʌ', 'ɡ'): 0,
#  ('ʌ', 'a'): 0,
#  ('ʌ', 'æ'): 0,
#  ('ʌ', 't͡ʃ'): 0,
#  ('ʌ', 'ʊ'): 0,
#  ('ʌ', 'ð'): 0,
#  ('ʌ', 'h'): 0,
#  ('ʌ', 'v'): 0,
#  ('ʌ', 'd'): 0,
#  ('ʌ', 'w'): 0,
#  ('ʌ', 's'): 0,
#  ('ʌ', 'uː'): 0,
#  ('ʌ', 'ŋ'): 0,
#  ('ʌ', 'd͡ʒ'): 0,
#  ('ʌ', 'b'): 0,
#  ('ʌ', 'ɝ'): 0,
#  ('ʌ', 'ʃ'): 0,
#  ('ʌ', 'ɫ'): 0,
#  ('ʌ', 'n̩'): 0,
#  ('ʌ', 'ɪ'): 0,
#  ('ʌ', 'ɚ'): 0,
#  ('ʌ', 'ə'): 0,
#  ('n', 'k'): 0,
#  ('n', 'ɑː'): 0,
#  ('n', 'l'): 0,
#  ('n', 'e'): 0,
#  ('n', 'ɨ'): 0,
#  ('n', 'p'): 0,
#  ('n', 'ɛ'): 0,
#  ('n', 'f'): 0,
#  ('n', 'l̩'): 0,
#  ('n', 'ɹ'): 0,
#  ('n', 'ʌ'): 0,
#  ('n', 'n'): 0,
#  ('n', 'ɒ'): 0,
#  ('n', 'i'): 0,
#  ('n', 'u'): 0,
#  ('n', 't'): 0,
#  ('n', 'z'): 0,
#  ('n', 'ɑ'): 0,
#  ('n', 'iː'): 0,
#  ('n', 'ɝː'): 0,
#  ('n', 'ɜ'): 0,
#  ('n', 'o'): 0,
#  ('n', 'j'): 0,
#  ('n', 'ʍ'): 0,
#  ('n', 'm'): 0,
#  ('n', 'θ'): 0,
#  ('n', 'ɔː'): 0,
#  ('n', 'ɔ'): 0,
#  ('n', 'ʒ'): 0,
#  ('n', 'ɡ'): 0,
#  ('n', 'a'): 0,
#  ('n', 'æ'): 0,
#  ('n', 't͡ʃ'): 0,
#  ('n', 'ʊ'): 0,
#  ('n', 'ð'): 0,
#  ('n', 'h'): 0,
#  ('n', 'v'): 0,
#  ('n', 'd'): 0,
#  ('n', 'w'): 0,
#  ('n', 's'): 0,
#  ('n', 'uː'): 0,
#  ('n', 'ŋ'): 0,
#  ('n', 'd͡ʒ'): 0,
#  ('n', 'b'): 0,
#  ('n', 'ɝ'): 0,
#  ('n', 'ʃ'): 0,
#  ('n', 'ɫ'): 0,
#  ('n', 'n̩'): 0,
#  ('n', 'ɪ'): 0,
#  ('n', 'ɚ'): 0,
#  ('n', 'ə'): 0,
#  ('ɒ', 'k'): 0,
#  ('ɒ', 'ɑː'): 0,
#  ('ɒ', 'l'): 0,
#  ('ɒ', 'e'): 0,
#  ('ɒ', 'ɨ'): 0,
#  ('ɒ', 'p'): 0,
#  ('ɒ', 'ɛ'): 0,
#  ('ɒ', 'f'): 0,
#  ('ɒ', 'l̩'): 0,
#  ('ɒ', 'ɹ'): 0,
#  ('ɒ', 'ʌ'): 0,
#  ('ɒ', 'n'): 0,
#  ('ɒ', 'ɒ'): 0,
#  ('ɒ', 'i'): 0,
#  ('ɒ', 'u'): 0,
#  ('ɒ', 't'): 0,
#  ('ɒ', 'z'): 0,
#  ('ɒ', 'ɑ'): 0,
#  ('ɒ', 'iː'): 0,
#  ('ɒ', 'ɝː'): 0,
#  ('ɒ', 'ɜ'): 0,
#  ('ɒ', 'o'): 0,
#  ('ɒ', 'j'): 0,
#  ('ɒ', 'ʍ'): 0,
#  ('ɒ', 'm'): 0,
#  ('ɒ', 'θ'): 0,
#  ('ɒ', 'ɔː'): 0,
#  ('ɒ', 'ɔ'): 0,
#  ('ɒ', 'ʒ'): 0,
#  ('ɒ', 'ɡ'): 0,
#  ('ɒ', 'a'): 0,
#  ('ɒ', 'æ'): 0,
#  ('ɒ', 't͡ʃ'): 0,
#  ('ɒ', 'ʊ'): 0,
#  ('ɒ', 'ð'): 0,
#  ('ɒ', 'h'): 0,
#  ('ɒ', 'v'): 0,
#  ('ɒ', 'd'): 0,
#  ('ɒ', 'w'): 0,
#  ('ɒ', 's'): 0,
#  ('ɒ', 'uː'): 0,
#  ('ɒ', 'ŋ'): 0,
#  ('ɒ', 'd͡ʒ'): 0,
#  ('ɒ', 'b'): 0,
#  ('ɒ', 'ɝ'): 0,
#  ('ɒ', 'ʃ'): 0,
#  ('ɒ', 'ɫ'): 0,
#  ('ɒ', 'n̩'): 0,
#  ('ɒ', 'ɪ'): 0,
#  ('ɒ', 'ɚ'): 0,
#  ('ɒ', 'ə'): 0,
#  ('i', 'k'): 0,
#  ('i', 'ɑː'): 0,
#  ('i', 'l'): 0,
#  ('i', 'e'): 0,
#  ('i', 'ɨ'): 0,
#  ('i', 'p'): 0,
#  ('i', 'ɛ'): 0,
#  ('i', 'f'): 0,
#  ('i', 'l̩'): 0,
#  ('i', 'ɹ'): 0,
#  ('i', 'ʌ'): 0,
#  ('i', 'n'): 0,
#  ('i', 'ɒ'): 0,
#  ('i', 'i'): 0,
#  ('i', 'u'): 0,
#  ('i', 't'): 0,
#  ('i', 'z'): 0,
#  ('i', 'ɑ'): 0,
#  ('i', 'iː'): 0,
#  ('i', 'ɝː'): 0,
#  ('i', 'ɜ'): 0,
#  ('i', 'o'): 0,
#  ('i', 'j'): 0,
#  ('i', 'ʍ'): 0,
#  ('i', 'm'): 0,
#  ('i', 'θ'): 0,
#  ('i', 'ɔː'): 0,
#  ('i', 'ɔ'): 0,
#  ('i', 'ʒ'): 0,
#  ('i', 'ɡ'): 0,
#  ('i', 'a'): 0,
#  ('i', 'æ'): 0,
#  ('i', 't͡ʃ'): 0,
#  ('i', 'ʊ'): 0,
#  ('i', 'ð'): 0,
#  ('i', 'h'): 0,
#  ('i', 'v'): 0,
#  ('i', 'd'): 0,
#  ('i', 'w'): 0,
#  ('i', 's'): 0,
#  ('i', 'uː'): 0,
#  ('i', 'ŋ'): 0,
#  ('i', 'd͡ʒ'): 0,
#  ('i', 'b'): 0,
#  ('i', 'ɝ'): 0,
#  ('i', 'ʃ'): 0,
#  ('i', 'ɫ'): 0,
#  ('i', 'n̩'): 0,
#  ('i', 'ɪ'): 0,
#  ('i', 'ɚ'): 0,
#  ('i', 'ə'): 0,
#  ('u', 'k'): 0,
#  ('u', 'ɑː'): 0,
#  ('u', 'l'): 0,
#  ('u', 'e'): 0,
#  ('u', 'ɨ'): 0,
#  ('u', 'p'): 0,
#  ('u', 'ɛ'): 0,
#  ('u', 'f'): 0,
#  ('u', 'l̩'): 0,
#  ('u', 'ɹ'): 0,
#  ('u', 'ʌ'): 0,
#  ('u', 'n'): 0,
#  ('u', 'ɒ'): 0,
#  ('u', 'i'): 0,
#  ('u', 'u'): 0,
#  ('u', 't'): 0,
#  ('u', 'z'): 0,
#  ('u', 'ɑ'): 0,
#  ('u', 'iː'): 0,
#  ('u', 'ɝː'): 0,
#  ('u', 'ɜ'): 0,
#  ('u', 'o'): 0,
#  ('u', 'j'): 0,
#  ('u', 'ʍ'): 0,
#  ('u', 'm'): 0,
#  ('u', 'θ'): 0,
#  ('u', 'ɔː'): 0,
#  ('u', 'ɔ'): 0,
#  ('u', 'ʒ'): 0,
#  ('u', 'ɡ'): 0,
#  ('u', 'a'): 0,
#  ('u', 'æ'): 0,
#  ('u', 't͡ʃ'): 0,
#  ('u', 'ʊ'): 0,
#  ('u', 'ð'): 0,
#  ('u', 'h'): 0,
#  ('u', 'v'): 0,
#  ('u', 'd'): 0,
#  ('u', 'w'): 0,
#  ('u', 's'): 0,
#  ('u', 'uː'): 0,
#  ('u', 'ŋ'): 0,
#  ('u', 'd͡ʒ'): 0,
#  ('u', 'b'): 0,
#  ('u', 'ɝ'): 0,
#  ('u', 'ʃ'): 0,
#  ('u', 'ɫ'): 0,
#  ('u', 'n̩'): 0,
#  ('u', 'ɪ'): 0,
#  ('u', 'ɚ'): 0,
#  ('u', 'ə'): 0,
#  ('t', 'k'): 0,
#  ('t', 'ɑː'): 0,
#  ('t', 'l'): 0,
#  ('t', 'e'): 0,
#  ('t', 'ɨ'): 0,
#  ('t', 'p'): 0,
#  ('t', 'ɛ'): 0,
#  ('t', 'f'): 0,
#  ('t', 'l̩'): 0,
#  ('t', 'ɹ'): 0,
#  ('t', 'ʌ'): 0,
#  ('t', 'n'): 0,
#  ('t', 'ɒ'): 0,
#  ('t', 'i'): 0,
#  ('t', 'u'): 0,
#  ('t', 't'): 0,
#  ('t', 'z'): 0,
#  ('t', 'ɑ'): 0,
#  ('t', 'iː'): 0,
#  ('t', 'ɝː'): 0,
#  ('t', 'ɜ'): 0,
#  ('t', 'o'): 0,
#  ('t', 'j'): 0,
#  ('t', 'ʍ'): 0,
#  ('t', 'm'): 0,
#  ('t', 'θ'): 0,
#  ('t', 'ɔː'): 0,
#  ('t', 'ɔ'): 0,
#  ('t', 'ʒ'): 0,
#  ('t', 'ɡ'): 0,
#  ('t', 'a'): 0,
#  ('t', 'æ'): 0,
#  ('t', 't͡ʃ'): 0,
#  ('t', 'ʊ'): 0,
#  ('t', 'ð'): 0,
#  ('t', 'h'): 0,
#  ('t', 'v'): 0,
#  ('t', 'd'): 0,
#  ('t', 'w'): 0,
#  ('t', 's'): 0,
#  ('t', 'uː'): 0,
#  ('t', 'ŋ'): 0,
#  ('t', 'd͡ʒ'): 0,
#  ('t', 'b'): 0,
#  ('t', 'ɝ'): 0,
#  ('t', 'ʃ'): 0,
#  ('t', 'ɫ'): 0,
#  ('t', 'n̩'): 0,
#  ('t', 'ɪ'): 0,
#  ('t', 'ɚ'): 0,
#  ('t', 'ə'): 0,
#  ('z', 'k'): 0,
#  ('z', 'ɑː'): 0,
#  ('z', 'l'): 0,
#  ('z', 'e'): 0,
#  ('z', 'ɨ'): 0,
#  ('z', 'p'): 0,
#  ('z', 'ɛ'): 0,
#  ('z', 'f'): 0,
#  ('z', 'l̩'): 0,
#  ('z', 'ɹ'): 0,
#  ('z', 'ʌ'): 0,
#  ('z', 'n'): 0,
#  ('z', 'ɒ'): 0,
#  ('z', 'i'): 0,
#  ('z', 'u'): 0,
#  ('z', 't'): 0,
#  ('z', 'z'): 0,
#  ('z', 'ɑ'): 0,
#  ('z', 'iː'): 0,
#  ('z', 'ɝː'): 0,
#  ('z', 'ɜ'): 0,
#  ('z', 'o'): 0,
#  ('z', 'j'): 0,
#  ('z', 'ʍ'): 0,
#  ('z', 'm'): 0,
#  ('z', 'θ'): 0,
#  ('z', 'ɔː'): 0,
#  ('z', 'ɔ'): 0,
#  ('z', 'ʒ'): 0,
#  ('z', 'ɡ'): 0,
#  ('z', 'a'): 0,
#  ('z', 'æ'): 0,
#  ('z', 't͡ʃ'): 0,
#  ('z', 'ʊ'): 0,
#  ('z', 'ð'): 0,
#  ('z', 'h'): 0,
#  ('z', 'v'): 0,
#  ('z', 'd'): 0,
#  ('z', 'w'): 0,
#  ('z', 's'): 0,
#  ('z', 'uː'): 0,
#  ('z', 'ŋ'): 0,
#  ('z', 'd͡ʒ'): 0,
#  ('z', 'b'): 0,
#  ('z', 'ɝ'): 0,
#  ('z', 'ʃ'): 0,
#  ('z', 'ɫ'): 0,
#  ('z', 'n̩'): 0,
#  ('z', 'ɪ'): 0,
#  ('z', 'ɚ'): 0,
#  ('z', 'ə'): 0,
#  ('ɑ', 'k'): 0,
#  ('ɑ', 'ɑː'): 0,
#  ('ɑ', 'l'): 0,
#  ('ɑ', 'e'): 0,
#  ('ɑ', 'ɨ'): 0,
#  ('ɑ', 'p'): 0,
#  ('ɑ', 'ɛ'): 0,
#  ('ɑ', 'f'): 0,
#  ('ɑ', 'l̩'): 0,
#  ('ɑ', 'ɹ'): 0,
#  ('ɑ', 'ʌ'): 0,
#  ('ɑ', 'n'): 0,
#  ('ɑ', 'ɒ'): 0,
#  ('ɑ', 'i'): 0,
#  ('ɑ', 'u'): 0,
#  ('ɑ', 't'): 0,
#  ('ɑ', 'z'): 0,
#  ('ɑ', 'ɑ'): 0,
#  ('ɑ', 'iː'): 0,
#  ('ɑ', 'ɝː'): 0,
#  ('ɑ', 'ɜ'): 0,
#  ('ɑ', 'o'): 0,
#  ('ɑ', 'j'): 0,
#  ('ɑ', 'ʍ'): 0,
#  ('ɑ', 'm'): 0,
#  ('ɑ', 'θ'): 0,
#  ('ɑ', 'ɔː'): 0,
#  ('ɑ', 'ɔ'): 0,
#  ('ɑ', 'ʒ'): 0,
#  ('ɑ', 'ɡ'): 0,
#  ('ɑ', 'a'): 0,
#  ('ɑ', 'æ'): 0,
#  ('ɑ', 't͡ʃ'): 0,
#  ('ɑ', 'ʊ'): 0,
#  ('ɑ', 'ð'): 0,
#  ('ɑ', 'h'): 0,
#  ('ɑ', 'v'): 0,
#  ('ɑ', 'd'): 0,
#  ('ɑ', 'w'): 0,
#  ('ɑ', 's'): 0,
#  ('ɑ', 'uː'): 0,
#  ('ɑ', 'ŋ'): 0,
#  ('ɑ', 'd͡ʒ'): 0,
#  ('ɑ', 'b'): 0,
#  ('ɑ', 'ɝ'): 0,
#  ('ɑ', 'ʃ'): 0,
#  ('ɑ', 'ɫ'): 0,
#  ('ɑ', 'n̩'): 0,
#  ('ɑ', 'ɪ'): 0,
#  ('ɑ', 'ɚ'): 0,
#  ('ɑ', 'ə'): 0,
#  ('iː', 'k'): 0,
#  ('iː', 'ɑː'): 0,
#  ('iː', 'l'): 0,
#  ('iː', 'e'): 0,
#  ('iː', 'ɨ'): 0,
#  ('iː', 'p'): 0,
#  ('iː', 'ɛ'): 0,
#  ('iː', 'f'): 0,
#  ('iː', 'l̩'): 0,
#  ('iː', 'ɹ'): 0,
#  ('iː', 'ʌ'): 0,
#  ('iː', 'n'): 0,
#  ('iː', 'ɒ'): 0,
#  ('iː', 'i'): 0,
#  ('iː', 'u'): 0,
#  ('iː', 't'): 0,
#  ('iː', 'z'): 0,
#  ('iː', 'ɑ'): 0,
#  ('iː', 'iː'): 0,
#  ('iː', 'ɝː'): 0,
#  ('iː', 'ɜ'): 0,
#  ('iː', 'o'): 0,
#  ('iː', 'j'): 0,
#  ('iː', 'ʍ'): 0,
#  ('iː', 'm'): 0,
#  ('iː', 'θ'): 0,
#  ('iː', 'ɔː'): 0,
#  ('iː', 'ɔ'): 0,
#  ('iː', 'ʒ'): 0,
#  ('iː', 'ɡ'): 0,
#  ('iː', 'a'): 0,
#  ('iː', 'æ'): 0,
#  ('iː', 't͡ʃ'): 0,
#  ('iː', 'ʊ'): 0,
#  ('iː', 'ð'): 0,
#  ('iː', 'h'): 0,
#  ('iː', 'v'): 0,
#  ('iː', 'd'): 0,
#  ('iː', 'w'): 0,
#  ('iː', 's'): 0,
#  ('iː', 'uː'): 0,
#  ('iː', 'ŋ'): 0,
#  ('iː', 'd͡ʒ'): 0,
#  ('iː', 'b'): 0,
#  ('iː', 'ɝ'): 0,
#  ('iː', 'ʃ'): 0,
#  ('iː', 'ɫ'): 0,
#  ('iː', 'n̩'): 0,
#  ('iː', 'ɪ'): 0,
#  ('iː', 'ɚ'): 0,
#  ('iː', 'ə'): 0,
#  ('ɝː', 'k'): 0,
#  ('ɝː', 'ɑː'): 0,
#  ('ɝː', 'l'): 0,
#  ('ɝː', 'e'): 0,
#  ('ɝː', 'ɨ'): 0,
#  ('ɝː', 'p'): 0,
#  ('ɝː', 'ɛ'): 0,
#  ('ɝː', 'f'): 0,
#  ('ɝː', 'l̩'): 0,
#  ('ɝː', 'ɹ'): 0,
#  ('ɝː', 'ʌ'): 0,
#  ('ɝː', 'n'): 0,
#  ('ɝː', 'ɒ'): 0,
#  ('ɝː', 'i'): 0,
#  ('ɝː', 'u'): 0,
#  ('ɝː', 't'): 0,
#  ('ɝː', 'z'): 0,
#  ('ɝː', 'ɑ'): 0,
#  ('ɝː', 'iː'): 0,
#  ('ɝː', 'ɝː'): 0,
#  ('ɝː', 'ɜ'): 0,
#  ('ɝː', 'o'): 0,
#  ('ɝː', 'j'): 0,
#  ('ɝː', 'ʍ'): 0,
#  ('ɝː', 'm'): 0,
#  ('ɝː', 'θ'): 0,
#  ('ɝː', 'ɔː'): 0,
#  ('ɝː', 'ɔ'): 0,
#  ('ɝː', 'ʒ'): 0,
#  ('ɝː', 'ɡ'): 0,
#  ('ɝː', 'a'): 0,
#  ...}

# %%
# now slide a width-3 window through the corpus, and increment the (p1,p2) count for every (p1,p2) 
# phoneme pair you encounter, provided a word boundary ('*') appears between them.

# YOUR CODE GOES HERE.
for i in range(len(ec) - 2):
    window = ec[i: (i+3)]
    if window[1] == '*':
         ptp_across_count[(window[0], window[2])] += 1

ptp_across_count
# Out:
# {('k', 'k'): 0,
#  ('k', 'ɑː'): 0,
#  ('k', 'l'): 0,
#  ('k', 'e'): 0,
#  ('k', 'ɨ'): 0,
#  ('k', 'p'): 1,
#  ('k', 'ɛ'): 0,
#  ('k', 'f'): 1,
#  ('k', 'l̩'): 0,
#  ('k', 'ɹ'): 0,
#  ('k', 'ʌ'): 0,
#  ('k', 'n'): 0,
#  ('k', 'ɒ'): 0,
#  ('k', 'i'): 0,
#  ('k', 'u'): 0,
#  ('k', 't'): 1,
#  ('k', 'z'): 0,
#  ('k', 'ɑ'): 0,
#  ('k', 'iː'): 0,
#  ('k', 'ɝː'): 0,
#  ('k', 'ɜ'): 0,
#  ('k', 'o'): 2,
#  ('k', 'j'): 3,
#  ('k', 'ʍ'): 0,
#  ('k', 'm'): 0,
#  ('k', 'θ'): 0,
#  ('k', 'ɔː'): 0,
#  ('k', 'ɔ'): 0,
#  ('k', 'ʒ'): 0,
#  ('k', 'ɡ'): 1,
#  ('k', 'a'): 0,
#  ('k', 'æ'): 0,
#  ('k', 't͡ʃ'): 0,
#  ('k', 'ʊ'): 0,
#  ('k', 'ð'): 9,
#  ('k', 'h'): 3,
#  ('k', 'v'): 0,
#  ('k', 'd'): 1,
#  ('k', 'w'): 1,
#  ('k', 's'): 5,
#  ('k', 'uː'): 0,
#  ('k', 'ŋ'): 0,
#  ('k', 'd͡ʒ'): 0,
#  ('k', 'b'): 2,
#  ('k', 'ɝ'): 0,
#  ('k', 'ʃ'): 0,
#  ('k', 'ɫ'): 0,
#  ('k', 'n̩'): 0,
#  ('k', 'ɪ'): 10,
#  ('k', 'ɚ'): 0,
#  ('k', 'ə'): 4,
#  ('ɑː', 'k'): 0,
#  ('ɑː', 'ɑː'): 0,
#  ('ɑː', 'l'): 0,
#  ('ɑː', 'e'): 0,
#  ('ɑː', 'ɨ'): 0,
#  ('ɑː', 'p'): 0,
#  ('ɑː', 'ɛ'): 0,
#  ('ɑː', 'f'): 0,
#  ('ɑː', 'l̩'): 0,
#  ('ɑː', 'ɹ'): 0,
#  ('ɑː', 'ʌ'): 0,
#  ('ɑː', 'n'): 0,
#  ('ɑː', 'ɒ'): 0,
#  ('ɑː', 'i'): 0,
#  ('ɑː', 'u'): 0,
#  ('ɑː', 't'): 2,
#  ('ɑː', 'z'): 0,
#  ('ɑː', 'ɑ'): 0,
#  ('ɑː', 'iː'): 0,
#  ('ɑː', 'ɝː'): 0,
#  ('ɑː', 'ɜ'): 0,
#  ('ɑː', 'o'): 0,
#  ('ɑː', 'j'): 0,
#  ('ɑː', 'ʍ'): 0,
#  ('ɑː', 'm'): 0,
#  ('ɑː', 'θ'): 0,
#  ('ɑː', 'ɔː'): 0,
#  ('ɑː', 'ɔ'): 0,
#  ('ɑː', 'ʒ'): 0,
#  ('ɑː', 'ɡ'): 0,
#  ('ɑː', 'a'): 0,
#  ('ɑː', 'æ'): 0,
#  ('ɑː', 't͡ʃ'): 0,
#  ('ɑː', 'ʊ'): 0,
#  ('ɑː', 'ð'): 0,
#  ('ɑː', 'h'): 0,
#  ('ɑː', 'v'): 0,
#  ('ɑː', 'd'): 0,
#  ('ɑː', 'w'): 0,
#  ('ɑː', 's'): 0,
#  ('ɑː', 'uː'): 0,
#  ('ɑː', 'ŋ'): 0,
#  ('ɑː', 'd͡ʒ'): 0,
#  ('ɑː', 'b'): 0,
#  ('ɑː', 'ɝ'): 0,
#  ('ɑː', 'ʃ'): 0,
#  ('ɑː', 'ɫ'): 0,
#  ('ɑː', 'n̩'): 0,
#  ('ɑː', 'ɪ'): 0,
#  ('ɑː', 'ɚ'): 0,
#  ('ɑː', 'ə'): 0,
#  ('l', 'k'): 1,
#  ('l', 'ɑː'): 0,
#  ('l', 'l'): 1,
#  ('l', 'e'): 0,
#  ('l', 'ɨ'): 0,
#  ('l', 'p'): 1,
#  ('l', 'ɛ'): 0,
#  ('l', 'f'): 0,
#  ('l', 'l̩'): 0,
#  ('l', 'ɹ'): 0,
#  ('l', 'ʌ'): 0,
#  ('l', 'n'): 3,
#  ('l', 'ɒ'): 0,
#  ('l', 'i'): 0,
#  ('l', 'u'): 0,
#  ('l', 't'): 1,
#  ('l', 'z'): 0,
#  ('l', 'ɑ'): 0,
#  ('l', 'iː'): 0,
#  ('l', 'ɝː'): 0,
#  ('l', 'ɜ'): 0,
#  ('l', 'o'): 1,
#  ('l', 'j'): 2,
#  ('l', 'ʍ'): 4,
#  ('l', 'm'): 4,
#  ('l', 'θ'): 0,
#  ('l', 'ɔː'): 0,
#  ('l', 'ɔ'): 0,
#  ('l', 'ʒ'): 0,
#  ('l', 'ɡ'): 0,
#  ('l', 'a'): 0,
#  ('l', 'æ'): 0,
#  ('l', 't͡ʃ'): 0,
#  ('l', 'ʊ'): 0,
#  ('l', 'ð'): 1,
#  ('l', 'h'): 1,
#  ('l', 'v'): 0,
#  ('l', 'd'): 2,
#  ('l', 'w'): 2,
#  ('l', 's'): 0,
#  ('l', 'uː'): 0,
#  ('l', 'ŋ'): 0,
#  ('l', 'd͡ʒ'): 0,
#  ('l', 'b'): 2,
#  ('l', 'ɝ'): 0,
#  ('l', 'ʃ'): 0,
#  ('l', 'ɫ'): 0,
#  ('l', 'n̩'): 0,
#  ('l', 'ɪ'): 1,
#  ('l', 'ɚ'): 0,
#  ('l', 'ə'): 0,
#  ('e', 'k'): 0,
#  ('e', 'ɑː'): 0,
#  ('e', 'l'): 0,
#  ('e', 'e'): 0,
#  ('e', 'ɨ'): 0,
#  ('e', 'p'): 0,
#  ('e', 'ɛ'): 0,
#  ('e', 'f'): 0,
#  ('e', 'l̩'): 0,
#  ('e', 'ɹ'): 0,
#  ('e', 'ʌ'): 0,
#  ('e', 'n'): 0,
#  ('e', 'ɒ'): 0,
#  ('e', 'i'): 0,
#  ('e', 'u'): 0,
#  ('e', 't'): 0,
#  ('e', 'z'): 0,
#  ('e', 'ɑ'): 0,
#  ('e', 'iː'): 0,
#  ('e', 'ɝː'): 0,
#  ('e', 'ɜ'): 0,
#  ('e', 'o'): 0,
#  ('e', 'j'): 0,
#  ('e', 'ʍ'): 0,
#  ('e', 'm'): 0,
#  ('e', 'θ'): 0,
#  ('e', 'ɔː'): 0,
#  ('e', 'ɔ'): 0,
#  ('e', 'ʒ'): 0,
#  ('e', 'ɡ'): 0,
#  ('e', 'a'): 0,
#  ('e', 'æ'): 0,
#  ('e', 't͡ʃ'): 0,
#  ('e', 'ʊ'): 0,
#  ('e', 'ð'): 0,
#  ('e', 'h'): 0,
#  ('e', 'v'): 0,
#  ('e', 'd'): 0,
#  ('e', 'w'): 0,
#  ('e', 's'): 0,
#  ('e', 'uː'): 0,
#  ('e', 'ŋ'): 0,
#  ('e', 'd͡ʒ'): 0,
#  ('e', 'b'): 0,
#  ('e', 'ɝ'): 0,
#  ('e', 'ʃ'): 0,
#  ('e', 'ɫ'): 0,
#  ('e', 'n̩'): 0,
#  ('e', 'ɪ'): 0,
#  ('e', 'ɚ'): 0,
#  ('e', 'ə'): 0,
#  ('ɨ', 'k'): 0,
#  ('ɨ', 'ɑː'): 0,
#  ('ɨ', 'l'): 0,
#  ('ɨ', 'e'): 0,
#  ('ɨ', 'ɨ'): 0,
#  ('ɨ', 'p'): 0,
#  ('ɨ', 'ɛ'): 0,
#  ('ɨ', 'f'): 0,
#  ('ɨ', 'l̩'): 0,
#  ('ɨ', 'ɹ'): 0,
#  ('ɨ', 'ʌ'): 0,
#  ('ɨ', 'n'): 0,
#  ('ɨ', 'ɒ'): 0,
#  ('ɨ', 'i'): 0,
#  ('ɨ', 'u'): 0,
#  ('ɨ', 't'): 0,
#  ('ɨ', 'z'): 0,
#  ('ɨ', 'ɑ'): 0,
#  ('ɨ', 'iː'): 0,
#  ('ɨ', 'ɝː'): 0,
#  ('ɨ', 'ɜ'): 0,
#  ('ɨ', 'o'): 0,
#  ('ɨ', 'j'): 0,
#  ('ɨ', 'ʍ'): 0,
#  ('ɨ', 'm'): 0,
#  ('ɨ', 'θ'): 0,
#  ('ɨ', 'ɔː'): 0,
#  ('ɨ', 'ɔ'): 0,
#  ('ɨ', 'ʒ'): 0,
#  ('ɨ', 'ɡ'): 0,
#  ('ɨ', 'a'): 0,
#  ('ɨ', 'æ'): 0,
#  ('ɨ', 't͡ʃ'): 0,
#  ('ɨ', 'ʊ'): 0,
#  ('ɨ', 'ð'): 0,
#  ('ɨ', 'h'): 0,
#  ('ɨ', 'v'): 0,
#  ('ɨ', 'd'): 0,
#  ('ɨ', 'w'): 0,
#  ('ɨ', 's'): 0,
#  ('ɨ', 'uː'): 0,
#  ('ɨ', 'ŋ'): 0,
#  ('ɨ', 'd͡ʒ'): 0,
#  ('ɨ', 'b'): 0,
#  ('ɨ', 'ɝ'): 0,
#  ('ɨ', 'ʃ'): 0,
#  ('ɨ', 'ɫ'): 0,
#  ('ɨ', 'n̩'): 0,
#  ('ɨ', 'ɪ'): 0,
#  ('ɨ', 'ɚ'): 0,
#  ('ɨ', 'ə'): 0,
#  ('p', 'k'): 0,
#  ('p', 'ɑː'): 0,
#  ('p', 'l'): 0,
#  ('p', 'e'): 0,
#  ('p', 'ɨ'): 0,
#  ('p', 'p'): 1,
#  ('p', 'ɛ'): 0,
#  ('p', 'f'): 0,
#  ('p', 'l̩'): 0,
#  ('p', 'ɹ'): 0,
#  ('p', 'ʌ'): 0,
#  ('p', 'n'): 0,
#  ('p', 'ɒ'): 0,
#  ('p', 'i'): 0,
#  ('p', 'u'): 0,
#  ('p', 't'): 0,
#  ('p', 'z'): 0,
#  ('p', 'ɑ'): 0,
#  ('p', 'iː'): 0,
#  ('p', 'ɝː'): 0,
#  ('p', 'ɜ'): 0,
#  ('p', 'o'): 0,
#  ('p', 'j'): 0,
#  ('p', 'ʍ'): 2,
#  ('p', 'm'): 0,
#  ('p', 'θ'): 1,
#  ('p', 'ɔː'): 0,
#  ('p', 'ɔ'): 0,
#  ('p', 'ʒ'): 0,
#  ('p', 'ɡ'): 0,
#  ('p', 'a'): 0,
#  ('p', 'æ'): 0,
#  ('p', 't͡ʃ'): 0,
#  ('p', 'ʊ'): 0,
#  ('p', 'ð'): 0,
#  ('p', 'h'): 0,
#  ('p', 'v'): 0,
#  ('p', 'd'): 0,
#  ('p', 'w'): 0,
#  ('p', 's'): 4,
#  ('p', 'uː'): 0,
#  ('p', 'ŋ'): 0,
#  ('p', 'd͡ʒ'): 0,
#  ('p', 'b'): 1,
#  ('p', 'ɝ'): 0,
#  ('p', 'ʃ'): 0,
#  ('p', 'ɫ'): 0,
#  ('p', 'n̩'): 0,
#  ('p', 'ɪ'): 0,
#  ('p', 'ɚ'): 0,
#  ('p', 'ə'): 1,
#  ('ɛ', 'k'): 0,
#  ('ɛ', 'ɑː'): 0,
#  ('ɛ', 'l'): 0,
#  ('ɛ', 'e'): 0,
#  ('ɛ', 'ɨ'): 0,
#  ('ɛ', 'p'): 0,
#  ('ɛ', 'ɛ'): 0,
#  ('ɛ', 'f'): 0,
#  ('ɛ', 'l̩'): 0,
#  ('ɛ', 'ɹ'): 0,
#  ('ɛ', 'ʌ'): 0,
#  ('ɛ', 'n'): 0,
#  ('ɛ', 'ɒ'): 0,
#  ('ɛ', 'i'): 0,
#  ('ɛ', 'u'): 0,
#  ('ɛ', 't'): 0,
#  ('ɛ', 'z'): 0,
#  ('ɛ', 'ɑ'): 0,
#  ('ɛ', 'iː'): 0,
#  ('ɛ', 'ɝː'): 0,
#  ('ɛ', 'ɜ'): 0,
#  ('ɛ', 'o'): 0,
#  ('ɛ', 'j'): 0,
#  ('ɛ', 'ʍ'): 0,
#  ('ɛ', 'm'): 0,
#  ('ɛ', 'θ'): 0,
#  ('ɛ', 'ɔː'): 0,
#  ('ɛ', 'ɔ'): 0,
#  ('ɛ', 'ʒ'): 0,
#  ('ɛ', 'ɡ'): 0,
#  ('ɛ', 'a'): 0,
#  ('ɛ', 'æ'): 0,
#  ('ɛ', 't͡ʃ'): 0,
#  ('ɛ', 'ʊ'): 0,
#  ('ɛ', 'ð'): 0,
#  ('ɛ', 'h'): 0,
#  ('ɛ', 'v'): 0,
#  ('ɛ', 'd'): 0,
#  ('ɛ', 'w'): 0,
#  ('ɛ', 's'): 0,
#  ('ɛ', 'uː'): 0,
#  ('ɛ', 'ŋ'): 0,
#  ('ɛ', 'd͡ʒ'): 0,
#  ('ɛ', 'b'): 0,
#  ('ɛ', 'ɝ'): 0,
#  ('ɛ', 'ʃ'): 0,
#  ('ɛ', 'ɫ'): 0,
#  ('ɛ', 'n̩'): 0,
#  ('ɛ', 'ɪ'): 0,
#  ('ɛ', 'ɚ'): 0,
#  ('ɛ', 'ə'): 0,
#  ('f', 'k'): 2,
#  ('f', 'ɑː'): 0,
#  ('f', 'l'): 0,
#  ('f', 'e'): 0,
#  ('f', 'ɨ'): 0,
#  ('f', 'p'): 0,
#  ('f', 'ɛ'): 0,
#  ('f', 'f'): 0,
#  ('f', 'l̩'): 0,
#  ('f', 'ɹ'): 0,
#  ('f', 'ʌ'): 0,
#  ('f', 'n'): 0,
#  ('f', 'ɒ'): 0,
#  ('f', 'i'): 0,
#  ('f', 'u'): 0,
#  ('f', 't'): 0,
#  ('f', 'z'): 0,
#  ('f', 'ɑ'): 0,
#  ('f', 'iː'): 0,
#  ('f', 'ɝː'): 0,
#  ('f', 'ɜ'): 0,
#  ('f', 'o'): 0,
#  ('f', 'j'): 1,
#  ('f', 'ʍ'): 0,
#  ('f', 'm'): 0,
#  ('f', 'θ'): 0,
#  ('f', 'ɔː'): 0,
#  ('f', 'ɔ'): 0,
#  ('f', 'ʒ'): 0,
#  ('f', 'ɡ'): 0,
#  ('f', 'a'): 0,
#  ('f', 'æ'): 0,
#  ('f', 't͡ʃ'): 0,
#  ('f', 'ʊ'): 0,
#  ('f', 'ð'): 1,
#  ('f', 'h'): 0,
#  ('f', 'v'): 1,
#  ('f', 'd'): 0,
#  ('f', 'w'): 0,
#  ('f', 's'): 0,
#  ('f', 'uː'): 0,
#  ('f', 'ŋ'): 0,
#  ('f', 'd͡ʒ'): 0,
#  ('f', 'b'): 0,
#  ('f', 'ɝ'): 0,
#  ('f', 'ʃ'): 1,
#  ('f', 'ɫ'): 0,
#  ('f', 'n̩'): 0,
#  ('f', 'ɪ'): 0,
#  ('f', 'ɚ'): 0,
#  ('f', 'ə'): 0,
#  ('l̩', 'k'): 0,
#  ('l̩', 'ɑː'): 0,
#  ('l̩', 'l'): 0,
#  ('l̩', 'e'): 0,
#  ('l̩', 'ɨ'): 0,
#  ('l̩', 'p'): 0,
#  ('l̩', 'ɛ'): 0,
#  ('l̩', 'f'): 0,
#  ('l̩', 'l̩'): 0,
#  ('l̩', 'ɹ'): 0,
#  ('l̩', 'ʌ'): 0,
#  ('l̩', 'n'): 0,
#  ('l̩', 'ɒ'): 0,
#  ('l̩', 'i'): 0,
#  ('l̩', 'u'): 0,
#  ('l̩', 't'): 0,
#  ('l̩', 'z'): 0,
#  ('l̩', 'ɑ'): 0,
#  ('l̩', 'iː'): 0,
#  ('l̩', 'ɝː'): 0,
#  ('l̩', 'ɜ'): 0,
#  ('l̩', 'o'): 1,
#  ('l̩', 'j'): 0,
#  ('l̩', 'ʍ'): 0,
#  ('l̩', 'm'): 0,
#  ('l̩', 'θ'): 0,
#  ('l̩', 'ɔː'): 0,
#  ('l̩', 'ɔ'): 0,
#  ('l̩', 'ʒ'): 0,
#  ('l̩', 'ɡ'): 0,
#  ('l̩', 'a'): 0,
#  ('l̩', 'æ'): 0,
#  ('l̩', 't͡ʃ'): 0,
#  ('l̩', 'ʊ'): 0,
#  ('l̩', 'ð'): 0,
#  ('l̩', 'h'): 0,
#  ('l̩', 'v'): 0,
#  ('l̩', 'd'): 0,
#  ('l̩', 'w'): 0,
#  ('l̩', 's'): 1,
#  ('l̩', 'uː'): 0,
#  ('l̩', 'ŋ'): 0,
#  ('l̩', 'd͡ʒ'): 0,
#  ('l̩', 'b'): 3,
#  ('l̩', 'ɝ'): 0,
#  ('l̩', 'ʃ'): 0,
#  ('l̩', 'ɫ'): 0,
#  ('l̩', 'n̩'): 0,
#  ('l̩', 'ɪ'): 0,
#  ('l̩', 'ɚ'): 0,
#  ('l̩', 'ə'): 0,
#  ('ɹ', 'k'): 1,
#  ('ɹ', 'ɑː'): 0,
#  ('ɹ', 'l'): 1,
#  ('ɹ', 'e'): 0,
#  ('ɹ', 'ɨ'): 0,
#  ('ɹ', 'p'): 1,
#  ('ɹ', 'ɛ'): 2,
#  ('ɹ', 'f'): 2,
#  ('ɹ', 'l̩'): 0,
#  ('ɹ', 'ɹ'): 0,
#  ('ɹ', 'ʌ'): 0,
#  ('ɹ', 'n'): 2,
#  ('ɹ', 'ɒ'): 0,
#  ('ɹ', 'i'): 0,
#  ('ɹ', 'u'): 0,
#  ('ɹ', 't'): 2,
#  ('ɹ', 'z'): 0,
#  ('ɹ', 'ɑ'): 0,
#  ('ɹ', 'iː'): 0,
#  ('ɹ', 'ɝː'): 0,
#  ('ɹ', 'ɜ'): 0,
#  ('ɹ', 'o'): 5,
#  ('ɹ', 'j'): 1,
#  ('ɹ', 'ʍ'): 2,
#  ('ɹ', 'm'): 5,
#  ('ɹ', 'θ'): 4,
#  ('ɹ', 'ɔː'): 0,
#  ('ɹ', 'ɔ'): 0,
#  ('ɹ', 'ʒ'): 0,
#  ('ɹ', 'ɡ'): 4,
#  ('ɹ', 'a'): 0,
#  ('ɹ', 'æ'): 0,
#  ('ɹ', 't͡ʃ'): 0,
#  ('ɹ', 'ʊ'): 0,
#  ('ɹ', 'ð'): 1,
#  ('ɹ', 'h'): 1,
#  ('ɹ', 'v'): 0,
#  ('ɹ', 'd'): 3,
#  ('ɹ', 'w'): 1,
#  ('ɹ', 's'): 1,
#  ('ɹ', 'uː'): 0,
#  ('ɹ', 'ŋ'): 0,
#  ('ɹ', 'd͡ʒ'): 0,
#  ('ɹ', 'b'): 3,
#  ('ɹ', 'ɝ'): 0,
#  ('ɹ', 'ʃ'): 1,
#  ('ɹ', 'ɫ'): 0,
#  ('ɹ', 'n̩'): 0,
#  ('ɹ', 'ɪ'): 2,
#  ('ɹ', 'ɚ'): 0,
#  ('ɹ', 'ə'): 0,
#  ('ʌ', 'k'): 0,
#  ('ʌ', 'ɑː'): 0,
#  ('ʌ', 'l'): 0,
#  ('ʌ', 'e'): 0,
#  ('ʌ', 'ɨ'): 0,
#  ('ʌ', 'p'): 0,
#  ('ʌ', 'ɛ'): 0,
#  ('ʌ', 'f'): 0,
#  ('ʌ', 'l̩'): 0,
#  ('ʌ', 'ɹ'): 0,
#  ('ʌ', 'ʌ'): 0,
#  ('ʌ', 'n'): 0,
#  ('ʌ', 'ɒ'): 0,
#  ('ʌ', 'i'): 0,
#  ('ʌ', 'u'): 0,
#  ('ʌ', 't'): 0,
#  ('ʌ', 'z'): 0,
#  ('ʌ', 'ɑ'): 0,
#  ('ʌ', 'iː'): 0,
#  ('ʌ', 'ɝː'): 0,
#  ('ʌ', 'ɜ'): 0,
#  ('ʌ', 'o'): 0,
#  ('ʌ', 'j'): 0,
#  ('ʌ', 'ʍ'): 0,
#  ('ʌ', 'm'): 0,
#  ('ʌ', 'θ'): 0,
#  ('ʌ', 'ɔː'): 0,
#  ('ʌ', 'ɔ'): 0,
#  ('ʌ', 'ʒ'): 0,
#  ('ʌ', 'ɡ'): 0,
#  ('ʌ', 'a'): 0,
#  ('ʌ', 'æ'): 0,
#  ('ʌ', 't͡ʃ'): 0,
#  ('ʌ', 'ʊ'): 0,
#  ('ʌ', 'ð'): 0,
#  ('ʌ', 'h'): 0,
#  ('ʌ', 'v'): 0,
#  ('ʌ', 'd'): 0,
#  ('ʌ', 'w'): 0,
#  ('ʌ', 's'): 0,
#  ('ʌ', 'uː'): 0,
#  ('ʌ', 'ŋ'): 0,
#  ('ʌ', 'd͡ʒ'): 0,
#  ('ʌ', 'b'): 0,
#  ('ʌ', 'ɝ'): 0,
#  ('ʌ', 'ʃ'): 0,
#  ('ʌ', 'ɫ'): 0,
#  ('ʌ', 'n̩'): 0,
#  ('ʌ', 'ɪ'): 0,
#  ('ʌ', 'ɚ'): 0,
#  ('ʌ', 'ə'): 0,
#  ('n', 'k'): 0,
#  ('n', 'ɑː'): 0,
#  ('n', 'l'): 0,
#  ('n', 'e'): 1,
#  ('n', 'ɨ'): 0,
#  ('n', 'p'): 4,
#  ('n', 'ɛ'): 3,
#  ('n', 'f'): 0,
#  ('n', 'l̩'): 0,
#  ('n', 'ɹ'): 1,
#  ('n', 'ʌ'): 1,
#  ('n', 'n'): 4,
#  ('n', 'ɒ'): 0,
#  ('n', 'i'): 0,
#  ('n', 'u'): 0,
#  ('n', 't'): 5,
#  ('n', 'z'): 0,
#  ('n', 'ɑ'): 0,
#  ('n', 'iː'): 0,
#  ('n', 'ɝː'): 0,
#  ('n', 'ɜ'): 0,
#  ('n', 'o'): 1,
#  ('n', 'j'): 2,
#  ('n', 'ʍ'): 4,
#  ('n', 'm'): 2,
#  ('n', 'θ'): 4,
#  ('n', 'ɔː'): 0,
#  ('n', 'ɔ'): 0,
#  ('n', 'ʒ'): 0,
#  ('n', 'ɡ'): 2,
#  ('n', 'a'): 0,
#  ('n', 'æ'): 0,
#  ('n', 't͡ʃ'): 0,
#  ('n', 'ʊ'): 0,
#  ('n', 'ð'): 14,
#  ('n', 'h'): 4,
#  ('n', 'v'): 0,
#  ('n', 'd'): 6,
#  ('n', 'w'): 4,
#  ('n', 's'): 6,
#  ('n', 'uː'): 0,
#  ('n', 'ŋ'): 0,
#  ('n', 'd͡ʒ'): 0,
#  ('n', 'b'): 1,
#  ('n', 'ɝ'): 0,
#  ('n', 'ʃ'): 1,
#  ('n', 'ɫ'): 0,
#  ('n', 'n̩'): 0,
#  ('n', 'ɪ'): 1,
#  ('n', 'ɚ'): 0,
#  ('n', 'ə'): 2,
#  ('ɒ', 'k'): 0,
#  ('ɒ', 'ɑː'): 0,
#  ('ɒ', 'l'): 0,
#  ('ɒ', 'e'): 0,
#  ('ɒ', 'ɨ'): 0,
#  ('ɒ', 'p'): 0,
#  ('ɒ', 'ɛ'): 0,
#  ('ɒ', 'f'): 0,
#  ('ɒ', 'l̩'): 0,
#  ('ɒ', 'ɹ'): 0,
#  ('ɒ', 'ʌ'): 0,
#  ('ɒ', 'n'): 0,
#  ('ɒ', 'ɒ'): 0,
#  ('ɒ', 'i'): 0,
#  ('ɒ', 'u'): 0,
#  ('ɒ', 't'): 0,
#  ('ɒ', 'z'): 0,
#  ('ɒ', 'ɑ'): 0,
#  ('ɒ', 'iː'): 0,
#  ('ɒ', 'ɝː'): 0,
#  ('ɒ', 'ɜ'): 0,
#  ('ɒ', 'o'): 0,
#  ('ɒ', 'j'): 0,
#  ('ɒ', 'ʍ'): 0,
#  ('ɒ', 'm'): 0,
#  ('ɒ', 'θ'): 0,
#  ('ɒ', 'ɔː'): 0,
#  ('ɒ', 'ɔ'): 0,
#  ('ɒ', 'ʒ'): 0,
#  ('ɒ', 'ɡ'): 0,
#  ('ɒ', 'a'): 0,
#  ('ɒ', 'æ'): 0,
#  ('ɒ', 't͡ʃ'): 0,
#  ('ɒ', 'ʊ'): 0,
#  ('ɒ', 'ð'): 0,
#  ('ɒ', 'h'): 0,
#  ('ɒ', 'v'): 0,
#  ('ɒ', 'd'): 0,
#  ('ɒ', 'w'): 0,
#  ('ɒ', 's'): 0,
#  ('ɒ', 'uː'): 0,
#  ('ɒ', 'ŋ'): 0,
#  ('ɒ', 'd͡ʒ'): 0,
#  ('ɒ', 'b'): 0,
#  ('ɒ', 'ɝ'): 0,
#  ('ɒ', 'ʃ'): 0,
#  ('ɒ', 'ɫ'): 0,
#  ('ɒ', 'n̩'): 0,
#  ('ɒ', 'ɪ'): 0,
#  ('ɒ', 'ɚ'): 0,
#  ('ɒ', 'ə'): 0,
#  ('i', 'k'): 2,
#  ('i', 'ɑː'): 0,
#  ('i', 'l'): 2,
#  ('i', 'e'): 0,
#  ('i', 'ɨ'): 0,
#  ('i', 'p'): 3,
#  ('i', 'ɛ'): 0,
#  ('i', 'f'): 0,
#  ('i', 'l̩'): 0,
#  ('i', 'ɹ'): 1,
#  ('i', 'ʌ'): 0,
#  ('i', 'n'): 7,
#  ('i', 'ɒ'): 0,
#  ('i', 'i'): 0,
#  ('i', 'u'): 0,
#  ('i', 't'): 6,
#  ('i', 'z'): 0,
#  ('i', 'ɑ'): 0,
#  ('i', 'iː'): 0,
#  ('i', 'ɝː'): 0,
#  ('i', 'ɜ'): 0,
#  ('i', 'o'): 2,
#  ('i', 'j'): 2,
#  ('i', 'ʍ'): 2,
#  ('i', 'm'): 0,
#  ('i', 'θ'): 2,
#  ('i', 'ɔː'): 0,
#  ('i', 'ɔ'): 0,
#  ('i', 'ʒ'): 0,
#  ('i', 'ɡ'): 0,
#  ('i', 'a'): 0,
#  ('i', 'æ'): 0,
#  ('i', 't͡ʃ'): 0,
#  ('i', 'ʊ'): 0,
#  ('i', 'ð'): 2,
#  ('i', 'h'): 2,
#  ('i', 'v'): 0,
#  ('i', 'd'): 2,
#  ('i', 'w'): 2,
#  ('i', 's'): 2,
#  ('i', 'uː'): 0,
#  ('i', 'ŋ'): 0,
#  ('i', 'd͡ʒ'): 1,
#  ('i', 'b'): 2,
#  ('i', 'ɝ'): 0,
#  ('i', 'ʃ'): 0,
#  ('i', 'ɫ'): 0,
#  ('i', 'n̩'): 0,
#  ('i', 'ɪ'): 1,
#  ('i', 'ɚ'): 0,
#  ('i', 'ə'): 0,
#  ('u', 'k'): 0,
#  ('u', 'ɑː'): 0,
#  ('u', 'l'): 0,
#  ('u', 'e'): 0,
#  ('u', 'ɨ'): 0,
#  ('u', 'p'): 0,
#  ('u', 'ɛ'): 0,
#  ('u', 'f'): 0,
#  ('u', 'l̩'): 0,
#  ('u', 'ɹ'): 0,
#  ('u', 'ʌ'): 0,
#  ('u', 'n'): 0,
#  ('u', 'ɒ'): 0,
#  ('u', 'i'): 0,
#  ('u', 'u'): 0,
#  ('u', 't'): 0,
#  ('u', 'z'): 0,
#  ('u', 'ɑ'): 0,
#  ('u', 'iː'): 0,
#  ('u', 'ɝː'): 0,
#  ('u', 'ɜ'): 0,
#  ('u', 'o'): 0,
#  ('u', 'j'): 1,
#  ('u', 'ʍ'): 3,
#  ('u', 'm'): 2,
#  ('u', 'θ'): 3,
#  ('u', 'ɔː'): 0,
#  ('u', 'ɔ'): 0,
#  ('u', 'ʒ'): 0,
#  ('u', 'ɡ'): 0,
#  ('u', 'a'): 0,
#  ('u', 'æ'): 0,
#  ('u', 't͡ʃ'): 0,
#  ('u', 'ʊ'): 0,
#  ('u', 'ð'): 4,
#  ('u', 'h'): 0,
#  ('u', 'v'): 0,
#  ('u', 'd'): 3,
#  ('u', 'w'): 2,
#  ('u', 's'): 2,
#  ('u', 'uː'): 0,
#  ('u', 'ŋ'): 0,
#  ('u', 'd͡ʒ'): 0,
#  ('u', 'b'): 1,
#  ('u', 'ɝ'): 0,
#  ('u', 'ʃ'): 0,
#  ('u', 'ɫ'): 0,
#  ('u', 'n̩'): 0,
#  ('u', 'ɪ'): 2,
#  ('u', 'ɚ'): 1,
#  ('u', 'ə'): 0,
#  ('t', 'k'): 5,
#  ('t', 'ɑː'): 0,
#  ('t', 'l'): 7,
#  ('t', 'e'): 0,
#  ('t', 'ɨ'): 0,
#  ('t', 'p'): 9,
#  ('t', 'ɛ'): 5,
#  ('t', 'f'): 2,
#  ('t', 'l̩'): 0,
#  ('t', 'ɹ'): 3,
#  ('t', 'ʌ'): 3,
#  ('t', 'n'): 4,
#  ('t', 'ɒ'): 0,
#  ('t', 'i'): 0,
#  ('t', 'u'): 0,
#  ('t', 't'): 7,
#  ('t', 'z'): 0,
#  ('t', 'ɑ'): 0,
#  ('t', 'iː'): 0,
#  ('t', 'ɝː'): 0,
#  ('t', 'ɜ'): 0,
#  ('t', 'o'): 7,
#  ('t', 'j'): 4,
#  ('t', 'ʍ'): 10,
#  ('t', 'm'): 7,
#  ('t', 'θ'): 3,
#  ('t', 'ɔː'): 0,
#  ('t', 'ɔ'): 1,
#  ('t', 'ʒ'): 0,
#  ('t', 'ɡ'): 5,
#  ('t', 'a'): 0,
#  ('t', 'æ'): 1,
#  ('t', 't͡ʃ'): 0,
#  ('t', 'ʊ'): 0,
#  ('t', 'ð'): 11,
#  ('t', 'h'): 12,
#  ('t', 'v'): 1,
#  ('t', 'd'): 20,
#  ('t', 'w'): 14,
#  ('t', 's'): 13,
#  ('t', 'uː'): 0,
#  ('t', 'ŋ'): 0,
#  ('t', 'd͡ʒ'): 0,
#  ('t', 'b'): 7,
#  ('t', 'ɝ'): 0,
#  ('t', 'ʃ'): 2,
#  ('t', 'ɫ'): 0,
#  ('t', 'n̩'): 0,
#  ('t', 'ɪ'): 11,
#  ('t', 'ɚ'): 1,
#  ('t', 'ə'): 9,
#  ('z', 'k'): 0,
#  ('z', 'ɑː'): 0,
#  ('z', 'l'): 0,
#  ('z', 'e'): 0,
#  ('z', 'ɨ'): 0,
#  ('z', 'p'): 1,
#  ('z', 'ɛ'): 5,
#  ('z', 'f'): 3,
#  ('z', 'l̩'): 0,
#  ('z', 'ɹ'): 1,
#  ('z', 'ʌ'): 0,
#  ('z', 'n'): 2,
#  ('z', 'ɒ'): 0,
#  ('z', 'i'): 0,
#  ('z', 'u'): 0,
#  ('z', 't'): 3,
#  ('z', 'z'): 0,
#  ('z', 'ɑ'): 0,
#  ('z', 'iː'): 0,
#  ('z', 'ɝː'): 0,
#  ('z', 'ɜ'): 0,
#  ('z', 'o'): 0,
#  ('z', 'j'): 1,
#  ('z', 'ʍ'): 4,
#  ('z', 'm'): 0,
#  ('z', 'θ'): 3,
#  ('z', 'ɔː'): 0,
#  ('z', 'ɔ'): 0,
#  ('z', 'ʒ'): 0,
#  ('z', 'ɡ'): 2,
#  ('z', 'a'): 0,
#  ('z', 'æ'): 0,
#  ('z', 't͡ʃ'): 1,
#  ('z', 'ʊ'): 0,
#  ('z', 'ð'): 9,
#  ('z', 'h'): 2,
#  ('z', 'v'): 0,
#  ('z', 'd'): 4,
#  ('z', 'w'): 3,
#  ('z', 's'): 0,
#  ('z', 'uː'): 0,
#  ('z', 'ŋ'): 0,
#  ('z', 'd͡ʒ'): 1,
#  ('z', 'b'): 0,
#  ('z', 'ɝ'): 0,
#  ('z', 'ʃ'): 1,
#  ('z', 'ɫ'): 0,
#  ('z', 'n̩'): 0,
#  ('z', 'ɪ'): 9,
#  ('z', 'ɚ'): 0,
#  ('z', 'ə'): 3,
#  ('ɑ', 'k'): 0,
#  ('ɑ', 'ɑː'): 0,
#  ('ɑ', 'l'): 0,
#  ('ɑ', 'e'): 0,
#  ('ɑ', 'ɨ'): 0,
#  ('ɑ', 'p'): 0,
#  ('ɑ', 'ɛ'): 0,
#  ('ɑ', 'f'): 0,
#  ('ɑ', 'l̩'): 0,
#  ('ɑ', 'ɹ'): 0,
#  ('ɑ', 'ʌ'): 0,
#  ('ɑ', 'n'): 0,
#  ('ɑ', 'ɒ'): 0,
#  ('ɑ', 'i'): 0,
#  ('ɑ', 'u'): 0,
#  ('ɑ', 't'): 0,
#  ('ɑ', 'z'): 0,
#  ('ɑ', 'ɑ'): 0,
#  ('ɑ', 'iː'): 0,
#  ('ɑ', 'ɝː'): 0,
#  ('ɑ', 'ɜ'): 0,
#  ('ɑ', 'o'): 0,
#  ('ɑ', 'j'): 0,
#  ('ɑ', 'ʍ'): 0,
#  ('ɑ', 'm'): 0,
#  ('ɑ', 'θ'): 0,
#  ('ɑ', 'ɔː'): 0,
#  ('ɑ', 'ɔ'): 0,
#  ('ɑ', 'ʒ'): 0,
#  ('ɑ', 'ɡ'): 0,
#  ('ɑ', 'a'): 0,
#  ('ɑ', 'æ'): 0,
#  ('ɑ', 't͡ʃ'): 0,
#  ('ɑ', 'ʊ'): 0,
#  ('ɑ', 'ð'): 0,
#  ('ɑ', 'h'): 0,
#  ('ɑ', 'v'): 0,
#  ('ɑ', 'd'): 0,
#  ('ɑ', 'w'): 0,
#  ('ɑ', 's'): 0,
#  ('ɑ', 'uː'): 0,
#  ('ɑ', 'ŋ'): 0,
#  ('ɑ', 'd͡ʒ'): 0,
#  ('ɑ', 'b'): 0,
#  ('ɑ', 'ɝ'): 0,
#  ('ɑ', 'ʃ'): 0,
#  ('ɑ', 'ɫ'): 0,
#  ('ɑ', 'n̩'): 0,
#  ('ɑ', 'ɪ'): 0,
#  ('ɑ', 'ɚ'): 0,
#  ('ɑ', 'ə'): 0,
#  ('iː', 'k'): 0,
#  ('iː', 'ɑː'): 0,
#  ('iː', 'l'): 0,
#  ('iː', 'e'): 0,
#  ('iː', 'ɨ'): 0,
#  ('iː', 'p'): 2,
#  ('iː', 'ɛ'): 0,
#  ('iː', 'f'): 2,
#  ('iː', 'l̩'): 0,
#  ('iː', 'ɹ'): 1,
#  ('iː', 'ʌ'): 1,
#  ('iː', 'n'): 1,
#  ('iː', 'ɒ'): 0,
#  ('iː', 'i'): 0,
#  ('iː', 'u'): 0,
#  ('iː', 't'): 3,
#  ('iː', 'z'): 0,
#  ('iː', 'ɑ'): 0,
#  ('iː', 'iː'): 0,
#  ('iː', 'ɝː'): 0,
#  ('iː', 'ɜ'): 0,
#  ('iː', 'o'): 0,
#  ('iː', 'j'): 2,
#  ('iː', 'ʍ'): 4,
#  ('iː', 'm'): 1,
#  ('iː', 'θ'): 2,
#  ('iː', 'ɔː'): 0,
#  ('iː', 'ɔ'): 0,
#  ('iː', 'ʒ'): 0,
#  ('iː', 'ɡ'): 0,
#  ('iː', 'a'): 0,
#  ('iː', 'æ'): 0,
#  ('iː', 't͡ʃ'): 0,
#  ('iː', 'ʊ'): 0,
#  ('iː', 'ð'): 0,
#  ('iː', 'h'): 4,
#  ('iː', 'v'): 0,
#  ('iː', 'd'): 0,
#  ('iː', 'w'): 5,
#  ('iː', 's'): 9,
#  ('iː', 'uː'): 0,
#  ('iː', 'ŋ'): 0,
#  ('iː', 'd͡ʒ'): 0,
#  ('iː', 'b'): 12,
#  ('iː', 'ɝ'): 0,
#  ('iː', 'ʃ'): 0,
#  ('iː', 'ɫ'): 0,
#  ('iː', 'n̩'): 0,
#  ('iː', 'ɪ'): 0,
#  ('iː', 'ɚ'): 0,
#  ('iː', 'ə'): 1,
#  ('ɝː', 'k'): 0,
#  ('ɝː', 'ɑː'): 0,
#  ('ɝː', 'l'): 0,
#  ('ɝː', 'e'): 0,
#  ('ɝː', 'ɨ'): 0,
#  ('ɝː', 'p'): 0,
#  ('ɝː', 'ɛ'): 0,
#  ('ɝː', 'f'): 0,
#  ('ɝː', 'l̩'): 0,
#  ('ɝː', 'ɹ'): 0,
#  ('ɝː', 'ʌ'): 0,
#  ('ɝː', 'n'): 0,
#  ('ɝː', 'ɒ'): 0,
#  ('ɝː', 'i'): 0,
#  ('ɝː', 'u'): 0,
#  ('ɝː', 't'): 0,
#  ('ɝː', 'z'): 0,
#  ('ɝː', 'ɑ'): 0,
#  ('ɝː', 'iː'): 0,
#  ('ɝː', 'ɝː'): 0,
#  ('ɝː', 'ɜ'): 0,
#  ('ɝː', 'o'): 0,
#  ('ɝː', 'j'): 0,
#  ('ɝː', 'ʍ'): 0,
#  ('ɝː', 'm'): 0,
#  ('ɝː', 'θ'): 0,
#  ('ɝː', 'ɔː'): 0,
#  ('ɝː', 'ɔ'): 0,
#  ('ɝː', 'ʒ'): 0,
#  ('ɝː', 'ɡ'): 0,
#  ('ɝː', 'a'): 0,
#  ...}

# %%
# now do the same thing for within-word occurrences of (p1,p2).
# start by creating dict ptp_within_count and initializing all ptps to 0.

# YOUR CODE GOES HERE.
ptp_within_count = {ptp: 0 for ptp in ptps} # REPLACE

# now slide a width-2 window through the corpus, and increment the (p1,p2) count for every (p1,p2) 
# phoneme pair you encounter, directly adjacent to each other.  this is without phoneme boundaries.

# YOUR CODE GOES HERE.
for i in range(len(ec) - 1):
    window = ec[i: (i+2)]
    if '*' not in window:
         ptp_within_count[(window[0], window[1])] += 1

ptp_within_count
# Out:
# {('k', 'k'): 0,
#  ('k', 'ɑː'): 0,
#  ('k', 'l'): 3,
#  ('k', 'e'): 3,
#  ('k', 'ɨ'): 0,
#  ('k', 'p'): 0,
#  ('k', 'ɛ'): 1,
#  ('k', 'f'): 0,
#  ('k', 'l̩'): 0,
#  ('k', 'ɹ'): 3,
#  ('k', 'ʌ'): 3,
#  ('k', 'n'): 0,
#  ('k', 'ɒ'): 0,
#  ('k', 'i'): 1,
#  ('k', 'u'): 0,
#  ('k', 't'): 2,
#  ('k', 'z'): 0,
#  ('k', 'ɑ'): 1,
#  ('k', 'iː'): 1,
#  ('k', 'ɝː'): 0,
#  ('k', 'ɜ'): 0,
#  ('k', 'o'): 0,
#  ('k', 'j'): 4,
#  ('k', 'ʍ'): 0,
#  ('k', 'm'): 0,
#  ('k', 'θ'): 0,
#  ('k', 'ɔː'): 0,
#  ('k', 'ɔ'): 0,
#  ('k', 'ʒ'): 0,
#  ('k', 'ɡ'): 0,
#  ('k', 'a'): 2,
#  ('k', 'æ'): 0,
#  ('k', 't͡ʃ'): 0,
#  ('k', 'ʊ'): 1,
#  ('k', 'ð'): 0,
#  ('k', 'h'): 0,
#  ('k', 'v'): 0,
#  ('k', 'd'): 0,
#  ('k', 'w'): 0,
#  ('k', 's'): 9,
#  ('k', 'uː'): 5,
#  ('k', 'ŋ'): 0,
#  ('k', 'd͡ʒ'): 0,
#  ('k', 'b'): 0,
#  ('k', 'ɝ'): 0,
#  ('k', 'ʃ'): 0,
#  ('k', 'ɫ'): 0,
#  ('k', 'n̩'): 0,
#  ('k', 'ɪ'): 5,
#  ('k', 'ɚ'): 0,
#  ('k', 'ə'): 18,
#  ('ɑː', 'k'): 0,
#  ('ɑː', 'ɑː'): 0,
#  ('ɑː', 'l'): 0,
#  ('ɑː', 'e'): 0,
#  ('ɑː', 'ɨ'): 0,
#  ('ɑː', 'p'): 0,
#  ('ɑː', 'ɛ'): 0,
#  ('ɑː', 'f'): 0,
#  ('ɑː', 'l̩'): 0,
#  ('ɑː', 'ɹ'): 0,
#  ('ɑː', 'ʌ'): 0,
#  ('ɑː', 'n'): 0,
#  ('ɑː', 'ɒ'): 0,
#  ('ɑː', 'i'): 0,
#  ('ɑː', 'u'): 0,
#  ('ɑː', 't'): 0,
#  ('ɑː', 'z'): 0,
#  ('ɑː', 'ɑ'): 0,
#  ('ɑː', 'iː'): 0,
#  ('ɑː', 'ɝː'): 0,
#  ('ɑː', 'ɜ'): 0,
#  ('ɑː', 'o'): 0,
#  ('ɑː', 'j'): 0,
#  ('ɑː', 'ʍ'): 0,
#  ('ɑː', 'm'): 0,
#  ('ɑː', 'θ'): 0,
#  ('ɑː', 'ɔː'): 0,
#  ('ɑː', 'ɔ'): 0,
#  ('ɑː', 'ʒ'): 0,
#  ('ɑː', 'ɡ'): 0,
#  ('ɑː', 'a'): 0,
#  ('ɑː', 'æ'): 0,
#  ('ɑː', 't͡ʃ'): 0,
#  ('ɑː', 'ʊ'): 0,
#  ('ɑː', 'ð'): 0,
#  ('ɑː', 'h'): 0,
#  ('ɑː', 'v'): 0,
#  ('ɑː', 'd'): 0,
#  ('ɑː', 'w'): 0,
#  ('ɑː', 's'): 0,
#  ('ɑː', 'uː'): 0,
#  ('ɑː', 'ŋ'): 0,
#  ('ɑː', 'd͡ʒ'): 0,
#  ('ɑː', 'b'): 0,
#  ('ɑː', 'ɝ'): 0,
#  ('ɑː', 'ʃ'): 0,
#  ('ɑː', 'ɫ'): 0,
#  ('ɑː', 'n̩'): 0,
#  ('ɑː', 'ɪ'): 0,
#  ('ɑː', 'ɚ'): 0,
#  ('ɑː', 'ə'): 0,
#  ('l', 'k'): 0,
#  ('l', 'ɑː'): 0,
#  ('l', 'l'): 0,
#  ('l', 'e'): 17,
#  ('l', 'ɨ'): 0,
#  ('l', 'p'): 0,
#  ('l', 'ɛ'): 11,
#  ('l', 'f'): 0,
#  ('l', 'l̩'): 0,
#  ('l', 'ɹ'): 0,
#  ('l', 'ʌ'): 0,
#  ('l', 'n'): 0,
#  ('l', 'ɒ'): 0,
#  ('l', 'i'): 6,
#  ('l', 'u'): 0,
#  ('l', 't'): 4,
#  ('l', 'z'): 1,
#  ('l', 'ɑ'): 2,
#  ('l', 'iː'): 0,
#  ('l', 'ɝː'): 0,
#  ('l', 'ɜ'): 0,
#  ('l', 'o'): 5,
#  ('l', 'j'): 6,
#  ('l', 'ʍ'): 0,
#  ('l', 'm'): 0,
#  ('l', 'θ'): 0,
#  ('l', 'ɔː'): 0,
#  ('l', 'ɔ'): 0,
#  ('l', 'ʒ'): 0,
#  ('l', 'ɡ'): 0,
#  ('l', 'a'): 3,
#  ('l', 'æ'): 2,
#  ('l', 't͡ʃ'): 0,
#  ('l', 'ʊ'): 5,
#  ('l', 'ð'): 0,
#  ('l', 'h'): 0,
#  ('l', 'v'): 0,
#  ('l', 'd'): 5,
#  ('l', 'w'): 1,
#  ('l', 's'): 0,
#  ('l', 'uː'): 2,
#  ('l', 'ŋ'): 0,
#  ('l', 'd͡ʒ'): 0,
#  ('l', 'b'): 0,
#  ('l', 'ɝ'): 0,
#  ('l', 'ʃ'): 0,
#  ('l', 'ɫ'): 0,
#  ('l', 'n̩'): 0,
#  ('l', 'ɪ'): 5,
#  ('l', 'ɚ'): 1,
#  ('l', 'ə'): 3,
#  ('e', 'k'): 0,
#  ('e', 'ɑː'): 0,
#  ('e', 'l'): 0,
#  ('e', 'e'): 0,
#  ('e', 'ɨ'): 0,
#  ('e', 'p'): 0,
#  ('e', 'ɛ'): 0,
#  ('e', 'f'): 0,
#  ('e', 'l̩'): 0,
#  ('e', 'ɹ'): 0,
#  ('e', 'ʌ'): 0,
#  ('e', 'n'): 0,
#  ('e', 'ɒ'): 0,
#  ('e', 'i'): 0,
#  ('e', 'u'): 0,
#  ('e', 't'): 0,
#  ('e', 'z'): 0,
#  ('e', 'ɑ'): 0,
#  ('e', 'iː'): 0,
#  ('e', 'ɝː'): 0,
#  ('e', 'ɜ'): 0,
#  ('e', 'o'): 0,
#  ('e', 'j'): 0,
#  ('e', 'ʍ'): 0,
#  ('e', 'm'): 0,
#  ('e', 'θ'): 0,
#  ('e', 'ɔː'): 0,
#  ('e', 'ɔ'): 0,
#  ('e', 'ʒ'): 0,
#  ('e', 'ɡ'): 0,
#  ('e', 'a'): 0,
#  ('e', 'æ'): 0,
#  ('e', 't͡ʃ'): 0,
#  ('e', 'ʊ'): 0,
#  ('e', 'ð'): 0,
#  ('e', 'h'): 0,
#  ('e', 'v'): 0,
#  ('e', 'd'): 0,
#  ('e', 'w'): 0,
#  ('e', 's'): 0,
#  ('e', 'uː'): 0,
#  ('e', 'ŋ'): 0,
#  ('e', 'd͡ʒ'): 0,
#  ('e', 'b'): 0,
#  ('e', 'ɝ'): 0,
#  ('e', 'ʃ'): 0,
#  ('e', 'ɫ'): 0,
#  ('e', 'n̩'): 0,
#  ('e', 'ɪ'): 71,
#  ('e', 'ɚ'): 0,
#  ('e', 'ə'): 0,
#  ('ɨ', 'k'): 0,
#  ('ɨ', 'ɑː'): 0,
#  ('ɨ', 'l'): 0,
#  ('ɨ', 'e'): 0,
#  ('ɨ', 'ɨ'): 0,
#  ('ɨ', 'p'): 0,
#  ('ɨ', 'ɛ'): 0,
#  ('ɨ', 'f'): 0,
#  ('ɨ', 'l̩'): 0,
#  ('ɨ', 'ɹ'): 0,
#  ('ɨ', 'ʌ'): 0,
#  ('ɨ', 'n'): 1,
#  ('ɨ', 'ɒ'): 0,
#  ('ɨ', 'i'): 0,
#  ('ɨ', 'u'): 0,
#  ('ɨ', 't'): 0,
#  ('ɨ', 'z'): 0,
#  ('ɨ', 'ɑ'): 0,
#  ('ɨ', 'iː'): 0,
#  ('ɨ', 'ɝː'): 0,
#  ('ɨ', 'ɜ'): 0,
#  ('ɨ', 'o'): 0,
#  ('ɨ', 'j'): 0,
#  ('ɨ', 'ʍ'): 0,
#  ('ɨ', 'm'): 0,
#  ('ɨ', 'θ'): 0,
#  ('ɨ', 'ɔː'): 0,
#  ('ɨ', 'ɔ'): 0,
#  ('ɨ', 'ʒ'): 0,
#  ('ɨ', 'ɡ'): 0,
#  ('ɨ', 'a'): 0,
#  ('ɨ', 'æ'): 0,
#  ('ɨ', 't͡ʃ'): 0,
#  ('ɨ', 'ʊ'): 0,
#  ('ɨ', 'ð'): 0,
#  ('ɨ', 'h'): 0,
#  ('ɨ', 'v'): 0,
#  ('ɨ', 'd'): 0,
#  ('ɨ', 'w'): 0,
#  ('ɨ', 's'): 0,
#  ('ɨ', 'uː'): 0,
#  ('ɨ', 'ŋ'): 0,
#  ('ɨ', 'd͡ʒ'): 0,
#  ('ɨ', 'b'): 0,
#  ('ɨ', 'ɝ'): 0,
#  ('ɨ', 'ʃ'): 0,
#  ('ɨ', 'ɫ'): 0,
#  ('ɨ', 'n̩'): 0,
#  ('ɨ', 'ɪ'): 0,
#  ('ɨ', 'ɚ'): 0,
#  ('ɨ', 'ə'): 0,
#  ('p', 'k'): 0,
#  ('p', 'ɑː'): 0,
#  ('p', 'l'): 19,
#  ('p', 'e'): 0,
#  ('p', 'ɨ'): 1,
#  ('p', 'p'): 0,
#  ('p', 'ɛ'): 3,
#  ('p', 'f'): 0,
#  ('p', 'l̩'): 0,
#  ('p', 'ɹ'): 9,
#  ('p', 'ʌ'): 3,
#  ('p', 'n'): 0,
#  ('p', 'ɒ'): 0,
#  ('p', 'i'): 0,
#  ('p', 'u'): 0,
#  ('p', 't'): 0,
#  ('p', 'z'): 0,
#  ('p', 'ɑ'): 1,
#  ('p', 'iː'): 0,
#  ('p', 'ɝː'): 0,
#  ('p', 'ɜ'): 0,
#  ('p', 'o'): 0,
#  ('p', 'j'): 0,
#  ('p', 'ʍ'): 0,
#  ('p', 'm'): 0,
#  ('p', 'θ'): 0,
#  ('p', 'ɔː'): 0,
#  ('p', 'ɔ'): 0,
#  ('p', 'ʒ'): 0,
#  ('p', 'ɡ'): 0,
#  ('p', 'a'): 0,
#  ('p', 'æ'): 1,
#  ('p', 't͡ʃ'): 0,
#  ('p', 'ʊ'): 0,
#  ('p', 'ð'): 0,
#  ('p', 'h'): 0,
#  ('p', 'v'): 0,
#  ('p', 'd'): 0,
#  ('p', 'w'): 0,
#  ('p', 's'): 1,
#  ('p', 'uː'): 0,
#  ('p', 'ŋ'): 0,
#  ('p', 'd͡ʒ'): 0,
#  ('p', 'b'): 0,
#  ('p', 'ɝ'): 0,
#  ('p', 'ʃ'): 0,
#  ('p', 'ɫ'): 0,
#  ('p', 'n̩'): 0,
#  ('p', 'ɪ'): 5,
#  ('p', 'ɚ'): 0,
#  ('p', 'ə'): 3,
#  ('ɛ', 'k'): 5,
#  ('ɛ', 'ɑː'): 0,
#  ('ɛ', 'l'): 17,
#  ('ɛ', 'e'): 0,
#  ('ɛ', 'ɨ'): 0,
#  ('ɛ', 'p'): 0,
#  ('ɛ', 'ɛ'): 0,
#  ('ɛ', 'f'): 1,
#  ('ɛ', 'l̩'): 0,
#  ('ɛ', 'ɹ'): 20,
#  ('ɛ', 'ʌ'): 0,
#  ('ɛ', 'n'): 14,
#  ('ɛ', 'ɒ'): 0,
#  ('ɛ', 'i'): 0,
#  ('ɛ', 'u'): 0,
#  ('ɛ', 't'): 6,
#  ('ɛ', 'z'): 0,
#  ('ɛ', 'ɑ'): 0,
#  ('ɛ', 'iː'): 0,
#  ('ɛ', 'ɝː'): 0,
#  ('ɛ', 'ɜ'): 0,
#  ('ɛ', 'o'): 0,
#  ('ɛ', 'j'): 0,
#  ('ɛ', 'ʍ'): 0,
#  ('ɛ', 'm'): 1,
#  ('ɛ', 'θ'): 0,
#  ('ɛ', 'ɔː'): 0,
#  ('ɛ', 'ɔ'): 0,
#  ('ɛ', 'ʒ'): 0,
#  ('ɛ', 'ɡ'): 2,
#  ('ɛ', 'a'): 0,
#  ('ɛ', 'æ'): 0,
#  ('ɛ', 't͡ʃ'): 0,
#  ('ɛ', 'ʊ'): 0,
#  ('ɛ', 'ð'): 0,
#  ('ɛ', 'h'): 0,
#  ('ɛ', 'v'): 6,
#  ('ɛ', 'd'): 0,
#  ('ɛ', 'w'): 0,
#  ('ɛ', 's'): 16,
#  ('ɛ', 'uː'): 0,
#  ('ɛ', 'ŋ'): 0,
#  ('ɛ', 'd͡ʒ'): 0,
#  ('ɛ', 'b'): 0,
#  ('ɛ', 'ɝ'): 0,
#  ('ɛ', 'ʃ'): 0,
#  ('ɛ', 'ɫ'): 4,
#  ('ɛ', 'n̩'): 0,
#  ('ɛ', 'ɪ'): 0,
#  ('ɛ', 'ɚ'): 0,
#  ('ɛ', 'ə'): 11,
#  ('f', 'k'): 0,
#  ('f', 'ɑː'): 0,
#  ('f', 'l'): 0,
#  ('f', 'e'): 0,
#  ('f', 'ɨ'): 0,
#  ('f', 'p'): 0,
#  ('f', 'ɛ'): 0,
#  ('f', 'f'): 0,
#  ('f', 'l̩'): 0,
#  ('f', 'ɹ'): 2,
#  ('f', 'ʌ'): 0,
#  ('f', 'n'): 0,
#  ('f', 'ɒ'): 0,
#  ('f', 'i'): 0,
#  ('f', 'u'): 0,
#  ('f', 't'): 8,
#  ('f', 'z'): 0,
#  ('f', 'ɑ'): 0,
#  ('f', 'iː'): 0,
#  ('f', 'ɝː'): 0,
#  ('f', 'ɜ'): 0,
#  ('f', 'o'): 3,
#  ('f', 'j'): 0,
#  ('f', 'ʍ'): 0,
#  ('f', 'm'): 0,
#  ('f', 'θ'): 0,
#  ('f', 'ɔː'): 0,
#  ('f', 'ɔ'): 4,
#  ('f', 'ʒ'): 0,
#  ('f', 'ɡ'): 0,
#  ('f', 'a'): 0,
#  ('f', 'æ'): 0,
#  ('f', 't͡ʃ'): 0,
#  ('f', 'ʊ'): 0,
#  ('f', 'ð'): 0,
#  ('f', 'h'): 0,
#  ('f', 'v'): 0,
#  ('f', 'd'): 0,
#  ('f', 'w'): 0,
#  ('f', 's'): 0,
#  ('f', 'uː'): 0,
#  ('f', 'ŋ'): 0,
#  ('f', 'd͡ʒ'): 0,
#  ('f', 'b'): 0,
#  ('f', 'ɝ'): 0,
#  ('f', 'ʃ'): 0,
#  ('f', 'ɫ'): 0,
#  ('f', 'n̩'): 0,
#  ('f', 'ɪ'): 3,
#  ('f', 'ɚ'): 7,
#  ('f', 'ə'): 1,
#  ('l̩', 'k'): 0,
#  ('l̩', 'ɑː'): 0,
#  ('l̩', 'l'): 0,
#  ('l̩', 'e'): 0,
#  ('l̩', 'ɨ'): 0,
#  ('l̩', 'p'): 0,
#  ('l̩', 'ɛ'): 0,
#  ('l̩', 'f'): 0,
#  ('l̩', 'l̩'): 0,
#  ('l̩', 'ɹ'): 0,
#  ('l̩', 'ʌ'): 0,
#  ('l̩', 'n'): 0,
#  ('l̩', 'ɒ'): 0,
#  ('l̩', 'i'): 0,
#  ('l̩', 'u'): 0,
#  ('l̩', 't'): 0,
#  ('l̩', 'z'): 0,
#  ('l̩', 'ɑ'): 0,
#  ('l̩', 'iː'): 0,
#  ('l̩', 'ɝː'): 0,
#  ('l̩', 'ɜ'): 0,
#  ('l̩', 'o'): 0,
#  ('l̩', 'j'): 0,
#  ('l̩', 'ʍ'): 0,
#  ('l̩', 'm'): 0,
#  ('l̩', 'θ'): 0,
#  ('l̩', 'ɔː'): 0,
#  ('l̩', 'ɔ'): 0,
#  ('l̩', 'ʒ'): 0,
#  ('l̩', 'ɡ'): 0,
#  ('l̩', 'a'): 0,
#  ('l̩', 'æ'): 0,
#  ('l̩', 't͡ʃ'): 0,
#  ('l̩', 'ʊ'): 0,
#  ('l̩', 'ð'): 0,
#  ('l̩', 'h'): 0,
#  ('l̩', 'v'): 0,
#  ('l̩', 'd'): 0,
#  ('l̩', 'w'): 0,
#  ('l̩', 's'): 0,
#  ('l̩', 'uː'): 0,
#  ('l̩', 'ŋ'): 0,
#  ('l̩', 'd͡ʒ'): 0,
#  ('l̩', 'b'): 0,
#  ('l̩', 'ɝ'): 0,
#  ('l̩', 'ʃ'): 0,
#  ('l̩', 'ɫ'): 0,
#  ('l̩', 'n̩'): 0,
#  ('l̩', 'ɪ'): 0,
#  ('l̩', 'ɚ'): 0,
#  ('l̩', 'ə'): 0,
#  ('ɹ', 'k'): 4,
#  ('ɹ', 'ɑː'): 0,
#  ('ɹ', 'l'): 0,
#  ('ɹ', 'e'): 4,
#  ('ɹ', 'ɨ'): 0,
#  ('ɹ', 'p'): 1,
#  ('ɹ', 'ɛ'): 4,
#  ('ɹ', 'f'): 1,
#  ('ɹ', 'l̩'): 0,
#  ('ɹ', 'ɹ'): 0,
#  ('ɹ', 'ʌ'): 3,
#  ('ɹ', 'n'): 1,
#  ('ɹ', 'ɒ'): 0,
#  ('ɹ', 'i'): 5,
#  ('ɹ', 'u'): 1,
#  ('ɹ', 't'): 5,
#  ('ɹ', 'z'): 3,
#  ('ɹ', 'ɑ'): 3,
#  ('ɹ', 'iː'): 3,
#  ('ɹ', 'ɝː'): 0,
#  ('ɹ', 'ɜ'): 0,
#  ('ɹ', 'o'): 7,
#  ('ɹ', 'j'): 0,
#  ('ɹ', 'ʍ'): 0,
#  ('ɹ', 'm'): 0,
#  ('ɹ', 'θ'): 0,
#  ('ɹ', 'ɔː'): 0,
#  ('ɹ', 'ɔ'): 3,
#  ('ɹ', 'ʒ'): 0,
#  ('ɹ', 'ɡ'): 0,
#  ('ɹ', 'a'): 13,
#  ('ɹ', 'æ'): 4,
#  ('ɹ', 't͡ʃ'): 0,
#  ('ɹ', 'ʊ'): 2,
#  ('ɹ', 'ð'): 0,
#  ('ɹ', 'h'): 0,
#  ('ɹ', 'v'): 0,
#  ('ɹ', 'd'): 1,
#  ('ɹ', 'w'): 0,
#  ('ɹ', 's'): 0,
#  ('ɹ', 'uː'): 0,
#  ('ɹ', 'ŋ'): 0,
#  ('ɹ', 'd͡ʒ'): 0,
#  ('ɹ', 'b'): 0,
#  ('ɹ', 'ɝ'): 0,
#  ('ɹ', 'ʃ'): 0,
#  ('ɹ', 'ɫ'): 0,
#  ('ɹ', 'n̩'): 0,
#  ('ɹ', 'ɪ'): 8,
#  ('ɹ', 'ɚ'): 0,
#  ('ɹ', 'ə'): 3,
#  ('ʌ', 'k'): 0,
#  ('ʌ', 'ɑː'): 0,
#  ('ʌ', 'l'): 0,
#  ('ʌ', 'e'): 0,
#  ('ʌ', 'ɨ'): 0,
#  ('ʌ', 'p'): 4,
#  ('ʌ', 'ɛ'): 0,
#  ('ʌ', 'f'): 0,
#  ('ʌ', 'l̩'): 0,
#  ('ʌ', 'ɹ'): 0,
#  ('ʌ', 'ʌ'): 0,
#  ('ʌ', 'n'): 17,
#  ('ʌ', 'ɒ'): 0,
#  ('ʌ', 'i'): 0,
#  ('ʌ', 'u'): 0,
#  ('ʌ', 't'): 53,
#  ('ʌ', 'z'): 5,
#  ('ʌ', 'ɑ'): 0,
#  ('ʌ', 'iː'): 0,
#  ('ʌ', 'ɝː'): 0,
#  ('ʌ', 'ɜ'): 0,
#  ('ʌ', 'o'): 0,
#  ('ʌ', 'j'): 0,
#  ('ʌ', 'ʍ'): 0,
#  ('ʌ', 'm'): 16,
#  ('ʌ', 'θ'): 0,
#  ('ʌ', 'ɔː'): 0,
#  ('ʌ', 'ɔ'): 0,
#  ('ʌ', 'ʒ'): 0,
#  ('ʌ', 'ɡ'): 0,
#  ('ʌ', 'a'): 0,
#  ('ʌ', 'æ'): 0,
#  ('ʌ', 't͡ʃ'): 0,
#  ('ʌ', 'ʊ'): 0,
#  ('ʌ', 'ð'): 3,
#  ('ʌ', 'h'): 0,
#  ('ʌ', 'v'): 6,
#  ('ʌ', 'd'): 1,
#  ('ʌ', 'w'): 0,
#  ('ʌ', 's'): 3,
#  ('ʌ', 'uː'): 0,
#  ('ʌ', 'ŋ'): 1,
#  ('ʌ', 'd͡ʒ'): 0,
#  ('ʌ', 'b'): 3,
#  ('ʌ', 'ɝ'): 0,
#  ('ʌ', 'ʃ'): 0,
#  ('ʌ', 'ɫ'): 0,
#  ('ʌ', 'n̩'): 0,
#  ('ʌ', 'ɪ'): 0,
#  ('ʌ', 'ɚ'): 0,
#  ('ʌ', 'ə'): 0,
#  ('n', 'k'): 0,
#  ('n', 'ɑː'): 0,
#  ('n', 'l'): 0,
#  ('n', 'e'): 3,
#  ('n', 'ɨ'): 0,
#  ('n', 'p'): 0,
#  ('n', 'ɛ'): 2,
#  ('n', 'f'): 0,
#  ('n', 'l̩'): 0,
#  ('n', 'ɹ'): 0,
#  ('n', 'ʌ'): 4,
#  ('n', 'n'): 0,
#  ('n', 'ɒ'): 8,
#  ('n', 'i'): 5,
#  ('n', 'u'): 0,
#  ('n', 't'): 35,
#  ('n', 'z'): 4,
#  ('n', 'ɑ'): 0,
#  ('n', 'iː'): 5,
#  ('n', 'ɝː'): 0,
#  ('n', 'ɜ'): 0,
#  ('n', 'o'): 3,
#  ('n', 'j'): 0,
#  ('n', 'ʍ'): 0,
#  ('n', 'm'): 0,
#  ('n', 'θ'): 0,
#  ('n', 'ɔː'): 0,
#  ('n', 'ɔ'): 0,
#  ('n', 'ʒ'): 0,
#  ('n', 'ɡ'): 0,
#  ('n', 'a'): 9,
#  ('n', 'æ'): 1,
#  ('n', 't͡ʃ'): 0,
#  ('n', 'ʊ'): 0,
#  ('n', 'ð'): 0,
#  ('n', 'h'): 0,
#  ('n', 'v'): 1,
#  ('n', 'd'): 15,
#  ('n', 'w'): 0,
#  ('n', 's'): 4,
#  ('n', 'uː'): 0,
#  ('n', 'ŋ'): 0,
#  ('n', 'd͡ʒ'): 1,
#  ('n', 'b'): 0,
#  ('n', 'ɝ'): 0,
#  ('n', 'ʃ'): 0,
#  ('n', 'ɫ'): 0,
#  ('n', 'n̩'): 0,
#  ('n', 'ɪ'): 4,
#  ('n', 'ɚ'): 0,
#  ('n', 'ə'): 3,
#  ('ɒ', 'k'): 0,
#  ('ɒ', 'ɑː'): 0,
#  ('ɒ', 'l'): 0,
#  ('ɒ', 'e'): 0,
#  ('ɒ', 'ɨ'): 0,
#  ('ɒ', 'p'): 0,
#  ('ɒ', 'ɛ'): 0,
#  ('ɒ', 'f'): 0,
#  ('ɒ', 'l̩'): 0,
#  ('ɒ', 'ɹ'): 0,
#  ('ɒ', 'ʌ'): 0,
#  ('ɒ', 'n'): 0,
#  ('ɒ', 'ɒ'): 0,
#  ('ɒ', 'i'): 0,
#  ('ɒ', 'u'): 0,
#  ('ɒ', 't'): 8,
#  ('ɒ', 'z'): 0,
#  ('ɒ', 'ɑ'): 0,
#  ('ɒ', 'iː'): 0,
#  ('ɒ', 'ɝː'): 0,
#  ('ɒ', 'ɜ'): 0,
#  ('ɒ', 'o'): 0,
#  ('ɒ', 'j'): 0,
#  ('ɒ', 'ʍ'): 0,
#  ('ɒ', 'm'): 1,
#  ('ɒ', 'θ'): 0,
#  ('ɒ', 'ɔː'): 0,
#  ('ɒ', 'ɔ'): 0,
#  ('ɒ', 'ʒ'): 0,
#  ('ɒ', 'ɡ'): 0,
#  ('ɒ', 'a'): 0,
#  ('ɒ', 'æ'): 0,
#  ('ɒ', 't͡ʃ'): 0,
#  ('ɒ', 'ʊ'): 0,
#  ('ɒ', 'ð'): 0,
#  ('ɒ', 'h'): 0,
#  ('ɒ', 'v'): 0,
#  ('ɒ', 'd'): 0,
#  ('ɒ', 'w'): 0,
#  ('ɒ', 's'): 0,
#  ('ɒ', 'uː'): 0,
#  ('ɒ', 'ŋ'): 0,
#  ('ɒ', 'd͡ʒ'): 0,
#  ('ɒ', 'b'): 0,
#  ('ɒ', 'ɝ'): 0,
#  ('ɒ', 'ʃ'): 0,
#  ('ɒ', 'ɫ'): 0,
#  ('ɒ', 'n̩'): 0,
#  ('ɒ', 'ɪ'): 0,
#  ('ɒ', 'ɚ'): 0,
#  ('ɒ', 'ə'): 0,
#  ('i', 'k'): 0,
#  ('i', 'ɑː'): 0,
#  ('i', 'l'): 0,
#  ('i', 'e'): 0,
#  ('i', 'ɨ'): 0,
#  ('i', 'p'): 0,
#  ('i', 'ɛ'): 0,
#  ('i', 'f'): 0,
#  ('i', 'l̩'): 0,
#  ('i', 'ɹ'): 0,
#  ('i', 'ʌ'): 0,
#  ('i', 'n'): 0,
#  ('i', 'ɒ'): 0,
#  ('i', 'i'): 0,
#  ('i', 'u'): 0,
#  ('i', 't'): 1,
#  ('i', 'z'): 2,
#  ('i', 'ɑ'): 0,
#  ('i', 'iː'): 0,
#  ('i', 'ɝː'): 0,
#  ('i', 'ɜ'): 0,
#  ('i', 'o'): 0,
#  ('i', 'j'): 0,
#  ('i', 'ʍ'): 0,
#  ('i', 'm'): 2,
#  ('i', 'θ'): 0,
#  ('i', 'ɔː'): 0,
#  ('i', 'ɔ'): 0,
#  ('i', 'ʒ'): 0,
#  ('i', 'ɡ'): 0,
#  ('i', 'a'): 0,
#  ('i', 'æ'): 0,
#  ('i', 't͡ʃ'): 1,
#  ('i', 'ʊ'): 0,
#  ('i', 'ð'): 0,
#  ('i', 'h'): 0,
#  ('i', 'v'): 0,
#  ('i', 'd'): 0,
#  ('i', 'w'): 1,
#  ('i', 's'): 0,
#  ('i', 'uː'): 0,
#  ('i', 'ŋ'): 0,
#  ('i', 'd͡ʒ'): 0,
#  ('i', 'b'): 1,
#  ('i', 'ɝ'): 0,
#  ('i', 'ʃ'): 0,
#  ('i', 'ɫ'): 0,
#  ('i', 'n̩'): 0,
#  ('i', 'ɪ'): 0,
#  ('i', 'ɚ'): 0,
#  ('i', 'ə'): 0,
#  ('u', 'k'): 0,
#  ('u', 'ɑː'): 0,
#  ('u', 'l'): 0,
#  ('u', 'e'): 0,
#  ('u', 'ɨ'): 0,
#  ('u', 'p'): 0,
#  ('u', 'ɛ'): 0,
#  ('u', 'f'): 0,
#  ('u', 'l̩'): 0,
#  ('u', 'ɹ'): 0,
#  ('u', 'ʌ'): 0,
#  ('u', 'n'): 0,
#  ('u', 'ɒ'): 0,
#  ('u', 'i'): 0,
#  ('u', 'u'): 0,
#  ('u', 't'): 0,
#  ('u', 'z'): 0,
#  ('u', 'ɑ'): 0,
#  ('u', 'iː'): 0,
#  ('u', 'ɝː'): 0,
#  ('u', 'ɜ'): 0,
#  ('u', 'o'): 0,
#  ('u', 'j'): 0,
#  ('u', 'ʍ'): 0,
#  ('u', 'm'): 1,
#  ('u', 'θ'): 0,
#  ('u', 'ɔː'): 0,
#  ('u', 'ɔ'): 0,
#  ('u', 'ʒ'): 0,
#  ('u', 'ɡ'): 0,
#  ('u', 'a'): 0,
#  ('u', 'æ'): 0,
#  ('u', 't͡ʃ'): 0,
#  ('u', 'ʊ'): 0,
#  ('u', 'ð'): 0,
#  ('u', 'h'): 0,
#  ('u', 'v'): 2,
#  ('u', 'd'): 0,
#  ('u', 'w'): 0,
#  ('u', 's'): 0,
#  ('u', 'uː'): 0,
#  ('u', 'ŋ'): 0,
#  ('u', 'd͡ʒ'): 0,
#  ('u', 'b'): 0,
#  ('u', 'ɝ'): 0,
#  ('u', 'ʃ'): 0,
#  ('u', 'ɫ'): 0,
#  ('u', 'n̩'): 0,
#  ('u', 'ɪ'): 0,
#  ('u', 'ɚ'): 0,
#  ('u', 'ə'): 0,
#  ('t', 'k'): 0,
#  ('t', 'ɑː'): 0,
#  ('t', 'l'): 0,
#  ('t', 'e'): 2,
#  ('t', 'ɨ'): 0,
#  ('t', 'p'): 0,
#  ('t', 'ɛ'): 13,
#  ('t', 'f'): 0,
#  ('t', 'l̩'): 4,
#  ('t', 'ɹ'): 10,
#  ('t', 'ʌ'): 0,
#  ('t', 'n'): 0,
#  ('t', 'ɒ'): 0,
#  ('t', 'i'): 9,
#  ('t', 'u'): 9,
#  ('t', 't'): 0,
#  ('t', 'z'): 0,
#  ('t', 'ɑ'): 6,
#  ('t', 'iː'): 1,
#  ('t', 'ɝː'): 0,
#  ('t', 'ɜ'): 0,
#  ('t', 'o'): 0,
#  ('t', 'j'): 0,
#  ('t', 'ʍ'): 0,
#  ('t', 'm'): 0,
#  ('t', 'θ'): 0,
#  ('t', 'ɔː'): 0,
#  ('t', 'ɔ'): 6,
#  ('t', 'ʒ'): 0,
#  ('t', 'ɡ'): 0,
#  ('t', 'a'): 4,
#  ('t', 'æ'): 2,
#  ('t', 't͡ʃ'): 0,
#  ('t', 'ʊ'): 21,
#  ('t', 'ð'): 0,
#  ('t', 'h'): 0,
#  ('t', 'v'): 0,
#  ('t', 'd'): 0,
#  ('t', 'w'): 0,
#  ('t', 's'): 15,
#  ('t', 'uː'): 0,
#  ('t', 'ŋ'): 0,
#  ('t', 'd͡ʒ'): 0,
#  ('t', 'b'): 0,
#  ('t', 'ɝ'): 0,
#  ('t', 'ʃ'): 0,
#  ('t', 'ɫ'): 0,
#  ('t', 'n̩'): 1,
#  ('t', 'ɪ'): 7,
#  ('t', 'ɚ'): 2,
#  ('t', 'ə'): 12,
#  ('z', 'k'): 0,
#  ('z', 'ɑː'): 0,
#  ('z', 'l'): 0,
#  ('z', 'e'): 0,
#  ('z', 'ɨ'): 0,
#  ('z', 'p'): 0,
#  ('z', 'ɛ'): 0,
#  ('z', 'f'): 0,
#  ('z', 'l̩'): 0,
#  ('z', 'ɹ'): 0,
#  ('z', 'ʌ'): 0,
#  ('z', 'n'): 0,
#  ('z', 'ɒ'): 0,
#  ('z', 'i'): 0,
#  ('z', 'u'): 0,
#  ('z', 't'): 0,
#  ('z', 'z'): 0,
#  ('z', 'ɑ'): 0,
#  ('z', 'iː'): 0,
#  ('z', 'ɝː'): 0,
#  ('z', 'ɜ'): 0,
#  ('z', 'o'): 0,
#  ('z', 'j'): 0,
#  ('z', 'ʍ'): 0,
#  ('z', 'm'): 0,
#  ('z', 'θ'): 0,
#  ('z', 'ɔː'): 0,
#  ('z', 'ɔ'): 0,
#  ('z', 'ʒ'): 0,
#  ('z', 'ɡ'): 0,
#  ('z', 'a'): 0,
#  ('z', 'æ'): 0,
#  ('z', 't͡ʃ'): 0,
#  ('z', 'ʊ'): 0,
#  ('z', 'ð'): 0,
#  ('z', 'h'): 0,
#  ('z', 'v'): 0,
#  ('z', 'd'): 0,
#  ('z', 'w'): 0,
#  ('z', 's'): 0,
#  ('z', 'uː'): 0,
#  ('z', 'ŋ'): 0,
#  ('z', 'd͡ʒ'): 0,
#  ('z', 'b'): 0,
#  ('z', 'ɝ'): 0,
#  ('z', 'ʃ'): 0,
#  ('z', 'ɫ'): 0,
#  ('z', 'n̩'): 0,
#  ('z', 'ɪ'): 2,
#  ('z', 'ɚ'): 1,
#  ('z', 'ə'): 3,
#  ('ɑ', 'k'): 6,
#  ('ɑ', 'ɑː'): 0,
#  ('ɑ', 'l'): 0,
#  ('ɑ', 'e'): 0,
#  ('ɑ', 'ɨ'): 0,
#  ('ɑ', 'p'): 3,
#  ('ɑ', 'ɛ'): 0,
#  ('ɑ', 'f'): 0,
#  ('ɑ', 'l̩'): 0,
#  ('ɑ', 'ɹ'): 8,
#  ('ɑ', 'ʌ'): 0,
#  ('ɑ', 'n'): 1,
#  ('ɑ', 'ɒ'): 0,
#  ('ɑ', 'i'): 0,
#  ('ɑ', 'u'): 0,
#  ('ɑ', 't'): 1,
#  ('ɑ', 'z'): 0,
#  ('ɑ', 'ɑ'): 0,
#  ('ɑ', 'iː'): 0,
#  ('ɑ', 'ɝː'): 0,
#  ('ɑ', 'ɜ'): 0,
#  ('ɑ', 'o'): 0,
#  ('ɑ', 'j'): 0,
#  ('ɑ', 'ʍ'): 0,
#  ('ɑ', 'm'): 1,
#  ('ɑ', 'θ'): 0,
#  ('ɑ', 'ɔː'): 0,
#  ('ɑ', 'ɔ'): 0,
#  ('ɑ', 'ʒ'): 0,
#  ('ɑ', 'ɡ'): 0,
#  ('ɑ', 'a'): 0,
#  ('ɑ', 'æ'): 0,
#  ('ɑ', 't͡ʃ'): 0,
#  ('ɑ', 'ʊ'): 0,
#  ('ɑ', 'ð'): 0,
#  ('ɑ', 'h'): 0,
#  ('ɑ', 'v'): 0,
#  ('ɑ', 'd'): 1,
#  ('ɑ', 'w'): 0,
#  ('ɑ', 's'): 0,
#  ('ɑ', 'uː'): 0,
#  ('ɑ', 'ŋ'): 0,
#  ('ɑ', 'd͡ʒ'): 0,
#  ('ɑ', 'b'): 2,
#  ('ɑ', 'ɝ'): 0,
#  ('ɑ', 'ʃ'): 0,
#  ('ɑ', 'ɫ'): 0,
#  ('ɑ', 'n̩'): 0,
#  ('ɑ', 'ɪ'): 0,
#  ('ɑ', 'ɚ'): 0,
#  ('ɑ', 'ə'): 0,
#  ('iː', 'k'): 0,
#  ('iː', 'ɑː'): 0,
#  ('iː', 'l'): 0,
#  ('iː', 'e'): 0,
#  ('iː', 'ɨ'): 0,
#  ('iː', 'p'): 1,
#  ('iː', 'ɛ'): 0,
#  ('iː', 'f'): 0,
#  ('iː', 'l̩'): 0,
#  ('iː', 'ɹ'): 0,
#  ('iː', 'ʌ'): 0,
#  ('iː', 'n'): 3,
#  ('iː', 'ɒ'): 0,
#  ('iː', 'i'): 0,
#  ('iː', 'u'): 0,
#  ('iː', 't'): 2,
#  ('iː', 'z'): 6,
#  ('iː', 'ɑ'): 0,
#  ('iː', 'iː'): 0,
#  ('iː', 'ɝː'): 0,
#  ('iː', 'ɜ'): 0,
#  ('iː', 'o'): 0,
#  ('iː', 'j'): 0,
#  ('iː', 'ʍ'): 0,
#  ('iː', 'm'): 0,
#  ('iː', 'θ'): 0,
#  ('iː', 'ɔː'): 0,
#  ('iː', 'ɔ'): 0,
#  ('iː', 'ʒ'): 0,
#  ('iː', 'ɡ'): 0,
#  ('iː', 'a'): 0,
#  ('iː', 'æ'): 0,
#  ('iː', 't͡ʃ'): 0,
#  ('iː', 'ʊ'): 0,
#  ('iː', 'ð'): 0,
#  ('iː', 'h'): 0,
#  ('iː', 'v'): 0,
#  ('iː', 'd'): 6,
#  ('iː', 'w'): 0,
#  ('iː', 's'): 3,
#  ('iː', 'uː'): 0,
#  ('iː', 'ŋ'): 0,
#  ('iː', 'd͡ʒ'): 0,
#  ('iː', 'b'): 0,
#  ('iː', 'ɝ'): 0,
#  ('iː', 'ʃ'): 0,
#  ('iː', 'ɫ'): 0,
#  ('iː', 'n̩'): 0,
#  ('iː', 'ɪ'): 0,
#  ('iː', 'ɚ'): 0,
#  ('iː', 'ə'): 0,
#  ('ɝː', 'k'): 0,
#  ('ɝː', 'ɑː'): 0,
#  ('ɝː', 'l'): 0,
#  ('ɝː', 'e'): 0,
#  ('ɝː', 'ɨ'): 0,
#  ('ɝː', 'p'): 0,
#  ('ɝː', 'ɛ'): 0,
#  ('ɝː', 'f'): 0,
#  ('ɝː', 'l̩'): 0,
#  ('ɝː', 'ɹ'): 0,
#  ('ɝː', 'ʌ'): 0,
#  ('ɝː', 'n'): 0,
#  ('ɝː', 'ɒ'): 0,
#  ('ɝː', 'i'): 0,
#  ('ɝː', 'u'): 0,
#  ('ɝː', 't'): 0,
#  ('ɝː', 'z'): 2,
#  ('ɝː', 'ɑ'): 0,
#  ('ɝː', 'iː'): 0,
#  ('ɝː', 'ɝː'): 0,
#  ('ɝː', 'ɜ'): 0,
#  ('ɝː', 'o'): 0,
#  ('ɝː', 'j'): 0,
#  ('ɝː', 'ʍ'): 0,
#  ('ɝː', 'm'): 0,
#  ('ɝː', 'θ'): 0,
#  ('ɝː', 'ɔː'): 0,
#  ('ɝː', 'ɔ'): 0,
#  ('ɝː', 'ʒ'): 0,
#  ('ɝː', 'ɡ'): 0,
#  ('ɝː', 'a'): 0,
#  ...}

# %%
# create a dict pwb = prob word boundary, that holds, for each ptp, the prob(word boundary | ptp).
# key = ptp, value = prob.
# value is obtained as ptp_across_count[ptp] / (ptp_across_count[ptp] + ptp_within_count[ptp])
# NB: for some PTPs all values could be 0 - we will collect these in a list called unused.
# then only compute probs for PTPs that were used, i.e. are not in list unused.

# YOUR CODE GOES HERE.
unused = [ptp for ptp in ptps if ptp_across_count[ptp] == 0 and ptp_within_count[ptp] == 0]  # REPLACE
pwb = {ptp: ptp_across_count[ptp] / (ptp_across_count[ptp] + ptp_within_count[ptp]) for ptp in ptps if ptp not in un}  # REPLACE

print(len(ptps), len(unused), len(pwb))
pwb
# Out:
# 2601 1985 616
# {('k', 'l'): 0.0,
#  ('k', 'e'): 0.0,
#  ('k', 'p'): 1.0,
#  ('k', 'ɛ'): 0.0,
#  ('k', 'f'): 1.0,
#  ('k', 'ɹ'): 0.0,
#  ('k', 'ʌ'): 0.0,
#  ('k', 'i'): 0.0,
#  ('k', 't'): 0.3333333333333333,
#  ('k', 'ɑ'): 0.0,
#  ('k', 'iː'): 0.0,
#  ('k', 'o'): 1.0,
#  ('k', 'j'): 0.42857142857142855,
#  ('k', 'ɡ'): 1.0,
#  ('k', 'a'): 0.0,
#  ('k', 'ʊ'): 0.0,
#  ('k', 'ð'): 1.0,
#  ('k', 'h'): 1.0,
#  ('k', 'd'): 1.0,
#  ('k', 'w'): 1.0,
#  ('k', 's'): 0.35714285714285715,
#  ('k', 'uː'): 0.0,
#  ('k', 'b'): 1.0,
#  ('k', 'ɪ'): 0.6666666666666666,
#  ('k', 'ə'): 0.18181818181818182,
#  ('ɑː', 't'): 1.0,
#  ('l', 'k'): 1.0,
#  ('l', 'l'): 1.0,
#  ('l', 'e'): 0.0,
#  ('l', 'p'): 1.0,
#  ('l', 'ɛ'): 0.0,
#  ('l', 'n'): 1.0,
#  ('l', 'i'): 0.0,
#  ('l', 't'): 0.2,
#  ('l', 'z'): 0.0,
#  ('l', 'ɑ'): 0.0,
#  ('l', 'o'): 0.16666666666666666,
#  ('l', 'j'): 0.25,
#  ('l', 'ʍ'): 1.0,
#  ('l', 'm'): 1.0,
#  ('l', 'a'): 0.0,
#  ('l', 'æ'): 0.0,
#  ('l', 'ʊ'): 0.0,
#  ('l', 'ð'): 1.0,
#  ('l', 'h'): 1.0,
#  ('l', 'd'): 0.2857142857142857,
#  ('l', 'w'): 0.6666666666666666,
#  ('l', 'uː'): 0.0,
#  ('l', 'b'): 1.0,
#  ('l', 'ɪ'): 0.16666666666666666,
#  ('l', 'ɚ'): 0.0,
#  ('l', 'ə'): 0.0,
#  ('e', 'ɪ'): 0.0,
#  ('ɨ', 'n'): 0.0,
#  ('p', 'l'): 0.0,
#  ('p', 'ɨ'): 0.0,
#  ('p', 'p'): 1.0,
#  ('p', 'ɛ'): 0.0,
#  ('p', 'ɹ'): 0.0,
#  ('p', 'ʌ'): 0.0,
#  ('p', 'ɑ'): 0.0,
#  ('p', 'ʍ'): 1.0,
#  ('p', 'θ'): 1.0,
#  ('p', 'æ'): 0.0,
#  ('p', 's'): 0.8,
#  ('p', 'b'): 1.0,
#  ('p', 'ɪ'): 0.0,
#  ('p', 'ə'): 0.25,
#  ('ɛ', 'k'): 0.0,
#  ('ɛ', 'l'): 0.0,
#  ('ɛ', 'f'): 0.0,
#  ('ɛ', 'ɹ'): 0.0,
#  ('ɛ', 'n'): 0.0,
#  ('ɛ', 't'): 0.0,
#  ('ɛ', 'm'): 0.0,
#  ('ɛ', 'ɡ'): 0.0,
#  ('ɛ', 'v'): 0.0,
#  ('ɛ', 's'): 0.0,
#  ('ɛ', 'ɫ'): 0.0,
#  ('ɛ', 'ə'): 0.0,
#  ('f', 'k'): 1.0,
#  ('f', 'ɹ'): 0.0,
#  ('f', 't'): 0.0,
#  ('f', 'o'): 0.0,
#  ('f', 'j'): 1.0,
#  ('f', 'ɔ'): 0.0,
#  ('f', 'ð'): 1.0,
#  ('f', 'v'): 1.0,
#  ('f', 'ʃ'): 1.0,
#  ('f', 'ɪ'): 0.0,
#  ('f', 'ɚ'): 0.0,
#  ('f', 'ə'): 0.0,
#  ('l̩', 'o'): 1.0,
#  ('l̩', 's'): 1.0,
#  ('l̩', 'b'): 1.0,
#  ('ɹ', 'k'): 0.2,
#  ('ɹ', 'l'): 1.0,
#  ('ɹ', 'e'): 0.0,
#  ('ɹ', 'p'): 0.5,
#  ('ɹ', 'ɛ'): 0.3333333333333333,
#  ('ɹ', 'f'): 0.6666666666666666,
#  ('ɹ', 'ʌ'): 0.0,
#  ('ɹ', 'n'): 0.6666666666666666,
#  ('ɹ', 'i'): 0.0,
#  ('ɹ', 'u'): 0.0,
#  ('ɹ', 't'): 0.2857142857142857,
#  ('ɹ', 'z'): 0.0,
#  ('ɹ', 'ɑ'): 0.0,
#  ('ɹ', 'iː'): 0.0,
#  ('ɹ', 'o'): 0.4166666666666667,
#  ('ɹ', 'j'): 1.0,
#  ('ɹ', 'ʍ'): 1.0,
#  ('ɹ', 'm'): 1.0,
#  ('ɹ', 'θ'): 1.0,
#  ('ɹ', 'ɔ'): 0.0,
#  ('ɹ', 'ɡ'): 1.0,
#  ('ɹ', 'a'): 0.0,
#  ('ɹ', 'æ'): 0.0,
#  ('ɹ', 'ʊ'): 0.0,
#  ('ɹ', 'ð'): 1.0,
#  ('ɹ', 'h'): 1.0,
#  ('ɹ', 'd'): 0.75,
#  ('ɹ', 'w'): 1.0,
#  ('ɹ', 's'): 1.0,
#  ('ɹ', 'b'): 1.0,
#  ('ɹ', 'ʃ'): 1.0,
#  ('ɹ', 'ɪ'): 0.2,
#  ('ɹ', 'ə'): 0.0,
#  ('ʌ', 'p'): 0.0,
#  ('ʌ', 'n'): 0.0,
#  ('ʌ', 't'): 0.0,
#  ('ʌ', 'z'): 0.0,
#  ('ʌ', 'm'): 0.0,
#  ('ʌ', 'ð'): 0.0,
#  ('ʌ', 'v'): 0.0,
#  ('ʌ', 'd'): 0.0,
#  ('ʌ', 's'): 0.0,
#  ('ʌ', 'ŋ'): 0.0,
#  ('ʌ', 'b'): 0.0,
#  ('n', 'e'): 0.25,
#  ('n', 'p'): 1.0,
#  ('n', 'ɛ'): 0.6,
#  ('n', 'ɹ'): 1.0,
#  ('n', 'ʌ'): 0.2,
#  ('n', 'n'): 1.0,
#  ('n', 'ɒ'): 0.0,
#  ('n', 'i'): 0.0,
#  ('n', 't'): 0.125,
#  ('n', 'z'): 0.0,
#  ('n', 'iː'): 0.0,
#  ('n', 'o'): 0.25,
#  ('n', 'j'): 1.0,
#  ('n', 'ʍ'): 1.0,
#  ('n', 'm'): 1.0,
#  ('n', 'θ'): 1.0,
#  ('n', 'ɡ'): 1.0,
#  ('n', 'a'): 0.0,
#  ('n', 'æ'): 0.0,
#  ('n', 'ð'): 1.0,
#  ('n', 'h'): 1.0,
#  ('n', 'v'): 0.0,
#  ('n', 'd'): 0.2857142857142857,
#  ('n', 'w'): 1.0,
#  ('n', 's'): 0.6,
#  ('n', 'd͡ʒ'): 0.0,
#  ('n', 'b'): 1.0,
#  ('n', 'ʃ'): 1.0,
#  ('n', 'ɪ'): 0.2,
#  ('n', 'ə'): 0.4,
#  ('ɒ', 't'): 0.0,
#  ('ɒ', 'm'): 0.0,
#  ('i', 'k'): 1.0,
#  ('i', 'l'): 1.0,
#  ('i', 'p'): 1.0,
#  ('i', 'ɹ'): 1.0,
#  ('i', 'n'): 1.0,
#  ('i', 't'): 0.8571428571428571,
#  ('i', 'z'): 0.0,
#  ('i', 'o'): 1.0,
#  ('i', 'j'): 1.0,
#  ('i', 'ʍ'): 1.0,
#  ('i', 'm'): 0.0,
#  ('i', 'θ'): 1.0,
#  ('i', 't͡ʃ'): 0.0,
#  ('i', 'ð'): 1.0,
#  ('i', 'h'): 1.0,
#  ('i', 'd'): 1.0,
#  ('i', 'w'): 0.6666666666666666,
#  ('i', 's'): 1.0,
#  ('i', 'd͡ʒ'): 1.0,
#  ('i', 'b'): 0.6666666666666666,
#  ('i', 'ɪ'): 1.0,
#  ('u', 'j'): 1.0,
#  ('u', 'ʍ'): 1.0,
#  ('u', 'm'): 0.6666666666666666,
#  ('u', 'θ'): 1.0,
#  ('u', 'ð'): 1.0,
#  ('u', 'v'): 0.0,
#  ('u', 'd'): 1.0,
#  ('u', 'w'): 1.0,
#  ('u', 's'): 1.0,
#  ('u', 'b'): 1.0,
#  ('u', 'ɪ'): 1.0,
#  ('u', 'ɚ'): 1.0,
#  ('t', 'k'): 1.0,
#  ('t', 'l'): 1.0,
#  ('t', 'e'): 0.0,
#  ('t', 'p'): 1.0,
#  ('t', 'ɛ'): 0.2777777777777778,
#  ('t', 'f'): 1.0,
#  ('t', 'l̩'): 0.0,
#  ('t', 'ɹ'): 0.23076923076923078,
#  ('t', 'ʌ'): 1.0,
#  ('t', 'n'): 1.0,
#  ('t', 'i'): 0.0,
#  ('t', 'u'): 0.0,
#  ('t', 't'): 1.0,
#  ('t', 'ɑ'): 0.0,
#  ('t', 'iː'): 0.0,
#  ('t', 'o'): 1.0,
#  ('t', 'j'): 1.0,
#  ('t', 'ʍ'): 1.0,
#  ('t', 'm'): 1.0,
#  ('t', 'θ'): 1.0,
#  ('t', 'ɔ'): 0.14285714285714285,
#  ('t', 'ɡ'): 1.0,
#  ('t', 'a'): 0.0,
#  ('t', 'æ'): 0.3333333333333333,
#  ('t', 'ʊ'): 0.0,
#  ('t', 'ð'): 1.0,
#  ('t', 'h'): 1.0,
#  ('t', 'v'): 1.0,
#  ('t', 'd'): 1.0,
#  ('t', 'w'): 1.0,
#  ('t', 's'): 0.4642857142857143,
#  ('t', 'b'): 1.0,
#  ('t', 'ʃ'): 1.0,
#  ('t', 'n̩'): 0.0,
#  ('t', 'ɪ'): 0.6111111111111112,
#  ('t', 'ɚ'): 0.3333333333333333,
#  ('t', 'ə'): 0.42857142857142855,
#  ('z', 'p'): 1.0,
#  ('z', 'ɛ'): 1.0,
#  ('z', 'f'): 1.0,
#  ('z', 'ɹ'): 1.0,
#  ('z', 'n'): 1.0,
#  ('z', 't'): 1.0,
#  ('z', 'j'): 1.0,
#  ('z', 'ʍ'): 1.0,
#  ('z', 'θ'): 1.0,
#  ('z', 'ɡ'): 1.0,
#  ('z', 't͡ʃ'): 1.0,
#  ('z', 'ð'): 1.0,
#  ('z', 'h'): 1.0,
#  ('z', 'd'): 1.0,
#  ('z', 'w'): 1.0,
#  ('z', 'd͡ʒ'): 1.0,
#  ('z', 'ʃ'): 1.0,
#  ('z', 'ɪ'): 0.8181818181818182,
#  ('z', 'ɚ'): 0.0,
#  ('z', 'ə'): 0.5,
#  ('ɑ', 'k'): 0.0,
#  ('ɑ', 'p'): 0.0,
#  ('ɑ', 'ɹ'): 0.0,
#  ('ɑ', 'n'): 0.0,
#  ('ɑ', 't'): 0.0,
#  ('ɑ', 'm'): 0.0,
#  ('ɑ', 'd'): 0.0,
#  ('ɑ', 'b'): 0.0,
#  ('iː', 'p'): 0.6666666666666666,
#  ('iː', 'f'): 1.0,
#  ('iː', 'ɹ'): 1.0,
#  ('iː', 'ʌ'): 1.0,
#  ('iː', 'n'): 0.25,
#  ('iː', 't'): 0.6,
#  ('iː', 'z'): 0.0,
#  ('iː', 'j'): 1.0,
#  ('iː', 'ʍ'): 1.0,
#  ('iː', 'm'): 1.0,
#  ('iː', 'θ'): 1.0,
#  ('iː', 'h'): 1.0,
#  ('iː', 'd'): 0.0,
#  ('iː', 'w'): 1.0,
#  ('iː', 's'): 0.75,
#  ('iː', 'b'): 1.0,
#  ('iː', 'ə'): 1.0,
#  ('ɝː', 'z'): 0.0,
#  ('ɜ', 'ɹ'): 0.0,
#  ('o', 'ʊ'): 0.0,
#  ('j', 'ɛ'): 0.0,
#  ('j', 'u'): 0.0,
#  ('j', 'ɑ'): 0.0,
#  ('j', 'ɝː'): 0.0,
#  ('j', 'ʊ'): 0.0,
#  ('j', 'uː'): 0.0,
#  ('j', 'ə'): 0.0,
#  ('ʍ', 'ɛ'): 0.0,
#  ('ʍ', 'ʌ'): 0.0,
#  ('ʍ', 'a'): 0.0,
#  ('ʍ', 'ɪ'): 0.0,
#  ('m', 'k'): 1.0,
#  ('m', 'l'): 1.0,
#  ('m', 'e'): 0.0,
#  ('m', 'p'): 0.3333333333333333,
#  ('m', 'ɛ'): 0.5,
#  ('m', 'f'): 1.0,
#  ('m', 'ʌ'): 1.0,
#  ('m', 'n'): 1.0,
#  ('m', 'i'): 0.0,
#  ('m', 't'): 1.0,
#  ('m', 'z'): 0.0,
#  ('m', 'ɑ'): 0.0,
#  ('m', 'iː'): 0.0,
#  ('m', 'o'): 1.0,
#  ('m', 'ʍ'): 1.0,
#  ('m', 'm'): 1.0,
#  ('m', 'θ'): 0.0,
#  ('m', 'ɔ'): 0.14285714285714285,
#  ('m', 'a'): 0.25,
#  ('m', 'd'): 1.0,
#  ('m', 'w'): 1.0,
#  ('m', 's'): 1.0,
#  ('m', 'b'): 0.0,
#  ('m', 'ʃ'): 1.0,
#  ('m', 'ɪ'): 0.75,
#  ('m', 'ɚ'): 0.0,
#  ('θ', 'ɛ'): 1.0,
#  ('θ', 'ɹ'): 0.0,
#  ('θ', 'ɔ'): 0.0,
#  ('θ', 'ð'): 1.0,
#  ('θ', 'h'): 1.0,
#  ('θ', 'ɝ'): 0.0,
#  ('θ', 'ɪ'): 0.16666666666666666,
#  ('θ', 'ə'): 1.0,
#  ('ɔː', 'l'): 0.0,
#  ('ɔ', 'k'): 0.0,
#  ('ɔ', 'l'): 0.0,
#  ('ɔ', 'f'): 0.0,
#  ('ɔ', 'ɹ'): 0.0,
#  ('ɔ', 't'): 0.0,
#  ('ɔ', 'ɡ'): 0.0,
#  ('ɔ', 'ŋ'): 0.0,
#  ('ɔ', 'ʃ'): 0.0,
#  ('ɔ', 'ɪ'): 0.1,
#  ('ɔ', 'ə'): 1.0,
#  ('ʒ', 'o'): 0.0,
#  ('ʒ', 'ɪ'): 0.0,
#  ('ɡ', 'e'): 0.0,
#  ('ɡ', 'ɛ'): 0.0,
#  ('ɡ', 'ʌ'): 0.0,
#  ('ɡ', 'z'): 0.0,
#  ('ɡ', 'o'): 0.0,
#  ('ɡ', 'ɔ'): 0.0,
#  ('ɡ', 'b'): 1.0,
#  ('ɡ', 'ɪ'): 0.1,
#  ('ɡ', 'ɚ'): 0.0,
#  ('ɡ', 'ə'): 0.0,
#  ('a', 'ʊ'): 0.0,
#  ('a', 'ɪ'): 0.0,
#  ('æ', 'k'): 0.0,
#  ('æ', 'p'): 0.0,
#  ('æ', 'f'): 0.0,
#  ('æ', 'n'): 0.0,
#  ('æ', 't'): 0.0,
#  ('æ', 'v'): 0.0,
#  ('æ', 'd'): 0.0,
#  ('æ', 'w'): 0.0,
#  ('æ', 's'): 0.0,
#  ('t͡ʃ', 'ɛ'): 0.0,
#  ('t͡ʃ', 'ɚ'): 0.0,
#  ('ʊ', 'k'): 0.47058823529411764,
#  ('ʊ', 'l'): 0.3333333333333333,
#  ('ʊ', 'p'): 1.0,
#  ('ʊ', 'ɛ'): 1.0,
#  ('ʊ', 'f'): 1.0,
#  ('ʊ', 'n'): 0.02702702702702703,
#  ('ʊ', 't'): 0.4,
#  ('ʊ', 'z'): 0.0,
#  ('ʊ', 'o'): 1.0,
#  ('ʊ', 'j'): 1.0,
#  ('ʊ', 'ʍ'): 1.0,
#  ('ʊ', 'm'): 1.0,
#  ('ʊ', 'θ'): 0.5,
#  ('ʊ', 'ɔ'): 1.0,
#  ('ʊ', 'ɡ'): 1.0,
#  ('ʊ', 'a'): 1.0,
#  ('ʊ', 'æ'): 1.0,
#  ('ʊ', 'ð'): 1.0,
#  ('ʊ', 'h'): 1.0,
#  ('ʊ', 'v'): 0.0,
#  ('ʊ', 'd'): 0.7777777777777778,
#  ('ʊ', 'w'): 1.0,
#  ('ʊ', 's'): 1.0,
#  ('ʊ', 'd͡ʒ'): 1.0,
#  ('ʊ', 'b'): 1.0,
#  ('ʊ', 'ɪ'): 0.75,
#  ('ʊ', 'ɚ'): 0.0,
#  ('ʊ', 'ə'): 0.07692307692307693,
#  ('ð', 'e'): 0.0,
#  ('ð', 'ɛ'): 0.0,
#  ('ð', 'iː'): 0.0,
#  ('ð', 'o'): 0.0,
#  ('ð', 'æ'): 0.0,
#  ('ð', 'ɪ'): 0.0,
#  ('ð', 'ɚ'): 0.0,
#  ('h', 'ɛ'): 0.0,
#  ('h', 'ʌ'): 0.0,
#  ('h', 'i'): 0.0,
#  ('h', 'iː'): 0.0,
#  ('h', 'o'): 0.0,
#  ('h', 'a'): 0.0,
#  ('h', 'æ'): 0.0,
#  ('h', 'ɝ'): 0.0,
#  ('h', 'ɪ'): 0.0,
#  ('h', 'ə'): 0.0,
#  ('v', 'p'): 1.0,
#  ('v', 'ɛ'): 0.0,
#  ('v', 'f'): 1.0,
#  ('v', 'ɹ'): 0.0,
#  ('v', 'z'): 0.0,
#  ('v', 'ɡ'): 1.0,
#  ('v', 'ð'): 1.0,
#  ('v', 'd'): 1.0,
#  ('v', 'b'): 1.0,
#  ('v', 'n̩'): 0.0,
#  ('v', 'ɪ'): 0.5,
#  ('v', 'ɚ'): 0.3333333333333333,
#  ('v', 'ə'): 0.2,
#  ('d', 'l'): 1.0,
#  ('d', 'e'): 0.0,
#  ('d', 'p'): 1.0,
#  ('d', 'l̩'): 0.0,
#  ('d', 'ɹ'): 0.3333333333333333,
#  ('d', 'ʌ'): 0.5,
#  ('d', 'i'): 0.0,
#  ('d', 'u'): 0.0,
#  ('d', 't'): 1.0,
#  ('d', 'z'): 0.0,
#  ('d', 'iː'): 0.0,
#  ('d', 'o'): 0.0,
#  ('d', 'j'): 1.0,
#  ('d', 'ʍ'): 1.0,
#  ('d', 'm'): 1.0,
#  ('d', 'ɔ'): 0.0,
#  ('d', 'ʒ'): 0.0,
#  ('d', 'a'): 0.0,
#  ('d', 'h'): 1.0,
#  ('d', 'd'): 1.0,
#  ('d', 'w'): 1.0,
#  ('d', 's'): 1.0,
#  ('d', 'ʃ'): 1.0,
#  ('d', 'ɪ'): 0.2,
#  ('d', 'ɚ'): 0.3333333333333333,
#  ('d', 'ə'): 0.4,
#  ('w', 'e'): 0.0,
#  ('w', 'ɛ'): 0.0,
#  ('w', 'ʌ'): 0.0,
#  ('w', 'n'): 0.0,
#  ('w', 'iː'): 0.0,
#  ('w', 'ɔ'): 0.0,
#  ('w', 'ʊ'): 0.0,
#  ('w', 'ɝ'): 0.0,
#  ('w', 'ɪ'): 0.0,
#  ('w', 'ə'): 0.0,
#  ('s', 'k'): 0.0,
#  ('s', 'ɑː'): 1.0,
#  ('s', 'l'): 1.0,
#  ('s', 'e'): 0.0,
#  ('s', 'p'): 1.0,
#  ('s', 'ɛ'): 0.3333333333333333,
#  ('s', 'ɹ'): 1.0,
#  ('s', 'ʌ'): 0.1,
#  ('s', 'n'): 0.5,
#  ('s', 't'): 0.11538461538461539,
#  ('s', 'iː'): 0.0,
#  ('s', 'ɜ'): 0.0,
#  ('s', 'o'): 0.16666666666666666,
#  ('s', 'j'): 1.0,
#  ('s', 'ʍ'): 1.0,
#  ('s', 'm'): 1.0,
#  ('s', 'ɔ'): 0.0,
#  ('s', 'ɡ'): 1.0,
#  ('s', 'a'): 0.0,
#  ('s', 'ð'): 1.0,
#  ('s', 'h'): 1.0,
#  ('s', 'v'): 1.0,
#  ('s', 'd'): 1.0,
#  ('s', 'w'): 1.0,
#  ('s', 's'): 1.0,
#  ('s', 'ɪ'): 0.45454545454545453,
#  ('s', 'ɚ'): 0.0,
#  ('s', 'ə'): 1.0,
#  ('uː', 'l'): 0.0,
#  ('uː', 'z'): 0.0,
#  ('uː', 'o'): 1.0,
#  ('uː', 'd'): 0.0,
#  ('uː', 's'): 0.0,
#  ('ŋ', 'k'): 0.1111111111111111,
#  ('ŋ', 'l'): 1.0,
#  ('ŋ', 'p'): 1.0,
#  ('ŋ', 'ɛ'): 1.0,
#  ('ŋ', 'ʌ'): 1.0,
#  ('ŋ', 'n'): 1.0,
#  ('ŋ', 't'): 1.0,
#  ('ŋ', 'z'): 0.0,
#  ('ŋ', 'o'): 1.0,
#  ('ŋ', 'j'): 1.0,
#  ('ŋ', 'ʍ'): 1.0,
#  ('ŋ', 'm'): 1.0,
#  ('ŋ', 'θ'): 1.0,
#  ('ŋ', 'ɡ'): 0.0,
#  ('ŋ', 'ð'): 1.0,
#  ('ŋ', 'h'): 1.0,
#  ('ŋ', 'd'): 1.0,
#  ('ŋ', 'w'): 1.0,
#  ('ŋ', 's'): 1.0,
#  ('ŋ', 'ɪ'): 1.0,
#  ('ŋ', 'ə'): 1.0,
#  ('d͡ʒ', 'ʌ'): 0.0,
#  ('d͡ʒ', 'ɔ'): 0.0,
#  ('b', 'l'): 0.0,
#  ('b', 'ɛ'): 0.0,
#  ('b', 'ɹ'): 0.0,
#  ('b', 'ʌ'): 0.0,
#  ('b', 'ɒ'): 0.0,
#  ('b', 'i'): 0.0,
#  ('b', 'ɑ'): 0.0,
#  ('b', 'ɔː'): 0.0,
#  ('b', 'ɔ'): 0.0,
#  ('b', 'a'): 0.0,
#  ('b', 'æ'): 0.0,
#  ('b', 'ɪ'): 0.0,
#  ('b', 'ɚ'): 0.0,
#  ('b', 'ə'): 0.0,
#  ('ɝ', 'k'): 0.5,
#  ('ɝ', 'p'): 1.0,
#  ('ɝ', 't'): 0.25,
#  ('ɝ', 'd'): 0.0,
#  ('ɝ', 'ɪ'): 1.0,
#  ('ɝ', 'ə'): 0.5,
#  ('ʃ', 'ɹ'): 0.0,
#  ('ʃ', 'i'): 0.0,
#  ('ʃ', 't'): 0.0,
#  ('ʃ', 'ɑ'): 0.0,
#  ('ʃ', 'iː'): 0.0,
#  ('ʃ', 'ɪ'): 1.0,
#  ('ʃ', 'ə'): 0.0,
#  ('ɫ', 'ʍ'): 1.0,
#  ('ɫ', 'w'): 1.0,
#  ('ɫ', 'ɚ'): 1.0,
#  ('ɫ', 'ə'): 1.0,
#  ('n̩', 't'): 0.0,
#  ('n̩', 'z'): 0.0,
#  ('ɪ', 'k'): 0.07692307692307693,
#  ('ɪ', 'l'): 0.0,
#  ('ɪ', 'f'): 0.2,
#  ('ɪ', 'ɹ'): 0.16666666666666666,
#  ('ɪ', 'n'): 0.07894736842105263,
#  ('ɪ', 't'): 0.0,
#  ('ɪ', 'z'): 0.0,
#  ('ɪ', 'o'): 1.0,
#  ('ɪ', 'j'): 1.0,
#  ('ɪ', 'ʍ'): 1.0,
#  ('ɪ', 'm'): 0.0625,
#  ('ɪ', 'θ'): 0.0,
#  ('ɪ', 'ɡ'): 0.0,
#  ('ɪ', 'ð'): 1.0,
#  ('ɪ', 'h'): 0.6666666666666666,
#  ('ɪ', 'v'): 0.0,
#  ('ɪ', 'd'): 0.3870967741935484,
#  ('ɪ', 'w'): 1.0,
#  ('ɪ', 's'): 0.375,
#  ('ɪ', 'ŋ'): 0.0,
#  ('ɪ', 'b'): 0.2857142857142857,
#  ('ɪ', 'ʃ'): 0.0,
#  ('ɪ', 'ɪ'): 0.5,
#  ('ɪ', 'ɚ'): 1.0,
#  ('ɪ', 'ə'): 1.0,
#  ('ɚ', 'ɑː'): 1.0,
#  ('ɚ', 'l'): 0.0,
#  ('ɚ', 'p'): 0.0,
#  ('ɚ', 'f'): 1.0,
#  ('ɚ', 'ɹ'): 1.0,
#  ('ɚ', 'n'): 1.0,
#  ('ɚ', 't'): 1.0,
#  ('ɚ', 'z'): 0.0,
#  ('ɚ', 'o'): 1.0,
#  ('ɚ', 'j'): 1.0,
#  ('ɚ', 'ʍ'): 1.0,
#  ('ɚ', 'm'): 1.0,
#  ('ɚ', 'ð'): 1.0,
#  ('ɚ', 'd'): 0.0,
#  ('ɚ', 'w'): 1.0,
#  ('ɚ', 's'): 0.75,
#  ('ɚ', 'b'): 1.0,
#  ('ɚ', 'ɪ'): 1.0,
#  ('ɚ', 'ə'): 1.0,
#  ('ə', 'k'): 1.0,
#  ('ə', 'l'): 0.25,
#  ('ə', 'p'): 1.0,
#  ('ə', 'f'): 0.0,
#  ('ə', 'ɹ'): 0.0,
#  ('ə', 'n'): 0.0,
#  ('ə', 't'): 0.5,
#  ('ə', 'z'): 0.0,
#  ('ə', 'j'): 1.0,
#  ('ə', 'ʍ'): 1.0,
#  ('ə', 'm'): 0.5,
#  ('ə', 'θ'): 1.0,
#  ('ə', 'ɡ'): 0.6666666666666666,
#  ('ə', 'ʊ'): 0.0,
#  ('ə', 'v'): 0.0,
#  ('ə', 'd'): 0.5,
#  ('ə', 'w'): 0.5,
#  ('ə', 's'): 0.5,
#  ('ə', 'b'): 0.6363636363636364}

# %%
# plot used vs. not used.
N = 2   # number of bars
ind = np.arange(N)    # the x locations for the bars, evenly spaced
width = 0.35   # width of bars
plt.bar(ind, [len(pwb), len(unused)], width)
plt.xticks(ind, ('Used', 'Not used'))
plt.show()

# %%
plt.hist(pwb.values(), bins=50)
plt.show()

# %%
# find the PTPs that are always within-word, and print out some.

# YOUR CODE GOES HERE.
within = [ptp for ptp in ptps if ptp_across_count[ptp] == 0 and ptp_within_count[ptp] != 0]  # REPLACE
print(len(within), "PTPs are used only within words.  Here are some:")
print(random.sample(within, 20))

# now find the PTPs that are always between-word, and print out some.

# YOUR CODE GOES HERE.
between = [ptp for ptp in ptps if ptp_across_count[ptp] != 0 and ptp_within_count[ptp] == 0]  # REPLACE
print(len(between), "PTPs are used only between words.  Here are some:")
print(random.sample(between, 20))
# Out:
# 265 PTPs are used only within words.  Here are some:
# [('w', 'ɝ'), ('m', 'ɑ'), ('s', 'e'), ('m', 'e'), ('ə', 'v'), ('n', 'z'), ('j', 'ɝː'), ('b', 'ɔ'), ('v', 'ɛ'), ('ɔ', 'ɹ'), ('f', 'ɹ'), ('t', 'ʊ'), ('t', 'ɑ'), ('æ', 't'), ('ð', 'æ'), ('θ', 'ɔ'), ('ŋ', 'ɡ'), ('ɡ', 'z'), ('m', 'z'), ('k', 'ɹ')]
# 249 PTPs are used only between words.  Here are some:
# [('ʊ', 'ɔ'), ('ɹ', 's'), ('ɪ', 'j'), ('p', 'b'), ('ɝ', 'ɪ'), ('ɹ', 'ð'), ('n', 'ʃ'), ('ʊ', 'm'), ('iː', 'θ'), ('ʊ', 'p'), ('f', 'v'), ('z', 'f'), ('t', 'w'), ('z', 'j'), ('ɔ', 'ə'), ('m', 't'), ('t', 'ɡ'), ('z', 'p'), ('ɹ', 'b'), ('ʊ', 'd͡ʒ')]

# %% [markdown]
# # Observations and conclusions
#
# - Write your general observations about the results here, and conclusions you can draw from them.  A short paragraph would be fine, but please separately specify observations and conclusions.
#
# **Answer:**
#
# General observations: Among all the possible pairs of phonemes in the corpus, only around 1/4 of them are actually used; among those that are actually used, most of them either only appear within a word or only appear across word boundaries (the two categories are similar in number as well, both around 250), very few of them appear at both positions.
#
# Conclusions: Hockema (2006)'s results are replicated. Most English phoneme pairs examined can indeed be associated with a unique label of either "appears within a word" or "appears between words." Thus, it is theoretically possible that phoneme transition information can be used to detect word segmentation in English speech perception. However, apart from the problem of supervised learning, there is also the problem of generalizability:
#
# (1) It is probable that the result does not generalize to languages where most syllables (including at the end of words) begin with a consonant and end with a vowel, such as Italian; or more generally, to languages where most syllables are likely to appear at any place in a word, be it at the begnning, middle, or end, such as Chinese. Table 3 in Hockema's paper has shown that the top 10 interword transitions are all consonant-consonant pairs that sound weird when appearing in the middle of an English word; this is not the case for the two types of langauges (though there may be overlap) mentioned before.
#
# (2) It is also probable that the result does not generalize to langauges where word segmentation itself, even in written format, can sometimes be ambiguous and needs scaffolding from syntactic or other contextual information, such as Chinese. E.g., while "根据地形(according to topography)" is considered a phrase comprising of two words "根据(according to)" and "地形(topography)," "根据地(base camp)" is a single word that cannot be further segmented. There are numerous examples like this in everyday Chinese; again, this is also related to point (1), the flexibility of a syllable being at any position in a word, since this is exactly the way how Chinese words are formed -- picking single-syllable-characters with relevant meanings and joining them together.

# %% [markdown]
# # Extensions (optional)
#
# - Do the same thing for **another language** that is represented in both CHILDES and Wikipron!  If the cue works only holds for English, it is of limited interest.
# - Consider utterance boundaries.  As we discussed in class, this analysis can be seen as an instance of **supervised learning**, in that we know the right answers, i.e. we know where the word boundaries are, and we are adjusting parameters (probabilities) to accommodate those right answers.  But the child does not have this information - instead, the child must **infer** word boundaries from the information available.  One approach we considered was to note that although word boundaries are not clear, utterance boundaries are - and utterance boundaries are word boundaries.  Does this give the child enough information to actually segment speech, using the ideas we have explored here?  Find out!
