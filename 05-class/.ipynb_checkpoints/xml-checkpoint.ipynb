# %% [markdown]
# # Reading and manipulating XML
#
# A useful resource for this topic can be found [here](https://docs.python.org/3/library/xml.etree.elementtree.html).

# %%
import xml.etree.ElementTree as ET
import urllib.request

# %% [markdown]
# ### A simple example: the weather
#
# [This website](https://w1.weather.gov/xml/current_obs/KOAK.xml) is hosted by the National Weather Service, and shows the weather at Oakland airport, in XML format.  To see it in XML, right-click and select "View page source".
#
# - We are going to extract the temperature in degrees F, which is tagged 'temp_f'.
#
# - To do this, we first need to access the data from the web - see the very convenient [urllib](https://docs.python.org/3/howto/urllib2.html).

# %%
# access the data from the web.
target_url = 'http://www.weather.gov/xml/current_obs/KOAK.xml'
with urllib.request.urlopen(target_url) as response:
   data = response.read()
data
# Out:
# b'<?xml version="1.0" encoding="ISO-8859-1"?> \r\n<?xml-stylesheet href="latest_ob.xsl" type="text/xsl"?>\r\n<current_observation version="1.0"\r\n\t xmlns:xsd="http://www.w3.org/2001/XMLSchema"\r\n\t xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"\r\n\t xsi:noNamespaceSchemaLocation="http://www.weather.gov/view/current_observation.xsd">\r\n\t<credit>NOAA\'s National Weather Service</credit>\r\n\t<credit_URL>http://weather.gov/</credit_URL>\r\n\t\r\n\t\t<url>http://weather.gov/images/xml_logo.gif</url>\r\n\t\t<title>NOAA\'s National Weather Service</title>\r\n\t\t<link>http://weather.gov</link>\r\n\t\r\n\t<suggested_pickup>15 minutes after the hour</suggested_pickup>\r\n\t<suggested_pickup_period>60</suggested_pickup_period>\n\t<location>Oakland, Metro Oakland International Airport, CA</location>\n\t<station_id>KOAK</station_id>\n\t<latitude>37.7178</latitude>\n\t<longitude>-122.23294</longitude>\n\t<observation_time>Last Updated on Sep 27 2020, 2:53 pm PDT</observation_time>\r\n        <observation_time_rfc822>Sun, 27 Sep 2020 14:53:00 -0700</observation_time_rfc822>\n\t<weather>Partly Cloudy</weather>\n\t<temperature_string>95.0 F (35.0 C)</temperature_string>\r\n\t<temp_f>95.0</temp_f>\r\n\t<temp_c>35.0</temp_c>\n\t<relative_humidity>19</relative_humidity>\n\t<wind_string>Variable at 6.9 MPH (6 KT)</wind_string>\n\t<wind_dir>Variable</wind_dir>\n\t<wind_degrees>999</wind_degrees>\n\t<wind_mph>6.9</wind_mph>\n\t<wind_kt>6</wind_kt>\n\t<pressure_string>1010.7 mb</pressure_string>\n\t<pressure_mb>1010.7</pressure_mb>\n\t<pressure_in>29.85</pressure_in>\n\t<dewpoint_string>46.0 F (7.8 C)</dewpoint_string>\r\n\t<dewpoint_f>46.0</dewpoint_f>\r\n\t<dewpoint_c>7.8</dewpoint_c>\n\t<heat_index_string>91 F (33 C)</heat_index_string>\r\n      \t<heat_index_f>91</heat_index_f>\r\n      \t<heat_index_c>33</heat_index_c>\n\t<visibility_mi>10.00</visibility_mi>\n \t<icon_url_base>http://forecast.weather.gov/images/wtf/small/</icon_url_base>\n\t<two_day_history_url>http://www.weather.gov/data/obhistory/KOAK.html</two_day_history_url>\n\t<icon_url_name>sct.png</icon_url_name>\n\t<ob_url>http://www.weather.gov/data/METAR/KOAK.1.txt</ob_url>\n\t<disclaimer_url>http://weather.gov/disclaimer.html</disclaimer_url>\r\n\t<copyright_url>http://weather.gov/disclaimer.html</copyright_url>\r\n\t<privacy_policy_url>http://weather.gov/notice.html</privacy_policy_url>\r\n</current_observation>\n'

# %% [markdown]
# ### You need an XML parser
#
# You may be tempted to try to pull the desired information out of the above data using a regular expression.  And in this simple case, it would probably work.  But in general it's a bad idea, and can lead to [memorable meltdowns](http://stackoverflow.com/a/1732454) - see the top-ranked response which, although tongue-in-cheek and a bit purple, I hope will help to motivate the use of XML parsers in general.

# %%
root = ET.fromstring(data)
root
# Out:
# <Element 'current_observation' at 0x7f98f04912c0>

# %%
# first examine the root of the tree you just read in
print(root.tag, root.attrib)
# Out:
# current_observation {'version': '1.0', '{http://www.w3.org/2001/XMLSchema-instance}noNamespaceSchemaLocation': 'http://www.weather.gov/view/current_observation.xsd'}

# %%
# now look at children of root node.
for child in root:
    print(child.tag, ":", child.attrib)
# Out:
# credit : {}
# credit_URL : {}
# image : {}
# suggested_pickup : {}
# suggested_pickup_period : {}
# location : {}
# station_id : {}
# latitude : {}
# longitude : {}
# observation_time : {}
# observation_time_rfc822 : {}
# weather : {}
# temperature_string : {}
# temp_f : {}
# temp_c : {}
# relative_humidity : {}
# wind_string : {}
# wind_dir : {}
# wind_degrees : {}
# wind_mph : {}
# wind_kt : {}
# pressure_string : {}
# pressure_mb : {}
# pressure_in : {}
# dewpoint_string : {}
# dewpoint_f : {}
# dewpoint_c : {}
# heat_index_string : {}
# heat_index_f : {}
# heat_index_c : {}
# visibility_mi : {}
# icon_url_base : {}
# two_day_history_url : {}
# icon_url_name : {}
# ob_url : {}
# disclaimer_url : {}
# copyright_url : {}
# privacy_policy_url : {}

# %%
# finally, focus in on temperature in F, i.e. tag 'temp_f'.
# note that there could in principle be multiple elements with the target tag, so we get all of them.
for elt in root.iter('temp_f'):  # iter: traverse the whole tree, find nodes with the tag 'temp_f'
    print("Temperature in degrees F:", elt.text)
# Out:
# Temperature in degrees F: 95.0

# %% [markdown]
# ### Another example: a list of languages from Glottolog
#
# [This webpage](https://glottolog.org/glottolog/language) lists languages in Glottolog.  If you press the little download button in the upper right of the page, and select 'kml', you will get the [same information in KML](https://glottolog.org/glottolog/language.kml), which is an [XML-based notation for expressing geographic annotation and visualization](https://en.wikipedia.org/wiki/Keyhole_Markup_Language).
#
# We are going to read this in, and create a sorted list of all the languages mentioned.

# %%
# as before, we start by reading in the data from the web.
target_url = 'https://glottolog.org/glottolog/language.kml'
with urllib.request.urlopen(target_url) as response:
   data = response.read()
data
# Out:
# b'<?xml version="1.0" encoding="utf-8"?>\n<kml xmlns="http://earth.google.com/kml/2.1"\n     xmlns:atom="http://www.w3.org/2005/Atom">\n  <Document>\n    <name>Languages</name>\n      <description>\n      </description>\n    <open>1</open>\n    \n    <Style id="cani1243">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Canichana</name>\n      <description>\n        <![CDATA[\n        <a class="Language" href="https://glottolog.org/resource/languoid/id/cani1243" title="Canichana">Canichana</a>\n        ]]>\n      </description>\n      <Point><coordinates>-64.944455,-14.3058</coordinates></Point>\n        <styleUrl>#cani1243</styleUrl>\n    </Placemark>\n    <Style id="morb1239">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Mor (Bomberai Peninsula)</name>\n      <description>\n        <![CDATA[\n        <a class="Language" href="https://glottolog.org/resource/languoid/id/morb1239" title="Mor (Bomberai Peninsula)">Mor (Bomberai Peninsula)</a>\n        ]]>\n      </description>\n      <Point><coordinates>132.845,-2.85747</coordinates></Point>\n        <styleUrl>#morb1239</styleUrl>\n    </Placemark>\n    <Style id="rama1271">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Ramanos</name>\n      <description>\n        <![CDATA[\n        <a class="Language" href="https://glottolog.org/resource/languoid/id/rama1271" title="Ramanos">Ramanos</a>\n        ]]>\n      </description>\n      <Point><coordinates>-67.3590894,-14.3019482</coordinates></Point>\n        <styleUrl>#rama1271</styleUrl>\n    </Placemark>\n    <Style id="kimk1238">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Kimki</name>\n      <description>\n        <![CDATA[\n        <a class="Language" href="https://glottolog.org/resource/languoid/id/kimk1238" title="Kimki">Kimki</a>\n        ]]>\n      </description>\n      <Point><coordinates>140.884,-4.2742</coordinates></Point>\n        <styleUrl>#kimk1238</styleUrl>\n    </Placemark>\n    <Style id="odia1239">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Odiai</name>\n      <description>\n        <![CDATA[\n        <a class="Language" href="https://glottolog.org/resource/languoid/id/odia1239" title="Odiai">Odiai</a>\n        ]]>\n      </description>\n      <Point><coordinates>141.336,-3.82276</coordinates></Point>\n        <styleUrl>#odia1239</styleUrl>\n    </Placemark>\n    <Style id="yale1246">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Yale</name>\n      <description>\n        <![CDATA[\n        <a class="Language" href="https://glottolog.org/resource/languoid/id/yale1246" title="Yale">Yale</a>\n        ]]>\n      </description>\n      <Point><coordinates>141.566,-3.79762</coordinates></Point>\n        <styleUrl>#yale1246</styleUrl>\n    </Placemark>\n    <Style id="moro1289">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Marori</name>\n      <description>\n        <![CDATA[\n        <a class="Language" href="https://glottolog.org/resource/languoid/id/moro1289" title="Marori">Marori</a>\n        ]]>\n      </description>\n      <Point><coordinates>140.688,-8.5692</coordinates></Point>\n        <styleUrl>#moro1289</styleUrl>\n    </Placemark>\n    <Style id="kehu1238">\n      <IconStyle>\n        <Icon>\n          <href>...</href>\n        </Icon>\n      </IconStyle>\n    </Style>\n    <Placemark>\n      <name>Kehu</name>\n      <description>\n  ...

# %%
# now represent as XML tree
root = ET.fromstring(data)
root
# Out:
# <Element '{http://earth.google.com/kml/2.1}kml' at 0x7f98ed07b310>

# %%
# now look at children of root node.
for child in root:
    print(child.tag, ":", child.attrib)
# Out:
# {http://earth.google.com/kml/2.1}Document : {}

# %%
# note tag header.
th = '{http://earth.google.com/kml/2.1}'

ll = []  # list to hold results
# recursively traverse the entire tree, pulling out 'name' only.
for name in child.iter(th+'name'):  # header string + name
    ll.append(name.text)

# now print list out, sorted.
sorted(ll)
# Out:
# ['!O!ung',
#  '//Xegwi',
#  '/Xam',
#  'Aari',
#  'Aariya',
#  'Aasax',
#  'Abau',
#  'Abawiri',
#  'Abaza',
#  'Abinomn',
#  'Abipon',
#  'Abkhaz',
#  'Abom',
#  'Abu',
#  'Abui',
#  'Abun',
#  'Acheron',
#  "Achi', Cubulco",
#  'Achuar-Shiwiar',
#  'Achumawi',
#  'Acroá',
#  'Adabe',
#  'Adai',
#  'Adamorobe Sign Language',
#  'Adangme',
#  'Adap',
#  'Aduge',
#  'Adurgari',
#  'Adyghe',
#  'Adzera (Retired)',
#  'Aekyom',
#  'Aewa',
#  'Afghan Sign Language',
#  'Afghanistan Gorbat',
#  'Afitti',
#  'Afrihili',
#  'Agariya',
#  'Agavotaguerra',
#  'Agbirigba',
#  'Aghu Tharnggalu (Retired)',
#  'Agi',
#  'Agob-Ende-Kawam',
#  'Aguano',
#  'Aguaruna',
#  'Agutaynen',
#  'Ahe',
#  'Ahtena',
#  'Aikanã',
#  'Aiku',
#  'Aimele',
#  'Ainbai',
#  'Aiome',
#  'Airoran',
#  'Aja (Benin)',
#  'Aja (Sudan)',
#  'Ak',
#  'Aka',
#  'Akabea',
#  'Akabo',
#  'Akacari',
#  'Akajeru',
#  'Akakede',
#  'Akakol',
#  'Akakora',
#  'Akarbale',
#  'Akhvakh',
#  'Akkadian',
#  'Akpes',
#  'Al-Sayyid Bedouin Sign Language',
#  'Alabama',
#  'Alacalufe-Austral',
#  'Alacalufe-Central',
#  'Alaguilac',
#  'Alak',
#  'Alamblak',
#  'Alangan',
#  'Alapmunte',
#  'Alawa',
#  'Albanian Sign Language',
#  'Aleut',
#  'Algerian Sign Language',
#  'Alipur Sign Language',
#  'Allentiac',
#  'Alsea-Yaquina',
#  'Alu-Sinagen',
#  'Alutor',
#  'Alyawarr',
#  'Ama (Papua New Guinea)',
#  'Ama (Sudan)',
#  'Amaimon',
#  'Amal',
#  'Amam',
#  'Amami O Shima Sign Language',
#  'Amanab',
#  'Amapá Creole',
#  'Amarakaeri',
#  'Ambakich',
#  'Ambala Ayta',
#  'Ambermo',
#  'Ambrak',
#  'Ambulas',
#  'Amdang',
#  'Amerax',
#  'American Indian Pidgin English',
#  'Ami',
#  'Amikoana',
#  'Amis',
#  'Amkoe',
#  'Amorite',
#  'Amotomanco',
#  'Ampari Dogon',
#  'Amri Karbi',
#  'Amto',
#  'Amur Nivkh',
#  'Amurdak',
#  'Ana Tinga Dogon',
#  'Anasi',
#  'Ancient Greek',
#  'Ancient Ligurian',
#  'Andai',
#  'Andaqui',
#  'Andarum',
#  'Andegerebinha',
#  'Andi',
#  'Andoa',
#  'Andoque',
#  'Andoquero',
#  'Anem',
#  'Aneme Wake',
#  'Anfillo',
#  'Angaataha',
#  'Angaité',
#  'Angami Naga Sign Language',
#  'Angguruk Yali',
#  'Angor',
#  'Angoram',
#  'Anindilyakwa',
#  'Anjam',
#  'Ankave',
#  'Anmatyerre',
#  'Anor',
#  'Anserma',
#  'Antakarinya',
#  'Antioquian',
#  'Anu-Hkongso',
#  'Ap Ma',
#  'Apalachee',
#  'Apalaí',
#  'Apiaka-Tocantins',
#  'Apoto',
#  'Aproumu Aizi',
#  'Apucikwar',
#  'Apurinã',
#  'Arabana',
#  'Arabela',
#  'Aracaju',
#  'Arafundi-Enga Pidgin',
#  'Araicu',
#  'Arakanese',
#  'Arakwal',
#  'Aramanik',
#  'Arammba',
#  'Aranama',
#  'Arapaso',
#  'Arawum',
#  'Arbëreshë Albanian',
#  'Archi',
#  'Arem',
#  'Argentine Sign Language',
#  'Ari',
#  'Arigidi',
#  'Arikapú',
#  'Arikara',
#  'Arikem',
#  'Arin',
#  'Aringa',
#  'Aritinngitigh',
#  'Arizona Tewa',
#  'Arma',
#  'Armenian Sign Language',
#  'Arta',
#  'Aruan',
#  'Aruba',
#  'Arusha',
#  'Arutani',
#  'Aruá (Amazonas State)',
#  'Arvanitika Albanian',
#  'Asabano',
#  'Ashkun',
#  'Askopan',
#  'Asoa',
#  'Assan',
#  'Assangori',
#  'Assiniboine',
#  'Atacame',
#  'Atakapa',
#  'Atayal',
#  'Ati',
#  'Atikamekw',
#  'Atohwaim',
#  'Atsugewi',
#  'Attié',
#  'Atuence',
#  'Au',
#  'Aushiri',
#  'Australian Aborigines Sign Language',
#  'Austrian Sign Language',
#  'Auwe',
#  'Auwon',
#  'Auye',
#  'Avar',
#  'Avestan',
#  'Avokaya',
#  'Awa-Cuaiquer',
#  'Awbono',
#  'Awera',
#  'Awetí',
#  'Awjilah',
#  'Awngi',
#  'Awtuw',
#  'Awyi',
#  'Ayi (China)',
#  'Ayoreo',
#  'Babalia Creole Arabic',
#  'Babuza',
#  'Badeshi',
#  'Badimaya',
#  'Badui',
#  'Baenan',
#  'Baga Koga',
#  'Baga Manduri',
#  'Baga Sitemu',
#  'Bagua',
#  'Bagusa',
#  'Baha Buyang',
#  'Baham',
#  'Bahau River Kenyah',
#  'Bai-Maclay',
#  'Baibai',
#  'Baissa Fali',
#  'Baka (Sudan)',
#  'Bakairí',
#  'Bakung Kenyah',
#  'Balaybalan',
#  'Bambassi',
#  'Bamu',
#  'Ban Khor Sign Language',
#  'Banaro',
#  'Banawá',
#  'Bandjigali',
#  'Bangime',
#  'Bangru',
#  'Bankan Tey Dogon',
#  'Bantik',
#  'Barai',
#  'Baramu',
#  'Barapasi',
#  'Barbacoas',
#  'Barbareño',
#  'Bardi',
#  'Bargam',
#  'Bariji',
#  'Barikanchi',
#  'Barikewa',
#  'Barranbinya',
#  'Baruya',
#  'Barí',
#  'Basap',
#  'Basay',
#  'Bashkir',
#  'Basketo',
#  'Basque',
#  'Basque-Amerindian Pidgin',
#  'Bassari-Tanda',
#  'Bataan Ayta',
#  'Bats',
#  'Bauni',
#  'Bauwaki',
#  'Bauxite Pidgin',
#  'Bauzi',
#  'Bay Islands Sign Language',
#  'Bay Miwok',
#  'Bayali',
#  'Baygo',
#  'Bayono',
#  'Bayungu',
#  'Bazigar',
#  'Beami',
#  'Beja',
#  'Belarusian',
#  'Belgian Sign Language',
#  'Beli (Papua New Guinea)',
#  'Beli (Sudan)',
#  'Bella Coola',
#  'Belle-Isle Pidgin',
#  'Bemba (Democratic Republic of Congo)',
#  'Ben Tey Dogon',
#  'Ben-Lomond-Cape-Portland',
#  'Bench',
#  'Bendi',
#  'Bengkulu',
#  "Benyadu'",
#  'Beothuk',
#  'Bepour',
#  'Berbey Sign Language',
#  'Beria',
#  'Berik',
#  'Berta',
#  'Berti',
#  'Besisi',
#  'Betaf',
#  'Beti (Cameroon)',
#  'Betoi-Jirara',
#  'Bhalay',
#  'Bhatola',
#  'Biafada',
#  'Biage',
#  'Bian Marind',
#  'Biangai',
#  'Biao Mon',
#  'Biao-Jiao Mien',
#  'Bidai',
#  'Bigambal',
#  'Bikaru-Bragge',
#  'Biloxi',
#  'Bilua',
#  'Bima',
#  'Binahari-Ma',
#  'Binahari-Neme',
#  'Binandere',
#  'Bindal-Cunningham',
#  'Bindal-Gorton',
#  'Bindal-Mount Elliot',
#  'Bine',
#  'Bininj Kun-Wok',
#  'Bintulu',
#  'Binumarien',
#  'Birked',
#  'Birrdhawal',
#  'Birri',
#  'Bisorio',
#  'Bissa',
#  'Bisu (Retired)',
#  'Bitur',
#  'Biwat',
#  'Biyom',
#  'Bo (Papua New Guinea)',
#  'Bo-Ung',
#  'Bodo Gadaba',
#  'Bogaya',
#  'Boikin',
#  'Bolgarian',
#  'Bolongan',
#  'Bolyu',
#  'Bonari',
#  'Bondo',
#  'Bonerif',
#  'Bonggi',
#  'Bongo',
#  'Bongu',
#  'Boon',
#  'Bora',
#  'Borei',
#  'Borgarmalet',
#  'Borgu Fulfulde',
#  'Borna (Democratic Republic of Congo)',
#  'Boro',
#  'Boro (Ethiopia)',
#  'Bororo',
#  'Boruca',
#  'Bouni-Bobe',
#  'Bragat',
#  'Brahui',
#  'Brao',
#  'Brazilian Sign Language',
#  'Brem',
#  'Bribri Sign Language',
#  'British Sign Language',
#  'Broken Oghibbeway',
#  'Broken Slavey',
#  'Broome Pearling Lugger Pidgin',
#  'Brunca Sign Language',
#  'Bruny Island',
#  'Bubia',
#  'Buena Vista Yokuts',
#  'Bugan',
#  'Bugan (Retired)',
#  'Bugun',
#  'Bularnu',
#  'Bulgarian Sign Language',
#  'Bumang',
#  'Bumbita Arapesh',
#  'Bun',
#  'Buna',
#  'Bunaba',
#  'Bunak',
#  'Bungain',
#  'Bunoge Dogon',
#  'Bunun',
#  'Bura Sign Language',
#  'Buraka',
#  'Burarra',
#  'Burate',
#  'Burji',
#  'Burkina Faso Sign Language',
#  'Burmeso',
#  'Burun',
#  'Burundi Pidgin French',
#  'Burunge',
#  'Burushaski',
#  'Buruwai',
#  'Buso',
#  'Butam',
#  'Butler English',
#  'Buxinhua',
#  'Buya',
#  'Cabixi-Natterer',
#  'Cacaopera',
#  'Caddo',
#  'Cagua',
#  'Cahuarano',
#  'Caijia',
#  'Cajamarca Quechua',
#  'Cakchiquel-Quiché Mixed Language',
#  'Calamian Tagbanwa',
#  'Calchaqui',
#  'Callawalla',
#  'Calo',
#  'Calusa',
#  'Cambodian Sign Language',
#  'Camsá',
#  'Camtho',
#  'Camunic',
#  'Canari',
#  'Candoshi-Shapra',
#  'Canichana',
#  'Capoxo',
#  'Car Nicobarese',
#  'Carabayo',
#  'Caramanta',
#  'Carian',
#  'Caribbean Javanese',
#  'Carijona',
#  'Carolina Algonquian',
#  'Carútana',
#  'Cashibo-Cacataibo',
#  'Caspian and eastern Persia Gypsy',
#  'Casuarina Coast Asmat',
#  'Cataelano Mandaya',
#  'Catalan Sign Language',
#  'Catawba',
#  'Catuquinaru-Bach',
#  'Cauca',
#  'Cauqui of Cachuy',
#  'Cavineña',
#  'Cayubaba',
#  'Cayuga',
#  'Cayuse',
#  'Celtiberian',
#  'Central Alaskan Yupik',
#  'Central Aymara',
#  'Central Chong',
#  'Central Ju',
#  'Central Kalapuya',
#  'Central Khmer',
#  'Central Mansi',
#  'Central Moroccan Berber',
#  'Central Nicobarese',
#  'Central Pomo',
#  'Central Siberian Yupik',
#  'Central Sierra Miwok',
#  'Central Tarahumara',
#  'Central Taurus Sign Language',
#  'Central-Southern Persian Gypsy',
#  "Cha'palaa",
#  'Chacha',
#  'Chagatai',
#  'Chairel',
#  'Chalon',
#  'Chamacoco',
#  'Chamalal',
#  'Chamari',
#  'Chambri',
#  'Chamicuro',
#  'Chamorro',
#  'Changriwa',
#  'Changuena',
#  'Chaná',
#  'Chaouia of the Aures',
#  'Chapakura',
#  'Chara',
#  'Charrúa',
#  'Chaungtha',
#  'Chaura',
#  'Chechen',
#  'Chenapian',
#  'Cherokee',
#  'Chewong',
#  'Cheyenne',
#  'Chholo',
#  'Chiangmai Sign Language',
#  'Chiapanec',
#  'Chichimeca-Jonaz',
#  'Chickasaw',
#  'Chicomuceltec',
#  'Chilcotin',
#  'Chilean Quechua',
#  'Chilean Sign Language',
#  'Chimakum',
#  'Chimalapa Zoque',
#  'Chimariko',
#  'Chimila',
#  'Chinese Pidgin English',
#  'Chinese Pidgin Russian',
#  'Chinese Sign Language',
#  'Chini',
#  'Chipaya',
#  'Chipewyan',
#  'Chipiajes',
#  'Chirag',
#  'Chitimacha',
#  'Chittagonian (Retired)',
#  'Choctaw',
#  'Chol, Tila',
#  'Cholón',
#  'Chong of Chanthaburi',
#  'Chono',
#  'Chorotega',
#  'Chrau',
#  'Chuanqiandian Cluster Miao',
#  'Chuave',
#  'Chuj, Ixtatán',
#  'Chukchi',
#  'Chulym Turkic',
#  'Chumash',
#  'Chut',
#  'Chuvantsy',
#  'Chuvash',
#  'Cisalpine Gaulish',
#  'Clallam',
#  'Classical Quechua',
#  'Classical-Middle Armenian',
#  'Clatsop-Shoalwater Chinook',
#  'Coahuilteco',
#  'Coast Miwok',
#  'Cochimi',
#  'Cocopa',
#  'Coeruna',
#  "Coeur d'Alene",
#  'Cofán',
#  'Colima',
#  'Columbia-Wenatchi',
#  'Comanche',
#  'Comecrudan',
#  'Comox',
#  'Concho',
#  'Copainalá Zoque',
#  'Copallen',
#  'Coptic',
#  'Coroado-Puri',
#  'Cotoname',
#  'Cotoxo',
#  'Cowlitz',
#  'Coxima',
#  'Coyaima',
#  'Creek',
#  'Creolized Grand Ronde Chinook Jargon',
#  'Crimean Gothic',
#  'Croatian Sign Language',
#  'Crow',
#  'Cruzeño',
#  'Cua',
#  'Cuba Sign Language',
#  'Cueva',
#  'Cuiba',
#  'Cuitlatec',
#  'Culina',
#  'Culli',
#  'Cumeral',
#  'Cun',
#  'Cuneiform Luwian',
#  'Cusabo',
#  'Cushitic Taita',
#  'Czech Sign Language',
#  "Daantanai'",
#  "Daats'iin",
#  'Dabe',
#  'Dacian',
#  'Dadibi',
#  'Dafla',
#  'Daga',
#  'Dagang-Baoshan-Liangcun',
#  'Dagik',
#  'Dagoman',
#  'Dagur',
#  'Dahalo',
#  'Dama (Sierra Leone)',
#  'Damal',
#  'Dana',
#  'Danau',
#  'Danish Sign Language',
#  'Dao',
#  'Daonda',
#  'Dar Daju Daju',
#  'Dar Fur Daju',
#  'Dar Sila Daju',
#  'Darang Deng',
#  'Day',
#  'Dayao Yi',
#  'Dayi',
#  'Daza',
#  'Dazaga',
#  'Defaka',
#  'Degaru',
#  'Degere',
#  "Degexit'an",
#  'Dek',
#  'Dem',
#  'Demisa',
#  'Demta',
#  'Dendi (Benin)',
#  'Deni',
#  'Deori',
#  'Dera (Indonesia)',
#  'Desiya',
#  'Dhangu',
#  'Dhanwar (India)',
#  'Dharumbal',
#  'Dhimal',
#  'Dhivehi',
#  'Dibiyaso',
#  'Dicamay Agta',
#  'Dima',
#  'Dima-Bottego',
#  'Dime',
#  'Dimir',
#  'Ditidaht',
#  'Dizin',
#  'Djangun',
#  'Djawi',
#  'Djeebbana',
#  'Djeoromitxí',
#  'Djinang',
#  'Djinba',
#  'Dogul Dom Dogon',
#  'Dolgan',
#  'Domaaki',
#  'Domari',
#  'Dombano',
#  'Dominican Sign Language',
#  'Domu',
#  'Donno So Dogon',
#  'Dorasque',
#  'Doromu-Koki',
#  'Dororo',
#  'Dorze',
#  'Doso',
#  'Douentza Sign Language',
#  'Drung',
#  'Dubu',
#  'Duduela',
#  'Dumpu',
#  'Dumun',
#  'Duna',
#  'Dungu',
#  'Dupaninan Agta',
#  'Duriankere',
#  'Duruwa',
#  'Dusun Deyah',
#  'Dusun Malang',
#  'Dutch Sign Language',
#  'Duvle',
#  'Duvle-Wano-Pidgin',
#  'Dyaabugay',
#  'Dyaberdyaber',
#  'Dyangadi',
#  'Dyirbal',
#  'Dyugun',
#  'Dzao Min',
#  'Dâw',
#  'Early East African Pidgin Arabic',
#  'East Limba',
#  'East Taa',
#  'East Yugur',
#  'Eastern Abenaki',
#  'Eastern Armenian',
#  'Eastern Arrernte',
#  'Eastern Canadian Inuktitut',
#  'Eastern Katu',
#  'Eastern Keres',
#  'Eastern Mari',
#  'Eastern Pomo',
#  'Eastern Puroik',
#  'Ebira',
#  'Eblaite',
#  'Edolo',
#  'Edopi',
#  'Efatese',
#  'Efe',
#  'Ega',
#  'Egypt Sign Language',
#  'Egyptian (Ancient)',
#  'Eipomek',
#  'Ekari',
#  'Ekpeye',
#  'Elamite',
#  'Elepi',
#  'Elkei',
#  'Eloyi',
#  'Elpaputih',
#  'Elseng',
#  'Elymian',
#  'Emberá-Baudó',
#  'Emberá-Catío',
#  'Emberá-Chamí',
#  'Emberá-Tadó',
#  'Emok',
#  'Emumu',
#  'Enawené-Nawé',
#  'Enga',
#  'Enga Sign Language',
#  'Enggano',
#  'Enim',
#  'Envuelto',
#  'Epena',
#  'Erie',
#  'Erre',
#  'Erromintxela',
#  'Erzya',
#  'Ese',
#  'Ese Ejja',
#  'Eskayan',
#  'Esperanto',
#  'Esselen',
#  'Estonian Sign Language',
#  'Esuma',
#  'Eteocretan',
#  'Eteocypriot',
#  'Ethiopian Sign Language',
#  'Etruscan',
#  'Eudeve',
#  'Europanto',
#  'Even',
#  'Evenki',
#  'Ewondo Populaire',
#  'Extreme North Cameroon Sign Language',
#  'Eyak',
#  'Falam Chin (Retired)',
#  'Faliscan',
#  'Fanagalo',
#  'Far North Queensland Indigenous Sign Language',
#  'Fasu',
#  'Fayjatases',
#  'Fembe',
#  'Filomeno Mata Totonac',
#  'Finland-Swedish Sign Language',
#  'Finnish Sign Language',
#  'Fiwaga',
#  'Flecheiros',
#  'Foi',
#  'Foia Foia',
#  'Folopa',
#  'Foma',
#  'Forest Maninka',
#  'Francais Tirailleur',
#  'Francisco León Zoque',
#  'French Sign Language',
#  'Fulniô',
#  'Fum',
#  'Fur',
#  'Fuyug',
#  'Ga',
#  'Gaagudju',
#  'Gaam',
#  'Gabutamon',
#  'Gade',
#  'Gail',
#  'Gajirrabeng',
#  'Galatian',
#  'Galela',
#  'Galibi Carib',
#  'Galu',
#  'Gambera',
#  'Gambian Sign Language',
#  'Gambian Wolof',
#  'Gamela of Viana',
#  'Gamkonora',
#  'Gamo-Gofa-Dawro',
#  'Ganai',
#  'Ganggalida',
#  'Ganglau',
#  'Ganza',
#  'Garig-Ilgar',
#  'Garo',
#  'Garreh-Ajuran',
#  'Garrwa',
#  "Gata'",
#  'Gayil',
#  'Gayo',
#  'Gbati-ri',
#  'Gbaya (Sudan)',
#  'Geez',
#  'Geico',
#  'Geko Karen',
#  'Gelao',
#  'Geman Deng',
#  'Gende',
#  'Gengle',
#  'Georgian',
#  'Georgian Sign Language',
#  'German Sign Language',
#  'Gey',
#  'Ghadames',
#  'Ghanaian Sign Language',
#  'Ghandruk Sign Language',
#  'Ghardaia Sign Language',
#  'Gheg Albanian',
#  'Giangan',
#  'Gibanawa',
#  'Gidar',
#  'Ginuman',
#  'Gitxsan',
#  'Gizrra',
#  'Gnau',
#  'Gobasi',
#  'Gogodala',
#  'Gola',
#  'Gongduk',
#  'Gooniyandi',
#  'Gorovu',
#  'Gorum-Parenga',
#  'Gothic',
#  'Gowli',
#  'Grass Koiari',
#  'Greek Sign Language',
#  'Guachi',
#  'Guachipas',
#  'Guahibo',
#  'Guaicaro',
#  'Guaicurian',
#  'Guale',
#  'Guambiano',
#  'Guamo',
#  'Guana (Paraguay)',
#  'Guanche',
#  'Guatemalan Sign Language',
#  'Guató',
#  'Guayabero',
#  'Guazapar',
#  'Gueren',
#  'Guerrero Amuzgo',
#  'Gugadj',
#  'Gugu Mini',
#  'Guhu-Samane',
#  'Guinea-Bissau Sign Language',
#  'Guinean Sign Language',
#  'Guiqiong',
#  'Gule',
#  'Guliguli',
#  'Gulunggulu',
#  'Guragone',
#  'Guriaso',
#  'Gurindji Kriol',
#  'Gutian',
#  'Guugu Yimidhirr',
#  'Guwa',
#  'Guwar',
#  'Guyambal',
#  'Guyana Sign Language',
#  'Gwahatike',
#  'Gwama',
#  "Gwich'in",
#  'Güenoa',
#  'Hachijo',
#  'Hadza',
#  'Haiphong Sign Language',
#  'Haisla',
#  'Halkomelem',
#  'Hamba NW of Nachingwea south of Mbemkuru River',
#  'Hamer-Banna',
#  'Hamtai',
#  'Han',
#  'Hanga Hundi',
#  'Hanis',
#  'Hanoi Sign Language',
#  'Hanunoo',
#  'Harappan',
#  'Haraza',
#  'Haruai',
#  'Hatam',
#  'Hatang Kayi',
#  'Hattic',
#  'Hauna Trade Language',
#  'Hausa Sign Language',
#  'Haush',
#  'Havasupai-Walapai-Yavapai',
#  "Hawai'i Pidgin Sign Language",
#  'Heiltsuk-Oowekyala',
#  'Herde',
#  'Herschel Island Eskimo Trade Jargon',
#  'Heyo',
#  'Hibito',
#  'Hidatsa',
#  'Hieroglyphic Luwian',
#  'Highland Oaxaca Chontal',
#  'Highland Popoluca',
#  'Hills Karbi',
#  'Himarimã',
#  'Hiri Motu',
#  'Hittite',
#  'Hixkaryána',
#  'Hlai',
#  'Hmong Njua (Retired)',
#  'Ho Chi Minh City Sign Language',
#  'Ho-Chunk',
#  'Hoia Hoia-Ukusi-Koperami',
#  'Hokkaido Ainu',
#  'Hong Kong-Macau Sign Language',
#  'Hopi',
#  "Horace Holden's Pidgin Tobi",
#  'Horuru',
#  'Hoti',
#  'Hottentot Dutch',
#  'Hoxa',
#  'Hoyahoya-Matakaia',
#  'Hozo',
#  'Hruso',
#  'Huachipaeri',
#  'Huambisa',
#  'Huarijio',
#  'Huastec',
#  'Huastec, San Luís Potosí',
#  'Huastec, Southeastern',
#  'Huehuetla Tepehua',
#  'Huetar',
#  'Huichol',
#  'Huilliche',
#  'Huli',
#  'Humburi Senni Songhay',
#  'Humene',
#  'Hung',
#  'Hungarian',
#  'Hungarian Sign Language',
#  'Hup',
#  'Hupla',
#  'Huron-Wyandot',
#  'Hurrian',
#  "I'saka",
#  'Iapama',
#  'Iau',
#  'Ibatan',
#  'Iberian',
#  'Ibilo',
#  'Ibu',
#  'Icelandic Sign Language',
#  'Icelandic-Basque Pidgin',
#  "Ida'an",
#  'Idabaez',
#  'Idesa',
#  'Idi-Taeme',
#  'Idu',
#  'Iha',
#  'Ik',
#  'Ikobi',
#  'Ikpana',
#  'Ikpeng',
#  'Illyrian',
#  'Iloko',
#  'Imbabura',
#  'Imbongu',
#  'Imeraguen',
#  'Imonda',
#  'Imunga Trade Language',
#  'Indian Sign Language',
#  'Ineseño',
#  'Ingush',
#  'Inpui Naga',
#  'Interlingue (Occidental)',
#  'International Sign',
#  'Inuit Sign Language',
#  'Ioi Trade Jargon',
#  'Iowa-Oto',
#  'Ipalapa Amuzgo',
#  'Ipeka-Tapuia',
#  'Ipiko',
#  'Ipili',
#  'Iquito',
#  'Iranun',
#  'Iraqi Sign Language',
#  'Iraya',
#  'Irish Sign Language',
#  'Irántxe-Münkü',
#  'Isabi',
#  'Ishkashimi',
#  'Isirawa',
#  'Isnag',
#  'Israeli Sign Language',
#  'Italian Sign Language',
#  'Itbayat',
#  'Itene',
#  ...]

# %% [markdown]
# # Observations
#
# - With the proper tools at your disposal, handling XML is pretty easy!
