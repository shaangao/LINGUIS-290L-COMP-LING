# %% [markdown]
# # Generate pseudo-words using a Markov chain
#
# - We will read in a dataset of English words, with pronunciations, calculate phoneme transition probabilities from the data, and then use those phoneme transition probabilities to generate pseudo-words that follow the phonotactic probabilities of English.
# - This is essentially a simple Markov chain.  Every phoneme is a state - specifically, being in the state corresponding to phoneme $p$ means that we have just seen phoneme $p$.  Transition probabilities from state $p$ to some other state $q$ are determined from bigrams in the data.  How?
# - A bigram is a pair of consecutive symbolic units - in this case phonemes.  Thus transition probabilities such as $P(p_2|p_1)$ represent the probability of moving from the state that denotes our having just seen phoneme $p_1$ to the state that denotes our having just seen phoneme $p_2$;  this probability is determined by the relative frequency of encountering $p_2$ in the data, given that we have just seen $p_1$.
# - This notebook again uses [WikiPron](https://github.com/kylebgorman/wikipron), but this time we consider US pronunciation for English.  Analogous data for many other languages, in the same format, is available [here](https://github.com/kylebgorman/wikipron/tree/master/data), which you can download and use for extensions.

# %%
import re  # not necessary here
import pandas as pd
import numpy as np
import unicodedata
import random  # useful for sampling from a distribution

# %% [markdown]
# ### Read in data
#
# And format it so that pulling out phoneme transitions will be easy.

# %%
# read in english words.  
df = pd.read_csv("eng_us_phonemic.tsv", sep='\t', names=['Word', 'Pron'])
df.Pron = df.Pron.str.split()  # turn space-separated strings into lists of phonemes
df
# Out:
#              Word                            Pron
# 0          $deity              [d, e, ɪ, ɪ, t, i]
# 1          $deity                [d, iː, ɪ, t, i]
# 2          'cause                       [k, ʌ, z]
# 3       'dswounds           [d, z, w, u, n, d, z]
# 4             'em                            [m̩]
# ...           ...                             ...
# 53394     œconomy          [ɪː, k, ɒ, n, ɒ, m, i]
# 53395       œneus                [ɛ, n, j, uː, s]
# 53396       ǃkung                       [k, u, ŋ]
# 53397       ǃkung                       [k, ʊ, ŋ]
# 53398  ξυλάγγουρο  [k, s, i, l, a, ŋ, ɡ, u, ɾ, o]
#
# [53399 rows x 2 columns]

# %%
# sanity check
# find the US pronunciation of the word "aardvark"
df[df.Word=='aardvark']
# Out:
#         Word                   Pron
# 67  aardvark  [ɑ, ɹ, d, v, ɑ, ɹ, k]

# %%
# sanity check - and a chance to introduce the very useful pandas "sample" routine.
# find the US pronunciation of several other words.
df.sample(n=25)  # pick 25 random samples
# Out:
#                   Word                                        Pron
# 28223         landform                    [l, æ, n, d, f, ɔ, ɹ, m]
# 43374           sheela                               [ʃ, iː, l, ə]
# 43925            sines                             [s, a, ɪ, n, z]
# 22364         greeting                         [ɡ, ɹ, iː, t, ɪ, ŋ]
# 3754             anvil                             [æ, n, v, ɪ, l]
# 46463     supersession                 [s, u, p, ɚ, s, ɛ, ʃ, ə, n]
# 38369       principled              [p, ɹ, ɪ, n, s, ə, p, ə, l, d]
# 5204            awaked                          [ə, w, e, ɪ, k, t]
# 31064           memoir                          [m, ɛ, m, w, ɑ, ɹ]
# 27742           kisses                             [k, ɪ, s, ɪ, z]
# 88               abaca                             [æ, b, ə, k, ɑ]
# 46433         superego                 [s, u, p, ɛ, ɹ, i, ɡ, o, ʊ]
# 6835       bioorganism  [b, a, ɪ, o, ʊ, ɔ, ɹ, ɡ, ə, n, ɪ, z, ə, m]
# 43302         shanghai                          [ʃ, æ, ŋ, h, a, ɪ]
# 32876             nasa                                [n, æ, s, ə]
# 21984          goofing                            [ɡ, uː, f, ɪ, ŋ]
# 20685           funded                          [f, ʌ, n, d, ɪ, d]
# 34793            otomi                         [o, ʊ, t, ə, m, iː]
# 23110          handled                         [h, æ, n, d, l̩, d]
# 38249          presume                       [p, ɹ, i, z, j, u, m]
# 22215          granola                    [ɡ, ɹ, ə, n, o, ʊ, l, ə]
# 11955  condescendingly     [k, ɒ, n, d, ɪ, s, e, n, d, ɪ, ŋ, l, i]
# 36820            piauí                           [p, iː, a, ʊ, iː]
# 18963        faversham                    [f, æ, v, ə, ɹ, ʃ, ə, m]
# 33616           normal                          [n, ɔ, ɹ, m, ə, l]

# %%
# now add START and STOP pseudo-phonemes at beginning and end of each word.
# a chance to introduce the very useful pandas "apply" routine.
df.Pron = df.Pron.apply(lambda x: ['START'] + x + ['STOP'])
df
# Out:
#              Word                                         Pron
# 0          $deity              [START, d, e, ɪ, ɪ, t, i, STOP]
# 1          $deity                [START, d, iː, ɪ, t, i, STOP]
# 2          'cause                       [START, k, ʌ, z, STOP]
# 3       'dswounds           [START, d, z, w, u, n, d, z, STOP]
# 4             'em                            [START, m̩, STOP]
# ...           ...                                          ...
# 53394     œconomy          [START, ɪː, k, ɒ, n, ɒ, m, i, STOP]
# 53395       œneus                [START, ɛ, n, j, uː, s, STOP]
# 53396       ǃkung                       [START, k, u, ŋ, STOP]
# 53397       ǃkung                       [START, k, ʊ, ŋ, STOP]
# 53398  ξυλάγγουρο  [START, k, s, i, l, a, ŋ, ɡ, u, ɾ, o, STOP]
#
# [53399 rows x 2 columns]

# %% [markdown]
# ### Get bigram conditional probabilities for each pair of phonemes

# %%
# start by getting the set of all phonemes in the dataset.
# we will have one state for each phoneme.
phonemes = set([p for l in df.Pron for p in l]) # for every list in df.pron; for every phoneme in that list
print(len(phonemes))
print(phonemes)
# Out:
# 186
# {'ʊ̂', 'ɾ̃', 'STOP', 'æ', 't͡s', 'ʉː', 'ɚː', 'eː', 'ú', 'iː', 'pː', 'ē', 'ɛ͡ɪ', 'ɡː', 'ɑ̃', 'ʃʰ', 'bᵊ', 'ɔ̃', 'i', 'ɔ', 'nˡ', 'ɛ̝', 'ʍ', 'ːs', 'ɹ̩', 'f', 'u', 'k̚', 'ɣ', 'ĭ', 'nː', 'îː', 'dʰ', 'ʊ̩', 'ʊ̯', 'ɪ̈', 'oˀ', 'ç', 'ɹʷ', 'ɹː', 'õ', 'ɫ̩', 'o̞', 'ɫ', 't͡ɕ', 'fː', 'ʊː', 'e͡ɪ', 'ɒː', 'ɻ', 'ä', 'ɑː', 't͡ʃ', 'y', 'm̩', 'ʒ', 'd͡ʒ', 'ɑˑ', 'ɪʲ', 'e͜ɚ', 'ʀ', 'a', 'ɜː', 'ɐ', 'k', 'kʰ', 'v', 't͡ʃʰ', 'r̩', 'ã', '↓', 'ʊ̆', 'd̪', 'χ', 'ŋ', 'ɘ', 'ɒ', 't', 'θ', 'lʲ', 'ɪˑ', 'ɱ', 'ɪ̪', 'æ̃', 'ɛː', 'ʊ̪', 'e', 'o͡ʊ', 'ɲ', 'p̬', '˞', 'b', 'tʰ', 'ɾ', 'ʔ', 'ĩ', 'ɔ͡ɪ', 'ɖ', 'əˑ', '~', 'ɭ', 'ɵ', 'ə̯', 'sː', 'ɐː', 'n', 'ʙ̩ː', 'ʌ', 'n̩', 'ɯ', 'w', 'tᵊ', 'ɜ', 'oː', 'ŭ̥', 'ɪ', 'ɚ', 'ɪ̯', 'ø', 'ɝː', 'ɝ', 'c', 'ɹ', 'ĭ̥', 'bʲ', 'l͡s', 'l', 'm̩ː', 'ṽ', 'ə', 'ɛ̃', 'ɒ̃', 'ɬ', 'ɜ̃', 'ʌ̈', 't͡ʃ̩̩', 'ɡ', 'äː', 'əʳ', 'dʲ', 'ʈ', 'tː', 'ð', 'kᵊ', 'ɛ͡ɹ', 'ɦ', 'ɽ', 'd', 'q', 'ɔː', 'ɕː', 'æː', 'r', 'ɛˑ', 'j', 't̬', 'ʊ', 'START', 'ʃː', 'ɵ̞', 'ʃ', 'œ', 'h', 'p', 't̬ᵊ', 'm', 'əː', 'ə̆', 'ɛ', 'ɑ', 's', 'ʉ', 'pʰ', 'mː', 'ô', 'ɨ', 'ʌː', 'l̩', 'uː', 'x', 'ɪː', 'ʏ', 'ʁ', 'o', 'z', 'aː'}

# %% [markdown]
# Now get simple phoneme transition **counts** for every pair of phonemes.  Later, we will turn these into probabilities.
#
# We will use [Laplace (add-one) smoothing](https://en.wikipedia.org/wiki/Additive_smoothing), which means that every phoneme pair gets a "freebie" count of 1 to start with, before actually seeing any data.  Ask me why we might want to do such a thing.

# %%
# ptc = phoneme transition counts.
# this structure is a dict.
# its key is a tuple of 2 phonemes: (p1, p2), and the corresponding value is the count for those 2 phonemes.
# here, we start by initializing each count with 1: add-one smoothing.
# MODIFY THIS NEXT PART TO INITIALIZE ALL COUNTS TO 1.
ptc = {}  # YOUR CODE GOES HERE.

for phoneme1 in phonemes:
    for phoneme2 in phonemes:
        ptc[(phoneme1, phoneme2)] = 1

print(len(ptc)) # sanity check
        
ptc
# Out:
# 34596
# {('ʊ̂', 'ʊ̂'): 1,
#  ('ʊ̂', 'ɾ̃'): 1,
#  ('ʊ̂', 'STOP'): 1,
#  ('ʊ̂', 'æ'): 1,
#  ('ʊ̂', 't͡s'): 1,
#  ('ʊ̂', 'ʉː'): 1,
#  ('ʊ̂', 'ɚː'): 1,
#  ('ʊ̂', 'eː'): 1,
#  ('ʊ̂', 'ú'): 1,
#  ('ʊ̂', 'iː'): 1,
#  ('ʊ̂', 'pː'): 1,
#  ('ʊ̂', 'ē'): 1,
#  ('ʊ̂', 'ɛ͡ɪ'): 1,
#  ('ʊ̂', 'ɡː'): 1,
#  ('ʊ̂', 'ɑ̃'): 1,
#  ('ʊ̂', 'ʃʰ'): 1,
#  ('ʊ̂', 'bᵊ'): 1,
#  ('ʊ̂', 'ɔ̃'): 1,
#  ('ʊ̂', 'i'): 1,
#  ('ʊ̂', 'ɔ'): 1,
#  ('ʊ̂', 'nˡ'): 1,
#  ('ʊ̂', 'ɛ̝'): 1,
#  ('ʊ̂', 'ʍ'): 1,
#  ('ʊ̂', 'ːs'): 1,
#  ('ʊ̂', 'ɹ̩'): 1,
#  ('ʊ̂', 'f'): 1,
#  ('ʊ̂', 'u'): 1,
#  ('ʊ̂', 'k̚'): 1,
#  ('ʊ̂', 'ɣ'): 1,
#  ('ʊ̂', 'ĭ'): 1,
#  ('ʊ̂', 'nː'): 1,
#  ('ʊ̂', 'îː'): 1,
#  ('ʊ̂', 'dʰ'): 1,
#  ('ʊ̂', 'ʊ̩'): 1,
#  ('ʊ̂', 'ʊ̯'): 1,
#  ('ʊ̂', 'ɪ̈'): 1,
#  ('ʊ̂', 'oˀ'): 1,
#  ('ʊ̂', 'ç'): 1,
#  ('ʊ̂', 'ɹʷ'): 1,
#  ('ʊ̂', 'ɹː'): 1,
#  ('ʊ̂', 'õ'): 1,
#  ('ʊ̂', 'ɫ̩'): 1,
#  ('ʊ̂', 'o̞'): 1,
#  ('ʊ̂', 'ɫ'): 1,
#  ('ʊ̂', 't͡ɕ'): 1,
#  ('ʊ̂', 'fː'): 1,
#  ('ʊ̂', 'ʊː'): 1,
#  ('ʊ̂', 'e͡ɪ'): 1,
#  ('ʊ̂', 'ɒː'): 1,
#  ('ʊ̂', 'ɻ'): 1,
#  ('ʊ̂', 'ä'): 1,
#  ('ʊ̂', 'ɑː'): 1,
#  ('ʊ̂', 't͡ʃ'): 1,
#  ('ʊ̂', 'y'): 1,
#  ('ʊ̂', 'm̩'): 1,
#  ('ʊ̂', 'ʒ'): 1,
#  ('ʊ̂', 'd͡ʒ'): 1,
#  ('ʊ̂', 'ɑˑ'): 1,
#  ('ʊ̂', 'ɪʲ'): 1,
#  ('ʊ̂', 'e͜ɚ'): 1,
#  ('ʊ̂', 'ʀ'): 1,
#  ('ʊ̂', 'a'): 1,
#  ('ʊ̂', 'ɜː'): 1,
#  ('ʊ̂', 'ɐ'): 1,
#  ('ʊ̂', 'k'): 1,
#  ('ʊ̂', 'kʰ'): 1,
#  ('ʊ̂', 'v'): 1,
#  ('ʊ̂', 't͡ʃʰ'): 1,
#  ('ʊ̂', 'r̩'): 1,
#  ('ʊ̂', 'ã'): 1,
#  ('ʊ̂', '↓'): 1,
#  ('ʊ̂', 'ʊ̆'): 1,
#  ('ʊ̂', 'd̪'): 1,
#  ('ʊ̂', 'χ'): 1,
#  ('ʊ̂', 'ŋ'): 1,
#  ('ʊ̂', 'ɘ'): 1,
#  ('ʊ̂', 'ɒ'): 1,
#  ('ʊ̂', 't'): 1,
#  ('ʊ̂', 'θ'): 1,
#  ('ʊ̂', 'lʲ'): 1,
#  ('ʊ̂', 'ɪˑ'): 1,
#  ('ʊ̂', 'ɱ'): 1,
#  ('ʊ̂', 'ɪ̪'): 1,
#  ('ʊ̂', 'æ̃'): 1,
#  ('ʊ̂', 'ɛː'): 1,
#  ('ʊ̂', 'ʊ̪'): 1,
#  ('ʊ̂', 'e'): 1,
#  ('ʊ̂', 'o͡ʊ'): 1,
#  ('ʊ̂', 'ɲ'): 1,
#  ('ʊ̂', 'p̬'): 1,
#  ('ʊ̂', '˞'): 1,
#  ('ʊ̂', 'b'): 1,
#  ('ʊ̂', 'tʰ'): 1,
#  ('ʊ̂', 'ɾ'): 1,
#  ('ʊ̂', 'ʔ'): 1,
#  ('ʊ̂', 'ĩ'): 1,
#  ('ʊ̂', 'ɔ͡ɪ'): 1,
#  ('ʊ̂', 'ɖ'): 1,
#  ('ʊ̂', 'əˑ'): 1,
#  ('ʊ̂', '~'): 1,
#  ('ʊ̂', 'ɭ'): 1,
#  ('ʊ̂', 'ɵ'): 1,
#  ('ʊ̂', 'ə̯'): 1,
#  ('ʊ̂', 'sː'): 1,
#  ('ʊ̂', 'ɐː'): 1,
#  ('ʊ̂', 'n'): 1,
#  ('ʊ̂', 'ʙ̩ː'): 1,
#  ('ʊ̂', 'ʌ'): 1,
#  ('ʊ̂', 'n̩'): 1,
#  ('ʊ̂', 'ɯ'): 1,
#  ('ʊ̂', 'w'): 1,
#  ('ʊ̂', 'tᵊ'): 1,
#  ('ʊ̂', 'ɜ'): 1,
#  ('ʊ̂', 'oː'): 1,
#  ('ʊ̂', 'ŭ̥'): 1,
#  ('ʊ̂', 'ɪ'): 1,
#  ('ʊ̂', 'ɚ'): 1,
#  ('ʊ̂', 'ɪ̯'): 1,
#  ('ʊ̂', 'ø'): 1,
#  ('ʊ̂', 'ɝː'): 1,
#  ('ʊ̂', 'ɝ'): 1,
#  ('ʊ̂', 'c'): 1,
#  ('ʊ̂', 'ɹ'): 1,
#  ('ʊ̂', 'ĭ̥'): 1,
#  ('ʊ̂', 'bʲ'): 1,
#  ('ʊ̂', 'l͡s'): 1,
#  ('ʊ̂', 'l'): 1,
#  ('ʊ̂', 'm̩ː'): 1,
#  ('ʊ̂', 'ṽ'): 1,
#  ('ʊ̂', 'ə'): 1,
#  ('ʊ̂', 'ɛ̃'): 1,
#  ('ʊ̂', 'ɒ̃'): 1,
#  ('ʊ̂', 'ɬ'): 1,
#  ('ʊ̂', 'ɜ̃'): 1,
#  ('ʊ̂', 'ʌ̈'): 1,
#  ('ʊ̂', 't͡ʃ̩̩'): 1,
#  ('ʊ̂', 'ɡ'): 1,
#  ('ʊ̂', 'äː'): 1,
#  ('ʊ̂', 'əʳ'): 1,
#  ('ʊ̂', 'dʲ'): 1,
#  ('ʊ̂', 'ʈ'): 1,
#  ('ʊ̂', 'tː'): 1,
#  ('ʊ̂', 'ð'): 1,
#  ('ʊ̂', 'kᵊ'): 1,
#  ('ʊ̂', 'ɛ͡ɹ'): 1,
#  ('ʊ̂', 'ɦ'): 1,
#  ('ʊ̂', 'ɽ'): 1,
#  ('ʊ̂', 'd'): 1,
#  ('ʊ̂', 'q'): 1,
#  ('ʊ̂', 'ɔː'): 1,
#  ('ʊ̂', 'ɕː'): 1,
#  ('ʊ̂', 'æː'): 1,
#  ('ʊ̂', 'r'): 1,
#  ('ʊ̂', 'ɛˑ'): 1,
#  ('ʊ̂', 'j'): 1,
#  ('ʊ̂', 't̬'): 1,
#  ('ʊ̂', 'ʊ'): 1,
#  ('ʊ̂', 'START'): 1,
#  ('ʊ̂', 'ʃː'): 1,
#  ('ʊ̂', 'ɵ̞'): 1,
#  ('ʊ̂', 'ʃ'): 1,
#  ('ʊ̂', 'œ'): 1,
#  ('ʊ̂', 'h'): 1,
#  ('ʊ̂', 'p'): 1,
#  ('ʊ̂', 't̬ᵊ'): 1,
#  ('ʊ̂', 'm'): 1,
#  ('ʊ̂', 'əː'): 1,
#  ('ʊ̂', 'ə̆'): 1,
#  ('ʊ̂', 'ɛ'): 1,
#  ('ʊ̂', 'ɑ'): 1,
#  ('ʊ̂', 's'): 1,
#  ('ʊ̂', 'ʉ'): 1,
#  ('ʊ̂', 'pʰ'): 1,
#  ('ʊ̂', 'mː'): 1,
#  ('ʊ̂', 'ô'): 1,
#  ('ʊ̂', 'ɨ'): 1,
#  ('ʊ̂', 'ʌː'): 1,
#  ('ʊ̂', 'l̩'): 1,
#  ('ʊ̂', 'uː'): 1,
#  ('ʊ̂', 'x'): 1,
#  ('ʊ̂', 'ɪː'): 1,
#  ('ʊ̂', 'ʏ'): 1,
#  ('ʊ̂', 'ʁ'): 1,
#  ('ʊ̂', 'o'): 1,
#  ('ʊ̂', 'z'): 1,
#  ('ʊ̂', 'aː'): 1,
#  ('ɾ̃', 'ʊ̂'): 1,
#  ('ɾ̃', 'ɾ̃'): 1,
#  ('ɾ̃', 'STOP'): 1,
#  ('ɾ̃', 'æ'): 1,
#  ('ɾ̃', 't͡s'): 1,
#  ('ɾ̃', 'ʉː'): 1,
#  ('ɾ̃', 'ɚː'): 1,
#  ('ɾ̃', 'eː'): 1,
#  ('ɾ̃', 'ú'): 1,
#  ('ɾ̃', 'iː'): 1,
#  ('ɾ̃', 'pː'): 1,
#  ('ɾ̃', 'ē'): 1,
#  ('ɾ̃', 'ɛ͡ɪ'): 1,
#  ('ɾ̃', 'ɡː'): 1,
#  ('ɾ̃', 'ɑ̃'): 1,
#  ('ɾ̃', 'ʃʰ'): 1,
#  ('ɾ̃', 'bᵊ'): 1,
#  ('ɾ̃', 'ɔ̃'): 1,
#  ('ɾ̃', 'i'): 1,
#  ('ɾ̃', 'ɔ'): 1,
#  ('ɾ̃', 'nˡ'): 1,
#  ('ɾ̃', 'ɛ̝'): 1,
#  ('ɾ̃', 'ʍ'): 1,
#  ('ɾ̃', 'ːs'): 1,
#  ('ɾ̃', 'ɹ̩'): 1,
#  ('ɾ̃', 'f'): 1,
#  ('ɾ̃', 'u'): 1,
#  ('ɾ̃', 'k̚'): 1,
#  ('ɾ̃', 'ɣ'): 1,
#  ('ɾ̃', 'ĭ'): 1,
#  ('ɾ̃', 'nː'): 1,
#  ('ɾ̃', 'îː'): 1,
#  ('ɾ̃', 'dʰ'): 1,
#  ('ɾ̃', 'ʊ̩'): 1,
#  ('ɾ̃', 'ʊ̯'): 1,
#  ('ɾ̃', 'ɪ̈'): 1,
#  ('ɾ̃', 'oˀ'): 1,
#  ('ɾ̃', 'ç'): 1,
#  ('ɾ̃', 'ɹʷ'): 1,
#  ('ɾ̃', 'ɹː'): 1,
#  ('ɾ̃', 'õ'): 1,
#  ('ɾ̃', 'ɫ̩'): 1,
#  ('ɾ̃', 'o̞'): 1,
#  ('ɾ̃', 'ɫ'): 1,
#  ('ɾ̃', 't͡ɕ'): 1,
#  ('ɾ̃', 'fː'): 1,
#  ('ɾ̃', 'ʊː'): 1,
#  ('ɾ̃', 'e͡ɪ'): 1,
#  ('ɾ̃', 'ɒː'): 1,
#  ('ɾ̃', 'ɻ'): 1,
#  ('ɾ̃', 'ä'): 1,
#  ('ɾ̃', 'ɑː'): 1,
#  ('ɾ̃', 't͡ʃ'): 1,
#  ('ɾ̃', 'y'): 1,
#  ('ɾ̃', 'm̩'): 1,
#  ('ɾ̃', 'ʒ'): 1,
#  ('ɾ̃', 'd͡ʒ'): 1,
#  ('ɾ̃', 'ɑˑ'): 1,
#  ('ɾ̃', 'ɪʲ'): 1,
#  ('ɾ̃', 'e͜ɚ'): 1,
#  ('ɾ̃', 'ʀ'): 1,
#  ('ɾ̃', 'a'): 1,
#  ('ɾ̃', 'ɜː'): 1,
#  ('ɾ̃', 'ɐ'): 1,
#  ('ɾ̃', 'k'): 1,
#  ('ɾ̃', 'kʰ'): 1,
#  ('ɾ̃', 'v'): 1,
#  ('ɾ̃', 't͡ʃʰ'): 1,
#  ('ɾ̃', 'r̩'): 1,
#  ('ɾ̃', 'ã'): 1,
#  ('ɾ̃', '↓'): 1,
#  ('ɾ̃', 'ʊ̆'): 1,
#  ('ɾ̃', 'd̪'): 1,
#  ('ɾ̃', 'χ'): 1,
#  ('ɾ̃', 'ŋ'): 1,
#  ('ɾ̃', 'ɘ'): 1,
#  ('ɾ̃', 'ɒ'): 1,
#  ('ɾ̃', 't'): 1,
#  ('ɾ̃', 'θ'): 1,
#  ('ɾ̃', 'lʲ'): 1,
#  ('ɾ̃', 'ɪˑ'): 1,
#  ('ɾ̃', 'ɱ'): 1,
#  ('ɾ̃', 'ɪ̪'): 1,
#  ('ɾ̃', 'æ̃'): 1,
#  ('ɾ̃', 'ɛː'): 1,
#  ('ɾ̃', 'ʊ̪'): 1,
#  ('ɾ̃', 'e'): 1,
#  ('ɾ̃', 'o͡ʊ'): 1,
#  ('ɾ̃', 'ɲ'): 1,
#  ('ɾ̃', 'p̬'): 1,
#  ('ɾ̃', '˞'): 1,
#  ('ɾ̃', 'b'): 1,
#  ('ɾ̃', 'tʰ'): 1,
#  ('ɾ̃', 'ɾ'): 1,
#  ('ɾ̃', 'ʔ'): 1,
#  ('ɾ̃', 'ĩ'): 1,
#  ('ɾ̃', 'ɔ͡ɪ'): 1,
#  ('ɾ̃', 'ɖ'): 1,
#  ('ɾ̃', 'əˑ'): 1,
#  ('ɾ̃', '~'): 1,
#  ('ɾ̃', 'ɭ'): 1,
#  ('ɾ̃', 'ɵ'): 1,
#  ('ɾ̃', 'ə̯'): 1,
#  ('ɾ̃', 'sː'): 1,
#  ('ɾ̃', 'ɐː'): 1,
#  ('ɾ̃', 'n'): 1,
#  ('ɾ̃', 'ʙ̩ː'): 1,
#  ('ɾ̃', 'ʌ'): 1,
#  ('ɾ̃', 'n̩'): 1,
#  ('ɾ̃', 'ɯ'): 1,
#  ('ɾ̃', 'w'): 1,
#  ('ɾ̃', 'tᵊ'): 1,
#  ('ɾ̃', 'ɜ'): 1,
#  ('ɾ̃', 'oː'): 1,
#  ('ɾ̃', 'ŭ̥'): 1,
#  ('ɾ̃', 'ɪ'): 1,
#  ('ɾ̃', 'ɚ'): 1,
#  ('ɾ̃', 'ɪ̯'): 1,
#  ('ɾ̃', 'ø'): 1,
#  ('ɾ̃', 'ɝː'): 1,
#  ('ɾ̃', 'ɝ'): 1,
#  ('ɾ̃', 'c'): 1,
#  ('ɾ̃', 'ɹ'): 1,
#  ('ɾ̃', 'ĭ̥'): 1,
#  ('ɾ̃', 'bʲ'): 1,
#  ('ɾ̃', 'l͡s'): 1,
#  ('ɾ̃', 'l'): 1,
#  ('ɾ̃', 'm̩ː'): 1,
#  ('ɾ̃', 'ṽ'): 1,
#  ('ɾ̃', 'ə'): 1,
#  ('ɾ̃', 'ɛ̃'): 1,
#  ('ɾ̃', 'ɒ̃'): 1,
#  ('ɾ̃', 'ɬ'): 1,
#  ('ɾ̃', 'ɜ̃'): 1,
#  ('ɾ̃', 'ʌ̈'): 1,
#  ('ɾ̃', 't͡ʃ̩̩'): 1,
#  ('ɾ̃', 'ɡ'): 1,
#  ('ɾ̃', 'äː'): 1,
#  ('ɾ̃', 'əʳ'): 1,
#  ('ɾ̃', 'dʲ'): 1,
#  ('ɾ̃', 'ʈ'): 1,
#  ('ɾ̃', 'tː'): 1,
#  ('ɾ̃', 'ð'): 1,
#  ('ɾ̃', 'kᵊ'): 1,
#  ('ɾ̃', 'ɛ͡ɹ'): 1,
#  ('ɾ̃', 'ɦ'): 1,
#  ('ɾ̃', 'ɽ'): 1,
#  ('ɾ̃', 'd'): 1,
#  ('ɾ̃', 'q'): 1,
#  ('ɾ̃', 'ɔː'): 1,
#  ('ɾ̃', 'ɕː'): 1,
#  ('ɾ̃', 'æː'): 1,
#  ('ɾ̃', 'r'): 1,
#  ('ɾ̃', 'ɛˑ'): 1,
#  ('ɾ̃', 'j'): 1,
#  ('ɾ̃', 't̬'): 1,
#  ('ɾ̃', 'ʊ'): 1,
#  ('ɾ̃', 'START'): 1,
#  ('ɾ̃', 'ʃː'): 1,
#  ('ɾ̃', 'ɵ̞'): 1,
#  ('ɾ̃', 'ʃ'): 1,
#  ('ɾ̃', 'œ'): 1,
#  ('ɾ̃', 'h'): 1,
#  ('ɾ̃', 'p'): 1,
#  ('ɾ̃', 't̬ᵊ'): 1,
#  ('ɾ̃', 'm'): 1,
#  ('ɾ̃', 'əː'): 1,
#  ('ɾ̃', 'ə̆'): 1,
#  ('ɾ̃', 'ɛ'): 1,
#  ('ɾ̃', 'ɑ'): 1,
#  ('ɾ̃', 's'): 1,
#  ('ɾ̃', 'ʉ'): 1,
#  ('ɾ̃', 'pʰ'): 1,
#  ('ɾ̃', 'mː'): 1,
#  ('ɾ̃', 'ô'): 1,
#  ('ɾ̃', 'ɨ'): 1,
#  ('ɾ̃', 'ʌː'): 1,
#  ('ɾ̃', 'l̩'): 1,
#  ('ɾ̃', 'uː'): 1,
#  ('ɾ̃', 'x'): 1,
#  ('ɾ̃', 'ɪː'): 1,
#  ('ɾ̃', 'ʏ'): 1,
#  ('ɾ̃', 'ʁ'): 1,
#  ('ɾ̃', 'o'): 1,
#  ('ɾ̃', 'z'): 1,
#  ('ɾ̃', 'aː'): 1,
#  ('STOP', 'ʊ̂'): 1,
#  ('STOP', 'ɾ̃'): 1,
#  ('STOP', 'STOP'): 1,
#  ('STOP', 'æ'): 1,
#  ('STOP', 't͡s'): 1,
#  ('STOP', 'ʉː'): 1,
#  ('STOP', 'ɚː'): 1,
#  ('STOP', 'eː'): 1,
#  ('STOP', 'ú'): 1,
#  ('STOP', 'iː'): 1,
#  ('STOP', 'pː'): 1,
#  ('STOP', 'ē'): 1,
#  ('STOP', 'ɛ͡ɪ'): 1,
#  ('STOP', 'ɡː'): 1,
#  ('STOP', 'ɑ̃'): 1,
#  ('STOP', 'ʃʰ'): 1,
#  ('STOP', 'bᵊ'): 1,
#  ('STOP', 'ɔ̃'): 1,
#  ('STOP', 'i'): 1,
#  ('STOP', 'ɔ'): 1,
#  ('STOP', 'nˡ'): 1,
#  ('STOP', 'ɛ̝'): 1,
#  ('STOP', 'ʍ'): 1,
#  ('STOP', 'ːs'): 1,
#  ('STOP', 'ɹ̩'): 1,
#  ('STOP', 'f'): 1,
#  ('STOP', 'u'): 1,
#  ('STOP', 'k̚'): 1,
#  ('STOP', 'ɣ'): 1,
#  ('STOP', 'ĭ'): 1,
#  ('STOP', 'nː'): 1,
#  ('STOP', 'îː'): 1,
#  ('STOP', 'dʰ'): 1,
#  ('STOP', 'ʊ̩'): 1,
#  ('STOP', 'ʊ̯'): 1,
#  ('STOP', 'ɪ̈'): 1,
#  ('STOP', 'oˀ'): 1,
#  ('STOP', 'ç'): 1,
#  ('STOP', 'ɹʷ'): 1,
#  ('STOP', 'ɹː'): 1,
#  ('STOP', 'õ'): 1,
#  ('STOP', 'ɫ̩'): 1,
#  ('STOP', 'o̞'): 1,
#  ('STOP', 'ɫ'): 1,
#  ('STOP', 't͡ɕ'): 1,
#  ('STOP', 'fː'): 1,
#  ('STOP', 'ʊː'): 1,
#  ('STOP', 'e͡ɪ'): 1,
#  ('STOP', 'ɒː'): 1,
#  ('STOP', 'ɻ'): 1,
#  ('STOP', 'ä'): 1,
#  ('STOP', 'ɑː'): 1,
#  ('STOP', 't͡ʃ'): 1,
#  ('STOP', 'y'): 1,
#  ('STOP', 'm̩'): 1,
#  ('STOP', 'ʒ'): 1,
#  ('STOP', 'd͡ʒ'): 1,
#  ('STOP', 'ɑˑ'): 1,
#  ('STOP', 'ɪʲ'): 1,
#  ('STOP', 'e͜ɚ'): 1,
#  ('STOP', 'ʀ'): 1,
#  ('STOP', 'a'): 1,
#  ('STOP', 'ɜː'): 1,
#  ('STOP', 'ɐ'): 1,
#  ('STOP', 'k'): 1,
#  ('STOP', 'kʰ'): 1,
#  ('STOP', 'v'): 1,
#  ('STOP', 't͡ʃʰ'): 1,
#  ('STOP', 'r̩'): 1,
#  ('STOP', 'ã'): 1,
#  ('STOP', '↓'): 1,
#  ('STOP', 'ʊ̆'): 1,
#  ('STOP', 'd̪'): 1,
#  ('STOP', 'χ'): 1,
#  ('STOP', 'ŋ'): 1,
#  ('STOP', 'ɘ'): 1,
#  ('STOP', 'ɒ'): 1,
#  ('STOP', 't'): 1,
#  ('STOP', 'θ'): 1,
#  ('STOP', 'lʲ'): 1,
#  ('STOP', 'ɪˑ'): 1,
#  ('STOP', 'ɱ'): 1,
#  ('STOP', 'ɪ̪'): 1,
#  ('STOP', 'æ̃'): 1,
#  ('STOP', 'ɛː'): 1,
#  ('STOP', 'ʊ̪'): 1,
#  ('STOP', 'e'): 1,
#  ('STOP', 'o͡ʊ'): 1,
#  ('STOP', 'ɲ'): 1,
#  ('STOP', 'p̬'): 1,
#  ('STOP', '˞'): 1,
#  ('STOP', 'b'): 1,
#  ('STOP', 'tʰ'): 1,
#  ('STOP', 'ɾ'): 1,
#  ('STOP', 'ʔ'): 1,
#  ('STOP', 'ĩ'): 1,
#  ('STOP', 'ɔ͡ɪ'): 1,
#  ('STOP', 'ɖ'): 1,
#  ('STOP', 'əˑ'): 1,
#  ('STOP', '~'): 1,
#  ('STOP', 'ɭ'): 1,
#  ('STOP', 'ɵ'): 1,
#  ('STOP', 'ə̯'): 1,
#  ('STOP', 'sː'): 1,
#  ('STOP', 'ɐː'): 1,
#  ('STOP', 'n'): 1,
#  ('STOP', 'ʙ̩ː'): 1,
#  ('STOP', 'ʌ'): 1,
#  ('STOP', 'n̩'): 1,
#  ('STOP', 'ɯ'): 1,
#  ('STOP', 'w'): 1,
#  ('STOP', 'tᵊ'): 1,
#  ('STOP', 'ɜ'): 1,
#  ('STOP', 'oː'): 1,
#  ('STOP', 'ŭ̥'): 1,
#  ('STOP', 'ɪ'): 1,
#  ('STOP', 'ɚ'): 1,
#  ('STOP', 'ɪ̯'): 1,
#  ('STOP', 'ø'): 1,
#  ('STOP', 'ɝː'): 1,
#  ('STOP', 'ɝ'): 1,
#  ('STOP', 'c'): 1,
#  ('STOP', 'ɹ'): 1,
#  ('STOP', 'ĭ̥'): 1,
#  ('STOP', 'bʲ'): 1,
#  ('STOP', 'l͡s'): 1,
#  ('STOP', 'l'): 1,
#  ('STOP', 'm̩ː'): 1,
#  ('STOP', 'ṽ'): 1,
#  ('STOP', 'ə'): 1,
#  ('STOP', 'ɛ̃'): 1,
#  ('STOP', 'ɒ̃'): 1,
#  ('STOP', 'ɬ'): 1,
#  ('STOP', 'ɜ̃'): 1,
#  ('STOP', 'ʌ̈'): 1,
#  ('STOP', 't͡ʃ̩̩'): 1,
#  ('STOP', 'ɡ'): 1,
#  ('STOP', 'äː'): 1,
#  ('STOP', 'əʳ'): 1,
#  ('STOP', 'dʲ'): 1,
#  ('STOP', 'ʈ'): 1,
#  ('STOP', 'tː'): 1,
#  ('STOP', 'ð'): 1,
#  ('STOP', 'kᵊ'): 1,
#  ('STOP', 'ɛ͡ɹ'): 1,
#  ('STOP', 'ɦ'): 1,
#  ('STOP', 'ɽ'): 1,
#  ('STOP', 'd'): 1,
#  ('STOP', 'q'): 1,
#  ('STOP', 'ɔː'): 1,
#  ('STOP', 'ɕː'): 1,
#  ('STOP', 'æː'): 1,
#  ('STOP', 'r'): 1,
#  ('STOP', 'ɛˑ'): 1,
#  ('STOP', 'j'): 1,
#  ('STOP', 't̬'): 1,
#  ('STOP', 'ʊ'): 1,
#  ('STOP', 'START'): 1,
#  ('STOP', 'ʃː'): 1,
#  ('STOP', 'ɵ̞'): 1,
#  ('STOP', 'ʃ'): 1,
#  ('STOP', 'œ'): 1,
#  ('STOP', 'h'): 1,
#  ('STOP', 'p'): 1,
#  ('STOP', 't̬ᵊ'): 1,
#  ('STOP', 'm'): 1,
#  ('STOP', 'əː'): 1,
#  ('STOP', 'ə̆'): 1,
#  ('STOP', 'ɛ'): 1,
#  ('STOP', 'ɑ'): 1,
#  ('STOP', 's'): 1,
#  ('STOP', 'ʉ'): 1,
#  ('STOP', 'pʰ'): 1,
#  ('STOP', 'mː'): 1,
#  ('STOP', 'ô'): 1,
#  ('STOP', 'ɨ'): 1,
#  ('STOP', 'ʌː'): 1,
#  ('STOP', 'l̩'): 1,
#  ('STOP', 'uː'): 1,
#  ('STOP', 'x'): 1,
#  ('STOP', 'ɪː'): 1,
#  ('STOP', 'ʏ'): 1,
#  ('STOP', 'ʁ'): 1,
#  ('STOP', 'o'): 1,
#  ('STOP', 'z'): 1,
#  ('STOP', 'aː'): 1,
#  ('æ', 'ʊ̂'): 1,
#  ('æ', 'ɾ̃'): 1,
#  ('æ', 'STOP'): 1,
#  ('æ', 'æ'): 1,
#  ('æ', 't͡s'): 1,
#  ('æ', 'ʉː'): 1,
#  ('æ', 'ɚː'): 1,
#  ('æ', 'eː'): 1,
#  ('æ', 'ú'): 1,
#  ('æ', 'iː'): 1,
#  ('æ', 'pː'): 1,
#  ('æ', 'ē'): 1,
#  ('æ', 'ɛ͡ɪ'): 1,
#  ('æ', 'ɡː'): 1,
#  ('æ', 'ɑ̃'): 1,
#  ('æ', 'ʃʰ'): 1,
#  ('æ', 'bᵊ'): 1,
#  ('æ', 'ɔ̃'): 1,
#  ('æ', 'ɪː'): 1,
#  ('æ', 'ʏ'): 1,
#  ('æ', 'ʁ'): 1,
#  ('æ', 'o'): 1,
#  ('æ', 'z'): 1,
#  ('æ', 'aː'): 1,
#  ('t͡s', 'ʊ̂'): 1,
#  ('t͡s', 'ɾ̃'): 1,
#  ('t͡s', 'STOP'): 1,
#  ('t͡s', 'æ'): 1,
#  ('t͡s', 't͡s'): 1,
#  ('t͡s', 'ʉː'): 1,
#  ('t͡s', 'ɚː'): 1,
#  ('t͡s', 'eː'): 1,
#  ('t͡s', 'ú'): 1,
#  ('t͡s', 'iː'): 1,
#  ('t͡s', 'pː'): 1,
#  ('t͡s', 'ē'): 1,
#  ('t͡s', 'ɛ͡ɪ'): 1,
#  ('t͡s', 'ɡː'): 1,
#  ('t͡s', 'ɑ̃'): 1,
#  ('t͡s', 'ʃʰ'): 1,
#  ('t͡s', 'bᵊ'): 1,
#  ('t͡s', 'ɔ̃'): 1,
#  ('t͡s', 'i'): 1,
#  ('t͡s', 'ɔ'): 1,
#  ('t͡s', 'nˡ'): 1,
#  ('t͡s', 'ɛ̝'): 1,
#  ('t͡s', 'ʍ'): 1,
#  ('t͡s', 'ːs'): 1,
#  ('t͡s', 'ɹ̩'): 1,
#  ('t͡s', 'f'): 1,
#  ('t͡s', 'u'): 1,
#  ('t͡s', 'k̚'): 1,
#  ('t͡s', 'ɣ'): 1,
#  ('t͡s', 'ĭ'): 1,
#  ('t͡s', 'nː'): 1,
#  ('t͡s', 'îː'): 1,
#  ('t͡s', 'dʰ'): 1,
#  ('t͡s', 'ʊ̩'): 1,
#  ('t͡s', 'ʊ̯'): 1,
#  ('t͡s', 'ɪ̈'): 1,
#  ('t͡s', 'oˀ'): 1,
#  ('t͡s', 'ç'): 1,
#  ('t͡s', 'ɹʷ'): 1,
#  ('t͡s', 'ɹː'): 1,
#  ('t͡s', 'õ'): 1,
#  ('t͡s', 'ɫ̩'): 1,
#  ('t͡s', 'o̞'): 1,
#  ('t͡s', 'ɫ'): 1,
#  ('t͡s', 't͡ɕ'): 1,
#  ('t͡s', 'fː'): 1,
#  ('t͡s', 'ʊː'): 1,
#  ('t͡s', 'e͡ɪ'): 1,
#  ('t͡s', 'ɒː'): 1,
#  ('t͡s', 'ɻ'): 1,
#  ('t͡s', 'ä'): 1,
#  ('t͡s', 'ɑː'): 1,
#  ('t͡s', 't͡ʃ'): 1,
#  ('t͡s', 'y'): 1,
#  ('t͡s', 'm̩'): 1,
#  ('t͡s', 'ʒ'): 1,
#  ('t͡s', 'd͡ʒ'): 1,
#  ('t͡s', 'ɑˑ'): 1,
#  ('t͡s', 'ɪʲ'): 1,
#  ('t͡s', 'e͜ɚ'): 1,
#  ('t͡s', 'ʀ'): 1,
#  ('t͡s', 'a'): 1,
#  ('t͡s', 'ɜː'): 1,
#  ('t͡s', 'ɐ'): 1,
#  ('t͡s', 'k'): 1,
#  ('t͡s', 'kʰ'): 1,
#  ('t͡s', 'v'): 1,
#  ('t͡s', 't͡ʃʰ'): 1,
#  ('t͡s', 'r̩'): 1,
#  ('t͡s', 'ã'): 1,
#  ('t͡s', '↓'): 1,
#  ('t͡s', 'ʊ̆'): 1,
#  ('t͡s', 'd̪'): 1,
#  ('t͡s', 'χ'): 1,
#  ('t͡s', 'ŋ'): 1,
#  ('t͡s', 'ɘ'): 1,
#  ('t͡s', 'ɒ'): 1,
#  ('t͡s', 't'): 1,
#  ('t͡s', 'θ'): 1,
#  ('t͡s', 'lʲ'): 1,
#  ('t͡s', 'ɪˑ'): 1,
#  ('t͡s', 'ɱ'): 1,
#  ('t͡s', 'ɪ̪'): 1,
#  ('t͡s', 'æ̃'): 1,
#  ('t͡s', 'ɛː'): 1,
#  ('t͡s', 'ʊ̪'): 1,
#  ('t͡s', 'e'): 1,
#  ('t͡s', 'o͡ʊ'): 1,
#  ('t͡s', 'ɲ'): 1,
#  ('t͡s', 'p̬'): 1,
#  ('t͡s', '˞'): 1,
#  ('t͡s', 'b'): 1,
#  ('t͡s', 'tʰ'): 1,
#  ('t͡s', 'ɾ'): 1,
#  ('t͡s', 'ʔ'): 1,
#  ('t͡s', 'ĩ'): 1,
#  ('t͡s', 'ɔ͡ɪ'): 1,
#  ('t͡s', 'ɖ'): 1,
#  ('t͡s', 'əˑ'): 1,
#  ('t͡s', '~'): 1,
#  ('t͡s', 'ɭ'): 1,
#  ('t͡s', 'ɵ'): 1,
#  ('t͡s', 'ə̯'): 1,
#  ('t͡s', 'sː'): 1,
#  ('t͡s', 'ɐː'): 1,
#  ('t͡s', 'n'): 1,
#  ('t͡s', 'ʙ̩ː'): 1,
#  ('t͡s', 'ʌ'): 1,
#  ('t͡s', 'n̩'): 1,
#  ('t͡s', 'ɯ'): 1,
#  ('t͡s', 'w'): 1,
#  ('t͡s', 'tᵊ'): 1,
#  ('t͡s', 'ɜ'): 1,
#  ('t͡s', 'oː'): 1,
#  ('t͡s', 'ŭ̥'): 1,
#  ('t͡s', 'ɪ'): 1,
#  ('t͡s', 'ɚ'): 1,
#  ('t͡s', 'ɪ̯'): 1,
#  ('t͡s', 'ø'): 1,
#  ('t͡s', 'ɝː'): 1,
#  ('t͡s', 'ɝ'): 1,
#  ('t͡s', 'c'): 1,
#  ('t͡s', 'ɹ'): 1,
#  ('t͡s', 'ĭ̥'): 1,
#  ('t͡s', 'bʲ'): 1,
#  ('t͡s', 'l͡s'): 1,
#  ('t͡s', 'l'): 1,
#  ('t͡s', 'm̩ː'): 1,
#  ('t͡s', 'ṽ'): 1,
#  ('t͡s', 'ə'): 1,
#  ('t͡s', 'ɛ̃'): 1,
#  ('t͡s', 'ɒ̃'): 1,
#  ('t͡s', 'ɬ'): 1,
#  ('t͡s', 'ɜ̃'): 1,
#  ('t͡s', 'ʌ̈'): 1,
#  ('t͡s', 't͡ʃ̩̩'): 1,
#  ('t͡s', 'ɡ'): 1,
#  ('t͡s', 'äː'): 1,
#  ('t͡s', 'əʳ'): 1,
#  ('t͡s', 'dʲ'): 1,
#  ('t͡s', 'ʈ'): 1,
#  ('t͡s', 'tː'): 1,
#  ('t͡s', 'ð'): 1,
#  ('t͡s', 'kᵊ'): 1,
#  ('t͡s', 'ɛ͡ɹ'): 1,
#  ('t͡s', 'ɦ'): 1,
#  ('t͡s', 'ɽ'): 1,
#  ('t͡s', 'd'): 1,
#  ('t͡s', 'q'): 1,
#  ('t͡s', 'ɔː'): 1,
#  ('t͡s', 'ɕː'): 1,
#  ('t͡s', 'æː'): 1,
#  ('t͡s', 'r'): 1,
#  ('t͡s', 'ɛˑ'): 1,
#  ('t͡s', 'j'): 1,
#  ('t͡s', 't̬'): 1,
#  ('t͡s', 'ʊ'): 1,
#  ('t͡s', 'START'): 1,
#  ('t͡s', 'ʃː'): 1,
#  ('t͡s', 'ɵ̞'): 1,
#  ('t͡s', 'ʃ'): 1,
#  ('t͡s', 'œ'): 1,
#  ('t͡s', 'h'): 1,
#  ('t͡s', 'p'): 1,
#  ('t͡s', 't̬ᵊ'): 1,
#  ('t͡s', 'm'): 1,
#  ('t͡s', 'əː'): 1,
#  ('t͡s', 'ə̆'): 1,
#  ('t͡s', 'ɛ'): 1,
#  ('t͡s', 'ɑ'): 1,
#  ('t͡s', 's'): 1,
#  ('t͡s', 'ʉ'): 1,
#  ('t͡s', 'pʰ'): 1,
#  ('t͡s', 'mː'): 1,
#  ('t͡s', 'ô'): 1,
#  ('t͡s', 'ɨ'): 1,
#  ('t͡s', 'ʌː'): 1,
#  ('t͡s', 'l̩'): 1,
#  ('t͡s', 'uː'): 1,
#  ('t͡s', 'x'): 1,
#  ('t͡s', 'ɪː'): 1,
#  ('t͡s', 'ʏ'): 1,
#  ('t͡s', 'ʁ'): 1,
#  ('t͡s', 'o'): 1,
#  ('t͡s', 'z'): 1,
#  ('t͡s', 'aː'): 1,
#  ('ʉː', 'ʊ̂'): 1,
#  ('ʉː', 'ɾ̃'): 1,
#  ('ʉː', 'STOP'): 1,
#  ('ʉː', 'æ'): 1,
#  ('ʉː', 't͡s'): 1,
#  ('ʉː', 'ʉː'): 1,
#  ('ʉː', 'ɚː'): 1,
#  ('ʉː', 'eː'): 1,
#  ('ʉː', 'ú'): 1,
#  ('ʉː', 'iː'): 1,
#  ('ʉː', 'pː'): 1,
#  ('ʉː', 'ē'): 1,
#  ('ʉː', 'ɛ͡ɪ'): 1,
#  ('ʉː', 'ɡː'): 1,
#  ('ʉː', 'ɑ̃'): 1,
#  ('ʉː', 'ʃʰ'): 1,
#  ('ʉː', 'bᵊ'): 1,
#  ('ʉː', 'ɔ̃'): 1,
#  ('ʉː', 'i'): 1,
#  ('ʉː', 'ɔ'): 1,
#  ('ʉː', 'nˡ'): 1,
#  ('ʉː', 'ɛ̝'): 1,
#  ('ʉː', 'ʍ'): 1,
#  ('ʉː', 'ːs'): 1,
#  ('ʉː', 'ɹ̩'): 1,
#  ('ʉː', 'f'): 1,
#  ('ʉː', 'u'): 1,
#  ('ʉː', 'k̚'): 1,
#  ('ʉː', 'ɣ'): 1,
#  ('ʉː', 'ĭ'): 1,
#  ('ʉː', 'nː'): 1,
#  ('ʉː', 'îː'): 1,
#  ('ʉː', 'dʰ'): 1,
#  ('ʉː', 'ʊ̩'): 1,
#  ('ʉː', 'ʊ̯'): 1,
#  ('ʉː', 'ɪ̈'): 1,
#  ('ʉː', 'oˀ'): 1,
#  ('ʉː', 'ç'): 1,
#  ('ʉː', 'ɹʷ'): 1,
#  ('ʉː', 'ɹː'): 1,
#  ('ʉː', 'õ'): 1,
#  ('ʉː', 'ɫ̩'): 1,
#  ('ʉː', 'o̞'): 1,
#  ('ʉː', 'ɫ'): 1,
#  ('ʉː', 't͡ɕ'): 1,
#  ('ʉː', 'fː'): 1,
#  ('ʉː', 'ʊː'): 1,
#  ('ʉː', 'e͡ɪ'): 1,
#  ('ʉː', 'ɒː'): 1,
#  ('ʉː', 'ɻ'): 1,
#  ('ʉː', 'ä'): 1,
#  ('ʉː', 'ɑː'): 1,
#  ('ʉː', 't͡ʃ'): 1,
#  ('ʉː', 'y'): 1,
#  ('ʉː', 'm̩'): 1,
#  ('ʉː', 'ʒ'): 1,
#  ('ʉː', 'd͡ʒ'): 1,
#  ('ʉː', 'ɑˑ'): 1,
#  ('ʉː', 'ɪʲ'): 1,
#  ('ʉː', 'e͜ɚ'): 1,
#  ('ʉː', 'ʀ'): 1,
#  ('ʉː', 'a'): 1,
#  ('ʉː', 'ɜː'): 1,
#  ('ʉː', 'ɐ'): 1,
#  ('ʉː', 'k'): 1,
#  ('ʉː', 'kʰ'): 1,
#  ('ʉː', 'v'): 1,
#  ('ʉː', 't͡ʃʰ'): 1,
#  ('ʉː', 'r̩'): 1,
#  ('ʉː', 'ã'): 1,
#  ...}

# %%
# now add in the actual bigram counts
prons = df.Pron
for pron in prons:
    # YOUR CODE GOES HERE.
    # increment the ptc count for (p1,p2) each time you encounter the bigram "p1 p2" in the data.
    for i in range(len(pron) - 1):
        ptc[(pron[i], pron[i + 1])] += 1
    

# sanity-check some of the counts.
print("START d", ptc[('START','d')])
print("d START", ptc[('d','START')])
print("f ɹ", ptc[('f','ɹ')])
print("ɹ f", ptc[('ɹ','f')])
print("g ɹ", ptc[('ɡ','ɹ')])
print("ɹ g", ptc[('ɹ','ɡ')])
print("s l", ptc[('s','l')])
print("l s", ptc[('l','s')])
# Out:
# START d 3380
# d START 1
# f ɹ 500
# ɹ f 153
# g ɹ 875
# ɹ g 125
# s l 404
# l s 135

# %% [markdown]
# Now transform the phoneme transition **counts** into phoneme transition **probabilities**.
#
# For every pair of phonemes $p_1, p_2$, we already have ptc($p_1$,$p_2$): the phoneme transition count from $p_1$ to $p_2$, i.e. the number of times we encountered the bigram $p_1 p_2$ in the data.
#
# From this, we want to obtain the transition **probability** $p(p_2|p_1)$, i.e. the probability of encountering $p_2$, given that we have just seen $p_1$.  Note the order of the two phonemes: our bigram is $p_1 p_2$, and we use the count for it (and other bigrams) to obtain $p(p_2|p_1)$.
#
# How?  This is a conditional probability, and following the Bishop chapter, or Jurafsky and Martin eqn 3.11, we may calculate it as:
#
# \begin{equation}
# p(p_2|p_1) = \frac{c(p_1 p_2)}{c(p_1)}
# \end{equation}
#
# where $c(\cdot)$ denotes count.  The numerator is simply the count for the bigram $p_1 p_2$.  The denominator is the count for $p_1$ whatever phoneme may follow it.  We have bigram counts, so we can easily obtain the denominator $c(p_1)$ as:
#
# \begin{equation}
# c(p_1) = \sum_{q \in P} c(p_1 q)
# \end{equation}
#
# where $P$ is the set of all phonemes.

# %%
# data structure for transition probabilities is a dict of dicts.
# the outer dict is keyed by phoneme (state), and has value inner dict.
# the inner dict is also keyed by phoneme, and holds the probability of moving from the outer phoneme
# to the inner phoneme, i.e. p(inner|outer).
# this structure should make it easy to convert counts to probs, normalize etc.

tp = dict()  # transition probs, outer dict.
for p1 in phonemes:
    d = dict()  # inner dict
    # YOUR CODE GOES HERE.
    p1_total = 0
    for key in ptc.keys():
        p1_total += ptc[key] if key[0] == p1 else 0
    for p2 in phonemes:
        d[p2] = ptc[(p1, p2)] / p1_total
    
    tp[p1] = d

# %%
# sanity check.
# the conditional probabilities p(p2|p1) should add up to 1.0 when summing across p2, for each p1.
print("Sanity check: do the conditional probabilities conditioned on each phoneme sum to 1.0?")
for p1 in phonemes:
    total = sum(tp[p1].values())
    print("Sum of conditional probabilities conditioned on", p1, total)
# Out:
# Sanity check: do the conditional probabilities conditioned on each phoneme sum to 1.0?
# Sum of conditional probabilities conditioned on ʊ̂ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɾ̃ 1.000000000000002
# Sum of conditional probabilities conditioned on STOP 0.9999999999999992
# Sum of conditional probabilities conditioned on æ 0.9999999999999991
# Sum of conditional probabilities conditioned on t͡s 0.9999999999999959
# Sum of conditional probabilities conditioned on ʉː 0.9999999999999959
# Sum of conditional probabilities conditioned on ɚː 1.000000000000002
# Sum of conditional probabilities conditioned on eː 0.9999999999999978
# Sum of conditional probabilities conditioned on ú 1.0000000000000027
# Sum of conditional probabilities conditioned on iː 1.000000000000001
# Sum of conditional probabilities conditioned on pː 1.0000000000000049
# Sum of conditional probabilities conditioned on ē 0.9999999999999959
# Sum of conditional probabilities conditioned on ɛ͡ɪ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɡː 1.0000000000000027
# Sum of conditional probabilities conditioned on ɑ̃ 0.9999999999999978
# Sum of conditional probabilities conditioned on ʃʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on bᵊ 1.0000000000000022
# Sum of conditional probabilities conditioned on ɔ̃ 0.9999999999999976
# Sum of conditional probabilities conditioned on i 0.9999999999999984
# Sum of conditional probabilities conditioned on ɔ 0.9999999999999994
# Sum of conditional probabilities conditioned on nˡ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ̝ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʍ 0.9999999999999974
# Sum of conditional probabilities conditioned on ːs 1.0000000000000027
# Sum of conditional probabilities conditioned on ɹ̩ 1.0000000000000024
# Sum of conditional probabilities conditioned on f 1.0000000000000016
# Sum of conditional probabilities conditioned on u 0.9999999999999988
# Sum of conditional probabilities conditioned on k̚ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɣ 1.0000000000000027
# Sum of conditional probabilities conditioned on ĭ 1.0000000000000007
# Sum of conditional probabilities conditioned on nː 0.9999999999999959
# Sum of conditional probabilities conditioned on îː 1.0000000000000027
# Sum of conditional probabilities conditioned on dʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̯ 0.9999999999999986
# Sum of conditional probabilities conditioned on ɪ̈ 1.000000000000001
# Sum of conditional probabilities conditioned on oˀ 1.0000000000000027
# Sum of conditional probabilities conditioned on ç 1.0000000000000027
# Sum of conditional probabilities conditioned on ɹʷ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɹː 1.000000000000005
# Sum of conditional probabilities conditioned on õ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɫ̩ 1.000000000000002
# Sum of conditional probabilities conditioned on o̞ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɫ 0.999999999999998
# Sum of conditional probabilities conditioned on t͡ɕ 1.0000000000000022
# Sum of conditional probabilities conditioned on fː 1.0000000000000022
# Sum of conditional probabilities conditioned on ʊː 1.0000000000000022
# Sum of conditional probabilities conditioned on e͡ɪ 0.9999999999999959
# Sum of conditional probabilities conditioned on ɒː 1.000000000000002
# Sum of conditional probabilities conditioned on ɻ 1.0000000000000049
# Sum of conditional probabilities conditioned on ä 1.000000000000002
# Sum of conditional probabilities conditioned on ɑː 1.000000000000001
# Sum of conditional probabilities conditioned on t͡ʃ 0.9999999999999996
# Sum of conditional probabilities conditioned on y 1.0000000000000024
# Sum of conditional probabilities conditioned on m̩ 1.0000000000000018
# Sum of conditional probabilities conditioned on ʒ 0.9999999999999993
# Sum of conditional probabilities conditioned on d͡ʒ 0.9999999999999996
# Sum of conditional probabilities conditioned on ɑˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɪʲ 1.0000000000000027
# Sum of conditional probabilities conditioned on e͜ɚ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʀ 1.0000000000000027
# Sum of conditional probabilities conditioned on a 1.0000000000000033
# Sum of conditional probabilities conditioned on ɜː 0.9999999999999988
# Sum of conditional probabilities conditioned on ɐ 1.0000000000000018
# Sum of conditional probabilities conditioned on k 1.0000000000000022
# Sum of conditional probabilities conditioned on kʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on v 0.9999999999999986
# Sum of conditional probabilities conditioned on t͡ʃʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on r̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ã 1.0000000000000027
# Sum of conditional probabilities conditioned on ↓ 1.0000000000000024
# Sum of conditional probabilities conditioned on ʊ̆ 1.0000000000000027
# Sum of conditional probabilities conditioned on d̪ 1.0000000000000027
# Sum of conditional probabilities conditioned on χ 1.0000000000000007
# Sum of conditional probabilities conditioned on ŋ 1.0000000000000042
# Sum of conditional probabilities conditioned on ɘ 1.0000000000000007
# Sum of conditional probabilities conditioned on ɒ 0.9999999999999991
# Sum of conditional probabilities conditioned on t 0.9999999999999997
# Sum of conditional probabilities conditioned on θ 1.0000000000000036
# Sum of conditional probabilities conditioned on lʲ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɪˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɱ 1.000000000000005
# Sum of conditional probabilities conditioned on ɪ̪ 1.0000000000000047
# Sum of conditional probabilities conditioned on æ̃ 0.9999999999999959
# Sum of conditional probabilities conditioned on ɛː 1.000000000000002
# Sum of conditional probabilities conditioned on ʊ̪ 1.0000000000000027
# Sum of conditional probabilities conditioned on e 1.0000000000000004
# Sum of conditional probabilities conditioned on o͡ʊ 1.0000000000000049
# Sum of conditional probabilities conditioned on ɲ 1.000000000000005
# Sum of conditional probabilities conditioned on p̬ 1.0000000000000022
# Sum of conditional probabilities conditioned on ˞ 1.0000000000000018
# Sum of conditional probabilities conditioned on b 0.9999999999999982
# Sum of conditional probabilities conditioned on tʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɾ 1.0000000000000009
# Sum of conditional probabilities conditioned on ʔ 1.0000000000000049
# Sum of conditional probabilities conditioned on ĩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɔ͡ɪ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɖ 1.0000000000000022
# Sum of conditional probabilities conditioned on əˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ~ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɭ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɵ 1.000000000000002
# Sum of conditional probabilities conditioned on ə̯ 0.9999999999999977
# Sum of conditional probabilities conditioned on sː 1.0000000000000022
# Sum of conditional probabilities conditioned on ɐː 1.0000000000000027
# Sum of conditional probabilities conditioned on n 0.9999999999999984
# Sum of conditional probabilities conditioned on ʙ̩ː 1.0000000000000027
# Sum of conditional probabilities conditioned on ʌ 0.9999999999999972
# Sum of conditional probabilities conditioned on n̩ 0.9999999999999997
# Sum of conditional probabilities conditioned on ɯ 1.0000000000000027
# Sum of conditional probabilities conditioned on w 0.9999999999999983
# Sum of conditional probabilities conditioned on tᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɜ 1.0000000000000007
# Sum of conditional probabilities conditioned on oː 1.0000000000000027
# Sum of conditional probabilities conditioned on ŭ̥ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɪ 0.9999999999999986
# Sum of conditional probabilities conditioned on ɚ 1.0000000000000029
# Sum of conditional probabilities conditioned on ɪ̯ 0.9999999999999982
# Sum of conditional probabilities conditioned on ø 1.0000000000000027
# Sum of conditional probabilities conditioned on ɝː 0.9999999999999979
# Sum of conditional probabilities conditioned on ɝ 0.9999999999999978
# Sum of conditional probabilities conditioned on c 1.0000000000000027
# Sum of conditional probabilities conditioned on ɹ 1.0000000000000022
# Sum of conditional probabilities conditioned on ĭ̥ 1.0000000000000027
# Sum of conditional probabilities conditioned on bʲ 1.0000000000000024
# Sum of conditional probabilities conditioned on l͡s 1.0000000000000027
# Sum of conditional probabilities conditioned on l 1.0000000000000024
# Sum of conditional probabilities conditioned on m̩ː 1.0000000000000027
# Sum of conditional probabilities conditioned on ṽ 1.0000000000000027
# Sum of conditional probabilities conditioned on ə 0.9999999999999983
# Sum of conditional probabilities conditioned on ɛ̃ 1.000000000000002
# Sum of conditional probabilities conditioned on ɒ̃ 1.0000000000000018
# Sum of conditional probabilities conditioned on ɬ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɜ̃ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʌ̈ 1.0000000000000027
# Sum of conditional probabilities conditioned on t͡ʃ̩̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɡ 0.9999999999999981
# Sum of conditional probabilities conditioned on äː 1.0000000000000027
# Sum of conditional probabilities conditioned on əʳ 1.0000000000000027
# Sum of conditional probabilities conditioned on dʲ 1.0000000000000022
# Sum of conditional probabilities conditioned on ʈ 1.000000000000002
# Sum of conditional probabilities conditioned on tː 1.0000000000000027
# Sum of conditional probabilities conditioned on ð 0.9999999999999989
# Sum of conditional probabilities conditioned on kᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ͡ɹ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɦ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɽ 1.0000000000000024
# Sum of conditional probabilities conditioned on d 1.0000000000000027
# Sum of conditional probabilities conditioned on q 1.0000000000000024
# Sum of conditional probabilities conditioned on ɔː 1.000000000000001
# Sum of conditional probabilities conditioned on ɕː 1.0000000000000027
# Sum of conditional probabilities conditioned on æː 1.0000000000000007
# Sum of conditional probabilities conditioned on r 1.0000000000000018
# Sum of conditional probabilities conditioned on ɛˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on j 1.0000000000000007
# Sum of conditional probabilities conditioned on t̬ 1.0000000000000007
# Sum of conditional probabilities conditioned on ʊ 0.9999999999999988
# Sum of conditional probabilities conditioned on START 1.0000000000000016
# Sum of conditional probabilities conditioned on ʃː 1.0000000000000047
# Sum of conditional probabilities conditioned on ɵ̞ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʃ 0.9999999999999991
# Sum of conditional probabilities conditioned on œ 1.0000000000000027
# Sum of conditional probabilities conditioned on h 1.0
# Sum of conditional probabilities conditioned on p 0.9999999999999992
# Sum of conditional probabilities conditioned on t̬ᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on m 0.9999999999999996
# Sum of conditional probabilities conditioned on əː 1.0000000000000018
# Sum of conditional probabilities conditioned on ə̆ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ 0.9999999999999984
# Sum of conditional probabilities conditioned on ɑ 1.000000000000001
# Sum of conditional probabilities conditioned on s 1.0000000000000024
# Sum of conditional probabilities conditioned on ʉ 1.000000000000002
# Sum of conditional probabilities conditioned on pʰ 1.0000000000000049
# Sum of conditional probabilities conditioned on mː 1.0000000000000024
# Sum of conditional probabilities conditioned on ô 1.0000000000000027
# Sum of conditional probabilities conditioned on ɨ 1.0000000000000022
# Sum of conditional probabilities conditioned on ʌː 1.0000000000000024
# Sum of conditional probabilities conditioned on l̩ 1.0000000000000073
# Sum of conditional probabilities conditioned on uː 1.0000000000000009
# Sum of conditional probabilities conditioned on x 1.000000000000004
# Sum of conditional probabilities conditioned on ɪː 1.000000000000002
# Sum of conditional probabilities conditioned on ʏ 1.0000000000000024
# Sum of conditional probabilities conditioned on ʁ 1.0000000000000024
# Sum of conditional probabilities conditioned on o 1.0000000000000002
# Sum of conditional probabilities conditioned on z 1.0000000000000067
# Sum of conditional probabilities conditioned on aː 0.9999999999999971

# %% [markdown]
# ### Congratulations!  You have created a Markov chain.
#
# Now use it to generate pseudo-words.

# %%
# specifically, let's generate 20 pseudo-words.
for i in range(20):
    # for each pseudo-word, we start by setting state to 'START'.
    state = 'START'
    print(state, end='')   # print state, but no newline.

    # now keep repeating this until you arrive at the 'STOP' state
    while (state != 'STOP'):
        next_state_options = list(tp[state].keys())
        next_state_probs = list(tp[state].values())
        new_state = np.random.choice(next_state_options, p=next_state_probs)
        print(" ", new_state, end='')
        state = new_state
    print(); print()
# Out:
# START  s  t  a  ʊ  v  ɪ  m  ɪ  ʃ  ə  n  h  ɝ  d  STOP
#
# START  d  ʒ  ə  t  ə  n  d  ʒ  ɛ  d  STOP
#
# START  b  ɝ  d  ʒ  ə  l  ʌ  n  ə  z  STOP
#
# START  t  ə  n  ɛ  f  k  ə  l  ɪ  s  ɛ  f  ə  n  ɪ  d  e  ɪ  l  i  STOP
#
# START  ʃ  p  ɪ  k  ə  STOP
#
# START  p  æ  t  ɹ  i  STOP
#
# START  ɡ  ə  STOP
#
# START  ə  l  ɬ  fː  ɝ  l  æ  k  STOP
#
# START  s  o  ʊ  STOP
#
# START  s  l  STOP
#
# START  ɡ  o  ʊ  ɛ  ʒ  ɪ  t  e  ɪ  t  STOP
#
# START  k  j  ʌ  n  ə  ɹ  ɪ  k  STOP
#
# START  d  STOP
#
# START  b  ɹ  ɑ  z  e  ɪ  ʃ  ə  t  ɑ  n  t  h  ɪ  t  s  ɪ  z  ɪ  ŋ  z  ɪ  k  ə  m  ɪ  n  ɒ  n  ɒ  ɹ  STOP
#
# START  æ  k  ɪ  ɡ  ɹ  θ  ə  k  s  t  ə  b  ɹ  ɛ̝  ʊ̯  l  ɪ  k  e  ɪ  ŋ  STOP
#
# START  k  STOP
#
# START  ɹ  i  STOP
#
# START  h  ɑ  ɹ  t  ʃ  STOP
#
# START  e  ɪ  z  STOP
#
# START  s  t  e  ɪ  t  l  STOP

# %% [markdown]
# OK, that seemed to more or less work.  We get some reasonable-looking outputs, and also some that look a little strange.
#
# Now, just to highlight how natural some of the stranger-looking outputs we just saw were, we'll try the same thing, but flipping the roles of $p_1$ and $p_2$ in the counts.  That is, when we see the bigram $p_1 p_2$, we increment the count for $p_2 p_1$.
#
# What does this do?  It rewards or strengthens transitions that tend to show up in the **opposite order** from that actually encountered.
#
# What sort of output should we predict?
#
# **[ YOUR ANSWER GOES HERE. ]**
#
# **1. Each output word tend to be very long, often with multiple encounters with "START" in the middle before getting to "STOP."**
#
# **2. The combination of phonemes in each output word will sound more natural when read backwards then read normally.**

# %%
# generate transition probabilities from counts again, but this time with p1 and p2 swapped, 
# as described above.  this will be a lightly but strategically edited variant of a code box
# above.
tp_swapped = dict()  # transition probs
for p1 in phonemes:
    d = dict()
    # YOUR CODE GOES HERE.
    p1_total = 0
    for key in ptc.keys():
        p1_total += ptc[key] if key[1] == p1 else 0
    for p2 in phonemes:
        d[p2] = ptc[(p2, p1)] / p1_total
    
    tp_swapped[p1] = d

# %%
# now generate 20 pseudo-words with these swapped transition probabilities.
for i in range(20):
    # for each pseudo-word, we start by setting state to 'START'.
    state = 'START'
    print(state, end='')   # print state, but no newline.

    # now keep repeating this until you arrive at the 'STOP' state
    while (state != 'STOP'):
        next_state_options = list(tp_swapped[state].keys())
        next_state_probs = list(tp_swapped[state].values())
        new_state = np.random.choice(next_state_options, p=next_state_probs)
        print(" ", new_state, end='')
        state = new_state
    print(); print()
# Out:
# START  lʲ  fː  q  õ  z  ɑː  z  æ  START  ɛ͡ɹ  iː  ʒ  əː  ʌː  ɪ̪  ɲ  f  START  e͜ɚ  äː  uː  s  START  ɘ  k  ɪ  START  ʉ  ʌ̈  äː  ɱ  ɛ̝  ɑ̃  ɲ  ʃʰ  ē  bʲ  o͡ʊ  ɵ  ʃː  ú  ɾ  t̬  e͡ɪ  ɪː  iː  n  ʊ  o  z  ɹ  ə  n  ɪ  k  START  dʲ  ɒː  æ̃  ʉː  ɹ̩  mː  ä  ô  k̚  nː  dʰ  ɭ  iː  ɹ  i  d  n  START  ɔː  k  ɛ  ʒ  ɪ̈  ɐː  t  i  t  s  START  t͡ʃ̩̩  t̬ᵊ  ɡː  ɔ  n  æ  k  START  ɻ  ʌː  ð  ɪ  l  ɡ  START  ʌ  s  n  æ  START  y  a  START  ɹ  b  æ  p  ɑ  d  START  ʊ̆  ʔ  ɹː  q  n  ɪ  e  l  k  START  bʲ  j  n  æ  ɹ  t  k  æ  k  START  ú  h  e͡ɪ  tᵊ  ɬ  ɪ  s  æ  h  ʊ  o  d͡ʒ  ɪ  e  ɹ  ə  d  æ  ɡ  START  x  ĭ̥  ɱ  oˀ  ʒ  d  ɪ  a  k  START  t͡s  ɡ  z  m  ɛ  n  æ  ɹ  k  START  ɘ  ɖ  ɛ  START  nˡ  uː  t  ə  s  START  bᵊ  t͡ʃʰ  ç  oː  nˡ  ʊ̯  ɻ  ɪ̈  ɡ  ɑ  p  m  ʊ  ə  START  fː  ɑ  p  m  ʃ  æ  START  õ  tː  y  j  t  ɛ  START  ʀ  ɜ  ʒ  d  n  ɪ  w  START  ʊ̩  ʌ̈  x  ɖ  m̩  ɛˑ  ʉː  ú  t͡ʃ̩̩  ʊ̪  e͜ɚ  ɝː  p  ɑ  b  ə  START  ːs  ʃ  ɪ  m  START  oː  ɵ̞  ɡː  z  bʲ  ɛː  h  t  s  k  ʊ  f  ɑ  p  START  eː  l͡s  ɪ̯  a  ɹ  ɛ  n  ɪ  f  ə  ɡ  ɛ  tʰ  p̬  ʉː  j  k  ə  ɡ  ʌ  z  n  ɪ  a  b  START  ʃʰ  ɐː  ʌː  ã  ʊ̩  ʌː  ɒː  ɡ  ɻ  o͡ʊ  lʲ  ɔ  q  ʀ  ʀ  ɪʲ  nˡ  ʊː  STOP
#
�̝  ʉː  aː  m̩ː  mː  o͡ʊ  ʉ  ʔ  ɒ  s  START  l͡s  ʀ  ʃː  ɵ  kʰ  ʏ  t̬ᵊ  lʲ  ɑː  START  ɽ  o  p  START  ĩ  ʁ  ɾ̃  ə̯  w  k  ɪ  e  l  ə  iː  s  START  k̚  əˑ  ṽ  ɕː  ĭ̥  ʃː  fː  ʔ  t  ɛ  f  START  ʊ̩  k  ɪ  s  ɪ  a  ɡ  t  ʌ  b  START  ʊ  a  START  ɜ̃  y  ʊ̯  o  t  s  n̩  t  START  t͡ʃ̩̩  ɛˑ  ô  ɔ̃  ṽ  ɻ  ø  ʍ  START  ɪ̯  a  ɹ  ɛ  ɹ  ə  START  əˑ  lʲ  ɛ͡ɪ  ɛ  START  o͡ʊ  s  ə  b  m  ə  k  ɹ  ə  ɹ  ɑ  w  START  t͡ʃʰ  pː  n  ə  START  ɲ  l̩  b  t  ə  START  ç  ɪˑ  ɔː  kᵊ  uː  j  START  ʊ̯  ɾ̃  ʁ  dʰ  ɔ  k  ʊ  o  ɹ  ɪ  e  START  t͡ɕ  w  ɡ  ɪ  a  b  e  s  b  æ  ɹ  ɑ  kʰ  nˡ  ã  ɜ̃  bᵊ  dʰ  l͡s  ä  ɜ  ɐː  fː  ʈ  t͡ʃʰ  oː  ʊ  o  l  ə  t͡ʃ  ʉ  ʉ  ɡ  START  t͡ʃʰ  ɛː  ð  START  ʉː  ʉ  w  s  ə  k  ʌ  w  ə  n  ɒ  n  b  START  ə̆  b  ɪ  e  f  START  ɲ  ɚː  m  START  ð  ɪ  t  ə  ʃ  ɪ  START  o  f  l  ɛ  h  START  nː  ɭ  t  ɪ  e  m  ɒ  t  s  ɚ  v  ɪ  ɹ  p  START  lʲ  ~  t͡ʃ  uː  d͡ʒ  n  ɪ  l  START  t͡ʃʰ  æ̃  d  ɪ  t  ɪ  s  ə  ʃ  t  s  ɛ  ʒ  ɑː  h  START  ɝ  s  t  ə  ɡ  ŋ  ɪ  f  START  ē  äː  STOP

# %% [markdown]
# # Observations
#
# - Write your general observations about the results here.  A few short sentences would be fine.
#
# It seems that phoneme transition probabilities are generally good at generating English pseudo-words, i.e., words that comply with the "rules" of English pronunciation, except for several single-phoneme ones. However, it is reasonable to speculate that transition probability alone probably does not generate well to words (i.e., generating sentences that comply with rules of English grammar). On the one hand, it may generate sentences that are statistically probable but ungrammatical, e.g., "I like to the cafeteria;" on the other hand, it cannot generate sentences that are grammatically but meaningless, such as the good o old "colorless green ideas sleep furiously." Therefore, the behaviorist view of a "sequential" language has its limitations. Sentential grammar is more than a sequence probability; that is where other views of language, such as the generative grammar of Chomsky, come in.

# %% [markdown]
# # Extensions (optional)
#
# - Do the same thing for other languages.  See [here](https://github.com/kylebgorman/wikipron/tree/master/data) for analogous WikiPron data from other languages, in the same format as the data we've used here.
# - Do the same thing for words rather than phonemes.  You could download a book in plain text from [Project Gutenberg](https://www.gutenberg.org/ebooks/search/?sort_order=downloads), and proceed from there.
