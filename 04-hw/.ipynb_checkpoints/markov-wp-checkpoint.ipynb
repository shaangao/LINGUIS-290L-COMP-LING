# %% [markdown]
# # Generate pseudo-words using a Markov chain
#
# - We will read in a dataset of English words, with pronunciations, calculate phoneme transition probabilities from the data, and then use those phoneme transition probabilities to generate pseudo-words that follow the phonotactic probabilities of English.
# - This is essentially a simple Markov chain.  Every phoneme is a state - specifically, being in the state corresponding to phoneme $p$ means that we have just seen phoneme $p$.  Transition probabilities from state $p$ to some other state $q$ are determined from bigrams in the data.  How?
# - A bigram is a pair of consecutive symbolic units - in this case phonemes.  Thus transition probabilities such as $P(p_2|p_1)$ represent the probability of moving from the state that denotes our having just seen phoneme $p_1$ to the state that denotes our having just seen phoneme $p_2$;  this probability is determined by the relative frequency of encountering $p_2$ in the data, given that we have just seen $p_1$.
# - This notebook again uses [WikiPron](https://github.com/kylebgorman/wikipron), but this time we consider US pronunciation for English.  Analogous data for many other languages, in the same format, is available [here](https://github.com/kylebgorman/wikipron/tree/master/data), which you can download and use for extensions.

# %%
import re
import pandas as pd
import numpy as np
import unicodedata
import random

# %% [markdown]
# ### Read in data
#
# And format it so that pulling out phoneme transitions will be easy.

# %%
# read in english words.  
df = pd.read_csv("eng_us_phonemic.tsv", sep='\t', names=['Word', 'Pron'])
df.Pron = df.Pron.str.split()  # turn space-separated strings into lists of phonemes
df
# Out:
#              Word                            Pron
# 0          $deity              [d, e, ɪ, ɪ, t, i]
# 1          $deity                [d, iː, ɪ, t, i]
# 2          'cause                       [k, ʌ, z]
# 3       'dswounds           [d, z, w, u, n, d, z]
# 4             'em                            [m̩]
# ...           ...                             ...
# 53394     œconomy          [ɪː, k, ɒ, n, ɒ, m, i]
# 53395       œneus                [ɛ, n, j, uː, s]
# 53396       ǃkung                       [k, u, ŋ]
# 53397       ǃkung                       [k, ʊ, ŋ]
# 53398  ξυλάγγουρο  [k, s, i, l, a, ŋ, ɡ, u, ɾ, o]
#
# [53399 rows x 2 columns]

# %%
# sanity check
# find the US pronunciation of the word "aardvark"
df[df.Word=='aardvark']
# Out:
#         Word                   Pron
# 67  aardvark  [ɑ, ɹ, d, v, ɑ, ɹ, k]

# %%
# sanity check - and a chance to introduce the very useful pandas "sample" routine.
# find the US pronunciation of several other words.
df.sample(n=25)
# Out:
#               Word                                Pron
# 51772          wff                           [w, ʊ, f]
# 6088        beamer                        [b, i, m, ɚ]
# 39941      reading                     [ɹ, i, d, i, ŋ]
# 14694      deshler                  [d, ɛ, ʃ, l, ə, ɹ]
# 35586   parasitism  [p, æ, ɹ, ə, s, a, ɪ, t, ɪ, z, m̩]
# 9885      cesspool                 [s, ɛ, s, p, uː, l]
# 14393       deleon                  [d, ə, l, i, ɑ, n]
# 15505  distressing         [d, ɪ, s, t, ɹ, ɛ, s, ɪ, ŋ]
# 37237        plate                     [p, l, e, ɪ, t]
# 30573     martinet            [m, æ, ɹ, t, ɪ, n, ɛ, t]
# 29503       lorenz                  [l, ə, ɹ, ɛ, n, z]
# 46336      sulfate               [s, ʌ, l, f, e, ɪ, t]
# 26          'scuse                    [s, k, j, uː, z]
# 6404       beloved               [b, ɪ, l, ʌ, v, ɪ, d]
# 37871    posterize      [p, ə, ʊ, s, t, ə, ɹ, a, ɪ, z]
# 1604    acephalous            [ə, s, ɛ, f, ə, l, ə, s]
# 45989       string                     [s, t, ɹ, ɪ, ŋ]
# 11346      coconut            [k, o, ʊ, k, ə, n, ʌ, t]
# 13777        dacha                     [d, æ, t, ʃ, ə]
# 40718    requisite            [ɹ, ɛ, k, w, ɪ, z, ɪ, t]
# 13891        dance                        [d, æ, n, s]
# 38601     promises            [p, ɹ, ɑ, m, ɪ, s, ɪ, z]
# 8333         bugan                     [b, ʊ, ɡ, ə, n]
# 23624     hematoma         [h, i, m, ə, t, o, ʊ, m, ə]
# 45649       stench                  [s, t, ɛ, n, t, ʃ]

# %%
# now add START and STOP pseudo-phonemes at beginning and end of each word.
# a chance to introduce the very useful pandas "apply" routine.
df.Pron = df.Pron.apply(lambda x: ['START'] + x + ['STOP'])
df
# Out:
#              Word                                         Pron
# 0          $deity              [START, d, e, ɪ, ɪ, t, i, STOP]
# 1          $deity                [START, d, iː, ɪ, t, i, STOP]
# 2          'cause                       [START, k, ʌ, z, STOP]
# 3       'dswounds           [START, d, z, w, u, n, d, z, STOP]
# 4             'em                            [START, m̩, STOP]
# ...           ...                                          ...
# 53394     œconomy          [START, ɪː, k, ɒ, n, ɒ, m, i, STOP]
# 53395       œneus                [START, ɛ, n, j, uː, s, STOP]
# 53396       ǃkung                       [START, k, u, ŋ, STOP]
# 53397       ǃkung                       [START, k, ʊ, ŋ, STOP]
# 53398  ξυλάγγουρο  [START, k, s, i, l, a, ŋ, ɡ, u, ɾ, o, STOP]
#
# [53399 rows x 2 columns]

# %% [markdown]
# ### Get bigram conditional probabilities for each pair of phonemes

# %%
# start by getting the set of all phonemes in the dataset.
# we will have one state for each phoneme.
phonemes = set([p for l in df.Pron for p in l])
print(len(phonemes))
print(phonemes)
# Out:
# 186
# {'ʏ', 'ʃː', 'ð', 'ŭ̥', 'ɖ', 'lʲ', 'n̩', 'ɪ̯', 'tʰ', 'ʙ̩ː', 'd', 'u', 'eː', 'ɹ̩', 'ɕː', 'x', 'd̪', 'dʲ', 'ʌ̈', 'ɹ', 'm', 'k̚', 'ə̯', 'r̩', 'mː', 'ɣ', 'aː', 'c', 'ʌː', 'ɪˑ', 'p', 'ɛ', 't͡s', 'ʊ̩', 'l', 'ɡː', 'ɲ', 'bʲ', 's', 'ɔ', 'ɘ', 'l̩', 'l͡s', 'oˀ', 'pʰ', 'ʊ̪', 'j', 'ɜ', '˞', 'w', 'œ', 'æː', 'ɝː', 'ä', 'ɑ', 'ʈ', 'ɭ', 'ɝ', 'v', 'ɔ͡ɪ', 'ʃʰ', 'n', 'kᵊ', 'õ', 'p̬', 't͡ʃ̩̩', 'uː', 'ʉː', 'ú', 'ɵ̞', 'fː', 't͡ɕ', 'əˑ', 'ĭ̥', 'ʌ', 'ɑː', 'ɔ̃', 'o͡ʊ', 'h', 'ɑˑ', 'e', 'ŋ', 'o̞', 'ɛ͡ɹ', 'χ', 'ɡ', 'iː', 'q', 'ɫ̩', '~', 'ṽ', 'a', 'bᵊ', 'ɾ', 'ɒː', 'ɪ̈', 'ɔː', 'ʊ̯', 'ɪ̪', 'm̩ː', 'ɦ', 'ɱ', 'START', 'ɪ', 'ə', 'ɪː', 'ɑ̃', 'kʰ', 'nː', 'ə̆', 'ø', 'ʍ', 't͡ʃ', 'e͡ɪ', 'ɨ', 'əʳ', 'ô', 't', 'ɫ', 'ʀ', 'ɜː', 'oː', 'ɜ̃', 'ɵ', 'tː', 'ʊ̂', 'ɪʲ', 'ɽ', 'ɹʷ', 'ɒ̃', 'ɹː', '↓', 'ɬ', 'ɛ͡ɪ', 'ē', 'ɯ', 'ɛː', 'ĭ', 'ʉ', 'θ', 't̬ᵊ', 'ɚ', 'o', 'ĩ', 'ɛ̃', 'k', 'ʊ̆', 'd͡ʒ', 'ʊ', 'əː', 'z', 'e͜ɚ', 'm̩', 'ɛ̝', 'ɛˑ', 'sː', 'nˡ', 'tᵊ', 'ç', 'ʁ', 'i', 'îː', 'dʰ', 'æ', 't͡ʃʰ', 'STOP', 'äː', 'ʃ', 'ɒ', 'y', 'pː', 'r', 'ɐ', 'ɾ̃', 't̬', 'ʒ', 'ã', 'ʊː', 'ɚː', 'ːs', 'ʔ', 'f', 'ɐː', 'ɻ', 'æ̃', 'b'}

# %% [markdown]
# Now get simple phoneme transition **counts** for every pair of phonemes.  Later, we will turn these into probabilities.
#
# We will use [Laplace (add-one) smoothing](https://en.wikipedia.org/wiki/Additive_smoothing), which means that every phoneme pair gets a "freebie" count of 1 to start with, before actually seeing any data.  Ask me why we might want to do such a thing.

# %%
# ptc = phoneme transition counts.
# every count is indexed by a tuple of 2 phonemes: (p1, p2).
# here, we start by initializing each count with 1: add-one smoothing.
ptc = {(p1,p2):1 for p1 in phonemes for p2 in phonemes}
ptc
# Out:
# {('ʏ', 'ʏ'): 1,
#  ('ʏ', 'ʃː'): 1,
#  ('ʏ', 'ð'): 1,
#  ('ʏ', 'ŭ̥'): 1,
#  ('ʏ', 'ɖ'): 1,
#  ('ʏ', 'lʲ'): 1,
#  ('ʏ', 'n̩'): 1,
#  ('ʏ', 'ɪ̯'): 1,
#  ('ʏ', 'tʰ'): 1,
#  ('ʏ', 'ʙ̩ː'): 1,
#  ('ʏ', 'd'): 1,
#  ('ʏ', 'u'): 1,
#  ('ʏ', 'eː'): 1,
#  ('ʏ', 'ɹ̩'): 1,
#  ('ʏ', 'ɕː'): 1,
#  ('ʏ', 'x'): 1,
#  ('ʏ', 'd̪'): 1,
#  ('ʏ', 'dʲ'): 1,
#  ('ʏ', 'ʌ̈'): 1,
#  ('ʏ', 'ɹ'): 1,
#  ('ʏ', 'm'): 1,
#  ('ʏ', 'k̚'): 1,
#  ('ʏ', 'ə̯'): 1,
#  ('ʏ', 'r̩'): 1,
#  ('ʏ', 'mː'): 1,
#  ('ʏ', 'ɣ'): 1,
#  ('ʏ', 'aː'): 1,
#  ('ʏ', 'c'): 1,
#  ('ʏ', 'ʌː'): 1,
#  ('ʏ', 'ɪˑ'): 1,
#  ('ʏ', 'p'): 1,
#  ('ʏ', 'ɛ'): 1,
#  ('ʏ', 't͡s'): 1,
#  ('ʏ', 'ʊ̩'): 1,
#  ('ʏ', 'l'): 1,
#  ('ʏ', 'ɡː'): 1,
#  ('ʏ', 'ɲ'): 1,
#  ('ʏ', 'bʲ'): 1,
#  ('ʏ', 's'): 1,
#  ('ʏ', 'ɔ'): 1,
#  ('ʏ', 'ɘ'): 1,
#  ('ʏ', 'l̩'): 1,
#  ('ʏ', 'l͡s'): 1,
#  ('ʏ', 'oˀ'): 1,
#  ('ʏ', 'pʰ'): 1,
#  ('ʏ', 'ʊ̪'): 1,
#  ('ʏ', 'j'): 1,
#  ('ʏ', 'ɜ'): 1,
#  ('ʏ', '˞'): 1,
#  ('ʏ', 'w'): 1,
#  ('ʏ', 'œ'): 1,
#  ('ʏ', 'æː'): 1,
#  ('ʏ', 'ɝː'): 1,
#  ('ʏ', 'ä'): 1,
#  ('ʏ', 'ɑ'): 1,
#  ('ʏ', 'ʈ'): 1,
#  ('ʏ', 'ɭ'): 1,
#  ('ʏ', 'ɝ'): 1,
#  ('ʏ', 'v'): 1,
#  ('ʏ', 'ɔ͡ɪ'): 1,
#  ('ʏ', 'ʃʰ'): 1,
#  ('ʏ', 'n'): 1,
#  ('ʏ', 'kᵊ'): 1,
#  ('ʏ', 'õ'): 1,
#  ('ʏ', 'p̬'): 1,
#  ('ʏ', 't͡ʃ̩̩'): 1,
#  ('ʏ', 'uː'): 1,
#  ('ʏ', 'ʉː'): 1,
#  ('ʏ', 'ú'): 1,
#  ('ʏ', 'ɵ̞'): 1,
#  ('ʏ', 'fː'): 1,
#  ('ʏ', 't͡ɕ'): 1,
#  ('ʏ', 'əˑ'): 1,
#  ('ʏ', 'ĭ̥'): 1,
#  ('ʏ', 'ʌ'): 1,
#  ('ʏ', 'ɑː'): 1,
#  ('ʏ', 'ɔ̃'): 1,
#  ('ʏ', 'o͡ʊ'): 1,
#  ('ʏ', 'h'): 1,
#  ('ʏ', 'ɑˑ'): 1,
#  ('ʏ', 'e'): 1,
#  ('ʏ', 'ŋ'): 1,
#  ('ʏ', 'o̞'): 1,
#  ('ʏ', 'ɛ͡ɹ'): 1,
#  ('ʏ', 'χ'): 1,
#  ('ʏ', 'ɡ'): 1,
#  ('ʏ', 'iː'): 1,
#  ('ʏ', 'q'): 1,
#  ('ʏ', 'ɫ̩'): 1,
#  ('ʏ', '~'): 1,
#  ('ʏ', 'ṽ'): 1,
#  ('ʏ', 'a'): 1,
#  ('ʏ', 'bᵊ'): 1,
#  ('ʏ', 'ɾ'): 1,
#  ('ʏ', 'ɒː'): 1,
#  ('ʏ', 'ɪ̈'): 1,
#  ('ʏ', 'ɔː'): 1,
#  ('ʏ', 'ʊ̯'): 1,
#  ('ʏ', 'ɪ̪'): 1,
#  ('ʏ', 'm̩ː'): 1,
#  ('ʏ', 'ɦ'): 1,
#  ('ʏ', 'ɱ'): 1,
#  ('ʏ', 'START'): 1,
#  ('ʏ', 'ɪ'): 1,
#  ('ʏ', 'ə'): 1,
#  ('ʏ', 'ɪː'): 1,
#  ('ʏ', 'ɑ̃'): 1,
#  ('ʏ', 'kʰ'): 1,
#  ('ʏ', 'nː'): 1,
#  ('ʏ', 'ə̆'): 1,
#  ('ʏ', 'ø'): 1,
#  ('ʏ', 'ʍ'): 1,
#  ('ʏ', 't͡ʃ'): 1,
#  ('ʏ', 'e͡ɪ'): 1,
#  ('ʏ', 'ɨ'): 1,
#  ('ʏ', 'əʳ'): 1,
#  ('ʏ', 'ô'): 1,
#  ('ʏ', 't'): 1,
#  ('ʏ', 'ɫ'): 1,
#  ('ʏ', 'ʀ'): 1,
#  ('ʏ', 'ɜː'): 1,
#  ('ʏ', 'oː'): 1,
#  ('ʏ', 'ɜ̃'): 1,
#  ('ʏ', 'ɵ'): 1,
#  ('ʏ', 'tː'): 1,
#  ('ʏ', 'ʊ̂'): 1,
#  ('ʏ', 'ɪʲ'): 1,
#  ('ʏ', 'ɽ'): 1,
#  ('ʏ', 'ɹʷ'): 1,
#  ('ʏ', 'ɒ̃'): 1,
#  ('ʏ', 'ɹː'): 1,
#  ('ʏ', '↓'): 1,
#  ('ʏ', 'ɬ'): 1,
#  ('ʏ', 'ɛ͡ɪ'): 1,
#  ('ʏ', 'ē'): 1,
#  ('ʏ', 'ɯ'): 1,
#  ('ʏ', 'ɛː'): 1,
#  ('ʏ', 'ĭ'): 1,
#  ('ʏ', 'ʉ'): 1,
#  ('ʏ', 'θ'): 1,
#  ('ʏ', 't̬ᵊ'): 1,
#  ('ʏ', 'ɚ'): 1,
#  ('ʏ', 'o'): 1,
#  ('ʏ', 'ĩ'): 1,
#  ('ʏ', 'ɛ̃'): 1,
#  ('ʏ', 'k'): 1,
#  ('ʏ', 'ʊ̆'): 1,
#  ('ʏ', 'd͡ʒ'): 1,
#  ('ʏ', 'ʊ'): 1,
#  ('ʏ', 'əː'): 1,
#  ('ʏ', 'z'): 1,
#  ('ʏ', 'e͜ɚ'): 1,
#  ('ʏ', 'm̩'): 1,
#  ('ʏ', 'ɛ̝'): 1,
#  ('ʏ', 'ɛˑ'): 1,
#  ('ʏ', 'sː'): 1,
#  ('ʏ', 'nˡ'): 1,
#  ('ʏ', 'tᵊ'): 1,
#  ('ʏ', 'ç'): 1,
#  ('ʏ', 'ʁ'): 1,
#  ('ʏ', 'i'): 1,
#  ('ʏ', 'îː'): 1,
#  ('ʏ', 'dʰ'): 1,
#  ('ʏ', 'æ'): 1,
#  ('ʏ', 't͡ʃʰ'): 1,
#  ('ʏ', 'STOP'): 1,
#  ('ʏ', 'äː'): 1,
#  ('ʏ', 'ʃ'): 1,
#  ('ʏ', 'ɒ'): 1,
#  ('ʏ', 'y'): 1,
#  ('ʏ', 'pː'): 1,
#  ('ʏ', 'r'): 1,
#  ('ʏ', 'ɐ'): 1,
#  ('ʏ', 'ɾ̃'): 1,
#  ('ʏ', 't̬'): 1,
#  ('ʏ', 'ʒ'): 1,
#  ('ʏ', 'ã'): 1,
#  ('ʏ', 'ʊː'): 1,
#  ('ʏ', 'ɚː'): 1,
#  ('ʏ', 'ːs'): 1,
#  ('ʏ', 'ʔ'): 1,
#  ('ʏ', 'f'): 1,
#  ('ʏ', 'ɐː'): 1,
#  ('ʏ', 'ɻ'): 1,
#  ('ʏ', 'æ̃'): 1,
#  ('ʏ', 'b'): 1,
#  ('ʃː', 'ʏ'): 1,
#  ('ʃː', 'ʃː'): 1,
#  ('ʃː', 'ð'): 1,
#  ('ʃː', 'ŭ̥'): 1,
#  ('ʃː', 'ɖ'): 1,
#  ('ʃː', 'lʲ'): 1,
#  ('ʃː', 'n̩'): 1,
#  ('ʃː', 'ɪ̯'): 1,
#  ('ʃː', 'tʰ'): 1,
#  ('ʃː', 'ʙ̩ː'): 1,
#  ('ʃː', 'd'): 1,
#  ('ʃː', 'u'): 1,
#  ('ʃː', 'eː'): 1,
#  ('ʃː', 'ɹ̩'): 1,
#  ('ʃː', 'ɕː'): 1,
#  ('ʃː', 'x'): 1,
#  ('ʃː', 'd̪'): 1,
#  ('ʃː', 'dʲ'): 1,
#  ('ʃː', 'ʌ̈'): 1,
#  ('ʃː', 'ɹ'): 1,
#  ('ʃː', 'm'): 1,
#  ('ʃː', 'k̚'): 1,
#  ('ʃː', 'ə̯'): 1,
#  ('ʃː', 'r̩'): 1,
#  ('ʃː', 'mː'): 1,
#  ('ʃː', 'ɣ'): 1,
#  ('ʃː', 'aː'): 1,
#  ('ʃː', 'c'): 1,
#  ('ʃː', 'ʌː'): 1,
#  ('ʃː', 'ɪˑ'): 1,
#  ('ʃː', 'p'): 1,
#  ('ʃː', 'ɛ'): 1,
#  ('ʃː', 't͡s'): 1,
#  ('ʃː', 'ʊ̩'): 1,
#  ('ʃː', 'l'): 1,
#  ('ʃː', 'ɡː'): 1,
#  ('ʃː', 'ɲ'): 1,
#  ('ʃː', 'bʲ'): 1,
#  ('ʃː', 's'): 1,
#  ('ʃː', 'ɔ'): 1,
#  ('ʃː', 'ɘ'): 1,
#  ('ʃː', 'l̩'): 1,
#  ('ʃː', 'l͡s'): 1,
#  ('ʃː', 'oˀ'): 1,
#  ('ʃː', 'pʰ'): 1,
#  ('ʃː', 'ʊ̪'): 1,
#  ('ʃː', 'j'): 1,
#  ('ʃː', 'ɜ'): 1,
#  ('ʃː', '˞'): 1,
#  ('ʃː', 'w'): 1,
#  ('ʃː', 'œ'): 1,
#  ('ʃː', 'æː'): 1,
#  ('ʃː', 'ɝː'): 1,
#  ('ʃː', 'ä'): 1,
#  ('ʃː', 'ɑ'): 1,
#  ('ʃː', 'ʈ'): 1,
#  ('ʃː', 'ɭ'): 1,
#  ('ʃː', 'ɝ'): 1,
#  ('ʃː', 'v'): 1,
#  ('ʃː', 'ɔ͡ɪ'): 1,
#  ('ʃː', 'ʃʰ'): 1,
#  ('ʃː', 'n'): 1,
#  ('ʃː', 'kᵊ'): 1,
#  ('ʃː', 'õ'): 1,
#  ('ʃː', 'p̬'): 1,
#  ('ʃː', 't͡ʃ̩̩'): 1,
#  ('ʃː', 'uː'): 1,
#  ('ʃː', 'ʉː'): 1,
#  ('ʃː', 'ú'): 1,
#  ('ʃː', 'ɵ̞'): 1,
#  ('ʃː', 'fː'): 1,
#  ('ʃː', 't͡ɕ'): 1,
#  ('ʃː', 'əˑ'): 1,
#  ('ʃː', 'ĭ̥'): 1,
#  ('ʃː', 'ʌ'): 1,
#  ('ʃː', 'ɑː'): 1,
#  ('ʃː', 'ɔ̃'): 1,
#  ('ʃː', 'o͡ʊ'): 1,
#  ('ʃː', 'h'): 1,
#  ('ʃː', 'ɑˑ'): 1,
#  ('ʃː', 'e'): 1,
#  ('ʃː', 'ŋ'): 1,
#  ('ʃː', 'o̞'): 1,
#  ('ʃː', 'ɛ͡ɹ'): 1,
#  ('ʃː', 'χ'): 1,
#  ('ʃː', 'ɡ'): 1,
#  ('ʃː', 'iː'): 1,
#  ('ʃː', 'q'): 1,
#  ('ʃː', 'ɫ̩'): 1,
#  ('ʃː', '~'): 1,
#  ('ʃː', 'ṽ'): 1,
#  ('ʃː', 'a'): 1,
#  ('ʃː', 'bᵊ'): 1,
#  ('ʃː', 'ɾ'): 1,
#  ('ʃː', 'ɒː'): 1,
#  ('ʃː', 'ɪ̈'): 1,
#  ('ʃː', 'ɔː'): 1,
#  ('ʃː', 'ʊ̯'): 1,
#  ('ʃː', 'ɪ̪'): 1,
#  ('ʃː', 'm̩ː'): 1,
#  ('ʃː', 'ɦ'): 1,
#  ('ʃː', 'ɱ'): 1,
#  ('ʃː', 'START'): 1,
#  ('ʃː', 'ɪ'): 1,
#  ('ʃː', 'ə'): 1,
#  ('ʃː', 'ɪː'): 1,
#  ('ʃː', 'ɑ̃'): 1,
#  ('ʃː', 'kʰ'): 1,
#  ('ʃː', 'nː'): 1,
#  ('ʃː', 'ə̆'): 1,
#  ('ʃː', 'ø'): 1,
#  ('ʃː', 'ʍ'): 1,
#  ('ʃː', 't͡ʃ'): 1,
#  ('ʃː', 'e͡ɪ'): 1,
#  ('ʃː', 'ɨ'): 1,
#  ('ʃː', 'əʳ'): 1,
#  ('ʃː', 'ô'): 1,
#  ('ʃː', 't'): 1,
#  ('ʃː', 'ɫ'): 1,
#  ('ʃː', 'ʀ'): 1,
#  ('ʃː', 'ɜː'): 1,
#  ('ʃː', 'oː'): 1,
#  ('ʃː', 'ɜ̃'): 1,
#  ('ʃː', 'ɵ'): 1,
#  ('ʃː', 'tː'): 1,
#  ('ʃː', 'ʊ̂'): 1,
#  ('ʃː', 'ɪʲ'): 1,
#  ('ʃː', 'ɽ'): 1,
#  ('ʃː', 'ɹʷ'): 1,
#  ('ʃː', 'ɒ̃'): 1,
#  ('ʃː', 'ɹː'): 1,
#  ('ʃː', '↓'): 1,
#  ('ʃː', 'ɬ'): 1,
#  ('ʃː', 'ɛ͡ɪ'): 1,
#  ('ʃː', 'ē'): 1,
#  ('ʃː', 'ɯ'): 1,
#  ('ʃː', 'ɛː'): 1,
#  ('ʃː', 'ĭ'): 1,
#  ('ʃː', 'ʉ'): 1,
#  ('ʃː', 'θ'): 1,
#  ('ʃː', 't̬ᵊ'): 1,
#  ('ʃː', 'ɚ'): 1,
#  ('ʃː', 'o'): 1,
#  ('ʃː', 'ĩ'): 1,
#  ('ʃː', 'ɛ̃'): 1,
#  ('ʃː', 'k'): 1,
#  ('ʃː', 'ʊ̆'): 1,
#  ('ʃː', 'd͡ʒ'): 1,
#  ('ʃː', 'ʊ'): 1,
#  ('ʃː', 'əː'): 1,
#  ('ʃː', 'z'): 1,
#  ('ʃː', 'e͜ɚ'): 1,
#  ('ʃː', 'm̩'): 1,
#  ('ʃː', 'ɛ̝'): 1,
#  ('ʃː', 'ɛˑ'): 1,
#  ('ʃː', 'sː'): 1,
#  ('ʃː', 'nˡ'): 1,
#  ('ʃː', 'tᵊ'): 1,
#  ('ʃː', 'ç'): 1,
#  ('ʃː', 'ʁ'): 1,
#  ('ʃː', 'i'): 1,
#  ('ʃː', 'îː'): 1,
#  ('ʃː', 'dʰ'): 1,
#  ('ʃː', 'æ'): 1,
#  ('ʃː', 't͡ʃʰ'): 1,
#  ('ʃː', 'STOP'): 1,
#  ('ʃː', 'äː'): 1,
#  ('ʃː', 'ʃ'): 1,
#  ('ʃː', 'ɒ'): 1,
#  ('ʃː', 'y'): 1,
#  ('ʃː', 'pː'): 1,
#  ('ʃː', 'r'): 1,
#  ('ʃː', 'ɐ'): 1,
#  ('ʃː', 'ɾ̃'): 1,
#  ('ʃː', 't̬'): 1,
#  ('ʃː', 'ʒ'): 1,
#  ('ʃː', 'ã'): 1,
#  ('ʃː', 'ʊː'): 1,
#  ('ʃː', 'ɚː'): 1,
#  ('ʃː', 'ːs'): 1,
#  ('ʃː', 'ʔ'): 1,
#  ('ʃː', 'f'): 1,
#  ('ʃː', 'ɐː'): 1,
#  ('ʃː', 'ɻ'): 1,
#  ('ʃː', 'æ̃'): 1,
#  ('ʃː', 'b'): 1,
#  ('ð', 'ʏ'): 1,
#  ('ð', 'ʃː'): 1,
#  ('ð', 'ð'): 1,
#  ('ð', 'ŭ̥'): 1,
#  ('ð', 'ɖ'): 1,
#  ('ð', 'lʲ'): 1,
#  ('ð', 'n̩'): 1,
#  ('ð', 'ɪ̯'): 1,
#  ('ð', 'tʰ'): 1,
#  ('ð', 'ʙ̩ː'): 1,
#  ('ð', 'd'): 1,
#  ('ð', 'u'): 1,
#  ('ð', 'eː'): 1,
#  ('ð', 'ɹ̩'): 1,
#  ('ð', 'ɕː'): 1,
#  ('ð', 'x'): 1,
#  ('ð', 'd̪'): 1,
#  ('ð', 'dʲ'): 1,
#  ('ð', 'ʌ̈'): 1,
#  ('ð', 'ɹ'): 1,
#  ('ð', 'm'): 1,
#  ('ð', 'k̚'): 1,
#  ('ð', 'ə̯'): 1,
#  ('ð', 'r̩'): 1,
#  ('ð', 'mː'): 1,
#  ('ð', 'ɣ'): 1,
#  ('ð', 'aː'): 1,
#  ('ð', 'c'): 1,
#  ('ð', 'ʌː'): 1,
#  ('ð', 'ɪˑ'): 1,
#  ('ð', 'p'): 1,
#  ('ð', 'ɛ'): 1,
#  ('ŭ̥', 'tʰ'): 1,
#  ('ŭ̥', 'ʙ̩ː'): 1,
#  ('ŭ̥', 'd'): 1,
#  ('ŭ̥', 'u'): 1,
#  ('ŭ̥', 'eː'): 1,
#  ('ŭ̥', 'ɹ̩'): 1,
#  ('ŭ̥', 'ɕː'): 1,
#  ('ŭ̥', 'x'): 1,
#  ('ŭ̥', 'd̪'): 1,
#  ('ŭ̥', 'dʲ'): 1,
#  ('ŭ̥', 'ʌ̈'): 1,
#  ('ŭ̥', 'ɹ'): 1,
#  ('ŭ̥', 'm'): 1,
#  ('ŭ̥', 'k̚'): 1,
#  ('ŭ̥', 'ə̯'): 1,
#  ('ŭ̥', 'r̩'): 1,
#  ('ŭ̥', 'mː'): 1,
#  ('ŭ̥', 'ɣ'): 1,
#  ('ŭ̥', 'aː'): 1,
#  ('ŭ̥', 'c'): 1,
#  ('ŭ̥', 'ʌː'): 1,
#  ('ŭ̥', 'ɪˑ'): 1,
#  ('ŭ̥', 'p'): 1,
#  ('ŭ̥', 'ɛ'): 1,
#  ('ŭ̥', 't͡s'): 1,
#  ('ŭ̥', 'ʊ̩'): 1,
#  ('ŭ̥', 'l'): 1,
#  ('ŭ̥', 'ɡː'): 1,
#  ('ŭ̥', 'ɲ'): 1,
#  ('ŭ̥', 'bʲ'): 1,
#  ('ŭ̥', 's'): 1,
#  ('ŭ̥', 'ɔ'): 1,
#  ('ŭ̥', 'ɘ'): 1,
#  ('ŭ̥', 'l̩'): 1,
#  ('ŭ̥', 'l͡s'): 1,
#  ('ŭ̥', 'oˀ'): 1,
#  ('ŭ̥', 'pʰ'): 1,
#  ('ŭ̥', 'ʊ̪'): 1,
#  ('ŭ̥', 'j'): 1,
#  ('ŭ̥', 'ɜ'): 1,
#  ('ŭ̥', '˞'): 1,
#  ('ŭ̥', 'w'): 1,
#  ('ŭ̥', 'œ'): 1,
#  ('ŭ̥', 'æː'): 1,
#  ('ŭ̥', 'ɝː'): 1,
#  ('ŭ̥', 'ä'): 1,
#  ('ŭ̥', 'ɑ'): 1,
#  ('ŭ̥', 'ʈ'): 1,
#  ('ŭ̥', 'ɭ'): 1,
#  ('ŭ̥', 'ɝ'): 1,
#  ('ŭ̥', 'v'): 1,
#  ('ŭ̥', 'ɔ͡ɪ'): 1,
#  ('ŭ̥', 'ʃʰ'): 1,
#  ('ŭ̥', 'n'): 1,
#  ('ŭ̥', 'kᵊ'): 1,
#  ('ŭ̥', 'õ'): 1,
#  ('ŭ̥', 'p̬'): 1,
#  ('ŭ̥', 't͡ʃ̩̩'): 1,
#  ('ŭ̥', 'uː'): 1,
#  ('ŭ̥', 'ʉː'): 1,
#  ('ŭ̥', 'ú'): 1,
#  ('ŭ̥', 'ɵ̞'): 1,
#  ('ŭ̥', 'fː'): 1,
#  ('ŭ̥', 't͡ɕ'): 1,
#  ('ŭ̥', 'əˑ'): 1,
#  ('ŭ̥', 'ĭ̥'): 1,
#  ('ŭ̥', 'ʌ'): 1,
#  ('ŭ̥', 'ɑː'): 1,
#  ('ŭ̥', 'ĩ'): 1,
#  ('ŭ̥', 'ɛ̃'): 1,
#  ('ŭ̥', 'k'): 1,
#  ('ŭ̥', 'ʊ̆'): 1,
#  ('ŭ̥', 'd͡ʒ'): 1,
#  ('ŭ̥', 'ʊ'): 1,
#  ('ŭ̥', 'əː'): 1,
#  ('ŭ̥', 'z'): 1,
#  ('ŭ̥', 'e͜ɚ'): 1,
#  ('ŭ̥', 'm̩'): 1,
#  ('ŭ̥', 'ɛ̝'): 1,
#  ('ŭ̥', 'ɛˑ'): 1,
#  ('ŭ̥', 'sː'): 1,
#  ('ŭ̥', 'nˡ'): 1,
#  ('ŭ̥', 'tᵊ'): 1,
#  ('ŭ̥', 'ç'): 1,
#  ('ŭ̥', 'ʁ'): 1,
#  ('ŭ̥', 'i'): 1,
#  ('ŭ̥', 'îː'): 1,
#  ('ŭ̥', 'dʰ'): 1,
#  ('ŭ̥', 'æ'): 1,
#  ('ŭ̥', 't͡ʃʰ'): 1,
#  ('ŭ̥', 'STOP'): 1,
#  ('ŭ̥', 'äː'): 1,
#  ('ŭ̥', 'ʃ'): 1,
#  ('ŭ̥', 'ɒ'): 1,
#  ('ŭ̥', 'y'): 1,
#  ('ŭ̥', 'pː'): 1,
#  ('ŭ̥', 'r'): 1,
#  ('ŭ̥', 'ɐ'): 1,
#  ('ŭ̥', 'ɾ̃'): 1,
#  ('ŭ̥', 't̬'): 1,
#  ('ŭ̥', 'ʒ'): 1,
#  ('ŭ̥', 'ã'): 1,
#  ('ŭ̥', 'ʊː'): 1,
#  ('ŭ̥', 'ɚː'): 1,
#  ('ŭ̥', 'ːs'): 1,
#  ('ŭ̥', 'ʔ'): 1,
#  ('ŭ̥', 'f'): 1,
#  ('ŭ̥', 'ɐː'): 1,
#  ('ŭ̥', 'ɻ'): 1,
#  ('ŭ̥', 'æ̃'): 1,
#  ('ŭ̥', 'b'): 1,
#  ('ɖ', 'ʏ'): 1,
#  ('ɖ', 'ʃː'): 1,
#  ('ɖ', 'ð'): 1,
#  ('ɖ', 'ŭ̥'): 1,
#  ('ɖ', 'ɖ'): 1,
#  ('ɖ', 'lʲ'): 1,
#  ('ɖ', 'n̩'): 1,
#  ('ɖ', 'ɪ̯'): 1,
#  ('ɖ', 'tʰ'): 1,
#  ('ɖ', 'ʙ̩ː'): 1,
#  ('ɖ', 'd'): 1,
#  ('ɖ', 'u'): 1,
#  ('ɖ', 'eː'): 1,
#  ('ɖ', 'ɹ̩'): 1,
#  ('ɖ', 'ɕː'): 1,
#  ('ɖ', 'x'): 1,
#  ('ɖ', 'd̪'): 1,
#  ('ɖ', 'dʲ'): 1,
#  ('ɖ', 'ʌ̈'): 1,
#  ('ɖ', 'ɹ'): 1,
#  ('ɖ', 'm'): 1,
#  ('ɖ', 'k̚'): 1,
#  ('ɖ', 'ə̯'): 1,
#  ('ɖ', 'r̩'): 1,
#  ('ɖ', 'mː'): 1,
#  ('ɖ', 'ɣ'): 1,
#  ('ɖ', 'aː'): 1,
#  ('ɖ', 'c'): 1,
#  ('ɖ', 'ʌː'): 1,
#  ('ɖ', 'ɪˑ'): 1,
#  ('ɖ', 'p'): 1,
#  ('ɖ', 'ɛ'): 1,
#  ('ɖ', 't͡s'): 1,
#  ('ɖ', 'ʊ̩'): 1,
#  ('ɖ', 'l'): 1,
#  ('ɖ', 'ɡː'): 1,
#  ('ɖ', 'ɲ'): 1,
#  ('ɖ', 'bʲ'): 1,
#  ('ɖ', 's'): 1,
#  ('ɖ', 'ɔ'): 1,
#  ('ɖ', 'ɘ'): 1,
#  ('ɖ', 'l̩'): 1,
#  ('ɖ', 'l͡s'): 1,
#  ('ɖ', 'oˀ'): 1,
#  ('ɖ', 'pʰ'): 1,
#  ('ɖ', 'ʊ̪'): 1,
#  ('ɖ', 'j'): 1,
#  ('ɖ', 'ɜ'): 1,
#  ('ɖ', '˞'): 1,
#  ('ɖ', 'w'): 1,
#  ('ɖ', 'œ'): 1,
#  ('ɖ', 'æː'): 1,
#  ('ɖ', 'ɝː'): 1,
#  ('ɖ', 'ä'): 1,
#  ('ɖ', 'ɑ'): 1,
#  ('ɖ', 'ʈ'): 1,
#  ('ɖ', 'ɭ'): 1,
#  ('ɖ', 'ɝ'): 1,
#  ('ɖ', 'v'): 1,
#  ('ɖ', 'ɔ͡ɪ'): 1,
#  ('ɖ', 'ʃʰ'): 1,
#  ('ɖ', 'n'): 1,
#  ('ɖ', 'kᵊ'): 1,
#  ('ɖ', 'õ'): 1,
#  ('ɖ', 'p̬'): 1,
#  ('ɖ', 't͡ʃ̩̩'): 1,
#  ('ɖ', 'uː'): 1,
#  ('ɖ', 'ʉː'): 1,
#  ('ɖ', 'ú'): 1,
#  ('ɖ', 'ɵ̞'): 1,
#  ('ɖ', 'fː'): 1,
#  ('ɖ', 't͡ɕ'): 1,
#  ('ɖ', 'əˑ'): 1,
#  ('ɖ', 'ĭ̥'): 1,
#  ('ɖ', 'ʌ'): 1,
#  ('ɖ', 'ɑː'): 1,
#  ('ɖ', 'ɔ̃'): 1,
#  ('ɖ', 'o͡ʊ'): 1,
#  ('ɖ', 'h'): 1,
#  ('ɖ', 'ɑˑ'): 1,
#  ('ɖ', 'e'): 1,
#  ('ɖ', 'ŋ'): 1,
#  ('ɖ', 'o̞'): 1,
#  ('ɖ', 'ɛ͡ɹ'): 1,
#  ('ɖ', 'χ'): 1,
#  ('ɖ', 'ɡ'): 1,
#  ('ɖ', 'iː'): 1,
#  ('ɖ', 'q'): 1,
#  ('ɖ', 'ɫ̩'): 1,
#  ('ɖ', '~'): 1,
#  ('ɖ', 'ṽ'): 1,
#  ('ɖ', 'a'): 1,
#  ('ɖ', 'bᵊ'): 1,
#  ('ɖ', 'ɾ'): 1,
#  ('ɖ', 'ɒː'): 1,
#  ('ɖ', 'ɪ̈'): 1,
#  ('ɖ', 'ɔː'): 1,
#  ('ɖ', 'ʊ̯'): 1,
#  ('ɖ', 'ɪ̪'): 1,
#  ('ɖ', 'm̩ː'): 1,
#  ('ɖ', 'ɦ'): 1,
#  ('lʲ', 'p̬'): 1,
#  ('lʲ', 't͡ʃ̩̩'): 1,
#  ('lʲ', 'uː'): 1,
#  ('lʲ', 'ʉː'): 1,
#  ('lʲ', 'ú'): 1,
#  ('lʲ', 'ɵ̞'): 1,
#  ...}

# %%
# now add in the actual bigram counts
prons = df.Pron
for pron in prons:
    for ix in range(1,len(pron)):
        p1 = pron[ix-1]
        p2 = pron[ix]
        ptc[(p1,p2)] += 1

# sanity-check some of the counts.
print("START d", ptc[('START','d')])
print("d START", ptc[('d','START')])
print("f ɹ", ptc[('f','ɹ')])
print("ɹ f", ptc[('ɹ','f')])
print("g ɹ", ptc[('ɡ','ɹ')])
print("ɹ g", ptc[('ɹ','ɡ')])
print("s l", ptc[('s','l')])
print("l s", ptc[('l','s')])
# Out:
# START d 3380
# d START 1
# f ɹ 500
# ɹ f 153
# g ɹ 875
# ɹ g 125
# s l 404
# l s 135

# %% [markdown]
# Now transform the phoneme transition **counts** into phoneme transition **probabilities**.
#
# For every pair of phonemes $p_1, p_2$, we already have ptc($p_1$,$p_2$): the phoneme transition count from $p_1$ to $p_2$, i.e. the number of times we encountered the bigram $p_1 p_2$ in the data.
#
# From this, we want to obtain the transition **probability** $p(p_2|p_1)$, i.e. the probability of encountering $p_2$, given that we have just seen $p_1$.  Note the order of the two phonemes: our bigram is $p_1 p_2$, and we use the count for it (and other bigrams) to obtain $p(p_2|p_1)$.
#
# How?  This is a conditional probability, and following the Bishop chapter, or Jurafsky and Martin eqn 3.11, we may calculate it as:
#
# \begin{equation}
# p(p_2|p_1) = \frac{c(p_1 p_2)}{c(p_1)}
# \end{equation}
#
# where $c(\cdot)$ denotes count.  The numerator is simply the count for the bigram $p_1 p_2$.  The denominator is the count for $p_1$ whatever phoneme may follow it.  We have bigram counts, so we can easily obtain the denominator $c(p_1)$ as:
#
# \begin{equation}
# c(p_1) = \sum_{q \in P} c(p_1 q)
# \end{equation}
#
# where $P$ is the set of all phonemes.

# %%
# data structure for transition probabilities is a dict of dicts.
# the outer dict is keyed by phoneme (state), and has value inner dict.
# the inner dict is also keyed by phoneme, and holds the probability of moving from the outer phoneme
# to the inner phoneme, i.e. p(inner|outer).
# this structure should make it easy to convert counts to probs, normalize etc.

tp = dict()  # transition probs, outer dict.
for p1 in phonemes:
    d = dict()  # inner dict
    for p2 in phonemes:
        d[p2] = ptc[(p1,p2)]
    total = sum(d.values())
    d = {k: v / total for k, v in d.items()}  # normalize
    tp[p1] = d

# %%
# sanity check.
# the conditional probabilities p(p2|p1) should add up to 1.0 when summing across p2, for each p1.
print("Sanity check: do the conditional probabilities conditioned on each phoneme sum to 1.0?")
for p1 in phonemes:
    total = sum(tp[p1].values())
    print("Sum of conditional probabilities conditioned on", p1, total)
# Out:
# Sanity check: do the conditional probabilities conditioned on each phoneme sum to 1.0?
# Sum of conditional probabilities conditioned on ʏ 1.0000000000000024
# Sum of conditional probabilities conditioned on ʃː 1.0000000000000047
# Sum of conditional probabilities conditioned on ð 0.999999999999999
# Sum of conditional probabilities conditioned on ŭ̥ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɖ 1.0000000000000024
# Sum of conditional probabilities conditioned on lʲ 1.0000000000000027
# Sum of conditional probabilities conditioned on n̩ 0.9999999999999997
# Sum of conditional probabilities conditioned on ɪ̯ 0.9999999999999978
# Sum of conditional probabilities conditioned on tʰ 1.0000000000000024
# Sum of conditional probabilities conditioned on ʙ̩ː 1.0000000000000027
# Sum of conditional probabilities conditioned on d 1.000000000000001
# Sum of conditional probabilities conditioned on u 0.9999999999999979
# Sum of conditional probabilities conditioned on eː 0.9999999999999977
# Sum of conditional probabilities conditioned on ɹ̩ 1.0000000000000022
# Sum of conditional probabilities conditioned on ɕː 1.0000000000000027
# Sum of conditional probabilities conditioned on x 1.0000000000000033
# Sum of conditional probabilities conditioned on d̪ 1.0000000000000027
# Sum of conditional probabilities conditioned on dʲ 1.0000000000000022
# Sum of conditional probabilities conditioned on ʌ̈ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɹ 1.0000000000000009
# Sum of conditional probabilities conditioned on m 1.000000000000001
# Sum of conditional probabilities conditioned on k̚ 1.0000000000000027
# Sum of conditional probabilities conditioned on ə̯ 0.9999999999999974
# Sum of conditional probabilities conditioned on r̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on mː 1.0000000000000022
# Sum of conditional probabilities conditioned on ɣ 1.0000000000000027
# Sum of conditional probabilities conditioned on aː 0.9999999999999964
# Sum of conditional probabilities conditioned on c 1.0000000000000027
# Sum of conditional probabilities conditioned on ʌː 1.0000000000000022
# Sum of conditional probabilities conditioned on ɪˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on p 0.9999999999999987
# Sum of conditional probabilities conditioned on ɛ 0.9999999999999963
# Sum of conditional probabilities conditioned on t͡s 0.9999999999999961
# Sum of conditional probabilities conditioned on ʊ̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on l 1.000000000000001
# Sum of conditional probabilities conditioned on ɡː 1.0000000000000027
# Sum of conditional probabilities conditioned on ɲ 1.0000000000000047
# Sum of conditional probabilities conditioned on bʲ 1.0000000000000024
# Sum of conditional probabilities conditioned on s 1.0000000000000016
# Sum of conditional probabilities conditioned on ɔ 0.9999999999999991
# Sum of conditional probabilities conditioned on ɘ 1.0000000000000007
# Sum of conditional probabilities conditioned on l̩ 0.9999999999999999
# Sum of conditional probabilities conditioned on l͡s 1.0000000000000027
# Sum of conditional probabilities conditioned on oˀ 1.0000000000000027
# Sum of conditional probabilities conditioned on pʰ 1.0000000000000047
# Sum of conditional probabilities conditioned on ʊ̪ 1.0000000000000027
# Sum of conditional probabilities conditioned on j 1.0000000000000033
# Sum of conditional probabilities conditioned on ɜ 1.0000000000000038
# Sum of conditional probabilities conditioned on ˞ 1.0000000000000022
# Sum of conditional probabilities conditioned on w 0.999999999999998
# Sum of conditional probabilities conditioned on œ 1.0000000000000027
# Sum of conditional probabilities conditioned on æː 1.0000000000000007
# Sum of conditional probabilities conditioned on ɝː 0.9999999999999979
# Sum of conditional probabilities conditioned on ä 1.000000000000002
# Sum of conditional probabilities conditioned on ɑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʈ 1.000000000000002
# Sum of conditional probabilities conditioned on ɭ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɝ 0.9999999999999959
# Sum of conditional probabilities conditioned on v 0.9999999999999992
# Sum of conditional probabilities conditioned on ɔ͡ɪ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʃʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on n 0.999999999999999
# Sum of conditional probabilities conditioned on kᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on õ 1.0000000000000027
# Sum of conditional probabilities conditioned on p̬ 1.0000000000000022
# Sum of conditional probabilities conditioned on t͡ʃ̩̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on uː 1.0000000000000007
# Sum of conditional probabilities conditioned on ʉː 0.9999999999999959
# Sum of conditional probabilities conditioned on ú 1.0000000000000027
# Sum of conditional probabilities conditioned on ɵ̞ 1.0000000000000027
# Sum of conditional probabilities conditioned on fː 1.0000000000000022
# Sum of conditional probabilities conditioned on t͡ɕ 1.0000000000000022
# Sum of conditional probabilities conditioned on əˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ĭ̥ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʌ 0.9999999999999951
# Sum of conditional probabilities conditioned on ɑː 1.0000000000000022
# Sum of conditional probabilities conditioned on ɔ̃ 0.9999999999999978
# Sum of conditional probabilities conditioned on o͡ʊ 1.0000000000000047
# Sum of conditional probabilities conditioned on h 1.0000000000000002
# Sum of conditional probabilities conditioned on ɑˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on e 1.0000000000000009
# Sum of conditional probabilities conditioned on ŋ 1.0
# Sum of conditional probabilities conditioned on o̞ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ͡ɹ 1.0000000000000027
# Sum of conditional probabilities conditioned on χ 1.0000000000000007
# Sum of conditional probabilities conditioned on ɡ 0.9999999999999962
# Sum of conditional probabilities conditioned on iː 1.000000000000001
# Sum of conditional probabilities conditioned on q 1.0000000000000024
# Sum of conditional probabilities conditioned on ɫ̩ 1.000000000000002
# Sum of conditional probabilities conditioned on ~ 1.0000000000000027
# Sum of conditional probabilities conditioned on ṽ 1.0000000000000027
# Sum of conditional probabilities conditioned on a 1.0000000000000038
# Sum of conditional probabilities conditioned on bᵊ 1.0000000000000024
# Sum of conditional probabilities conditioned on ɾ 1.0000000000000016
# Sum of conditional probabilities conditioned on ɒː 1.000000000000002
# Sum of conditional probabilities conditioned on ɪ̈ 1.000000000000001
# Sum of conditional probabilities conditioned on ɔː 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̯ 0.9999999999999987
# Sum of conditional probabilities conditioned on ɪ̪ 1.0000000000000049
# Sum of conditional probabilities conditioned on m̩ː 1.0000000000000027
# Sum of conditional probabilities conditioned on ɦ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɱ 1.0000000000000049
# Sum of conditional probabilities conditioned on START 1.0000000000000024
# Sum of conditional probabilities conditioned on ɪ 0.9999999999999981
# Sum of conditional probabilities conditioned on ə 0.9999999999999966
# Sum of conditional probabilities conditioned on ɪː 1.0000000000000018
# Sum of conditional probabilities conditioned on ɑ̃ 0.9999999999999978
# Sum of conditional probabilities conditioned on kʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on nː 0.999999999999996
# Sum of conditional probabilities conditioned on ə̆ 1.0000000000000027
# Sum of conditional probabilities conditioned on ø 1.0000000000000027
# Sum of conditional probabilities conditioned on ʍ 0.9999999999999961
# Sum of conditional probabilities conditioned on t͡ʃ 0.9999999999999996
# Sum of conditional probabilities conditioned on e͡ɪ 0.9999999999999959
# Sum of conditional probabilities conditioned on ɨ 1.0000000000000038
# Sum of conditional probabilities conditioned on əʳ 1.0000000000000027
# Sum of conditional probabilities conditioned on ô 1.0000000000000027
# Sum of conditional probabilities conditioned on t 0.9999999999999999
# Sum of conditional probabilities conditioned on ɫ 0.9999999999999986
# Sum of conditional probabilities conditioned on ʀ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɜː 0.9999999999999973
# Sum of conditional probabilities conditioned on oː 1.0000000000000027
# Sum of conditional probabilities conditioned on ɜ̃ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɵ 1.0000000000000022
# Sum of conditional probabilities conditioned on tː 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̂ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɪʲ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɽ 1.0000000000000024
# Sum of conditional probabilities conditioned on ɹʷ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɒ̃ 1.000000000000002
# Sum of conditional probabilities conditioned on ɹː 1.0000000000000044
# Sum of conditional probabilities conditioned on ↓ 1.0000000000000022
# Sum of conditional probabilities conditioned on ɬ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ͡ɪ 1.0000000000000027
# Sum of conditional probabilities conditioned on ē 0.999999999999996
# Sum of conditional probabilities conditioned on ɯ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛː 1.000000000000002
# Sum of conditional probabilities conditioned on ĭ 1.0000000000000007
# Sum of conditional probabilities conditioned on ʉ 1.000000000000002
# Sum of conditional probabilities conditioned on θ 1.000000000000003
# Sum of conditional probabilities conditioned on t̬ᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɚ 1.0000000000000009
# Sum of conditional probabilities conditioned on o 1.0000000000000004
# Sum of conditional probabilities conditioned on ĩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ̃ 1.000000000000002
# Sum of conditional probabilities conditioned on k 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̆ 1.0000000000000027
# Sum of conditional probabilities conditioned on d͡ʒ 0.9999999999999981
# Sum of conditional probabilities conditioned on ʊ 0.999999999999998
# Sum of conditional probabilities conditioned on əː 1.0000000000000018
# Sum of conditional probabilities conditioned on z 1.0000000000000004
# Sum of conditional probabilities conditioned on e͜ɚ 1.0000000000000027
# Sum of conditional probabilities conditioned on m̩ 1.0000000000000013
# Sum of conditional probabilities conditioned on ɛ̝ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on sː 1.0000000000000024
# Sum of conditional probabilities conditioned on nˡ 1.0000000000000027
# Sum of conditional probabilities conditioned on tᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on ç 1.0000000000000024
# Sum of conditional probabilities conditioned on ʁ 1.0000000000000024
# Sum of conditional probabilities conditioned on i 0.9999999999999993
# Sum of conditional probabilities conditioned on îː 1.0000000000000027
# Sum of conditional probabilities conditioned on dʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on æ 0.9999999999999989
# Sum of conditional probabilities conditioned on t͡ʃʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on STOP 0.9999999999999992
# Sum of conditional probabilities conditioned on äː 1.0000000000000027
# Sum of conditional probabilities conditioned on ʃ 0.9999999999999978
# Sum of conditional probabilities conditioned on ɒ 0.9999999999999988
# Sum of conditional probabilities conditioned on y 1.0000000000000024
# Sum of conditional probabilities conditioned on pː 1.0000000000000049
# Sum of conditional probabilities conditioned on r 1.0000000000000024
# Sum of conditional probabilities conditioned on ɐ 1.000000000000002
# Sum of conditional probabilities conditioned on ɾ̃ 1.000000000000002
# Sum of conditional probabilities conditioned on t̬ 1.0000000000000007
# Sum of conditional probabilities conditioned on ʒ 1.0000000000000013
# Sum of conditional probabilities conditioned on ã 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊː 1.0000000000000024
# Sum of conditional probabilities conditioned on ɚː 1.000000000000002
# Sum of conditional probabilities conditioned on ːs 1.0000000000000027
# Sum of conditional probabilities conditioned on ʔ 1.0000000000000044
# Sum of conditional probabilities conditioned on f 1.000000000000002
# Sum of conditional probabilities conditioned on ɐː 1.0000000000000027
# Sum of conditional probabilities conditioned on ɻ 1.0000000000000044
# Sum of conditional probabilities conditioned on æ̃ 0.9999999999999959
# Sum of conditional probabilities conditioned on b 0.9999999999999971

# %% [markdown]
# ### Congratulations!  You have created a Markov chain.
#
# Now use it to generate pseudo-words.

# %%
# specifically, let's generate 20 pseudo-words.
for i in range(20):
    # for each pseudo-word, we start by setting state to 'START'.
    state = 'START'
    print(state, end='')   # print state, but no newline.

    # now keep repeating this until you arrive at the 'STOP' state
    while (state != 'STOP'):
        next_state_options = list(tp[state].keys())
        next_state_probs = list(tp[state].values())
        new_state = np.random.choice(next_state_options, p=next_state_probs)
        print(" ", new_state, end='')
        state = new_state
    print(); print()
# Out:
# START  v  d  u  t  STOP
#
# START  æ  n  STOP
#
# START  v  STOP
#
# START  ɑː  STOP
#
# START  ə  n  STOP
#
# START  ɪ  d  ɪ  l  ə  ɹ  ɪ  ɑ  n  STOP
#
# START  t͡ʃ  STOP
#
# START  m  ɪ  s  STOP
#
# START  d  STOP
#
# START  s  ʃ  ə  s  STOP
#
# START  n  ə  t  l̩  STOP
#
# START  æ  b  ɔ  ɹ  ʌ̈  æː  æ̃  ɛ͡ɹ  d̪  ĭ  ɝː  ɪ  k  ɛ  d  ʒ  a  ɪ  n  t  ɹ  i  e  ɪ  STOP
#
# START  ɹ  ə  n  k  STOP
#
# START  v  e  ɪ  k  æ  k  j  u  l  v  ə  v  ə  ɹ  d  a  ʊ  s  STOP
#
# START  d  STOP
#
# START  p  i  ə  f  ɛ  l  i  ə  n  e  ɪ  k  a  ɪ  n  ə  ɹ  ɛ  n  o  ʊ  t͡ʃ  STOP
#
# START  t  STOP
#
# START  d͡ʒ  uː  k  w  ɔ  ŋ  STOP
#
# START  ə  l  i  ə  p  l  ɪ  n  d  ə  ɹ  o  ʊ  ɹ  o  ʊ  STOP
#
# START  ɹ  iː  d  ʒ  ə  ɹ  ə  STOP

# %% [markdown]
# OK, that seemed to more or less work.  We get some reasonable-looking outputs, and also some that look a little strange.
#
# Now, just to highlight how natural some of the stranger-looking outputs we just saw were, we'll try the same thing, but flipping the roles of $p_1$ and $p_2$ in the counts.  That is, when we see the bigram $p_1 p_2$, we increment the count for $p_2 p_1$.
#
# What does this do?  It rewards or strengthens transitions that tend to show up in the **opposite order** from that actually encountered.
#
# What sort of output should we predict?
#
# **[ YOUR ANSWER GOES HERE. ]**

# %%
# generate transition probabilities from counts again, but this time with p1 and p2 swapped, 
# as described above.  this will be a lightly but strategically edited variant of a code box
# above.
tp_swapped = dict()  # transition probs
for p1 in phonemes:
    d = dict()
    for p2 in phonemes:
        d[p2] = ptc[(p2,p1)]
    total = sum(d.values())
    d = {k: v / total for k, v in d.items()}  # normalize
    tp_swapped[p1] = d

# %%
# now generate 20 pseudo-words with these swapped transition probabilities.
for i in range(20):
    # for each pseudo-word, we start by setting state to 'START'.
    state = 'START'
    print(state, end='')   # print state, but no newline.

    # now keep repeating this until you arrive at the 'STOP' state
    while (state != 'STOP'):
        next_state_options = list(tp_swapped[state].keys())
        next_state_probs = list(tp_swapped[state].values())
        new_state = np.random.choice(next_state_options, p=next_state_probs)
        print(" ", new_state, end='')
        state = new_state
    print(); print()
# Out:
# START  c  d  START  ɹ  ə  START  e͡ɪ  n  ɪ  t  ɪ  ɪ  l  k  ɪ  a  l  ɪ  t  ɪ  ʒ  d  ɛ  v  ɛ  ɛ̃  ɹʷ  ɡ  ŋ  ɪ  d  eː  ːs  ɹʷ  ʊ̆  õ  ɪ̯  e  ɹ  ə  z  n  ə̯  eː  bʲ  ɪʲ  tʰ  kʰ  ʌ̈  i  n  uː  f  START  ɑ̃  o͡ʊ  ʌː  ʃʰ  ɒ̃  θ  ɛ  h  ʊ  ə  l  ə  t  n  ʌ  p  START  t͡s  c  b  æ  v  START  nˡ  ɫ  ə  t  ɪ  d  START  ɑ  p  START  ɜ  k  ɪ  s  ə  ɹ  t  ɪ  m  ʌ  s  n  ə  t͡ʃ  ↓  ʉ  bᵊ  ɛː  i  s  ɪ  a  t  k  START  dʲ  r  t  k  START  ɽ  ɣ  əˑ  c  STOP
