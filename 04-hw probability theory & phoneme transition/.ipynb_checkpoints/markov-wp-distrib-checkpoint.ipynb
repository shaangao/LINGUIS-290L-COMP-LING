# %% [markdown]
# # Generate pseudo-words using a Markov chain
#
# - We will read in a dataset of English words, with pronunciations, calculate phoneme transition probabilities from the data, and then use those phoneme transition probabilities to generate pseudo-words that follow the phonotactic probabilities of English.
# - This is essentially a simple Markov chain.  Every phoneme is a state - specifically, being in the state corresponding to phoneme $p$ means that we have just seen phoneme $p$.  Transition probabilities from state $p$ to some other state $q$ are determined from bigrams in the data.  How?
# - A bigram is a pair of consecutive symbolic units - in this case phonemes.  Thus transition probabilities such as $P(p_2|p_1)$ represent the probability of moving from the state that denotes our having just seen phoneme $p_1$ to the state that denotes our having just seen phoneme $p_2$;  this probability is determined by the relative frequency of encountering $p_2$ in the data, given that we have just seen $p_1$.
# - This notebook again uses [WikiPron](https://github.com/kylebgorman/wikipron), but this time we consider US pronunciation for English.  Analogous data for many other languages, in the same format, is available [here](https://github.com/kylebgorman/wikipron/tree/master/data), which you can download and use for extensions.

# %%
import re  # not necessary here
import pandas as pd
import numpy as np
import unicodedata
import random  # useful for sampling from a distribution

# %% [markdown]
# ### Read in data
#
# And format it so that pulling out phoneme transitions will be easy.

# %%
# read in english words.  
df = pd.read_csv("eng_us_phonemic.tsv", sep='\t', names=['Word', 'Pron'])
df.Pron = df.Pron.str.split()  # turn space-separated strings into lists of phonemes
df
# Out:
#              Word                            Pron
# 0          $deity              [d, e, ɪ, ɪ, t, i]
# 1          $deity                [d, iː, ɪ, t, i]
# 2          'cause                       [k, ʌ, z]
# 3       'dswounds           [d, z, w, u, n, d, z]
# 4             'em                            [m̩]
# ...           ...                             ...
# 53394     œconomy          [ɪː, k, ɒ, n, ɒ, m, i]
# 53395       œneus                [ɛ, n, j, uː, s]
# 53396       ǃkung                       [k, u, ŋ]
# 53397       ǃkung                       [k, ʊ, ŋ]
# 53398  ξυλάγγουρο  [k, s, i, l, a, ŋ, ɡ, u, ɾ, o]
#
# [53399 rows x 2 columns]

# %%
# sanity check
# find the US pronunciation of the word "aardvark"
df[df.Word=='aardvark']
# Out:
#         Word                   Pron
# 67  aardvark  [ɑ, ɹ, d, v, ɑ, ɹ, k]

# %%
# sanity check - and a chance to introduce the very useful pandas "sample" routine.
# find the US pronunciation of several other words.
df.sample(n=25)  # pick 25 random samples
# Out:
#                    Word                                           Pron
# 6842              biota                          [b, a, ɪ, ə, ʊ, t, ə]
# 5959             baster                             [b, e, ɪ, s, t, ɚ]
# 22706             gular                            [ɡ, j, uː, l, ə, r]
# 16148        druggeting                       [d, ɹ, ʌ, ɡ, ɪ, t, ɪ, ŋ]
# 29932              madd                                      [m, æ, d]
# 24349         hooverize                          [h, u, v, ɚ, a, ɪ, z]
# 26871          jennifer                          [d, ʒ, ɛ, n, ɪ, f, ɚ]
# 44560            snooze                                  [s, n, uː, z]
# 25102          idolatry                    [a, ɪ, d, ɑ, l, ə, t, ɹ, i]
# 49925            uneasy                               [ʌ, n, iː, z, i]
# 8940            calzone                    [k, æ, l, z, o, ʊ, n, e, ɪ]
# 3868          apodioxis           [æ, p, ə, ʊ, d, a, ɪ, ɒ, k, s, ɪ, s]
# 6779          billionth                          [b, ɪ, l, i, ə, n, θ]
# 18453       explicitize           [ɪ, k, s, p, l, ɪ, s, ɪ, t, a, ɪ, z]
# 17739           erdoğan                      [ɛ, ə, ɹ, d, o, ʊ, ɑː, n]
# 30462             mares                                [m, ɛ, ə, ɹ, z]
# 31478           miculek                       [m, ɪ, t, ʃ, ə, l, ɛ, k]
# 20464             fries                                [f, ɹ, a, ɪ, z]
# 33586  nonschizophrenia  [n, ɒ, n, s, k, ɪ, t, s, ə, f, ɹ, i, n, i, ə]
# 15737          dominica                       [d, ə, m, ɪ, n, ɪ, k, ə]
# 14103            deasil                                [d, ɛ, s, ə, l]
# 39678          ragequit                    [ɹ, e, ɪ, d, ʒ, k, w, ɪ, t]
# 4015         approximal                 [ə, p, ɹ, ɒ, k, s, ɪ, m, ə, l]
# 37897         postulate                 [p, ɑ, s, t, ʃ, ə, l, e, ɪ, t]
# 1462        acclamatory                 [ə, k, l, æ, m, ə, t, ɔ, ɹ, i]

# %%
# now add START and STOP pseudo-phonemes at beginning and end of each word.
# a chance to introduce the very useful pandas "apply" routine.
df.Pron = df.Pron.apply(lambda x: ['START'] + x + ['STOP'])
df
# Out:
#              Word                                         Pron
# 0          $deity              [START, d, e, ɪ, ɪ, t, i, STOP]
# 1          $deity                [START, d, iː, ɪ, t, i, STOP]
# 2          'cause                       [START, k, ʌ, z, STOP]
# 3       'dswounds           [START, d, z, w, u, n, d, z, STOP]
# 4             'em                            [START, m̩, STOP]
# ...           ...                                          ...
# 53394     œconomy          [START, ɪː, k, ɒ, n, ɒ, m, i, STOP]
# 53395       œneus                [START, ɛ, n, j, uː, s, STOP]
# 53396       ǃkung                       [START, k, u, ŋ, STOP]
# 53397       ǃkung                       [START, k, ʊ, ŋ, STOP]
# 53398  ξυλάγγουρο  [START, k, s, i, l, a, ŋ, ɡ, u, ɾ, o, STOP]
#
# [53399 rows x 2 columns]

# %% [markdown]
# ### Get bigram conditional probabilities for each pair of phonemes

# %%
# start by getting the set of all phonemes in the dataset.
# we will have one state for each phoneme.
phonemes = set([p for l in df.Pron for p in l]) # for every list in df.pron; for every phoneme in that list
print(len(phonemes))
print(phonemes)
# Out:
# 186
# {'y', 'ɡ', 't͡ʃ̩̩', 'əː', 'z', 'p', 't͡s', 'b', 'ɛː', 'ʊ̂', 'ʊ̯', 'ɛˑ', 'ɜː', 'ɻ', 'ʁ', 'bᵊ', 'n̩', 'ɪ', 'ɹ', 'ĭ', 'd̪', 'nˡ', 't̬', 'ʌː', 'r', 'ɔ͡ɪ', 's', 'nː', 't', 'ɒ', 't͡ɕ', 'e͜ɚ', 'ɫ̩', 'f', 'l͡s', 'ɹː', 'ɪˑ', 'ɪː', 'ʙ̩ː', 'õ', 'ə̯', 'ɝ', 'j', 'uː', 'd͡ʒ', 'ø', 'ɑ̃', 'ɲ', 'ɒ̃', 'ɑː', 'pː', 'æ', 'o', 'ē', 'dʰ', 'ɑ', 'ɛ͡ɪ', 'ɕː', 'START', 'ʊ̪', 'm̩', 'ç', 'ɒː', 'ɪʲ', 'ɖ', 'ʒ', 'l̩', 'îː', 'm', 'ô', 'ĭ̥', 'œ', 'ɐː', 'a', 'ːs', 'ɭ', 'ɛ', 'ú', 'ɛ̝', 'q', 'i', 'aː', 'e͡ɪ', 'æ̃', 'ɘ', 'ɱ', 'e', 'ṽ', 'ɾ', 'ʀ', 't͡ʃ', 'ʈ', 'c', 'ä', 'ɦ', 'ə', 'ɔː', 'sː', 'ɣ', 'ɛ̃', 'n', 'kᵊ', 'p̬', 'k', 'ŭ̥', 'ɪ̪', 'mː', 'æː', 'd', 'ʃː', 'dʲ', 'pʰ', 'ʃ', 'ã', 'o̞', 'ŋ', 'tː', 'v', 'əʳ', 'ɵ̞', 'STOP', 'θ', 'ɽ', 'fː', 'u', '~', 'ɫ', 'lʲ', 'äː', '˞', 'tᵊ', 'bʲ', 'ʉ', 'χ', 'ɐ', 'm̩ː', 'ɜ̃', 'k̚', 'ʌ̈', 'ʔ', 'ʌ', 'oˀ', 'ə̆', 'ʊː', 'ɝː', 't͡ʃʰ', 'ɵ', 'tʰ', 'kʰ', 'ɯ', 'ð', 'ɔ̃', 'ɛ͡ɹ', 'ɹʷ', 'ʊ̩', 'ɨ', 'oː', 'iː', '↓', 'ʏ', 'ɜ', 'ɪ̯', 'ɔ', 'əˑ', 'ʍ', 'h', 'r̩', 'ɪ̈', 'ɹ̩', 'ɑˑ', 'ʊ̆', 'ɡː', 'ʉː', 'ɚ', 'ɬ', 'eː', 'w', 'x', 'l', 'ʊ', 'o͡ʊ', 'ĩ', 'ɾ̃', 't̬ᵊ', 'ʃʰ', 'ɚː'}

# %% [markdown]
# Now get simple phoneme transition **counts** for every pair of phonemes.  Later, we will turn these into probabilities.
#
# We will use [Laplace (add-one) smoothing](https://en.wikipedia.org/wiki/Additive_smoothing), which means that every phoneme pair gets a "freebie" count of 1 to start with, before actually seeing any data.  Ask me why we might want to do such a thing.

# %%
# ptc = phoneme transition counts.
# this structure is a dict.
# its key is a tuple of 2 phonemes: (p1, p2), and the corresponding value is the count for those 2 phonemes.
# here, we start by initializing each count with 1: add-one smoothing.
# MODIFY THIS NEXT PART TO INITIALIZE ALL COUNTS TO 1.
ptc = {}  # YOUR CODE GOES HERE.

for phoneme1 in phonemes:
    for phoneme2 in phonemes:
        ptc[(phoneme1, phoneme2)] = 1

print(len(ptc)) # sanity check
        
ptc
# Out:
# 34596
# {('y', 'y'): 1,
#  ('y', 'ɡ'): 1,
#  ('y', 't͡ʃ̩̩'): 1,
#  ('y', 'əː'): 1,
#  ('y', 'z'): 1,
#  ('y', 'p'): 1,
#  ('y', 't͡s'): 1,
#  ('y', 'b'): 1,
#  ('y', 'ɛː'): 1,
#  ('y', 'ʊ̂'): 1,
#  ('y', 'ʊ̯'): 1,
#  ('y', 'ɛˑ'): 1,
#  ('y', 'ɜː'): 1,
#  ('y', 'ɻ'): 1,
#  ('y', 'ʁ'): 1,
#  ('y', 'bᵊ'): 1,
#  ('y', 'n̩'): 1,
#  ('y', 'ɪ'): 1,
#  ('y', 'ɹ'): 1,
#  ('y', 'ĭ'): 1,
#  ('y', 'd̪'): 1,
#  ('y', 'nˡ'): 1,
#  ('y', 't̬'): 1,
#  ('y', 'ʌː'): 1,
#  ('y', 'r'): 1,
#  ('y', 'ɔ͡ɪ'): 1,
#  ('y', 's'): 1,
#  ('y', 'nː'): 1,
#  ('y', 't'): 1,
#  ('y', 'ɒ'): 1,
#  ('y', 't͡ɕ'): 1,
#  ('y', 'e͜ɚ'): 1,
#  ('y', 'ɫ̩'): 1,
#  ('y', 'f'): 1,
#  ('y', 'l͡s'): 1,
#  ('y', 'ɹː'): 1,
#  ('y', 'ɪˑ'): 1,
#  ('y', 'ɪː'): 1,
#  ('y', 'ʙ̩ː'): 1,
#  ('y', 'õ'): 1,
#  ('y', 'ə̯'): 1,
#  ('y', 'ɝ'): 1,
#  ('y', 'j'): 1,
#  ('y', 'uː'): 1,
#  ('y', 'd͡ʒ'): 1,
#  ('y', 'ø'): 1,
#  ('y', 'ɑ̃'): 1,
#  ('y', 'ɲ'): 1,
#  ('y', 'ɒ̃'): 1,
#  ('y', 'ɑː'): 1,
#  ('y', 'pː'): 1,
#  ('y', 'æ'): 1,
#  ('y', 'o'): 1,
#  ('y', 'ē'): 1,
#  ('y', 'dʰ'): 1,
#  ('y', 'ɑ'): 1,
#  ('y', 'ɛ͡ɪ'): 1,
#  ('y', 'ɕː'): 1,
#  ('y', 'START'): 1,
#  ('y', 'ʊ̪'): 1,
#  ('y', 'm̩'): 1,
#  ('y', 'ç'): 1,
#  ('y', 'ɒː'): 1,
#  ('y', 'ɪʲ'): 1,
#  ('y', 'ɖ'): 1,
#  ('y', 'ʒ'): 1,
#  ('y', 'l̩'): 1,
#  ('y', 'îː'): 1,
#  ('y', 'm'): 1,
#  ('y', 'ô'): 1,
#  ('y', 'ĭ̥'): 1,
#  ('y', 'œ'): 1,
#  ('y', 'ɐː'): 1,
#  ('y', 'a'): 1,
#  ('y', 'ːs'): 1,
#  ('y', 'ɭ'): 1,
#  ('y', 'ɛ'): 1,
#  ('y', 'ú'): 1,
#  ('y', 'ɛ̝'): 1,
#  ('y', 'q'): 1,
#  ('y', 'i'): 1,
#  ('y', 'aː'): 1,
#  ('y', 'e͡ɪ'): 1,
#  ('y', 'æ̃'): 1,
#  ('y', 'ɘ'): 1,
#  ('y', 'ɱ'): 1,
#  ('y', 'e'): 1,
#  ('y', 'ṽ'): 1,
#  ('y', 'ɾ'): 1,
#  ('y', 'ʀ'): 1,
#  ('y', 't͡ʃ'): 1,
#  ('y', 'ʈ'): 1,
#  ('y', 'c'): 1,
#  ('y', 'ä'): 1,
#  ('y', 'ɦ'): 1,
#  ('y', 'ə'): 1,
#  ('y', 'ɔː'): 1,
#  ('y', 'sː'): 1,
#  ('y', 'ɣ'): 1,
#  ('y', 'ɛ̃'): 1,
#  ('y', 'n'): 1,
#  ('y', 'kᵊ'): 1,
#  ('y', 'p̬'): 1,
#  ('y', 'k'): 1,
#  ('y', 'ŭ̥'): 1,
#  ('y', 'ɪ̪'): 1,
#  ('y', 'mː'): 1,
#  ('y', 'æː'): 1,
#  ('y', 'd'): 1,
#  ('y', 'ʃː'): 1,
#  ('y', 'dʲ'): 1,
#  ('y', 'pʰ'): 1,
#  ('y', 'ʃ'): 1,
#  ('y', 'ã'): 1,
#  ('y', 'o̞'): 1,
#  ('y', 'ŋ'): 1,
#  ('y', 'tː'): 1,
#  ('y', 'v'): 1,
#  ('y', 'əʳ'): 1,
#  ('y', 'ɵ̞'): 1,
#  ('y', 'STOP'): 1,
#  ('y', 'θ'): 1,
#  ('y', 'ɽ'): 1,
#  ('y', 'fː'): 1,
#  ('y', 'u'): 1,
#  ('y', '~'): 1,
#  ('y', 'ɫ'): 1,
#  ('y', 'lʲ'): 1,
#  ('y', 'äː'): 1,
#  ('y', '˞'): 1,
#  ('y', 'tᵊ'): 1,
#  ('y', 'bʲ'): 1,
#  ('y', 'ʉ'): 1,
#  ('y', 'χ'): 1,
#  ('y', 'ɐ'): 1,
#  ('y', 'm̩ː'): 1,
#  ('y', 'ɜ̃'): 1,
#  ('y', 'k̚'): 1,
#  ('y', 'ʌ̈'): 1,
#  ('y', 'ʔ'): 1,
#  ('y', 'ʌ'): 1,
#  ('y', 'oˀ'): 1,
#  ('y', 'ə̆'): 1,
#  ('y', 'ʊː'): 1,
#  ('y', 'ɝː'): 1,
#  ('y', 't͡ʃʰ'): 1,
#  ('y', 'ɵ'): 1,
#  ('y', 'tʰ'): 1,
#  ('y', 'kʰ'): 1,
#  ('y', 'ɯ'): 1,
#  ('y', 'ð'): 1,
#  ('y', 'ɔ̃'): 1,
#  ('y', 'ɛ͡ɹ'): 1,
#  ('y', 'ɹʷ'): 1,
#  ('y', 'ʊ̩'): 1,
#  ('y', 'ɨ'): 1,
#  ('y', 'oː'): 1,
#  ('y', 'iː'): 1,
#  ('y', '↓'): 1,
#  ('y', 'ʏ'): 1,
#  ('y', 'ɜ'): 1,
#  ('y', 'ɪ̯'): 1,
#  ('y', 'ɔ'): 1,
#  ('y', 'əˑ'): 1,
#  ('y', 'ʍ'): 1,
#  ('y', 'h'): 1,
#  ('y', 'r̩'): 1,
#  ('y', 'ɪ̈'): 1,
#  ('y', 'ɹ̩'): 1,
#  ('y', 'ɑˑ'): 1,
#  ('y', 'ʊ̆'): 1,
#  ('y', 'ɡː'): 1,
#  ('y', 'ʉː'): 1,
#  ('y', 'ɚ'): 1,
#  ('y', 'ɬ'): 1,
#  ('y', 'eː'): 1,
#  ('y', 'w'): 1,
#  ('y', 'x'): 1,
#  ('y', 'l'): 1,
#  ('y', 'ʊ'): 1,
#  ('y', 'o͡ʊ'): 1,
#  ('y', 'ĩ'): 1,
#  ('y', 'ɾ̃'): 1,
#  ('y', 't̬ᵊ'): 1,
#  ('y', 'ʃʰ'): 1,
#  ('y', 'ɚː'): 1,
#  ('ɡ', 'y'): 1,
#  ('ɡ', 'ɡ'): 1,
#  ('ɡ', 't͡ʃ̩̩'): 1,
#  ('ɡ', 'əː'): 1,
#  ('ɡ', 'z'): 1,
#  ('ɡ', 'p'): 1,
#  ('ɡ', 't͡s'): 1,
#  ('ɡ', 'b'): 1,
#  ('ɡ', 'ɛː'): 1,
#  ('ɡ', 'ʊ̂'): 1,
#  ('ɡ', 'ʊ̯'): 1,
#  ('ɡ', 'ɛˑ'): 1,
#  ('ɡ', 'ɜː'): 1,
#  ('ɡ', 'ɻ'): 1,
#  ('ɡ', 'ʁ'): 1,
#  ('ɡ', 'bᵊ'): 1,
#  ('ɡ', 'n̩'): 1,
#  ('ɡ', 'ɪ'): 1,
#  ('ɡ', 'ɹ'): 1,
#  ('ɡ', 'ĭ'): 1,
#  ('ɡ', 'd̪'): 1,
#  ('ɡ', 'nˡ'): 1,
#  ('ɡ', 't̬'): 1,
#  ('ɡ', 'ʌː'): 1,
#  ('ɡ', 'r'): 1,
#  ('ɡ', 'ɔ͡ɪ'): 1,
#  ('ɡ', 's'): 1,
#  ('ɡ', 'nː'): 1,
#  ('ɡ', 't'): 1,
#  ('ɡ', 'ɒ'): 1,
#  ('ɡ', 't͡ɕ'): 1,
#  ('ɡ', 'e͜ɚ'): 1,
#  ('ɡ', 'ɫ̩'): 1,
#  ('ɡ', 'f'): 1,
#  ('ɡ', 'l͡s'): 1,
#  ('ɡ', 'ɹː'): 1,
#  ('ɡ', 'ɪˑ'): 1,
#  ('ɡ', 'ɪː'): 1,
#  ('ɡ', 'ʙ̩ː'): 1,
#  ('ɡ', 'õ'): 1,
#  ('ɡ', 'ə̯'): 1,
#  ('ɡ', 'ɝ'): 1,
#  ('ɡ', 'j'): 1,
#  ('ɡ', 'uː'): 1,
#  ('ɡ', 'd͡ʒ'): 1,
#  ('ɡ', 'ø'): 1,
#  ('ɡ', 'ɑ̃'): 1,
#  ('ɡ', 'ɲ'): 1,
#  ('ɡ', 'ɒ̃'): 1,
#  ('ɡ', 'ɑː'): 1,
#  ('ɡ', 'pː'): 1,
#  ('ɡ', 'æ'): 1,
#  ('ɡ', 'o'): 1,
#  ('ɡ', 'ē'): 1,
#  ('ɡ', 'dʰ'): 1,
#  ('ɡ', 'ɑ'): 1,
#  ('ɡ', 'ɛ͡ɪ'): 1,
#  ('ɡ', 'ɕː'): 1,
#  ('ɡ', 'START'): 1,
#  ('ɡ', 'ʊ̪'): 1,
#  ('ɡ', 'm̩'): 1,
#  ('ɡ', 'ç'): 1,
#  ('ɡ', 'ɒː'): 1,
#  ('ɡ', 'ɪʲ'): 1,
#  ('ɡ', 'ɖ'): 1,
#  ('ɡ', 'ʒ'): 1,
#  ('ɡ', 'l̩'): 1,
#  ('ɡ', 'îː'): 1,
#  ('ɡ', 'm'): 1,
#  ('ɡ', 'ô'): 1,
#  ('ɡ', 'ĭ̥'): 1,
#  ('ɡ', 'œ'): 1,
#  ('ɡ', 'ɐː'): 1,
#  ('ɡ', 'a'): 1,
#  ('ɡ', 'ːs'): 1,
#  ('ɡ', 'ɭ'): 1,
#  ('ɡ', 'ɛ'): 1,
#  ('ɡ', 'ú'): 1,
#  ('ɡ', 'ɛ̝'): 1,
#  ('ɡ', 'q'): 1,
#  ('ɡ', 'i'): 1,
#  ('ɡ', 'aː'): 1,
#  ('ɡ', 'e͡ɪ'): 1,
#  ('ɡ', 'æ̃'): 1,
#  ('ɡ', 'ɘ'): 1,
#  ('ɡ', 'ɱ'): 1,
#  ('ɡ', 'e'): 1,
#  ('ɡ', 'ṽ'): 1,
#  ('ɡ', 'ɾ'): 1,
#  ('ɡ', 'ʀ'): 1,
#  ('ɡ', 't͡ʃ'): 1,
#  ('ɡ', 'ʈ'): 1,
#  ('ɡ', 'c'): 1,
#  ('ɡ', 'ä'): 1,
#  ('ɡ', 'ɦ'): 1,
#  ('ɡ', 'ə'): 1,
#  ('ɡ', 'ɔː'): 1,
#  ('ɡ', 'sː'): 1,
#  ('ɡ', 'ɣ'): 1,
#  ('ɡ', 'ɛ̃'): 1,
#  ('ɡ', 'n'): 1,
#  ('ɡ', 'kᵊ'): 1,
#  ('ɡ', 'p̬'): 1,
#  ('ɡ', 'k'): 1,
#  ('ɡ', 'ŭ̥'): 1,
#  ('ɡ', 'ɪ̪'): 1,
#  ('ɡ', 'mː'): 1,
#  ('ɡ', 'æː'): 1,
#  ('ɡ', 'd'): 1,
#  ('ɡ', 'ʃː'): 1,
#  ('ɡ', 'dʲ'): 1,
#  ('ɡ', 'pʰ'): 1,
#  ('ɡ', 'ʃ'): 1,
#  ('ɡ', 'ã'): 1,
#  ('ɡ', 'o̞'): 1,
#  ('ɡ', 'ŋ'): 1,
#  ('ɡ', 'tː'): 1,
#  ('ɡ', 'v'): 1,
#  ('ɡ', 'əʳ'): 1,
#  ('ɡ', 'ɵ̞'): 1,
#  ('ɡ', 'STOP'): 1,
#  ('ɡ', 'θ'): 1,
#  ('ɡ', 'ɽ'): 1,
#  ('ɡ', 'fː'): 1,
#  ('ɡ', 'u'): 1,
#  ('ɡ', '~'): 1,
#  ('ɡ', 'ɫ'): 1,
#  ('ɡ', 'lʲ'): 1,
#  ('ɡ', 'äː'): 1,
#  ('ɡ', '˞'): 1,
#  ('ɡ', 'tᵊ'): 1,
#  ('ɡ', 'bʲ'): 1,
#  ('ɡ', 'ʉ'): 1,
#  ('ɡ', 'χ'): 1,
#  ('ɡ', 'ɐ'): 1,
#  ('ɡ', 'm̩ː'): 1,
#  ('ɡ', 'ɜ̃'): 1,
#  ('ɡ', 'k̚'): 1,
#  ('ɡ', 'ʌ̈'): 1,
#  ('ɡ', 'ʔ'): 1,
#  ('ɡ', 'ʌ'): 1,
#  ('ɡ', 'oˀ'): 1,
#  ('ɡ', 'ə̆'): 1,
#  ('ɡ', 'ʊː'): 1,
#  ('ɡ', 'ɝː'): 1,
#  ('ɡ', 't͡ʃʰ'): 1,
#  ('ɡ', 'ɵ'): 1,
#  ('ɡ', 'tʰ'): 1,
#  ('ɡ', 'kʰ'): 1,
#  ('ɡ', 'ɯ'): 1,
#  ('ɡ', 'ð'): 1,
#  ('ɡ', 'ɔ̃'): 1,
#  ('ɡ', 'ɛ͡ɹ'): 1,
#  ('ɡ', 'ɹʷ'): 1,
#  ('ɡ', 'ʊ̩'): 1,
#  ('ɡ', 'ɨ'): 1,
#  ('ɡ', 'oː'): 1,
#  ('ɡ', 'iː'): 1,
#  ('ɡ', '↓'): 1,
#  ('ɡ', 'ʏ'): 1,
#  ('ɡ', 'ɜ'): 1,
#  ('ɡ', 'ɪ̯'): 1,
#  ('ɡ', 'ɔ'): 1,
#  ('ɡ', 'əˑ'): 1,
#  ('ɡ', 'ʍ'): 1,
#  ('ɡ', 'h'): 1,
#  ('ɡ', 'r̩'): 1,
#  ('ɡ', 'ɪ̈'): 1,
#  ('ɡ', 'ɹ̩'): 1,
#  ('ɡ', 'ɑˑ'): 1,
#  ('ɡ', 'ʊ̆'): 1,
#  ('ɡ', 'ɡː'): 1,
#  ('ɡ', 'ʉː'): 1,
#  ('ɡ', 'ɚ'): 1,
#  ('ɡ', 'ɬ'): 1,
#  ('ɡ', 'eː'): 1,
#  ('ɡ', 'w'): 1,
#  ('ɡ', 'x'): 1,
#  ('ɡ', 'l'): 1,
#  ('ɡ', 'ʊ'): 1,
#  ('ɡ', 'o͡ʊ'): 1,
#  ('ɡ', 'ĩ'): 1,
#  ('ɡ', 'ɾ̃'): 1,
#  ('ɡ', 't̬ᵊ'): 1,
#  ('ɡ', 'ʃʰ'): 1,
#  ('ɡ', 'ɚː'): 1,
#  ('t͡ʃ̩̩', 'y'): 1,
#  ('t͡ʃ̩̩', 'ɡ'): 1,
#  ('t͡ʃ̩̩', 't͡ʃ̩̩'): 1,
#  ('t͡ʃ̩̩', 'əː'): 1,
#  ('t͡ʃ̩̩', 'z'): 1,
#  ('t͡ʃ̩̩', 'p'): 1,
#  ('t͡ʃ̩̩', 't͡s'): 1,
#  ('t͡ʃ̩̩', 'b'): 1,
#  ('t͡ʃ̩̩', 'ɛː'): 1,
#  ('t͡ʃ̩̩', 'ʊ̂'): 1,
#  ('t͡ʃ̩̩', 'ʊ̯'): 1,
#  ('t͡ʃ̩̩', 'ɛˑ'): 1,
#  ('t͡ʃ̩̩', 'ɜː'): 1,
#  ('t͡ʃ̩̩', 'ɻ'): 1,
#  ('t͡ʃ̩̩', 'ʁ'): 1,
#  ('t͡ʃ̩̩', 'bᵊ'): 1,
#  ('t͡ʃ̩̩', 'n̩'): 1,
#  ('t͡ʃ̩̩', 'ɪ'): 1,
#  ('t͡ʃ̩̩', 'ɹ'): 1,
#  ('t͡ʃ̩̩', 'ĭ'): 1,
#  ('t͡ʃ̩̩', 'd̪'): 1,
#  ('t͡ʃ̩̩', 'nˡ'): 1,
#  ('t͡ʃ̩̩', 't̬'): 1,
#  ('t͡ʃ̩̩', 'ʌː'): 1,
#  ('t͡ʃ̩̩', 'r'): 1,
#  ('t͡ʃ̩̩', 'ɔ͡ɪ'): 1,
#  ('t͡ʃ̩̩', 's'): 1,
#  ('t͡ʃ̩̩', 'nː'): 1,
#  ('t͡ʃ̩̩', 't'): 1,
#  ('t͡ʃ̩̩', 'ɒ'): 1,
#  ('t͡ʃ̩̩', 't͡ɕ'): 1,
#  ('t͡ʃ̩̩', 'e͜ɚ'): 1,
#  ('t͡ʃ̩̩', 'ɫ̩'): 1,
#  ('t͡ʃ̩̩', 'f'): 1,
#  ('t͡ʃ̩̩', 'l͡s'): 1,
#  ('t͡ʃ̩̩', 'ɹː'): 1,
#  ('t͡ʃ̩̩', 'ɪˑ'): 1,
#  ('t͡ʃ̩̩', 'ɪː'): 1,
#  ('t͡ʃ̩̩', 'ʙ̩ː'): 1,
#  ('t͡ʃ̩̩', 'õ'): 1,
#  ('t͡ʃ̩̩', 'ə̯'): 1,
#  ('t͡ʃ̩̩', 'ɝ'): 1,
#  ('t͡ʃ̩̩', 'j'): 1,
#  ('t͡ʃ̩̩', 'uː'): 1,
#  ('t͡ʃ̩̩', 'd͡ʒ'): 1,
#  ('t͡ʃ̩̩', 'ø'): 1,
#  ('t͡ʃ̩̩', 'ɑ̃'): 1,
#  ('t͡ʃ̩̩', 'ɲ'): 1,
#  ('t͡ʃ̩̩', 'ɒ̃'): 1,
#  ('t͡ʃ̩̩', 'ɑː'): 1,
#  ('t͡ʃ̩̩', 'pː'): 1,
#  ('t͡ʃ̩̩', 'æ'): 1,
#  ('t͡ʃ̩̩', 'o'): 1,
#  ('t͡ʃ̩̩', 'ē'): 1,
#  ('t͡ʃ̩̩', 'dʰ'): 1,
#  ('t͡ʃ̩̩', 'ɑ'): 1,
#  ('t͡ʃ̩̩', 'ɛ͡ɪ'): 1,
#  ('t͡ʃ̩̩', 'ɕː'): 1,
#  ('t͡ʃ̩̩', 'START'): 1,
#  ('t͡ʃ̩̩', 'ʊ̪'): 1,
#  ('t͡ʃ̩̩', 'm̩'): 1,
#  ('t͡ʃ̩̩', 'ç'): 1,
#  ('t͡ʃ̩̩', 'ɒː'): 1,
#  ('t͡ʃ̩̩', 'ɪʲ'): 1,
#  ('t͡ʃ̩̩', 'ɖ'): 1,
#  ('t͡ʃ̩̩', 'ʒ'): 1,
#  ('t͡ʃ̩̩', 'l̩'): 1,
#  ('t͡ʃ̩̩', 'îː'): 1,
#  ('t͡ʃ̩̩', 'm'): 1,
#  ('t͡ʃ̩̩', 'ô'): 1,
#  ('t͡ʃ̩̩', 'ĭ̥'): 1,
#  ('t͡ʃ̩̩', 'œ'): 1,
#  ('t͡ʃ̩̩', 'ɐː'): 1,
#  ('t͡ʃ̩̩', 'a'): 1,
#  ('t͡ʃ̩̩', 'ːs'): 1,
#  ('t͡ʃ̩̩', 'ɭ'): 1,
#  ('t͡ʃ̩̩', 'ɛ'): 1,
#  ('t͡ʃ̩̩', 'ú'): 1,
#  ('t͡ʃ̩̩', 'ɛ̝'): 1,
#  ('t͡ʃ̩̩', 'q'): 1,
#  ('t͡ʃ̩̩', 'i'): 1,
#  ('t͡ʃ̩̩', 'aː'): 1,
#  ('t͡ʃ̩̩', 'e͡ɪ'): 1,
#  ('t͡ʃ̩̩', 'æ̃'): 1,
#  ('t͡ʃ̩̩', 'ɘ'): 1,
#  ('t͡ʃ̩̩', 'ɱ'): 1,
#  ('t͡ʃ̩̩', 'e'): 1,
#  ('t͡ʃ̩̩', 'ṽ'): 1,
#  ('t͡ʃ̩̩', 'ɾ'): 1,
#  ('t͡ʃ̩̩', 'ʀ'): 1,
#  ('t͡ʃ̩̩', 't͡ʃ'): 1,
#  ('t͡ʃ̩̩', 'ʈ'): 1,
#  ('t͡ʃ̩̩', 'c'): 1,
#  ('t͡ʃ̩̩', 'ä'): 1,
#  ('t͡ʃ̩̩', 'ɦ'): 1,
#  ('t͡ʃ̩̩', 'ə'): 1,
#  ('t͡ʃ̩̩', 'ɔː'): 1,
#  ('t͡ʃ̩̩', 'sː'): 1,
#  ('t͡ʃ̩̩', 'ɣ'): 1,
#  ('t͡ʃ̩̩', 'ɛ̃'): 1,
#  ('t͡ʃ̩̩', 'n'): 1,
#  ('t͡ʃ̩̩', 'kᵊ'): 1,
#  ('t͡ʃ̩̩', 'p̬'): 1,
#  ('t͡ʃ̩̩', 'k'): 1,
#  ('t͡ʃ̩̩', 'ŭ̥'): 1,
#  ('t͡ʃ̩̩', 'ɪ̪'): 1,
#  ('t͡ʃ̩̩', 'mː'): 1,
#  ('t͡ʃ̩̩', 'æː'): 1,
#  ('t͡ʃ̩̩', 'd'): 1,
#  ('t͡ʃ̩̩', 'ʃː'): 1,
#  ('t͡ʃ̩̩', 'dʲ'): 1,
#  ('t͡ʃ̩̩', 'pʰ'): 1,
#  ('t͡ʃ̩̩', 'ʃ'): 1,
#  ('t͡ʃ̩̩', 'ã'): 1,
#  ('t͡ʃ̩̩', 'o̞'): 1,
#  ('t͡ʃ̩̩', 'ŋ'): 1,
#  ('t͡ʃ̩̩', 'tː'): 1,
#  ('t͡ʃ̩̩', 'v'): 1,
#  ('t͡ʃ̩̩', 'əʳ'): 1,
#  ('t͡ʃ̩̩', 'ɵ̞'): 1,
#  ('t͡ʃ̩̩', 'STOP'): 1,
#  ('t͡ʃ̩̩', 'θ'): 1,
#  ('t͡ʃ̩̩', 'ɽ'): 1,
#  ('t͡ʃ̩̩', 'fː'): 1,
#  ('t͡ʃ̩̩', 'u'): 1,
#  ('t͡ʃ̩̩', '~'): 1,
#  ('t͡ʃ̩̩', 'ɫ'): 1,
#  ('t͡ʃ̩̩', 'lʲ'): 1,
#  ('t͡ʃ̩̩', 'äː'): 1,
#  ('t͡ʃ̩̩', '˞'): 1,
#  ('t͡ʃ̩̩', 'tᵊ'): 1,
#  ('t͡ʃ̩̩', 'bʲ'): 1,
#  ('t͡ʃ̩̩', 'ʉ'): 1,
#  ('t͡ʃ̩̩', 'χ'): 1,
#  ('t͡ʃ̩̩', 'ɐ'): 1,
#  ('t͡ʃ̩̩', 'm̩ː'): 1,
#  ('t͡ʃ̩̩', 'ɜ̃'): 1,
#  ('t͡ʃ̩̩', 'k̚'): 1,
#  ('t͡ʃ̩̩', 'ʌ̈'): 1,
#  ('t͡ʃ̩̩', 'ʔ'): 1,
#  ('t͡ʃ̩̩', 'ʌ'): 1,
#  ('t͡ʃ̩̩', 'oˀ'): 1,
#  ('t͡ʃ̩̩', 'ə̆'): 1,
#  ('t͡ʃ̩̩', 'ʊː'): 1,
#  ('t͡ʃ̩̩', 'ɝː'): 1,
#  ('t͡ʃ̩̩', 't͡ʃʰ'): 1,
#  ('t͡ʃ̩̩', 'ɵ'): 1,
#  ('t͡ʃ̩̩', 'tʰ'): 1,
#  ('t͡ʃ̩̩', 'kʰ'): 1,
#  ('t͡ʃ̩̩', 'ɯ'): 1,
#  ('t͡ʃ̩̩', 'ð'): 1,
#  ('t͡ʃ̩̩', 'ɔ̃'): 1,
#  ('t͡ʃ̩̩', 'ɛ͡ɹ'): 1,
#  ('t͡ʃ̩̩', 'ɹʷ'): 1,
#  ('t͡ʃ̩̩', 'ʊ̩'): 1,
#  ('t͡ʃ̩̩', 'ɨ'): 1,
#  ('t͡ʃ̩̩', 'oː'): 1,
#  ('t͡ʃ̩̩', 'iː'): 1,
#  ('t͡ʃ̩̩', '↓'): 1,
#  ('t͡ʃ̩̩', 'ʏ'): 1,
#  ('t͡ʃ̩̩', 'ɜ'): 1,
#  ('t͡ʃ̩̩', 'ɪ̯'): 1,
#  ('t͡ʃ̩̩', 'ɔ'): 1,
#  ('t͡ʃ̩̩', 'əˑ'): 1,
#  ('t͡ʃ̩̩', 'ʍ'): 1,
#  ('t͡ʃ̩̩', 'h'): 1,
#  ('t͡ʃ̩̩', 'r̩'): 1,
#  ('t͡ʃ̩̩', 'ɪ̈'): 1,
#  ('t͡ʃ̩̩', 'ɹ̩'): 1,
#  ('t͡ʃ̩̩', 'ɑˑ'): 1,
#  ('t͡ʃ̩̩', 'ʊ̆'): 1,
#  ('t͡ʃ̩̩', 'ɡː'): 1,
#  ('t͡ʃ̩̩', 'ʉː'): 1,
#  ('t͡ʃ̩̩', 'ɚ'): 1,
#  ('t͡ʃ̩̩', 'ɬ'): 1,
#  ('t͡ʃ̩̩', 'eː'): 1,
#  ('t͡ʃ̩̩', 'w'): 1,
#  ('t͡ʃ̩̩', 'x'): 1,
#  ('t͡ʃ̩̩', 'l'): 1,
#  ('t͡ʃ̩̩', 'ʊ'): 1,
#  ('t͡ʃ̩̩', 'o͡ʊ'): 1,
#  ('t͡ʃ̩̩', 'ĩ'): 1,
#  ('t͡ʃ̩̩', 'ɾ̃'): 1,
#  ('t͡ʃ̩̩', 't̬ᵊ'): 1,
#  ('t͡ʃ̩̩', 'ʃʰ'): 1,
#  ('t͡ʃ̩̩', 'ɚː'): 1,
#  ('əː', 'y'): 1,
#  ('əː', 'ɡ'): 1,
#  ('əː', 't͡ʃ̩̩'): 1,
#  ('əː', 'əː'): 1,
#  ('əː', 'z'): 1,
#  ('əː', 'p'): 1,
#  ('əː', 't͡s'): 1,
#  ('əː', 'b'): 1,
#  ('əː', 'ɛː'): 1,
#  ('əː', 'ʊ̂'): 1,
#  ('əː', 'ʊ̯'): 1,
#  ('əː', 'ɛˑ'): 1,
#  ('əː', 'ɜː'): 1,
#  ('əː', 'ɻ'): 1,
#  ('əː', 'ʁ'): 1,
#  ('əː', 'bᵊ'): 1,
#  ('əː', 'n̩'): 1,
#  ('əː', 'ɪ'): 1,
#  ('əː', 'ɹ'): 1,
#  ('əː', 'ĭ'): 1,
#  ('əː', 'd̪'): 1,
#  ('əː', 'nˡ'): 1,
#  ('əː', 't̬'): 1,
#  ('əː', 'ʌː'): 1,
#  ('əː', 'r'): 1,
#  ('əː', 'ɔ͡ɪ'): 1,
#  ('əː', 's'): 1,
#  ('əː', 'nː'): 1,
#  ('əː', 't'): 1,
#  ('əː', 'ɒ'): 1,
#  ('əː', 't͡ɕ'): 1,
#  ('əː', 'e͜ɚ'): 1,
#  ('əː', 'ɫ̩'): 1,
#  ('əː', 'f'): 1,
#  ('əː', 'l͡s'): 1,
#  ('əː', 'ɹː'): 1,
#  ('əː', 'ɪˑ'): 1,
#  ('əː', 'ɪː'): 1,
#  ('əː', 'ʙ̩ː'): 1,
#  ('əː', 'õ'): 1,
#  ('əː', 'ə̯'): 1,
#  ('əː', 'ɝ'): 1,
#  ('əː', 'j'): 1,
#  ('əː', 'uː'): 1,
#  ('əː', 'd͡ʒ'): 1,
#  ('əː', 'ø'): 1,
#  ('əː', 'ɑ̃'): 1,
#  ('əː', 'ɲ'): 1,
#  ('əː', 'ɒ̃'): 1,
#  ('əː', 'ɑː'): 1,
#  ('əː', 'pː'): 1,
#  ('əː', 'æ'): 1,
#  ('əː', 'o'): 1,
#  ('əː', 'ē'): 1,
#  ('əː', 'dʰ'): 1,
#  ('əː', 'ɑ'): 1,
#  ('əː', 'ɛ͡ɪ'): 1,
#  ('əː', 'ɕː'): 1,
#  ('əː', 'START'): 1,
#  ('əː', 'ʊ̪'): 1,
#  ('əː', 'm̩'): 1,
#  ('əː', 'ç'): 1,
#  ('əː', 'ɒː'): 1,
#  ('əː', 'ɪʲ'): 1,
#  ('əː', 'ɖ'): 1,
#  ('əː', 'ʒ'): 1,
#  ('əː', 'l̩'): 1,
#  ('əː', 'îː'): 1,
#  ('əː', 'm'): 1,
#  ('əː', 'ô'): 1,
#  ('əː', 'ĭ̥'): 1,
#  ('əː', 'œ'): 1,
#  ('əː', 'ɐː'): 1,
#  ('əː', 'a'): 1,
#  ('əː', 'ːs'): 1,
#  ('əː', 'ɭ'): 1,
#  ('əː', 'ɛ'): 1,
#  ('əː', 'ú'): 1,
#  ('əː', 'ɛ̝'): 1,
#  ('əː', 'q'): 1,
#  ('əː', 'i'): 1,
#  ('əː', 'aː'): 1,
#  ('əː', 'e͡ɪ'): 1,
#  ('əː', 'æ̃'): 1,
#  ('əː', 'ɘ'): 1,
#  ('əː', 'ɱ'): 1,
#  ('əː', 'e'): 1,
#  ('əː', 'ṽ'): 1,
#  ('əː', 'ɾ'): 1,
#  ('əː', 'ʀ'): 1,
#  ('əː', 't͡ʃ'): 1,
#  ('əː', 'ʈ'): 1,
#  ('əː', 'c'): 1,
#  ('əː', 'ä'): 1,
#  ('əː', 'ɦ'): 1,
#  ('əː', 'ə'): 1,
#  ('əː', 'ɔː'): 1,
#  ('əː', 'sː'): 1,
#  ('əː', 'ɣ'): 1,
#  ('əː', 'ɛ̃'): 1,
#  ('əː', 'n'): 1,
#  ('əː', 'kᵊ'): 1,
#  ('əː', 'p̬'): 1,
#  ('əː', 'k'): 1,
#  ('əː', 'ŭ̥'): 1,
#  ('əː', 'ɪ̪'): 1,
#  ('əː', 'mː'): 1,
#  ('əː', 'æː'): 1,
#  ('əː', 'd'): 1,
#  ('əː', 'ʃː'): 1,
#  ('əː', 'dʲ'): 1,
#  ('əː', 'pʰ'): 1,
#  ('əː', 'ʃ'): 1,
#  ('əː', 'ã'): 1,
#  ('əː', 'o̞'): 1,
#  ('əː', 'ŋ'): 1,
#  ('əː', 'tː'): 1,
#  ('əː', 'v'): 1,
#  ('əː', 'əʳ'): 1,
#  ('əː', 'ɵ̞'): 1,
#  ('əː', 'STOP'): 1,
#  ('əː', 'θ'): 1,
#  ('əː', 'ɽ'): 1,
#  ('əː', 'fː'): 1,
#  ('əː', 'u'): 1,
#  ('əː', '~'): 1,
#  ('əː', 'ɫ'): 1,
#  ('əː', 'lʲ'): 1,
#  ('əː', 'äː'): 1,
#  ('əː', '˞'): 1,
#  ('əː', 'tᵊ'): 1,
#  ('əː', 'bʲ'): 1,
#  ('əː', 'ʉ'): 1,
#  ('əː', 'χ'): 1,
#  ('əː', 'ɐ'): 1,
#  ('əː', 'm̩ː'): 1,
#  ('əː', 'ɜ̃'): 1,
#  ('əː', 'k̚'): 1,
#  ('əː', 'ʌ̈'): 1,
#  ('əː', 'ʔ'): 1,
#  ('əː', 'ʌ'): 1,
#  ('əː', 'oˀ'): 1,
#  ('əː', 'ə̆'): 1,
#  ('əː', 'ʊː'): 1,
#  ('əː', 'ɝː'): 1,
#  ('əː', 't͡ʃʰ'): 1,
#  ('əː', 'ɵ'): 1,
#  ('əː', 'tʰ'): 1,
#  ('əː', 'kʰ'): 1,
#  ('əː', 'ɯ'): 1,
#  ('əː', 'ð'): 1,
#  ('əː', 'ɔ̃'): 1,
#  ('əː', 'ɛ͡ɹ'): 1,
#  ('əː', 'ɹʷ'): 1,
#  ('əː', 'ʊ̩'): 1,
#  ('əː', 'ɨ'): 1,
#  ('əː', 'oː'): 1,
#  ('əː', 'iː'): 1,
#  ('əː', '↓'): 1,
#  ('əː', 'ʏ'): 1,
#  ('əː', 'ɜ'): 1,
#  ('əː', 'ɪ̯'): 1,
#  ('əː', 'ɔ'): 1,
#  ('əː', 'əˑ'): 1,
#  ('əː', 'ʍ'): 1,
#  ('əː', 'h'): 1,
#  ('əː', 'r̩'): 1,
#  ('əː', 'ɪ̈'): 1,
#  ('əː', 'ɹ̩'): 1,
#  ('əː', 'ɑˑ'): 1,
#  ('əː', 'ʊ̆'): 1,
#  ('əː', 'ɡː'): 1,
#  ('əː', 'ʉː'): 1,
#  ('əː', 'ɚ'): 1,
#  ('əː', 'ɬ'): 1,
#  ('əː', 'eː'): 1,
#  ('əː', 'w'): 1,
#  ('əː', 'x'): 1,
#  ('əː', 'l'): 1,
#  ('əː', 'ʊ'): 1,
#  ('əː', 'o͡ʊ'): 1,
#  ('əː', 'ĩ'): 1,
#  ('əː', 'ɾ̃'): 1,
#  ('əː', 't̬ᵊ'): 1,
#  ('əː', 'ʃʰ'): 1,
#  ('əː', 'ɚː'): 1,
#  ('z', 'y'): 1,
#  ('z', 'ɡ'): 1,
#  ('z', 't͡ʃ̩̩'): 1,
#  ('z', 'əː'): 1,
#  ('z', 'z'): 1,
#  ('z', 'p'): 1,
#  ('z', 't͡s'): 1,
#  ('z', 'b'): 1,
#  ('z', 'ɛː'): 1,
#  ('z', 'ʊ̂'): 1,
#  ('z', 'ʊ̯'): 1,
#  ('z', 'ɛˑ'): 1,
#  ('z', 'ɜː'): 1,
#  ('z', 'ɻ'): 1,
#  ('z', 'ʁ'): 1,
#  ('z', 'bᵊ'): 1,
#  ('z', 'n̩'): 1,
#  ('z', 'ɪ'): 1,
#  ('z', 'ɹ'): 1,
#  ('z', 'ĭ'): 1,
#  ('z', 'd̪'): 1,
#  ('z', 'nˡ'): 1,
#  ('z', 't̬'): 1,
#  ('z', 'ʌː'): 1,
#  ('z', 'r'): 1,
#  ('z', 'ɔ͡ɪ'): 1,
#  ('z', 's'): 1,
#  ('z', 'nː'): 1,
#  ('z', 't'): 1,
#  ('z', 'ɒ'): 1,
#  ('z', 't͡ɕ'): 1,
#  ('z', 'e͜ɚ'): 1,
#  ('z', 'ɫ̩'): 1,
#  ('z', 'f'): 1,
#  ('z', 'l͡s'): 1,
#  ('z', 'ɹː'): 1,
#  ('z', 'ɪˑ'): 1,
#  ('z', 'ɪː'): 1,
#  ('z', 'ʙ̩ː'): 1,
#  ('z', 'õ'): 1,
#  ('z', 'ə̯'): 1,
#  ('z', 'ɝ'): 1,
#  ('z', 'j'): 1,
#  ('z', 'uː'): 1,
#  ('z', 'd͡ʒ'): 1,
#  ('z', 'ø'): 1,
#  ('z', 'ɑ̃'): 1,
#  ('z', 'ɲ'): 1,
#  ('z', 'ɒ̃'): 1,
#  ('z', 'ɑː'): 1,
#  ('z', 'pː'): 1,
#  ('z', 'æ'): 1,
#  ('z', 'o'): 1,
#  ('z', 'ē'): 1,
#  ('z', 'dʰ'): 1,
#  ('z', 'ɑ'): 1,
#  ('z', 'ɛ͡ɪ'): 1,
#  ('z', 'ɕː'): 1,
#  ('z', 'START'): 1,
#  ('z', 'ʊ̪'): 1,
#  ('z', 'm̩'): 1,
#  ('z', 'ç'): 1,
#  ('z', 'ɒː'): 1,
#  ('z', 'ɪʲ'): 1,
#  ('z', 'ɖ'): 1,
#  ('z', 'ʒ'): 1,
#  ('z', 'l̩'): 1,
#  ('z', 'îː'): 1,
#  ('z', 'm'): 1,
#  ('z', 'ô'): 1,
#  ('z', 'ĭ̥'): 1,
#  ('z', 'œ'): 1,
#  ('z', 'ɐː'): 1,
#  ('z', 'a'): 1,
#  ('z', 'ːs'): 1,
#  ('z', 'ɭ'): 1,
#  ('z', 'ɛ'): 1,
#  ('z', 'ú'): 1,
#  ('z', 'ɛ̝'): 1,
#  ('z', 'q'): 1,
#  ('z', 'i'): 1,
#  ('z', 'aː'): 1,
#  ('z', 'e͡ɪ'): 1,
#  ('z', 'æ̃'): 1,
#  ('z', 'ɘ'): 1,
#  ('z', 'ɱ'): 1,
#  ('z', 'e'): 1,
#  ('z', 'ṽ'): 1,
#  ('z', 'ɾ'): 1,
#  ('z', 'ʀ'): 1,
#  ('z', 't͡ʃ'): 1,
#  ('z', 'ʈ'): 1,
#  ('z', 'c'): 1,
#  ('z', 'ä'): 1,
#  ('z', 'ɦ'): 1,
#  ('z', 'ə'): 1,
#  ('z', 'ɔː'): 1,
#  ('z', 'sː'): 1,
#  ('z', 'ɣ'): 1,
#  ('z', 'ɛ̃'): 1,
#  ('z', 'n'): 1,
#  ('z', 'kᵊ'): 1,
#  ('z', 'p̬'): 1,
#  ('z', 'k'): 1,
#  ('z', 'ŭ̥'): 1,
#  ('z', 'ɪ̪'): 1,
#  ('z', 'mː'): 1,
#  ('z', 'æː'): 1,
#  ('z', 'd'): 1,
#  ('z', 'ʃː'): 1,
#  ('z', 'dʲ'): 1,
#  ('z', 'pʰ'): 1,
#  ('z', 'ʃ'): 1,
#  ('z', 'ã'): 1,
#  ('z', 'o̞'): 1,
#  ('z', 'ŋ'): 1,
#  ('z', 'tː'): 1,
#  ('z', 'v'): 1,
#  ('z', 'əʳ'): 1,
#  ('z', 'ɵ̞'): 1,
#  ('z', 'STOP'): 1,
#  ('z', 'θ'): 1,
#  ('z', 'ɽ'): 1,
#  ('z', 'fː'): 1,
#  ('z', 'u'): 1,
#  ('z', '~'): 1,
#  ('z', 'ɫ'): 1,
#  ('z', 'lʲ'): 1,
#  ('z', 'äː'): 1,
#  ('z', '˞'): 1,
#  ('z', 'tᵊ'): 1,
#  ('z', 'bʲ'): 1,
#  ('z', 'ʉ'): 1,
#  ('z', 'χ'): 1,
#  ('z', 'ɐ'): 1,
#  ('z', 'm̩ː'): 1,
#  ('z', 'ɜ̃'): 1,
#  ('z', 'k̚'): 1,
#  ('z', 'ʌ̈'): 1,
#  ('z', 'ʔ'): 1,
#  ('z', 'ʌ'): 1,
#  ('z', 'oˀ'): 1,
#  ('z', 'ə̆'): 1,
#  ('z', 'ʊː'): 1,
#  ('z', 'ɝː'): 1,
#  ('z', 't͡ʃʰ'): 1,
#  ('z', 'ɵ'): 1,
#  ('z', 'tʰ'): 1,
#  ('z', 'kʰ'): 1,
#  ('z', 'ɯ'): 1,
#  ('z', 'ð'): 1,
#  ('z', 'ɔ̃'): 1,
#  ('z', 'ɛ͡ɹ'): 1,
#  ('z', 'ɹʷ'): 1,
#  ('z', 'ʊ̩'): 1,
#  ('z', 'ɨ'): 1,
#  ('z', 'oː'): 1,
#  ('z', 'iː'): 1,
#  ('z', '↓'): 1,
#  ('z', 'ʏ'): 1,
#  ('z', 'ɜ'): 1,
#  ('z', 'ɪ̯'): 1,
#  ('z', 'ɔ'): 1,
#  ('z', 'əˑ'): 1,
#  ('z', 'ʍ'): 1,
#  ('z', 'h'): 1,
#  ('z', 'r̩'): 1,
#  ('z', 'ɪ̈'): 1,
#  ('z', 'ɹ̩'): 1,
#  ('z', 'ɑˑ'): 1,
#  ('z', 'ʊ̆'): 1,
#  ('z', 'ɡː'): 1,
#  ('z', 'ʉː'): 1,
#  ('z', 'ɚ'): 1,
#  ('z', 'ɬ'): 1,
#  ('z', 'eː'): 1,
#  ('z', 'w'): 1,
#  ('z', 'x'): 1,
#  ('z', 'l'): 1,
#  ('z', 'ʊ'): 1,
#  ('z', 'o͡ʊ'): 1,
#  ('z', 'ĩ'): 1,
#  ('z', 'ɾ̃'): 1,
#  ('z', 't̬ᵊ'): 1,
#  ('z', 'ʃʰ'): 1,
#  ('z', 'ɚː'): 1,
#  ('p', 'y'): 1,
#  ('p', 'ɡ'): 1,
#  ('p', 't͡ʃ̩̩'): 1,
#  ('p', 'əː'): 1,
#  ('p', 'z'): 1,
#  ('p', 'p'): 1,
#  ('p', 't͡s'): 1,
#  ('p', 'b'): 1,
#  ('p', 'ɛː'): 1,
#  ('p', 'ʊ̂'): 1,
#  ('p', 'ʊ̯'): 1,
#  ('p', 'ɛˑ'): 1,
#  ('p', 'ɜː'): 1,
#  ('p', 'ɻ'): 1,
#  ('p', 'ʁ'): 1,
#  ('p', 'bᵊ'): 1,
#  ('p', 'n̩'): 1,
#  ('p', 'ɪ'): 1,
#  ('p', 'ɹ'): 1,
#  ('p', 'ĭ'): 1,
#  ('p', 'd̪'): 1,
#  ('p', 'nˡ'): 1,
#  ('p', 't̬'): 1,
#  ('p', 'ʌː'): 1,
#  ('p', 'r'): 1,
#  ('p', 'ɔ͡ɪ'): 1,
#  ('p', 's'): 1,
#  ('p', 'nː'): 1,
#  ('p', 't'): 1,
#  ('p', 'ɒ'): 1,
#  ('p', 't͡ɕ'): 1,
#  ('p', 'e͜ɚ'): 1,
#  ('p', 'ɫ̩'): 1,
#  ('p', 'f'): 1,
#  ('p', 'l͡s'): 1,
#  ('p', 'ɹː'): 1,
#  ('p', 'ɪˑ'): 1,
#  ('p', 'ɪː'): 1,
#  ('p', 'ʙ̩ː'): 1,
#  ('p', 'õ'): 1,
#  ('p', 'ə̯'): 1,
#  ('p', 'ɝ'): 1,
#  ('p', 'j'): 1,
#  ('p', 'uː'): 1,
#  ('p', 'd͡ʒ'): 1,
#  ('p', 'ø'): 1,
#  ('p', 'ɑ̃'): 1,
#  ('p', 'ɲ'): 1,
#  ('p', 'ɒ̃'): 1,
#  ('p', 'ɑː'): 1,
#  ('p', 'pː'): 1,
#  ('p', 'æ'): 1,
#  ('p', 'o'): 1,
#  ('p', 'ē'): 1,
#  ('p', 'dʰ'): 1,
#  ('p', 'ɑ'): 1,
#  ('p', 'ɛ͡ɪ'): 1,
#  ('p', 'ɕː'): 1,
#  ('p', 'START'): 1,
#  ('p', 'ʊ̪'): 1,
#  ('p', 'm̩'): 1,
#  ('p', 'ç'): 1,
#  ('p', 'ɒː'): 1,
#  ('p', 'ɪʲ'): 1,
#  ('p', 'ɖ'): 1,
#  ('p', 'ʒ'): 1,
#  ('p', 'l̩'): 1,
#  ('p', 'îː'): 1,
#  ('p', 'm'): 1,
#  ('p', 'ô'): 1,
#  ...}

# %%
# now add in the actual bigram counts
prons = df.Pron
for pron in prons:
    # YOUR CODE GOES HERE.
    # increment the ptc count for (p1,p2) each time you encounter the bigram "p1 p2" in the data.
    for i in range(len(pron) - 1):
        ptc[(pron[i], pron[i + 1])] += 1
    

# sanity-check some of the counts.
print("START d", ptc[('START','d')])
print("d START", ptc[('d','START')])
print("f ɹ", ptc[('f','ɹ')])
print("ɹ f", ptc[('ɹ','f')])
print("g ɹ", ptc[('ɡ','ɹ')])
print("ɹ g", ptc[('ɹ','ɡ')])
print("s l", ptc[('s','l')])
print("l s", ptc[('l','s')])
# Out:
# START d 3380
# d START 1
# f ɹ 500
# ɹ f 153
# g ɹ 875
# ɹ g 125
# s l 404
# l s 135

# %% [markdown]
# Now transform the phoneme transition **counts** into phoneme transition **probabilities**.
#
# For every pair of phonemes $p_1, p_2$, we already have ptc($p_1$,$p_2$): the phoneme transition count from $p_1$ to $p_2$, i.e. the number of times we encountered the bigram $p_1 p_2$ in the data.
#
# From this, we want to obtain the transition **probability** $p(p_2|p_1)$, i.e. the probability of encountering $p_2$, given that we have just seen $p_1$.  Note the order of the two phonemes: our bigram is $p_1 p_2$, and we use the count for it (and other bigrams) to obtain $p(p_2|p_1)$.
#
# How?  This is a conditional probability, and following the Bishop chapter, or Jurafsky and Martin eqn 3.11, we may calculate it as:
#
# \begin{equation}
# p(p_2|p_1) = \frac{c(p_1 p_2)}{c(p_1)}
# \end{equation}
#
# where $c(\cdot)$ denotes count.  The numerator is simply the count for the bigram $p_1 p_2$.  The denominator is the count for $p_1$ whatever phoneme may follow it.  We have bigram counts, so we can easily obtain the denominator $c(p_1)$ as:
#
# \begin{equation}
# c(p_1) = \sum_{q \in P} c(p_1 q)
# \end{equation}
#
# where $P$ is the set of all phonemes.

# %%
# data structure for transition probabilities is a dict of dicts.
# the outer dict is keyed by phoneme (state), and has value inner dict.
# the inner dict is also keyed by phoneme, and holds the probability of moving from the outer phoneme
# to the inner phoneme, i.e. p(inner|outer).
# this structure should make it easy to convert counts to probs, normalize etc.

tp = dict()  # transition probs, outer dict.
for p1 in phonemes:
    d = dict()  # inner dict
    # YOUR CODE GOES HERE.
    p1_total = 0
    for key in ptc.keys():
        p1_total += ptc[key] if key[0] == p1 else 0
    for p2 in phonemes:
        d[p2] = ptc[(p1, p2)] / p1_total
    
    tp[p1] = d

# %%
# sanity check.
# the conditional probabilities p(p2|p1) should add up to 1.0 when summing across p2, for each p1.
print("Sanity check: do the conditional probabilities conditioned on each phoneme sum to 1.0?")
for p1 in phonemes:
    total = sum(tp[p1].values())
    print("Sum of conditional probabilities conditioned on", p1, total)
# Out:
# Sanity check: do the conditional probabilities conditioned on each phoneme sum to 1.0?
# Sum of conditional probabilities conditioned on y 1.0000000000000022
# Sum of conditional probabilities conditioned on ɡ 0.999999999999996
# Sum of conditional probabilities conditioned on t͡ʃ̩̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on əː 1.000000000000002
# Sum of conditional probabilities conditioned on z 1.000000000000002
# Sum of conditional probabilities conditioned on p 0.9999999999999982
# Sum of conditional probabilities conditioned on t͡s 0.9999999999999959
# Sum of conditional probabilities conditioned on b 0.9999999999999969
# Sum of conditional probabilities conditioned on ɛː 1.000000000000002
# Sum of conditional probabilities conditioned on ʊ̂ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̯ 0.9999999999999987
# Sum of conditional probabilities conditioned on ɛˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɜː 0.9999999999999972
# Sum of conditional probabilities conditioned on ɻ 1.0000000000000047
# Sum of conditional probabilities conditioned on ʁ 1.0000000000000027
# Sum of conditional probabilities conditioned on bᵊ 1.0000000000000022
# Sum of conditional probabilities conditioned on n̩ 0.9999999999999997
# Sum of conditional probabilities conditioned on ɪ 0.9999999999999989
# Sum of conditional probabilities conditioned on ɹ 1.000000000000002
# Sum of conditional probabilities conditioned on ĭ 1.0000000000000007
# Sum of conditional probabilities conditioned on d̪ 1.0000000000000027
# Sum of conditional probabilities conditioned on nˡ 1.0000000000000027
# Sum of conditional probabilities conditioned on t̬ 1.0000000000000007
# Sum of conditional probabilities conditioned on ʌː 1.0000000000000022
# Sum of conditional probabilities conditioned on r 1.000000000000003
# Sum of conditional probabilities conditioned on ɔ͡ɪ 1.0000000000000027
# Sum of conditional probabilities conditioned on s 1.0000000000000029
# Sum of conditional probabilities conditioned on nː 0.9999999999999959
# Sum of conditional probabilities conditioned on t 0.9999999999999996
# Sum of conditional probabilities conditioned on ɒ 0.9999999999999984
# Sum of conditional probabilities conditioned on t͡ɕ 1.0000000000000024
# Sum of conditional probabilities conditioned on e͜ɚ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɫ̩ 1.000000000000002
# Sum of conditional probabilities conditioned on f 1.0000000000000022
# Sum of conditional probabilities conditioned on l͡s 1.0000000000000027
# Sum of conditional probabilities conditioned on ɹː 1.0000000000000047
# Sum of conditional probabilities conditioned on ɪˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɪː 1.0000000000000018
# Sum of conditional probabilities conditioned on ʙ̩ː 1.0000000000000027
# Sum of conditional probabilities conditioned on õ 1.0000000000000027
# Sum of conditional probabilities conditioned on ə̯ 0.9999999999999976
# Sum of conditional probabilities conditioned on ɝ 0.9999999999999974
# Sum of conditional probabilities conditioned on j 1.0000000000000024
# Sum of conditional probabilities conditioned on uː 1.000000000000001
# Sum of conditional probabilities conditioned on d͡ʒ 0.9999999999999973
# Sum of conditional probabilities conditioned on ø 1.0000000000000027
# Sum of conditional probabilities conditioned on ɑ̃ 0.9999999999999979
# Sum of conditional probabilities conditioned on ɲ 1.000000000000005
# Sum of conditional probabilities conditioned on ɒ̃ 1.0000000000000016
# Sum of conditional probabilities conditioned on ɑː 1.000000000000002
# Sum of conditional probabilities conditioned on pː 1.0000000000000049
# Sum of conditional probabilities conditioned on æ 0.9999999999999988
# Sum of conditional probabilities conditioned on o 1.0
# Sum of conditional probabilities conditioned on ē 0.9999999999999959
# Sum of conditional probabilities conditioned on dʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɑ 1.0000000000000016
# Sum of conditional probabilities conditioned on ɛ͡ɪ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɕː 1.0000000000000027
# Sum of conditional probabilities conditioned on START 1.0000000000000024
# Sum of conditional probabilities conditioned on ʊ̪ 1.0000000000000027
# Sum of conditional probabilities conditioned on m̩ 1.0000000000000013
# Sum of conditional probabilities conditioned on ç 1.0000000000000024
# Sum of conditional probabilities conditioned on ɒː 1.000000000000002
# Sum of conditional probabilities conditioned on ɪʲ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɖ 1.0000000000000024
# Sum of conditional probabilities conditioned on ʒ 1.0000000000000016
# Sum of conditional probabilities conditioned on l̩ 1.0000000000000022
# Sum of conditional probabilities conditioned on îː 1.0000000000000027
# Sum of conditional probabilities conditioned on m 1.000000000000001
# Sum of conditional probabilities conditioned on ô 1.0000000000000027
# Sum of conditional probabilities conditioned on ĭ̥ 1.0000000000000027
# Sum of conditional probabilities conditioned on œ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɐː 1.0000000000000027
# Sum of conditional probabilities conditioned on a 1.0000000000000078
# Sum of conditional probabilities conditioned on ːs 1.0000000000000027
# Sum of conditional probabilities conditioned on ɭ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ 0.9999999999999979
# Sum of conditional probabilities conditioned on ú 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ̝ 1.0000000000000027
# Sum of conditional probabilities conditioned on q 1.0000000000000024
# Sum of conditional probabilities conditioned on i 0.9999999999999992
# Sum of conditional probabilities conditioned on aː 0.9999999999999966
# Sum of conditional probabilities conditioned on e͡ɪ 0.9999999999999959
# Sum of conditional probabilities conditioned on æ̃ 0.9999999999999961
# Sum of conditional probabilities conditioned on ɘ 1.0000000000000007
# Sum of conditional probabilities conditioned on ɱ 1.000000000000005
# Sum of conditional probabilities conditioned on e 1.0000000000000013
# Sum of conditional probabilities conditioned on ṽ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɾ 1.000000000000002
# Sum of conditional probabilities conditioned on ʀ 1.0000000000000027
# Sum of conditional probabilities conditioned on t͡ʃ 0.9999999999999994
# Sum of conditional probabilities conditioned on ʈ 1.000000000000002
# Sum of conditional probabilities conditioned on c 1.0000000000000027
# Sum of conditional probabilities conditioned on ä 1.000000000000002
# Sum of conditional probabilities conditioned on ɦ 1.0000000000000027
# Sum of conditional probabilities conditioned on ə 0.9999999999999983
# Sum of conditional probabilities conditioned on ɔː 1.0000000000000027
# Sum of conditional probabilities conditioned on sː 1.0000000000000022
# Sum of conditional probabilities conditioned on ɣ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɛ̃ 1.000000000000002
# Sum of conditional probabilities conditioned on n 0.9999999999999988
# Sum of conditional probabilities conditioned on kᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on p̬ 1.0000000000000022
# Sum of conditional probabilities conditioned on k 1.0000000000000038
# Sum of conditional probabilities conditioned on ŭ̥ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɪ̪ 1.0000000000000047
# Sum of conditional probabilities conditioned on mː 1.0000000000000022
# Sum of conditional probabilities conditioned on æː 1.0000000000000007
# Sum of conditional probabilities conditioned on d 1.000000000000002
# Sum of conditional probabilities conditioned on ʃː 1.0000000000000047
# Sum of conditional probabilities conditioned on dʲ 1.0000000000000022
# Sum of conditional probabilities conditioned on pʰ 1.000000000000005
# Sum of conditional probabilities conditioned on ʃ 0.9999999999999977
# Sum of conditional probabilities conditioned on ã 1.0000000000000027
# Sum of conditional probabilities conditioned on o̞ 1.0000000000000027
# Sum of conditional probabilities conditioned on ŋ 1.0000000000000004
# Sum of conditional probabilities conditioned on tː 1.0000000000000027
# Sum of conditional probabilities conditioned on v 0.9999999999999988
# Sum of conditional probabilities conditioned on əʳ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɵ̞ 1.0000000000000027
# Sum of conditional probabilities conditioned on STOP 0.9999999999999992
# Sum of conditional probabilities conditioned on θ 1.0000000000000036
# Sum of conditional probabilities conditioned on ɽ 1.0000000000000022
# Sum of conditional probabilities conditioned on fː 1.0000000000000024
# Sum of conditional probabilities conditioned on u 0.9999999999999977
# Sum of conditional probabilities conditioned on ~ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɫ 0.9999999999999984
# Sum of conditional probabilities conditioned on lʲ 1.0000000000000027
# Sum of conditional probabilities conditioned on äː 1.0000000000000027
# Sum of conditional probabilities conditioned on ˞ 1.000000000000002
# Sum of conditional probabilities conditioned on tᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on bʲ 1.0000000000000024
# Sum of conditional probabilities conditioned on ʉ 1.000000000000002
# Sum of conditional probabilities conditioned on χ 1.0000000000000007
# Sum of conditional probabilities conditioned on ɐ 1.0000000000000018
# Sum of conditional probabilities conditioned on m̩ː 1.0000000000000027
# Sum of conditional probabilities conditioned on ɜ̃ 1.0000000000000027
# Sum of conditional probabilities conditioned on k̚ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʌ̈ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʔ 1.0000000000000049
# Sum of conditional probabilities conditioned on ʌ 0.9999999999999971
# Sum of conditional probabilities conditioned on oˀ 1.0000000000000027
# Sum of conditional probabilities conditioned on ə̆ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊː 1.0000000000000022
# Sum of conditional probabilities conditioned on ɝː 0.9999999999999979
# Sum of conditional probabilities conditioned on t͡ʃʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɵ 1.0000000000000022
# Sum of conditional probabilities conditioned on tʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on kʰ 1.0000000000000029
# Sum of conditional probabilities conditioned on ɯ 1.0000000000000027
# Sum of conditional probabilities conditioned on ð 0.9999999999999989
# Sum of conditional probabilities conditioned on ɔ̃ 0.9999999999999977
# Sum of conditional probabilities conditioned on ɛ͡ɹ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɹʷ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɨ 1.0000000000000029
# Sum of conditional probabilities conditioned on oː 1.0000000000000027
# Sum of conditional probabilities conditioned on iː 1.000000000000001
# Sum of conditional probabilities conditioned on ↓ 1.0000000000000022
# Sum of conditional probabilities conditioned on ʏ 1.0000000000000022
# Sum of conditional probabilities conditioned on ɜ 1.000000000000004
# Sum of conditional probabilities conditioned on ɪ̯ 0.9999999999999973
# Sum of conditional probabilities conditioned on ɔ 0.9999999999999991
# Sum of conditional probabilities conditioned on əˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʍ 0.9999999999999952
# Sum of conditional probabilities conditioned on h 1.0000000000000002
# Sum of conditional probabilities conditioned on r̩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɪ̈ 1.000000000000001
# Sum of conditional probabilities conditioned on ɹ̩ 1.0000000000000022
# Sum of conditional probabilities conditioned on ɑˑ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʊ̆ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɡː 1.0000000000000027
# Sum of conditional probabilities conditioned on ʉː 0.999999999999996
# Sum of conditional probabilities conditioned on ɚ 1.0000000000000007
# Sum of conditional probabilities conditioned on ɬ 1.0000000000000027
# Sum of conditional probabilities conditioned on eː 0.9999999999999977
# Sum of conditional probabilities conditioned on w 0.9999999999999971
# Sum of conditional probabilities conditioned on x 1.0000000000000038
# Sum of conditional probabilities conditioned on l 1.000000000000002
# Sum of conditional probabilities conditioned on ʊ 0.999999999999998
# Sum of conditional probabilities conditioned on o͡ʊ 1.0000000000000047
# Sum of conditional probabilities conditioned on ĩ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɾ̃ 1.000000000000002
# Sum of conditional probabilities conditioned on t̬ᵊ 1.0000000000000027
# Sum of conditional probabilities conditioned on ʃʰ 1.0000000000000027
# Sum of conditional probabilities conditioned on ɚː 1.000000000000002

# %% [markdown]
# ### Congratulations!  You have created a Markov chain.
#
# Now use it to generate pseudo-words.

# %%
# specifically, let's generate 20 pseudo-words.
for i in range(20):
    # for each pseudo-word, we start by setting state to 'START'.
    state = 'START'
    print(state, end='')   # print state, but no newline.

    # now keep repeating this until you arrive at the 'STOP' state
    while (state != 'STOP'):
        next_state_options = list(tp[state].keys())
        next_state_probs = list(tp[state].values())
        new_state = np.random.choice(next_state_options, p=next_state_probs)
        print(" ", new_state, end='')
        state = new_state
    print(); print()
# Out:
# START  ɪ  l  STOP
#
# START  ə  n  ɪ  ɡ  z  STOP
#
# START  f  ɛ  l  ɪ  d  STOP
#
# START  l  ə  l  STOP
#
# START  t  ɪ  l  ɡ  STOP
#
# START  ə  n  d͡ʒ  ɛ̝  uː  STOP
#
# START  d  i  ə  d  ɛ  n  ɒ  m  ɑː  n  STOP
#
# START  h  a  ɪ  k  ə  s  ɑ  s  STOP
#
# START  f  ɛ  ə  p  ɹ  æ  f  ə  ɹ  ə  k  t  STOP
#
# START  n  ɪ  ə  ɹ  STOP
#
# START  s  ə  m  STOP
#
# START  ɛ  s  l  a  ɪ  n  STOP
#
# START  ɹ  STOP
#
# START  s  ɪ  t  æ  s  w  ɪ  STOP
#
# START  z  STOP
#
# START  ɹ  d  ə  s  t  ɪ  n  ɪ  ɾ  ə  n  s  t  ʃ  uː  m  z  STOP
#
# START  s  t  ə  d  ʒ  STOP
#
# START  f  ɝ  d  j  ɒ  ɡ  ɫ  pʰ  ɹ̩  ɪ̪  ə̆  ä  ɚː  ɛ̝  pʰ  ɜ̃  ã  ɾ  ə̯  d̪  p  ə  n  STOP
#
# START  k  STOP
#
# START  ʌ  p  ɪ  l  i  STOP

# %% [markdown]
# OK, that seemed to more or less work.  We get some reasonable-looking outputs, and also some that look a little strange.
#
# Now, just to highlight how natural some of the stranger-looking outputs we just saw were, we'll try the same thing, but flipping the roles of $p_1$ and $p_2$ in the counts.  That is, when we see the bigram $p_1 p_2$, we increment the count for $p_2 p_1$.
#
# What does this do?  It rewards or strengthens transitions that tend to show up in the **opposite order** from that actually encountered.
#
# What sort of output should we predict?
#
# **[ YOUR ANSWER GOES HERE. ]**
#
# **1. Each output word tend to be very long, often with multiple encounters with "START" in the middle before getting to "STOP."**
#
# **2. The combination of phonemes in each output word will sound more natural when read backwards then read normally.**

# %%
# generate transition probabilities from counts again, but this time with p1 and p2 swapped, 
# as described above.  this will be a lightly but strategically edited variant of a code box
# above.
tp_swapped = dict()  # transition probs
for p1 in phonemes:
    d = dict()
    # YOUR CODE GOES HERE.
    p1_total = 0
    for key in ptc.keys():
        p1_total += ptc[key] if key[1] == p1 else 0
    for p2 in phonemes:
        d[p2] = ptc[(p2, p1)] / p1_total
    
    tp_swapped[p1] = d

# %%
# now generate 20 pseudo-words with these swapped transition probabilities.
for i in range(20):
    # for each pseudo-word, we start by setting state to 'START'.
    state = 'START'
    print(state, end='')   # print state, but no newline.

    # now keep repeating this until you arrive at the 'STOP' state
    while (state != 'STOP'):
        next_state_options = list(tp_swapped[state].keys())
        next_state_probs = list(tp_swapped[state].values())
        new_state = np.random.choice(next_state_options, p=next_state_probs)
        print(" ", new_state, end='')
        state = new_state
    print(); print()
# Out:
# START  p̬  k̚  uː  ʍ  dʰ  χ  ô  c  ɔː  ɛ͡ɪ  e͡ɪ  w  START  fː  ɜ̃  d  ʊ  o  b  s  ɪ  a  h  t  ə  n  ə  ɹ  b  ɝ  l  ɪ  v  ɪ  e  ɹ  ə  ʒ  d  START  ʌ  k  ɹ  ʊ  o  m  ɛ  ʃ  k  ɑ  k  ə  START  k̚  ɑ̃  dʲ  ɑ̃  ŋ  ɪ  s  iː  w  k  ɛ  START  ã  ú  tʰ  θ  START  d͡ʒ  ɪ  ɹ  k  START  STOP
#
# START  əː  ə̆  ʌ̈  ʊː  m̩ː  h  START  ĭ̥  ʈ  ʔ  ɛ͡ɪ  l͡s  ɚː  q  ɔ̃  ʌ̈  x  ɫ̩  ô  ŋ  ɜː  ɡː  ɔ͡ɪ  o̞  dʲ  ɭ  y  æː  ʊː  ɹː  ɾ̃  oˀ  ɹ  ɑ  START  oː  æ  u  b  uː  j  n  ə  p  START  t̬  ɪ  ɹ  p  ə  k  ɪ  e  l  ə  n  ʌ  b  ə  ɹ  d  START  tʰ  a  ɹ  p  START  p̬  ɻ  ɑ  l  ə  j  n  ʊ  o  s  ɪ  n  ɪ  s  k  ŋ  ɪ  f  START
n  iː  d͡ʒ  ɑ  i  ɹ  ɪ  d  START  f  r  ə  START  ʌː  ɪː  ~  ɣ  l̩  b  m  ð  ɬ  əʳ  ɾ̃  ʊ̯  ʙ̩ː  nˡ  ɛ̝  bᵊ  v  ɝ  m  ɑ  k  ŋ  ɪ  a  b  START  ːs  ɔ͡ɪ  ɵ̞  ʊ̯  o  k  ɪ  l  k  p  m  START  l̩  b  ɪ  a  f  ɑ  t  n  ɚ  t  ɑ  p  START  dʰ  θ  f  START  ɒ̃  ɜː  v  ɛ  v  ʌ  s  t  ɔ  k  ɪ  f  ʊ  o  d  z  ɪ  w  ɵ̞  t̬ᵊ  ɝː  ʊ  o  ɡː  r  ə  ĩ  χ  ŋ  ɪ  a  t  ɑ  m  ɪ  e  l  ə  ɡ  ɪ  f  θ  ɹ  ɛ  START  əʳ  a  n  ʌ  s  b  START  ɘ  oˀ  ə̆  ɑː  k  ɪ  k  i  t  ɛ  s  ɪ  e  z  ɪ  a  b  m  START  ʉ  u  l  ɪ  ɹ  ə  l  p  START  õ  o  s  æ  START  ~  q  ɔ̃  əʳ  d  ɪ  s  START  ɨ  k  START  ɫ̩  f  START  ɹ  ə  k  æ  t  s  START  ɖ  pʰ  pʰ  ṽ  o̞  z  ɛ  n  ə  ʒ  d  ɪ  k  ʌ  l  ɛ  s  ə  k  ʊ  a  m  START  ɹ  ə  m  ə  n  ɨ  l  START  ɣ  ɱ  ˞  æ̃  h  START  ɹʷ  ɔː  s  ɪ  p  START  æː  ə̆  ɘ  d  ɪ  ɹ  ə  p  iː  ɹ  ɑː  d  START  iː  t  s  n  æ  b  m  ɑ  k  START  e͡ɪ  ɒː  ɔ͡ɪ  ɪː  ɪ̈  ɹ  d  ɪ  a  START  t  START  ɪ  e  START  tʰ  æː  r  ɡː  ɜː  t  n  ɪ  v  ɪ  n  START  o  l  ɛ  s  ɪ  START  i  ɹ  ɛ  m  ɪ  START  w  n  ə  t  i  h  START  i  ɹ  ə  START  ʌː  ɪː  χ  START  ʌ̈  ɜ̃  ɝː  STOP

# %% [markdown]
# # Observations
#
# - Write your general observations about the results here.  A few short sentences would be fine.
#
# It seems that phoneme transition probabilities are generally good at generating English pseudo-words, i.e., words that comply with the "rules" of English pronunciation, except for several single-phoneme ones. However, it is reasonable to speculate that transition probability alone probably does not generate well to words (i.e., generating sentences that comply with rules of English grammar). On the one hand, it may generate sentences that are statistically probable but ungrammatical, e.g., "I like to the cafeteria;" on the other hand, it cannot generate sentences that are grammatically but meaningless, such as the good o old "colorless green ideas sleep furiously." Therefore, the behaviorist view of a "sequential" language has its limitations. Sentential grammar is more than a sequence probability; that is where other views of language, such as the generative grammar of Chomsky, come in.

# %% [markdown]
# # Extensions (optional)
#
# - Do the same thing for other languages.  See [here](https://github.com/kylebgorman/wikipron/tree/master/data) for analogous WikiPron data from other languages, in the same format as the data we've used here.
# - Do the same thing for words rather than phonemes.  You could download a book in plain text from [Project Gutenberg](https://www.gutenberg.org/ebooks/search/?sort_order=downloads), and proceed from there.
